# %%
n=int(input())
talika=list(map(int,input().split()))

talika2=[]
for i in range(len(talika)):
  talika2.append(talika.index(i+1)+1)
print(*talika2,sep=' ')
# Out:
# 5
# 2 3 1 4
# [2, 3, 1, 4]
# 3 1 2 4

# %%
# Out:
# 4 1 2 3
