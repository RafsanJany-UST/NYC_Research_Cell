# %%
if(int(input())%2==0):
  print(1)
else:
  print(2)
# Out:
# 6
# 1

# %%
print(536870911/29)
print(29*2)
# Out:
# 18512790.03448276
# 58

# %%
print(536870910/29)
print(29*2)
# Out:
# 18512790.0
# 58

# %%
for i in range(100)
  if(536870911%i or 536870910%i):
    break
# Out:
#   File "<ipython-input-30-50cc33a4dc53>", line 1
#     for i in range(100)
#                        ^
# SyntaxError: invalid syntax

# %%
print(i)
# Out:
# 9
