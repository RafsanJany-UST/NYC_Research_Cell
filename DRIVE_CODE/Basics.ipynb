# %% [markdown]
# # PRINT SOMETING

# %%
print("hello world!")
print("Annanta Jolil is the best univetsity.")
# Out:
# hello world!
# Annanta Jolil is the best univetsity.

# %%
print("Din the Day")
# Out:
# Din the Day

# %% [markdown]
# #INPUT

# %%
x=input("Inpur value of x:")
print(x)
# Out:
# Inpur value of x:iiii
# iiii

# %% [markdown]
# #Sumation of two number

# %%
x=
y=
