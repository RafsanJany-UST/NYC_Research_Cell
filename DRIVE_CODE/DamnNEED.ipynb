# %% [markdown]
# #Finding Frequnecy in a List

# %%
def find_freq(lis):
  frequency = {}
  for item in tqdm(lis):
    if item in frequency:
        frequency[item] += 1
    else:
        frequency[item] = 1
  return frequency
