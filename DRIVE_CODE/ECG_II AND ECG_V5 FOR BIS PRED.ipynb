# %% [markdown]
# <a href="https://colab.research.google.com/github/vitaldb/examples/blob/master/eeg_mac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of anesthetic concentration from EEG
# In this example, we will build a model to predict anesthetic concentration (age-related MAC) from EEG during Sevoflurane anesthesia.
#
# > Note that <b>all users who use Vital DB, an open biosignal dataset, must agree to the Data Use Agreement below.
# </b> If you do not agree, please close this window.
# Click here: [Data Use Agreement](https://vitaldb.net/dataset/?query=overview&documentId=13qqajnNZzkN7NZ9aXnaQ-47NWy7kx-a6gbrcEsi-gak&sectionId=h.vcpgs1yemdb5)

# %% [markdown]
# ## Required libraries

# %%
# !pip install vitaldb
import vitaldb
import random
import numpy as np
import pandas as pd
import scipy.signal
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: vitaldb in c:\users\majid\appdata\roaming\python\python39\site-packages (1.4.7)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from vitaldb) (1.24.4)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from vitaldb) (1.4.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from vitaldb) (2.28.1)
# Requirement already satisfied: wfdb in c:\users\majid\appdata\roaming\python\python39\site-packages (from vitaldb) (4.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->vitaldb) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->vitaldb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->vitaldb) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->vitaldb) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->vitaldb) (2022.9.14)
# Requirement already satisfied: SoundFile>=0.10.0 in c:\users\majid\appdata\roaming\python\python39\site-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\programdata\anaconda3\lib\site-packages (from wfdb->vitaldb) (3.5.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from wfdb->vitaldb) (1.9.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in c:\programdata\anaconda3\lib\site-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.21)

# %% [markdown]
# ## Preprocessing

# %%
SRATE = 128  # in hz
SEGLEN = 4 * SRATE  # segment samples
MAX_CASES = 100

df_trks = pd.read_csv("https://api.vitaldb.net/trks")  # track information
df_cases = pd.read_csv("https://api.vitaldb.net/cases")  # patient information

# track names and column order when loading data
track_names = ['SNUADC/ECG_II', 'SNUADC/ECG_V5', 'BIS/BIS']
ECG_II = 0
ECG_V5 = 1
BIS = 2

# Inclusion & Exclusion criteria
caseids = set(df_cases.loc[df_cases['age'] > 18, 'caseid'])
caseids &= set(df_trks.loc[df_trks['tname'] == 'SNUADC/ECG_II', 'caseid'])
caseids &= set(df_trks.loc[df_trks['tname'] == 'BIS/BIS', 'caseid'])
caseids &= set(df_trks.loc[df_trks['tname'] == 'SNUADC/ECG_V5', 'caseid'])
caseids -= set(df_trks.loc[df_trks['tname'] == 'Primus/EXP_DES', 'caseid'])
caseids -= set(df_trks.loc[df_trks['tname'] == 'Orchestra/PPF20_CE', 'caseid'])
caseids -= set(df_trks.loc[df_trks['tname'] == 'Orchestra/RFTN50_CE', 'caseid'])
caseids = list(caseids)
print(f'Total {len(caseids)} cases found')

# Initialize data lists
x_ecg_ii = []  # ECG II
x_ecg_v5 = []  # ECG V5
b = []  # BIS
c = []  # caseids
icase = 0  # number of loaded cases

for caseid in caseids:
    print(f'loading caseid={caseid} ({icase + 1}/{MAX_CASES})', end='...', flush=True)

    # extract data
    vals = vitaldb.load_case(caseid, track_names, 1 / SRATE)

    # exclude cases without ECG data
    if np.isnan(np.nanmax(vals[:, ECG_II])):
        print('no ECG II data')
        continue

    if np.isnan(np.nanmax(vals[:, ECG_V5])):
        print('no ECG V5 data')
        continue

    # exclude cases without BIS
    if not np.any(vals[:, BIS] > 0):
        print('all bis <= 0')
        continue

    # trim cases with BIS
    valid_idx = np.where(vals[:, BIS] > 0)[0]
    first_idx = valid_idx[0]
    last_idx = valid_idx[-1]
    vals = vals[first_idx:last_idx + 1, :]

    # exclude cases shorter than 30 min
    if len(vals) < 1800 * SRATE:
        print('len bis < 30 min')
        continue

    # forward fill in BIS value up to 7 sec
    vals[:, BIS:] = pd.DataFrame(vals[:, BIS:]).ffill(limit=7*SRATE).values

    # extract segments
    oldlen = len(b)
    for isamp in range(SEGLEN, len(vals), 2 * SRATE):
        bis = vals[isamp, BIS]
        if np.isnan(bis) or bis == 0:
            continue
        # add to dataset
        ecg_ii = vals[isamp - SEGLEN:isamp, ECG_II]
        ecg_v5 = vals[isamp - SEGLEN:isamp, ECG_V5]
        x_ecg_ii.append(ecg_ii)
        x_ecg_v5.append(ecg_v5)
        b.append(bis)
        c.append(caseid)

    # print results
    icase += 1
    print(f'{len(b) - oldlen} segments read -> total {len(b)} segments ({icase}/{MAX_CASES})')
    if icase >= MAX_CASES:
        break

# Change the input datasets to numpy arrays
x_ecg_ii = np.array(x_ecg_ii)
x_ecg_v5 = np.array(x_ecg_v5)
b = np.array(b)
c = np.array(c)
# Out:
# Total 547 cases found
# loading caseid=2 (1/100)...7530 segments read -> total 7530 segments (1/100)
# loading caseid=4104 (2/100)...3176 segments read -> total 10706 segments (2/100)
# loading caseid=12 (3/100)...15222 segments read -> total 25928 segments (3/100)
# loading caseid=4112 (4/100)...10929 segments read -> total 36857 segments (4/100)
# loading caseid=18 (5/100)...all bis <= 0
# loading caseid=4116 (5/100)...4984 segments read -> total 41841 segments (5/100)
# loading caseid=21 (6/100)...5859 segments read -> total 47700 segments (6/100)
# loading caseid=4119 (7/100)...1562 segments read -> total 49262 segments (7/100)
# loading caseid=25 (8/100)...7072 segments read -> total 56334 segments (8/100)
# loading caseid=4126 (9/100)...all bis <= 0
# loading caseid=39 (9/100)...all bis <= 0
# loading caseid=4135 (9/100)...5881 segments read -> total 62215 segments (9/100)
# loading caseid=4141 (10/100)...all bis <= 0
# loading caseid=4144 (10/100)...9372 segments read -> total 71587 segments (10/100)
# loading caseid=4147 (11/100)...all bis <= 0
# loading caseid=4151 (11/100)...6445 segments read -> total 78032 segments (11/100)
# loading caseid=58 (12/100)...7097 segments read -> total 85129 segments (12/100)
# loading caseid=62 (13/100)...4723 segments read -> total 89852 segments (13/100)
# loading caseid=4158 (14/100)...6065 segments read -> total 95917 segments (14/100)
# loading caseid=4160 (15/100)...4921 segments read -> total 100838 segments (15/100)
# loading caseid=4167 (16/100)...9215 segments read -> total 110053 segments (16/100)
# loading caseid=4182 (17/100)...all bis <= 0
# loading caseid=87 (17/100)...4849 segments read -> total 114902 segments (17/100)
# loading caseid=95 (18/100)...1865 segments read -> total 116767 segments (18/100)
# loading caseid=100 (19/100)...1711 segments read -> total 118478 segments (19/100)
# loading caseid=114 (20/100)...8034 segments read -> total 126512 segments (20/100)
# loading caseid=4213 (21/100)...3700 segments read -> total 130212 segments (21/100)
# loading caseid=120 (22/100)...all bis <= 0
# loading caseid=130 (22/100)...8567 segments read -> total 138779 segments (22/100)
# loading caseid=131 (23/100)...all bis <= 0
# loading caseid=133 (23/100)...4946 segments read -> total 143725 segments (23/100)
# loading caseid=4231 (24/100)...all bis <= 0
# loading caseid=146 (24/100)...7857 segments read -> total 151582 segments (24/100)
# loading caseid=148 (25/100)...5993 segments read -> total 157575 segments (25/100)
# loading caseid=4247 (26/100)...3453 segments read -> total 161028 segments (26/100)
# loading caseid=4254 (27/100)...6070 segments read -> total 167098 segments (27/100)
# loading caseid=4265 (28/100)...7403 segments read -> total 174501 segments (28/100)
# loading caseid=174 (29/100)...1655 segments read -> total 176156 segments (29/100)
# loading caseid=176 (30/100)...all bis <= 0
# loading caseid=4291 (30/100)...all bis <= 0
# loading caseid=4300 (30/100)...3814 segments read -> total 179970 segments (30/100)
# loading caseid=4308 (31/100)...3548 segments read -> total 183518 segments (31/100)
# loading caseid=220 (32/100)...4347 segments read -> total 187865 segments (32/100)
# loading caseid=4319 (33/100)...all bis <= 0
# loading caseid=4331 (33/100)...3831 segments read -> total 191696 segments (33/100)
# loading caseid=238 (34/100)...5755 segments read -> total 197451 segments (34/100)
# loading caseid=239 (35/100)...6134 segments read -> total 203585 segments (35/100)
# loading caseid=4343 (36/100)...all bis <= 0
# loading caseid=4345 (36/100)...2446 segments read -> total 206031 segments (36/100)
# loading caseid=250 (37/100)...5557 segments read -> total 211588 segments (37/100)
# loading caseid=4357 (38/100)...3676 segments read -> total 215264 segments (38/100)
# loading caseid=4363 (39/100)...8850 segments read -> total 224114 segments (39/100)
# loading caseid=269 (40/100)...5238 segments read -> total 229352 segments (40/100)
# loading caseid=4370 (41/100)...1359 segments read -> total 230711 segments (41/100)
# loading caseid=275 (42/100)...all bis <= 0
# loading caseid=288 (42/100)...2001 segments read -> total 232712 segments (42/100)
# loading caseid=4393 (43/100)...4120 segments read -> total 236832 segments (43/100)
# loading caseid=299 (44/100)...2076 segments read -> total 238908 segments (44/100)
# loading caseid=4420 (45/100)...6684 segments read -> total 245592 segments (45/100)
# loading caseid=4423 (46/100)...2769 segments read -> total 248361 segments (46/100)
# loading caseid=346 (47/100)...2847 segments read -> total 251208 segments (47/100)
# loading caseid=349 (48/100)...11759 segments read -> total 262967 segments (48/100)
# loading caseid=355 (49/100)...4681 segments read -> total 267648 segments (49/100)
# loading caseid=361 (50/100)...2602 segments read -> total 270250 segments (50/100)
# loading caseid=4458 (51/100)...3262 segments read -> total 273512 segments (51/100)
# loading caseid=370 (52/100)...2177 segments read -> total 275689 segments (52/100)
# loading caseid=4468 (53/100)...all bis <= 0
# loading caseid=374 (53/100)...4375 segments read -> total 280064 segments (53/100)
# loading caseid=376 (54/100)...2106 segments read -> total 282170 segments (54/100)
# loading caseid=396 (55/100)...all bis <= 0
# loading caseid=4493 (55/100)...3202 segments read -> total 285372 segments (55/100)
# loading caseid=4495 (56/100)...all bis <= 0
# loading caseid=406 (56/100)...9351 segments read -> total 294723 segments (56/100)
# loading caseid=4508 (57/100)...all bis <= 0
# loading caseid=4509 (57/100)...11166 segments read -> total 305889 segments (57/100)
# loading caseid=4512 (58/100)...all bis <= 0
# loading caseid=4517 (58/100)...4787 segments read -> total 310676 segments (58/100)
# loading caseid=427 (59/100)...4599 segments read -> total 315275 segments (59/100)
# loading caseid=4533 (60/100)...all bis <= 0
# loading caseid=4534 (60/100)...9117 segments read -> total 324392 segments (60/100)
# loading caseid=441 (61/100)...5781 segments read -> total 330173 segments (61/100)
# loading caseid=472 (62/100)...12479 segments read -> total 342652 segments (62/100)
# loading caseid=4569 (63/100)...1991 segments read -> total 344643 segments (63/100)
# loading caseid=475 (64/100)...all bis <= 0
# loading caseid=4574 (64/100)...11643 segments read -> total 356286 segments (64/100)
# loading caseid=4580 (65/100)...6387 segments read -> total 362673 segments (65/100)
# loading caseid=4583 (66/100)...all bis <= 0
# loading caseid=506 (66/100)...all bis <= 0
# loading caseid=4602 (66/100)...4984 segments read -> total 367657 segments (66/100)
# loading caseid=4603 (67/100)...9673 segments read -> total 377330 segments (67/100)
# loading caseid=511 (68/100)...2198 segments read -> total 379528 segments (68/100)
# loading caseid=4608 (69/100)...all bis <= 0
# loading caseid=514 (69/100)...all bis <= 0
# loading caseid=516 (69/100)...6431 segments read -> total 385959 segments (69/100)
# loading caseid=517 (70/100)...7366 segments read -> total 393325 segments (70/100)
# loading caseid=525 (71/100)...8996 segments read -> total 402321 segments (71/100)
# loading caseid=4628 (72/100)...1617 segments read -> total 403938 segments (72/100)
# loading caseid=534 (73/100)...6751 segments read -> total 410689 segments (73/100)
# loading caseid=535 (74/100)...3084 segments read -> total 413773 segments (74/100)
# loading caseid=536 (75/100)...3333 segments read -> total 417106 segments (75/100)
# loading caseid=4636 (76/100)...len bis < 30 min
# loading caseid=541 (76/100)...2884 segments read -> total 419990 segments (76/100)
# loading caseid=4655 (77/100)...2686 segments read -> total 422676 segments (77/100)
# loading caseid=4669 (78/100)...all bis <= 0
# loading caseid=4672 (78/100)...8593 segments read -> total 431269 segments (78/100)
# loading caseid=580 (79/100)...1908 segments read -> total 433177 segments (79/100)
# loading caseid=4683 (80/100)...4555 segments read -> total 437732 segments (80/100)
# loading caseid=4693 (81/100)...2202 segments read -> total 439934 segments (81/100)
# loading caseid=600 (82/100)...4730 segments read -> total 444664 segments (82/100)
# loading caseid=4696 (83/100)...3989 segments read -> total 448653 segments (83/100)
# loading caseid=4703 (84/100)...825 segments read -> total 449478 segments (84/100)
# loading caseid=619 (85/100)...all bis <= 0
# loading caseid=4731 (85/100)...10479 segments read -> total 459957 segments (85/100)
# loading caseid=643 (86/100)...2801 segments read -> total 462758 segments (86/100)
# loading caseid=4740 (87/100)...all bis <= 0
# loading caseid=649 (87/100)...6889 segments read -> total 469647 segments (87/100)
# loading caseid=653 (88/100)...4290 segments read -> total 473937 segments (88/100)
# loading caseid=656 (89/100)...1557 segments read -> total 475494 segments (89/100)
# loading caseid=4759 (90/100)...11880 segments read -> total 487374 segments (90/100)
# loading caseid=4774 (91/100)...3139 segments read -> total 490513 segments (91/100)
# loading caseid=688 (92/100)...all bis <= 0
# loading caseid=689 (92/100)...1805 segments read -> total 492318 segments (92/100)
# loading caseid=695 (93/100)...2117 segments read -> total 494435 segments (93/100)
# loading caseid=703 (94/100)...4840 segments read -> total 499275 segments (94/100)
# loading caseid=4800 (95/100)...12876 segments read -> total 512151 segments (95/100)
# loading caseid=721 (96/100)...5891 segments read -> total 518042 segments (96/100)
# loading caseid=4817 (97/100)...15019 segments read -> total 533061 segments (97/100)
# loading caseid=750 (98/100)...22679 segments read -> total 555740 segments (98/100)
# loading caseid=4847 (99/100)...2439 segments read -> total 558179 segments (99/100)
# loading caseid=758 (100/100)...3773 segments read -> total 561952 segments (100/100)

# %% [markdown]
# ## Filtering input data

# %%
# exclude segments
print('invalid samples...', end='', flush=True)

# If there is NaN in any ECG II or ECG V5 segment
valid_mask_nan = ~(np.max(np.isnan(x_ecg_ii), axis=1) > 0) & ~(np.max(np.isnan(x_ecg_v5), axis=1) > 0)

# BIS impedance check (difference between max and min BIS values > 12)
valid_mask_bis = (np.nanmax(b) - np.nanmin(b) > 12)

# Noisy sample check (max absolute value of ECG II and ECG V5 < 100)
valid_mask_noisy = (np.nanmax(np.abs(x_ecg_ii), axis=1) < 100) & (np.nanmax(np.abs(x_ecg_v5), axis=1) < 100)

# Combine all conditions
valid_mask = valid_mask_nan & valid_mask_bis & valid_mask_noisy

# Apply the masks
x_ecg_ii = x_ecg_ii[valid_mask]
x_ecg_v5 = x_ecg_v5[valid_mask]
b = b[valid_mask]
c = c[valid_mask]

print(f'{100*(1-np.mean(valid_mask)):.1f}% removed')
# Out:
# invalid samples...0.0% removed

# %% [markdown]
# ## Splitting samples into training and testing dataset

# %%
# Case ID
caseids = list(np.unique(c))
# random.shuffle(caseids)

# Split dataset into training and testing data
ntest = max(1, int(len(caseids) * 0.2))
caseids_train = caseids[ntest:]
caseids_test = caseids[:ntest]

train_mask = np.isin(c, caseids_train)
test_mask = np.isin(c, caseids_test)
x_train_ecg_ii = x_ecg_ii[train_mask]  # Use x_ecg_ii
x_train_ecg_v5 = x_ecg_v5[train_mask]  # Use x_ecg_v5
y_train = b[train_mask]  # BIS as the target variable

x_test_ecg_ii = x_ecg_ii[test_mask]  # Use x_ecg_ii
x_test_ecg_v5 = x_ecg_v5[test_mask]  # Use x_ecg_v5
y_test = b[test_mask]  # BIS as the target variable
c_test = c[test_mask]

print('====================================================')
print(f'total: {len(caseids)} cases {len(b)} samples')
print(f'train: {len(np.unique(c[train_mask]))} cases {len(y_train)} samples')
print(f'test {len(np.unique(c_test))} cases {len(y_test)} samples')
print('====================================================')
# Out:
# ====================================================
# total: 100 cases 554817 samples
# train: 80 cases 439118 samples
# test 20 cases 115699 samples
# ====================================================

# %% [markdown]
# ## Modeling and Evaluation

# %%
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import LSTM, Dense, Dropout, Input, concatenate, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Define the input shapes for ECG2 and ECG5
inp_ecg2 = Input(shape=(x_train_ecg_ii.shape[1], 1))
inp_ecg5 = Input(shape=(x_train_ecg_v5.shape[1], 1))

# LSTM layer for ECG2
out_ecg2 = LSTM(units=64, return_sequences=True)(inp_ecg2)
out_ecg2 = Dropout(0.2)(out_ecg2)

# LSTM layer for ECG5
out_ecg5 = LSTM(units=64, return_sequences=True)(inp_ecg5)
out_ecg5 = Dropout(0.2)(out_ecg5)

# Concatenate the output of LSTM layers
merged = concatenate([out_ecg2, out_ecg5])

# Global max pooling
out = GlobalMaxPooling1D()(merged)

# Dense layers
out = Dense(128, activation='relu')(out)
out = Dropout(0.2)(out)
out = Dense(1)(out)

# Create the model
model_lstm = Model(inputs=[inp_ecg2, inp_ecg5], outputs=[out])

# Compile the model
model_lstm.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# Model summary
model_lstm.summary()

# Fit the model



#______________
#pyHRV

import biosppy
import numpy as np
import pyhrv.tools as tools
from opensignalsreader import OpenSignalsReader



signal, rpeaks = biosppy.signals.ecg.ecg(x_train_ecg_ii, show=False)[1:3]
nni_ecg_ii = tools.nn_intervals(rpeaks)

signal, rpeaks = biosppy.signals.ecg.ecg(x_train_ecg_v5, show=False)[1:3]
nni_ecg_v5 = tools.nn_intervals(rpeaks)

#______________
hist_lstm = model_lstm.fit([nni_ecg_ii, nni_ecg_v5], y_train,
                           validation_split=0.2, epochs=10, batch_size=4096,
                           callbacks=[ModelCheckpoint(monitor='val_loss', filepath='model_lstm_2.h5', verbose=1, save_best_only=True)])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_16 (InputLayer)          [(None, 512, 1)]     0           []
#
#  lstm_14 (LSTM)                 (None, 512, 64)      16896       ['input_15[0][0]']
#
#  lstm_15 (LSTM)                 (None, 512, 64)      16896       ['input_16[0][0]']
#
#  dropout_18 (Dropout)           (None, 512, 64)      0           ['lstm_14[0][0]']
#
#  dropout_19 (Dropout)           (None, 512, 64)      0           ['lstm_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 512, 128)     0           ['dropout_18[0][0]',
#                                                                   'dropout_19[0][0]']
#
#  global_max_pooling1d_4 (Global  (None, 128)         0           ['concatenate_7[0][0]']
#  MaxPooling1D)
#
#  dense_8 (Dense)                (None, 128)          16512       ['global_max_pooling1d_4[0][0]']
#
#  dropout_20 (Dropout)           (None, 128)          0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 1)            129         ['dropout_20[0][0]']
#
# ==================================================================================================
# Total params: 50,433
# Trainable params: 50,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 86/86 [==============================] - ETA: 0s - loss: 20.1308 - mean_absolute_error: 20.1308
# Epoch 1: val_loss improved from inf to 11.13329, saving model to model_lstm_2.h5
# 86/86 [==============================] - 1501s 17s/step - loss: 20.1308 - mean_absolute_error: 20.1308 - val_loss: 11.1333 - val_mean_absolute_error: 11.1333
# Epoch 2/10
# 86/86 [==============================] - ETA: 0s - loss: 8.6823 - mean_absolute_error: 8.6823
# Epoch 2: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1312s 15s/step - loss: 8.6823 - mean_absolute_error: 8.6823 - val_loss: 11.3553 - val_mean_absolute_error: 11.3553
# Epoch 3/10
# 86/86 [==============================] - ETA: 0s - loss: 8.6129 - mean_absolute_error: 8.6129
# Epoch 3: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1331s 15s/step - loss: 8.6129 - mean_absolute_error: 8.6129 - val_loss: 11.4436 - val_mean_absolute_error: 11.4436
# Epoch 4/10
# 86/86 [==============================] - ETA: 0s - loss: 8.5603 - mean_absolute_error: 8.5603
# Epoch 4: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1367s 16s/step - loss: 8.5603 - mean_absolute_error: 8.5603 - val_loss: 11.4392 - val_mean_absolute_error: 11.4392
# Epoch 5/10
# 86/86 [==============================] - ETA: 0s - loss: 8.4422 - mean_absolute_error: 8.4422
# Epoch 5: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1311s 15s/step - loss: 8.4422 - mean_absolute_error: 8.4422 - val_loss: 11.7628 - val_mean_absolute_error: 11.7628
# Epoch 6/10
# 86/86 [==============================] - ETA: 0s - loss: 8.4077 - mean_absolute_error: 8.4077
# Epoch 6: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1318s 15s/step - loss: 8.4077 - mean_absolute_error: 8.4077 - val_loss: 11.8392 - val_mean_absolute_error: 11.8392
# Epoch 7/10
# 86/86 [==============================] - ETA: 0s - loss: 8.3868 - mean_absolute_error: 8.3868
# Epoch 7: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1292s 15s/step - loss: 8.3868 - mean_absolute_error: 8.3868 - val_loss: 11.7008 - val_mean_absolute_error: 11.7008
# Epoch 8/10
# 86/86 [==============================] - ETA: 0s - loss: 8.3749 - mean_absolute_error: 8.3749
# Epoch 8: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1303s 15s/step - loss: 8.3749 - mean_absolute_error: 8.3749 - val_loss: 11.8410 - val_mean_absolute_error: 11.8410
# Epoch 9/10
# 86/86 [==============================] - ETA: 0s - loss: 8.3759 - mean_absolute_error: 8.3759
# Epoch 9: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1286s 15s/step - loss: 8.3759 - mean_absolute_error: 8.3759 - val_loss: 11.6665 - val_mean_absolute_error: 11.6665
# Epoch 10/10
# 86/86 [==============================] - ETA: 0s - loss: 8.3604 - mean_absolute_error: 8.3604
# Epoch 10: val_loss did not improve from 11.13329
# 86/86 [==============================] - 1286s 15s/step - loss: 8.3604 - mean_absolute_error: 8.3604 - val_loss: 11.3619 - val_mean_absolute_error: 11.3619

# %%
# Load the trained model
from keras.models import load_model

# Load the saved model (change the filename if necessary)
model_lstm = load_model('model_lstm_2.h5')

# Perform predictions on the test set
pred_test_lstm = model_lstm.predict([x_test_ecg_ii, x_test_ecg_v5]).flatten()

# Optionally, apply post-processing (e.g., median filtering)
for caseid in np.unique(c_test):
    case_mask = (c_test == caseid)
    pred_test_lstm[case_mask] = scipy.signal.medfilt(pred_test_lstm[case_mask], 15)

# Calculate Mean Absolute Error (MAE) for accuracy
test_mae_lstm = np.mean(np.abs(y_test - pred_test_lstm))
print(f"Test MAE (LSTM): {test_mae_lstm}")

# Optionally, calculate accuracy within a threshold
threshold = 5  # Set your desired threshold
accuracy_percentage = np.mean(np.abs(pred_test_lstm - y_test) < threshold) * 100
print(f"Accuracy within {threshold} units: {accuracy_percentage:.2f}%")
# Out:
# 3616/3616 [==============================] - 191s 53ms/step
# Test MAE (LSTM): 14.09238393588695
# Accuracy within 5 units: 18.24%
