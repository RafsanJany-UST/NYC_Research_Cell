# %% [markdown]
# #power Digite Sum

# %%
h=str((pow(2,1000)))
print(h)
s=int(h[0])+int(h[1])
print(s)
num=0
for i in h:
  num=num+int(i)
print(num)
# Out:
# 1366

# %% [markdown]
# #Factorial digit sum

# %%
import math as m
num=int(input())

s=m.factorial(num)

sum=0
for i in str(s):
  sum=sum+int(i)
print(sum)
# Out:
# 100
# 648

# %% [markdown]
# #Counting Sundays

# %%
s1=4*30
s2=7*31
s3=28
sum=s1+s2+s3
print(sum)
print(int(sum/7))
print(sum%7)
print(52*7)
# Out:
# 365
# 52
# 1
# 364

# %% [markdown]
# #Digit factorials

# %%
def fact(n):
  res=1
  for i in range(1,n+1):
    res=res*i
  return res

print(fact(3))
# Out:
# 6

# %%
print(145+40585)
# Out:
# 40730

# %%
t=0
while(t<=1000000000):
  t=t+1
  s=str(t)
  c=(lets(s))
  if (c==t):
    print(c,"-------",t)
# Out:
# 1 ------- 1
# 2 ------- 2
# 145 ------- 145
# 40585 ------- 40585
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e1f0f7d38df1> in <module>()
#       3   t=t+1
#       4   s=str(t)
# ----> 5   c=(lets(s))
#       6   if (c==t):
#       7     print(c,"-------",t)
#
# <ipython-input-12-bd7e6539b3f7> in lets(s)
#       1 def lets(s):
#       2   sum=0
# ----> 3   for i in s:
#       4     sum=sum+fact(int(i))
#       5   return sum
#
# KeyboardInterrupt:

# %%
def lets(s):
  sum=0
  for i in s:
    sum=sum+fact(int(i))
  return sum

lets('145')
# Out:
# 145

# %% [markdown]
# #Number letter counts

# %%
i=1
while(i<=9):
  j=1
  while(j<=9):
    k=1
    while(k<=9):
      l=1
      while(l<=9):
        
        print(fun(i,j,k,l))
        
        l+=1
      k+=1
    j+=1
  i+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 2.9
# [6, 2]
# 2.8
# None
# 2.6
# None
# 2.5
# None
# 2.4
# None
# 2.4
# None
# 2.3
# None
# 2.1
# [6, 3]
# 2.1
# [6, 3]
# 2.0
# [6, 3]
# 1.9
# [6, 3]
# 1.9
# [6, 3]
# 1.8
# None
# 1.8
# None
# 1.7
# None
# 1.7
# None
# 1.6
# [6, 4]
# 1.6
# [6, 4]
# 1.5
# [6, 4]
# 1.5
# [6, 4]
# 1.5
# [6, 4]
# 1.4
# [6, 4]
# 1.4
# [6, 4]
# 1.4
# [6, 4]
# 1.3
# None
# 1.3
# [6, 5]
# 1.3
# [6, 5]
# 1.2
# [6, 5]
# 1.2
# [6, 5]
# 1.2
# [6, 5]
# 1.2
# [6, 5]
# 1.2
# [6, 5]
# 1.1
# None
# 1.1
# None
# 1.1
# [6, 6]
# 1.1
# [6, 6]
# 1.0
# [6, 6]
# 1.0
# [6, 6]
# 1.0
# [6, 6]
# 1.0
# [6, 6]
# 1.0
# [6, 6]
# 1.0
# [6, 6]
# 1.0
# [6, 6]
# 0.9
# None
# 0.9
# None
# 0.9
# None
# 0.9
# None
# 0.9
# None
# 0.9
# [6, 6]
# 0.9
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.8
# None
# 0.7
# None
# 0.7
# None
# 0.7
# None
# 0.7
# None
# 0.7
# None
# 0.7
# None
# 0.7
# None
# 0.7
# None
# ...

# %%
def fun(i,j,k,l):
  a=int(str(i)+str(j))
  b=int(str(k)+str(l))
  full=float("{:.1f}".format(a/b))
  print(full)
  talika=[(i/l),(j/k),(i/k),(j/l)]
  t1=full-.1
  t2=full+.1
  if (t1==(i/l) or t2==(i/l) or full==(i/l)):
    return [i,l]
  elif (t1==(j/k) or t2==(j/k) or full==(j/k)):
    return [j,k]
  elif (t1==(i/k) or t2==(i/k) or full==(i/k)):
    return [i,k]
  elif (t1==(j/l) or t2==(j/l) or full==(j/l)):
    return [j,l]


print(fun(4,9,8,9))
# Out:
# 0.6
# [4, 8]
