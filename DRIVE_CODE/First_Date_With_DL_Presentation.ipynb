# %% [markdown]
# #Lets Make a Traditional Program

# %%
celsius = [-40, -10,  0,  8, 15, 22,  38]

# %%
def cel_to_far(c):
  f = c * (9/5) + 32
  return f

# %%
fahrenheit = []
for i in celsius:
  fahrenheit.append(cel_to_far(i))

print(fahrenheit)
# Out:
# [-40.0, 14.0, 32.0, 46.4, 59.0, 71.6, 100.4]

# %%
for i,c in enumerate(celsius):
  print(c,"degrees Celsius = ", fahrenheit[i],"degrees Fahrenheit")
# Out:
# -40 degrees Celsius =  -40.0 degrees Fahrenheit
# -10 degrees Celsius =  14.0 degrees Fahrenheit
# 0 degrees Celsius =  32.0 degrees Fahrenheit
# 8 degrees Celsius =  46.4 degrees Fahrenheit
# 15 degrees Celsius =  59.0 degrees Fahrenheit
# 22 degrees Celsius =  71.6 degrees Fahrenheit
# 38 degrees Celsius =  100.4 degrees Fahrenheit

# %% [markdown]
# ##Lets Do the Job
#
# So we have the input and the output. Our Algorithm or formula is f=c*(9/5)+32. Lets make a Nural Network which can detect the algorithm with our inputdata (<i>celsius</i>) and outputdata (<i>fahrenheit</i>).

# %%
import numpy as np

# %% [markdown]
# Make Numpy Dataset

# %%
celsius_in = np.array(celsius,  dtype=float)
fahrenheit_out = np.array(fahrenheit,  dtype=float)

# %% [markdown]
# ## Create the model

# %%
import tensorflow as tf

# %% [markdown]
# ### Build a layer

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Assemble layers into the model

# %%
model = tf.keras.Sequential([l0])

#model = tf.keras.Sequential(
#    tf.keras.layers.Dense(units=1, input_shape=[1])
#)"""

# %% [markdown]
# ## Compile the model, with loss and optimizer functions

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %% [markdown]
# ## Train the model

# %%
# %%time
history = model.fit(celsius_in, fahrenheit_out, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model
# CPU times: user 13 s, sys: 521 ms, total: 13.5 s
# Wall time: 15.1 s

# %% [markdown]
# ## Display training statistics

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## Use the model to predict values

# %%
input_data = np.array([[100.0]])
prediction = model.predict(input_data)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[211.57268]]

# %% [markdown]
# #Actual Value

# %%
cel_to_far(100.0)
# Out:
# 212.0

# %% [markdown]
# ## Looking at the layer weights and bias

# %%
print("These are the layer variables, weight:",l0.get_weights()[0],", bias:",l0.get_weights()[1])
# Out:
# These are the layer variables, weight: [[1.8248603]] , bias: [29.086634]

# %% [markdown]
# ---
#
# ---

# %%
import random


celsius_2 = []
fahrenheit_2=[]

for i in range(500):
  c_scaled=  float("{:.2f}".format(random.uniform(-10.5, 75)))
  celsius_2.append(c_scaled)
  f_scaled = float("{:.2f}".format(cel_to_far(c_scaled)))
  fahrenheit_2.append(f_scaled)

# %%
for i,c in enumerate(celsius_2):
  print(c,"degrees Celsius = ", fahrenheit_2[i],"degrees Fahrenheit")
# Out:
# 6.83 degrees Celsius =  44.29 degrees Fahrenheit
# -2.3 degrees Celsius =  27.86 degrees Fahrenheit
# 8.25 degrees Celsius =  46.85 degrees Fahrenheit
# 68.38 degrees Celsius =  155.08 degrees Fahrenheit
# 57.59 degrees Celsius =  135.66 degrees Fahrenheit
# 15.15 degrees Celsius =  59.27 degrees Fahrenheit
# 59.4 degrees Celsius =  138.92 degrees Fahrenheit
# 10.49 degrees Celsius =  50.88 degrees Fahrenheit
# 56.93 degrees Celsius =  134.47 degrees Fahrenheit
# 50.96 degrees Celsius =  123.73 degrees Fahrenheit
# 67.7 degrees Celsius =  153.86 degrees Fahrenheit
# 1.7 degrees Celsius =  35.06 degrees Fahrenheit
# 26.19 degrees Celsius =  79.14 degrees Fahrenheit
# 58.06 degrees Celsius =  136.51 degrees Fahrenheit
# 42.48 degrees Celsius =  108.46 degrees Fahrenheit
# 6.73 degrees Celsius =  44.11 degrees Fahrenheit
# -4.16 degrees Celsius =  24.51 degrees Fahrenheit
# 8.9 degrees Celsius =  48.02 degrees Fahrenheit
# 39.91 degrees Celsius =  103.84 degrees Fahrenheit
# 68.08 degrees Celsius =  154.54 degrees Fahrenheit
# 48.93 degrees Celsius =  120.07 degrees Fahrenheit
# 0.88 degrees Celsius =  33.58 degrees Fahrenheit
# 29.87 degrees Celsius =  85.77 degrees Fahrenheit
# -3.15 degrees Celsius =  26.33 degrees Fahrenheit
# -0.16 degrees Celsius =  31.71 degrees Fahrenheit
# -8.86 degrees Celsius =  16.05 degrees Fahrenheit
# 10.5 degrees Celsius =  50.9 degrees Fahrenheit
# 63.42 degrees Celsius =  146.16 degrees Fahrenheit
# -3.42 degrees Celsius =  25.84 degrees Fahrenheit
# -6.04 degrees Celsius =  21.13 degrees Fahrenheit
# 23.64 degrees Celsius =  74.55 degrees Fahrenheit
# 66.16 degrees Celsius =  151.09 degrees Fahrenheit
# 24.97 degrees Celsius =  76.95 degrees Fahrenheit
# 46.88 degrees Celsius =  116.38 degrees Fahrenheit
# -6.14 degrees Celsius =  20.95 degrees Fahrenheit
# 68.73 degrees Celsius =  155.71 degrees Fahrenheit
# 68.0 degrees Celsius =  154.4 degrees Fahrenheit
# 39.44 degrees Celsius =  102.99 degrees Fahrenheit
# 25.25 degrees Celsius =  77.45 degrees Fahrenheit
# 29.38 degrees Celsius =  84.88 degrees Fahrenheit
# 33.56 degrees Celsius =  92.41 degrees Fahrenheit
# 73.77 degrees Celsius =  164.79 degrees Fahrenheit
# -9.5 degrees Celsius =  14.9 degrees Fahrenheit
# 17.74 degrees Celsius =  63.93 degrees Fahrenheit
# 67.6 degrees Celsius =  153.68 degrees Fahrenheit
# 47.69 degrees Celsius =  117.84 degrees Fahrenheit
# 18.99 degrees Celsius =  66.18 degrees Fahrenheit
# 18.18 degrees Celsius =  64.72 degrees Fahrenheit
# 18.42 degrees Celsius =  65.16 degrees Fahrenheit
# 13.31 degrees Celsius =  55.96 degrees Fahrenheit
# 71.36 degrees Celsius =  160.45 degrees Fahrenheit
# -7.63 degrees Celsius =  18.27 degrees Fahrenheit
# 38.73 degrees Celsius =  101.71 degrees Fahrenheit
# 37.22 degrees Celsius =  99.0 degrees Fahrenheit
# -8.19 degrees Celsius =  17.26 degrees Fahrenheit
# 72.5 degrees Celsius =  162.5 degrees Fahrenheit
# 43.2 degrees Celsius =  109.76 degrees Fahrenheit
# 67.55 degrees Celsius =  153.59 degrees Fahrenheit
# 29.02 degrees Celsius =  84.24 degrees Fahrenheit
# 19.89 degrees Celsius =  67.8 degrees Fahrenheit
# 29.41 degrees Celsius =  84.94 degrees Fahrenheit
# 47.14 degrees Celsius =  116.85 degrees Fahrenheit
# 40.96 degrees Celsius =  105.73 degrees Fahrenheit
# 1.62 degrees Celsius =  34.92 degrees Fahrenheit
# 11.45 degrees Celsius =  52.61 degrees Fahrenheit
# 20.82 degrees Celsius =  69.48 degrees Fahrenheit
# 13.12 degrees Celsius =  55.62 degrees Fahrenheit
# 74.44 degrees Celsius =  165.99 degrees Fahrenheit
# 30.63 degrees Celsius =  87.13 degrees Fahrenheit
# 70.31 degrees Celsius =  158.56 degrees Fahrenheit
# 61.44 degrees Celsius =  142.59 degrees Fahrenheit
# 40.17 degrees Celsius =  104.31 degrees Fahrenheit
# 40.11 degrees Celsius =  104.2 degrees Fahrenheit
# 23.82 degrees Celsius =  74.88 degrees Fahrenheit
# 8.33 degrees Celsius =  46.99 degrees Fahrenheit
# 6.69 degrees Celsius =  44.04 degrees Fahrenheit
# 61.52 degrees Celsius =  142.74 degrees Fahrenheit
# 19.05 degrees Celsius =  66.29 degrees Fahrenheit
# 60.68 degrees Celsius =  141.22 degrees Fahrenheit
# 71.4 degrees Celsius =  160.52 degrees Fahrenheit
# 6.07 degrees Celsius =  42.93 degrees Fahrenheit
# 14.95 degrees Celsius =  58.91 degrees Fahrenheit
# 52.01 degrees Celsius =  125.62 degrees Fahrenheit
# 17.46 degrees Celsius =  63.43 degrees Fahrenheit
# 40.13 degrees Celsius =  104.23 degrees Fahrenheit
# 8.41 degrees Celsius =  47.14 degrees Fahrenheit
# 67.89 degrees Celsius =  154.2 degrees Fahrenheit
# 38.96 degrees Celsius =  102.13 degrees Fahrenheit
# 47.84 degrees Celsius =  118.11 degrees Fahrenheit
# 39.64 degrees Celsius =  103.35 degrees Fahrenheit
# 66.4 degrees Celsius =  151.52 degrees Fahrenheit
# 34.91 degrees Celsius =  94.84 degrees Fahrenheit
# 52.29 degrees Celsius =  126.12 degrees Fahrenheit
# 64.27 degrees Celsius =  147.69 degrees Fahrenheit
# 59.54 degrees Celsius =  139.17 degrees Fahrenheit
# 4.94 degrees Celsius =  40.89 degrees Fahrenheit
# 41.54 degrees Celsius =  106.77 degrees Fahrenheit
# -9.51 degrees Celsius =  14.88 degrees Fahrenheit
# 19.01 degrees Celsius =  66.22 degrees Fahrenheit
# 15.59 degrees Celsius =  60.06 degrees Fahrenheit
# 35.81 degrees Celsius =  96.46 degrees Fahrenheit
# 16.34 degrees Celsius =  61.41 degrees Fahrenheit
# 40.21 degrees Celsius =  104.38 degrees Fahrenheit
# 47.43 degrees Celsius =  117.37 degrees Fahrenheit
# 4.14 degrees Celsius =  39.45 degrees Fahrenheit
# 21.51 degrees Celsius =  70.72 degrees Fahrenheit
# 21.57 degrees Celsius =  70.83 degrees Fahrenheit
# -2.27 degrees Celsius =  27.91 degrees Fahrenheit
# 45.87 degrees Celsius =  114.57 degrees Fahrenheit
# 64.3 degrees Celsius =  147.74 degrees Fahrenheit
# 16.02 degrees Celsius =  60.84 degrees Fahrenheit
# 74.27 degrees Celsius =  165.69 degrees Fahrenheit
# 0.24 degrees Celsius =  32.43 degrees Fahrenheit
# 66.19 degrees Celsius =  151.14 degrees Fahrenheit
# 1.13 degrees Celsius =  34.03 degrees Fahrenheit
# 64.69 degrees Celsius =  148.44 degrees Fahrenheit
# -7.79 degrees Celsius =  17.98 degrees Fahrenheit
# 50.62 degrees Celsius =  123.12 degrees Fahrenheit
# 7.67 degrees Celsius =  45.81 degrees Fahrenheit
# 59.6 degrees Celsius =  139.28 degrees Fahrenheit
# 27.55 degrees Celsius =  81.59 degrees Fahrenheit
# -2.0 degrees Celsius =  28.4 degrees Fahrenheit
# -8.84 degrees Celsius =  16.09 degrees Fahrenheit
# 32.19 degrees Celsius =  89.94 degrees Fahrenheit
# 37.07 degrees Celsius =  98.73 degrees Fahrenheit
# 6.57 degrees Celsius =  43.83 degrees Fahrenheit
# -3.27 degrees Celsius =  26.11 degrees Fahrenheit
# 31.77 degrees Celsius =  89.19 degrees Fahrenheit
# 59.04 degrees Celsius =  138.27 degrees Fahrenheit
# 57.27 degrees Celsius =  135.09 degrees Fahrenheit
# 58.54 degrees Celsius =  137.37 degrees Fahrenheit
# 12.43 degrees Celsius =  54.37 degrees Fahrenheit
# 25.68 degrees Celsius =  78.22 degrees Fahrenheit
# 18.52 degrees Celsius =  65.34 degrees Fahrenheit
# 72.09 degrees Celsius =  161.76 degrees Fahrenheit
# 29.04 degrees Celsius =  84.27 degrees Fahrenheit
# 41.94 degrees Celsius =  107.49 degrees Fahrenheit
# 18.04 degrees Celsius =  64.47 degrees Fahrenheit
# 22.37 degrees Celsius =  72.27 degrees Fahrenheit
# 4.8 degrees Celsius =  40.64 degrees Fahrenheit
# 43.05 degrees Celsius =  109.49 degrees Fahrenheit
# 40.14 degrees Celsius =  104.25 degrees Fahrenheit
# 3.72 degrees Celsius =  38.7 degrees Fahrenheit
# 71.59 degrees Celsius =  160.86 degrees Fahrenheit
# 28.56 degrees Celsius =  83.41 degrees Fahrenheit
# 65.42 degrees Celsius =  149.76 degrees Fahrenheit
# -2.99 degrees Celsius =  26.62 degrees Fahrenheit
# 69.28 degrees Celsius =  156.7 degrees Fahrenheit
# 12.72 degrees Celsius =  54.9 degrees Fahrenheit
# 70.11 degrees Celsius =  158.2 degrees Fahrenheit
# 17.08 degrees Celsius =  62.74 degrees Fahrenheit
# 71.35 degrees Celsius =  160.43 degrees Fahrenheit
# 69.99 degrees Celsius =  157.98 degrees Fahrenheit
# -5.54 degrees Celsius =  22.03 degrees Fahrenheit
# 32.89 degrees Celsius =  91.2 degrees Fahrenheit
# 18.49 degrees Celsius =  65.28 degrees Fahrenheit
# 11.07 degrees Celsius =  51.93 degrees Fahrenheit
# 52.06 degrees Celsius =  125.71 degrees Fahrenheit
# -4.97 degrees Celsius =  23.05 degrees Fahrenheit
# 3.4 degrees Celsius =  38.12 degrees Fahrenheit
# 66.69 degrees Celsius =  152.04 degrees Fahrenheit
# 9.6 degrees Celsius =  49.28 degrees Fahrenheit
# 74.76 degrees Celsius =  166.57 degrees Fahrenheit
# 19.4 degrees Celsius =  66.92 degrees Fahrenheit
# 56.66 degrees Celsius =  133.99 degrees Fahrenheit
# 30.32 degrees Celsius =  86.58 degrees Fahrenheit
# 68.9 degrees Celsius =  156.02 degrees Fahrenheit
# 46.61 degrees Celsius =  115.9 degrees Fahrenheit
# 74.8 degrees Celsius =  166.64 degrees Fahrenheit
# 53.69 degrees Celsius =  128.64 degrees Fahrenheit
# 17.76 degrees Celsius =  63.97 degrees Fahrenheit
# 72.19 degrees Celsius =  161.94 degrees Fahrenheit
# 0.85 degrees Celsius =  33.53 degrees Fahrenheit
# 66.28 degrees Celsius =  151.3 degrees Fahrenheit
# 67.83 degrees Celsius =  154.09 degrees Fahrenheit
# 41.91 degrees Celsius =  107.44 degrees Fahrenheit
# 25.43 degrees Celsius =  77.77 degrees Fahrenheit
# 36.99 degrees Celsius =  98.58 degrees Fahrenheit
# 0.67 degrees Celsius =  33.21 degrees Fahrenheit
# 25.28 degrees Celsius =  77.5 degrees Fahrenheit
# 61.39 degrees Celsius =  142.5 degrees Fahrenheit
# 15.3 degrees Celsius =  59.54 degrees Fahrenheit
# 55.88 degrees Celsius =  132.58 degrees Fahrenheit
# 18.93 degrees Celsius =  66.07 degrees Fahrenheit
# 45.91 degrees Celsius =  114.64 degrees Fahrenheit
# 33.11 degrees Celsius =  91.6 degrees Fahrenheit
# 40.9 degrees Celsius =  105.62 degrees Fahrenheit
# 32.89 degrees Celsius =  91.2 degrees Fahrenheit
# 56.05 degrees Celsius =  132.89 degrees Fahrenheit
# 66.18 degrees Celsius =  151.12 degrees Fahrenheit
# 8.02 degrees Celsius =  46.44 degrees Fahrenheit
# 48.87 degrees Celsius =  119.97 degrees Fahrenheit
# 39.08 degrees Celsius =  102.34 degrees Fahrenheit
# 41.18 degrees Celsius =  106.12 degrees Fahrenheit
# 68.23 degrees Celsius =  154.81 degrees Fahrenheit
# 69.07 degrees Celsius =  156.33 degrees Fahrenheit
# 73.82 degrees Celsius =  164.88 degrees Fahrenheit
# 66.33 degrees Celsius =  151.39 degrees Fahrenheit
# 59.6 degrees Celsius =  139.28 degrees Fahrenheit
# -0.21 degrees Celsius =  31.62 degrees Fahrenheit
# 7.36 degrees Celsius =  45.25 degrees Fahrenheit
# 56.97 degrees Celsius =  134.55 degrees Fahrenheit
# 62.39 degrees Celsius =  144.3 degrees Fahrenheit
# 59.97 degrees Celsius =  139.95 degrees Fahrenheit
# 73.78 degrees Celsius =  164.8 degrees Fahrenheit
# 9.9 degrees Celsius =  49.82 degrees Fahrenheit
# 17.63 degrees Celsius =  63.73 degrees Fahrenheit
# 12.6 degrees Celsius =  54.68 degrees Fahrenheit
# -6.24 degrees Celsius =  20.77 degrees Fahrenheit
# 54.23 degrees Celsius =  129.61 degrees Fahrenheit
# 50.77 degrees Celsius =  123.39 degrees Fahrenheit
# 41.93 degrees Celsius =  107.47 degrees Fahrenheit
# 51.13 degrees Celsius =  124.03 degrees Fahrenheit
# 47.74 degrees Celsius =  117.93 degrees Fahrenheit
# 10.54 degrees Celsius =  50.97 degrees Fahrenheit
# 74.3 degrees Celsius =  165.74 degrees Fahrenheit
# 47.57 degrees Celsius =  117.63 degrees Fahrenheit
# 31.25 degrees Celsius =  88.25 degrees Fahrenheit
# 68.08 degrees Celsius =  154.54 degrees Fahrenheit
# 27.92 degrees Celsius =  82.26 degrees Fahrenheit
# 67.18 degrees Celsius =  152.92 degrees Fahrenheit
# 32.64 degrees Celsius =  90.75 degrees Fahrenheit
# 33.9 degrees Celsius =  93.02 degrees Fahrenheit
# 4.92 degrees Celsius =  40.86 degrees Fahrenheit
# -9.15 degrees Celsius =  15.53 degrees Fahrenheit
# -2.99 degrees Celsius =  26.62 degrees Fahrenheit
# 29.67 degrees Celsius =  85.41 degrees Fahrenheit
# 28.49 degrees Celsius =  83.28 degrees Fahrenheit
# 25.06 degrees Celsius =  77.11 degrees Fahrenheit
# 57.93 degrees Celsius =  136.27 degrees Fahrenheit
# 23.63 degrees Celsius =  74.53 degrees Fahrenheit
# 65.95 degrees Celsius =  150.71 degrees Fahrenheit
# 11.79 degrees Celsius =  53.22 degrees Fahrenheit
# 74.05 degrees Celsius =  165.29 degrees Fahrenheit
# 3.72 degrees Celsius =  38.7 degrees Fahrenheit
# 6.53 degrees Celsius =  43.75 degrees Fahrenheit
# 39.73 degrees Celsius =  103.51 degrees Fahrenheit
# 34.21 degrees Celsius =  93.58 degrees Fahrenheit
# 67.92 degrees Celsius =  154.26 degrees Fahrenheit
# 24.2 degrees Celsius =  75.56 degrees Fahrenheit
# 58.65 degrees Celsius =  137.57 degrees Fahrenheit
# 61.41 degrees Celsius =  142.54 degrees Fahrenheit
# 72.99 degrees Celsius =  163.38 degrees Fahrenheit
# 56.33 degrees Celsius =  133.39 degrees Fahrenheit
# 19.42 degrees Celsius =  66.96 degrees Fahrenheit
# 34.51 degrees Celsius =  94.12 degrees Fahrenheit
# 63.43 degrees Celsius =  146.17 degrees Fahrenheit
# 45.48 degrees Celsius =  113.86 degrees Fahrenheit
# 17.73 degrees Celsius =  63.91 degrees Fahrenheit
# 4.33 degrees Celsius =  39.79 degrees Fahrenheit
# 49.49 degrees Celsius =  121.08 degrees Fahrenheit
# 52.59 degrees Celsius =  126.66 degrees Fahrenheit
# 8.34 degrees Celsius =  47.01 degrees Fahrenheit
# 46.6 degrees Celsius =  115.88 degrees Fahrenheit
# 36.84 degrees Celsius =  98.31 degrees Fahrenheit
# 32.82 degrees Celsius =  91.08 degrees Fahrenheit
# 41.47 degrees Celsius =  106.65 degrees Fahrenheit
# 40.63 degrees Celsius =  105.13 degrees Fahrenheit
# 71.28 degrees Celsius =  160.3 degrees Fahrenheit
# 65.69 degrees Celsius =  150.24 degrees Fahrenheit
# 14.75 degrees Celsius =  58.55 degrees Fahrenheit
# 51.48 degrees Celsius =  124.66 degrees Fahrenheit
# 39.28 degrees Celsius =  102.7 degrees Fahrenheit
# 5.4 degrees Celsius =  41.72 degrees Fahrenheit
# 20.98 degrees Celsius =  69.76 degrees Fahrenheit
# 63.62 degrees Celsius =  146.52 degrees Fahrenheit
# -3.14 degrees Celsius =  26.35 degrees Fahrenheit
# 74.45 degrees Celsius =  166.01 degrees Fahrenheit
# 6.48 degrees Celsius =  43.66 degrees Fahrenheit
# 55.62 degrees Celsius =  132.12 degrees Fahrenheit
# -9.94 degrees Celsius =  14.11 degrees Fahrenheit
# 26.8 degrees Celsius =  80.24 degrees Fahrenheit
# 32.57 degrees Celsius =  90.63 degrees Fahrenheit
# 44.69 degrees Celsius =  112.44 degrees Fahrenheit
# 73.63 degrees Celsius =  164.53 degrees Fahrenheit
# 6.04 degrees Celsius =  42.87 degrees Fahrenheit
# 20.54 degrees Celsius =  68.97 degrees Fahrenheit
# 74.45 degrees Celsius =  166.01 degrees Fahrenheit
# 20.77 degrees Celsius =  69.39 degrees Fahrenheit
# -5.49 degrees Celsius =  22.12 degrees Fahrenheit
# 34.12 degrees Celsius =  93.42 degrees Fahrenheit
# 17.3 degrees Celsius =  63.14 degrees Fahrenheit
# 5.01 degrees Celsius =  41.02 degrees Fahrenheit
# 42.03 degrees Celsius =  107.65 degrees Fahrenheit
# 21.35 degrees Celsius =  70.43 degrees Fahrenheit
# 48.95 degrees Celsius =  120.11 degrees Fahrenheit
# 53.77 degrees Celsius =  128.79 degrees Fahrenheit
# 23.82 degrees Celsius =  74.88 degrees Fahrenheit
# 4.55 degrees Celsius =  40.19 degrees Fahrenheit
# -6.99 degrees Celsius =  19.42 degrees Fahrenheit
# 24.98 degrees Celsius =  76.96 degrees Fahrenheit
# 26.91 degrees Celsius =  80.44 degrees Fahrenheit
# 23.42 degrees Celsius =  74.16 degrees Fahrenheit
# 70.57 degrees Celsius =  159.03 degrees Fahrenheit
# 71.82 degrees Celsius =  161.28 degrees Fahrenheit
# 38.61 degrees Celsius =  101.5 degrees Fahrenheit
# 3.92 degrees Celsius =  39.06 degrees Fahrenheit
# 46.95 degrees Celsius =  116.51 degrees Fahrenheit
# 38.58 degrees Celsius =  101.44 degrees Fahrenheit
# 69.93 degrees Celsius =  157.87 degrees Fahrenheit
# -3.14 degrees Celsius =  26.35 degrees Fahrenheit
# 30.35 degrees Celsius =  86.63 degrees Fahrenheit
# 33.49 degrees Celsius =  92.28 degrees Fahrenheit
# 43.01 degrees Celsius =  109.42 degrees Fahrenheit
# 47.48 degrees Celsius =  117.46 degrees Fahrenheit
# 47.92 degrees Celsius =  118.26 degrees Fahrenheit
# 56.65 degrees Celsius =  133.97 degrees Fahrenheit
# 3.33 degrees Celsius =  37.99 degrees Fahrenheit
# 28.45 degrees Celsius =  83.21 degrees Fahrenheit
# 44.51 degrees Celsius =  112.12 degrees Fahrenheit
# 63.89 degrees Celsius =  147.0 degrees Fahrenheit
# 74.46 degrees Celsius =  166.03 degrees Fahrenheit
# 33.8 degrees Celsius =  92.84 degrees Fahrenheit
# 63.32 degrees Celsius =  145.98 degrees Fahrenheit
# 39.75 degrees Celsius =  103.55 degrees Fahrenheit
# -2.92 degrees Celsius =  26.74 degrees Fahrenheit
# -2.04 degrees Celsius =  28.33 degrees Fahrenheit
# 12.04 degrees Celsius =  53.67 degrees Fahrenheit
# 42.15 degrees Celsius =  107.87 degrees Fahrenheit
# 11.44 degrees Celsius =  52.59 degrees Fahrenheit
# 52.74 degrees Celsius =  126.93 degrees Fahrenheit
# 14.26 degrees Celsius =  57.67 degrees Fahrenheit
# 66.31 degrees Celsius =  151.36 degrees Fahrenheit
# 44.36 degrees Celsius =  111.85 degrees Fahrenheit
# 6.29 degrees Celsius =  43.32 degrees Fahrenheit
# 40.04 degrees Celsius =  104.07 degrees Fahrenheit
# 63.2 degrees Celsius =  145.76 degrees Fahrenheit
# 5.95 degrees Celsius =  42.71 degrees Fahrenheit
# 66.33 degrees Celsius =  151.39 degrees Fahrenheit
# 66.89 degrees Celsius =  152.4 degrees Fahrenheit
# 46.04 degrees Celsius =  114.87 degrees Fahrenheit
# 52.5 degrees Celsius =  126.5 degrees Fahrenheit
# 37.63 degrees Celsius =  99.73 degrees Fahrenheit
# -1.92 degrees Celsius =  28.54 degrees Fahrenheit
# 34.13 degrees Celsius =  93.43 degrees Fahrenheit
# 30.97 degrees Celsius =  87.75 degrees Fahrenheit
# 71.28 degrees Celsius =  160.3 degrees Fahrenheit
# 68.67 degrees Celsius =  155.61 degrees Fahrenheit
# 0.78 degrees Celsius =  33.4 degrees Fahrenheit
# -1.54 degrees Celsius =  29.23 degrees Fahrenheit
# 20.99 degrees Celsius =  69.78 degrees Fahrenheit
# 16.81 degrees Celsius =  62.26 degrees Fahrenheit
# -5.06 degrees Celsius =  22.89 degrees Fahrenheit
# 7.12 degrees Celsius =  44.82 degrees Fahrenheit
# 33.57 degrees Celsius =  92.43 degrees Fahrenheit
# 56.89 degrees Celsius =  134.4 degrees Fahrenheit
# 71.86 degrees Celsius =  161.35 degrees Fahrenheit
# 57.99 degrees Celsius =  136.38 degrees Fahrenheit
# 3.82 degrees Celsius =  38.88 degrees Fahrenheit
# 35.64 degrees Celsius =  96.15 degrees Fahrenheit
# 74.46 degrees Celsius =  166.03 degrees Fahrenheit
# 44.65 degrees Celsius =  112.37 degrees Fahrenheit
# 47.29 degrees Celsius =  117.12 degrees Fahrenheit
# 11.13 degrees Celsius =  52.03 degrees Fahrenheit
# 35.33 degrees Celsius =  95.59 degrees Fahrenheit
# -7.8 degrees Celsius =  17.96 degrees Fahrenheit
# 33.97 degrees Celsius =  93.15 degrees Fahrenheit
# 57.68 degrees Celsius =  135.82 degrees Fahrenheit
# 31.2 degrees Celsius =  88.16 degrees Fahrenheit
# -7.48 degrees Celsius =  18.54 degrees Fahrenheit
# 7.69 degrees Celsius =  45.84 degrees Fahrenheit
# 63.3 degrees Celsius =  145.94 degrees Fahrenheit
# 19.78 degrees Celsius =  67.6 degrees Fahrenheit
# 36.1 degrees Celsius =  96.98 degrees Fahrenheit
# 24.1 degrees Celsius =  75.38 degrees Fahrenheit
# 26.5 degrees Celsius =  79.7 degrees Fahrenheit
# 20.99 degrees Celsius =  69.78 degrees Fahrenheit
# 62.56 degrees Celsius =  144.61 degrees Fahrenheit
# 49.22 degrees Celsius =  120.6 degrees Fahrenheit
# 0.34 degrees Celsius =  32.61 degrees Fahrenheit
# 36.13 degrees Celsius =  97.03 degrees Fahrenheit
# 50.17 degrees Celsius =  122.31 degrees Fahrenheit
# 44.3 degrees Celsius =  111.74 degrees Fahrenheit
# 12.87 degrees Celsius =  55.17 degrees Fahrenheit
# 47.78 degrees Celsius =  118.0 degrees Fahrenheit
# 38.38 degrees Celsius =  101.08 degrees Fahrenheit
# 25.02 degrees Celsius =  77.04 degrees Fahrenheit
# -9.11 degrees Celsius =  15.6 degrees Fahrenheit
# 43.43 degrees Celsius =  110.17 degrees Fahrenheit
# -5.05 degrees Celsius =  22.91 degrees Fahrenheit
# 29.62 degrees Celsius =  85.32 degrees Fahrenheit
# 51.73 degrees Celsius =  125.11 degrees Fahrenheit
# 60.52 degrees Celsius =  140.94 degrees Fahrenheit
# 73.69 degrees Celsius =  164.64 degrees Fahrenheit
# 69.49 degrees Celsius =  157.08 degrees Fahrenheit
# 2.2 degrees Celsius =  35.96 degrees Fahrenheit
# 21.41 degrees Celsius =  70.54 degrees Fahrenheit
# 37.48 degrees Celsius =  99.46 degrees Fahrenheit
# 1.67 degrees Celsius =  35.01 degrees Fahrenheit
# 21.82 degrees Celsius =  71.28 degrees Fahrenheit
# 29.34 degrees Celsius =  84.81 degrees Fahrenheit
# 8.82 degrees Celsius =  47.88 degrees Fahrenheit
# 42.28 degrees Celsius =  108.1 degrees Fahrenheit
# 64.67 degrees Celsius =  148.41 degrees Fahrenheit
# 38.4 degrees Celsius =  101.12 degrees Fahrenheit
# 22.07 degrees Celsius =  71.73 degrees Fahrenheit
# 9.33 degrees Celsius =  48.79 degrees Fahrenheit
# 49.1 degrees Celsius =  120.38 degrees Fahrenheit
# 46.99 degrees Celsius =  116.58 degrees Fahrenheit
# 50.3 degrees Celsius =  122.54 degrees Fahrenheit
# -8.37 degrees Celsius =  16.93 degrees Fahrenheit
# 33.68 degrees Celsius =  92.62 degrees Fahrenheit
# 31.83 degrees Celsius =  89.29 degrees Fahrenheit
# 8.9 degrees Celsius =  48.02 degrees Fahrenheit
# 4.09 degrees Celsius =  39.36 degrees Fahrenheit
# 70.2 degrees Celsius =  158.36 degrees Fahrenheit
# 31.3 degrees Celsius =  88.34 degrees Fahrenheit
# 17.79 degrees Celsius =  64.02 degrees Fahrenheit
# -6.36 degrees Celsius =  20.55 degrees Fahrenheit
# 39.01 degrees Celsius =  102.22 degrees Fahrenheit
# 54.37 degrees Celsius =  129.87 degrees Fahrenheit
# 42.31 degrees Celsius =  108.16 degrees Fahrenheit
# -4.38 degrees Celsius =  24.12 degrees Fahrenheit
# 16.94 degrees Celsius =  62.49 degrees Fahrenheit
# -1.61 degrees Celsius =  29.1 degrees Fahrenheit
# 19.4 degrees Celsius =  66.92 degrees Fahrenheit
# 31.36 degrees Celsius =  88.45 degrees Fahrenheit
# 46.67 degrees Celsius =  116.01 degrees Fahrenheit
# 71.71 degrees Celsius =  161.08 degrees Fahrenheit
# 6.03 degrees Celsius =  42.85 degrees Fahrenheit
# 69.6 degrees Celsius =  157.28 degrees Fahrenheit
# 68.03 degrees Celsius =  154.45 degrees Fahrenheit
# 29.02 degrees Celsius =  84.24 degrees Fahrenheit
# 33.24 degrees Celsius =  91.83 degrees Fahrenheit
# 74.29 degrees Celsius =  165.72 degrees Fahrenheit
# 63.06 degrees Celsius =  145.51 degrees Fahrenheit
# -3.75 degrees Celsius =  25.25 degrees Fahrenheit
# 10.71 degrees Celsius =  51.28 degrees Fahrenheit
# 35.92 degrees Celsius =  96.66 degrees Fahrenheit
# 39.47 degrees Celsius =  103.05 degrees Fahrenheit
# 29.05 degrees Celsius =  84.29 degrees Fahrenheit
# 14.4 degrees Celsius =  57.92 degrees Fahrenheit
# 31.02 degrees Celsius =  87.84 degrees Fahrenheit
# 14.48 degrees Celsius =  58.06 degrees Fahrenheit
# -10.0 degrees Celsius =  14.0 degrees Fahrenheit
# 51.53 degrees Celsius =  124.75 degrees Fahrenheit
# 5.69 degrees Celsius =  42.24 degrees Fahrenheit
# 53.99 degrees Celsius =  129.18 degrees Fahrenheit
# 53.4 degrees Celsius =  128.12 degrees Fahrenheit
# 55.64 degrees Celsius =  132.15 degrees Fahrenheit
# 69.08 degrees Celsius =  156.34 degrees Fahrenheit
# 19.04 degrees Celsius =  66.27 degrees Fahrenheit
# 26.09 degrees Celsius =  78.96 degrees Fahrenheit
# 56.16 degrees Celsius =  133.09 degrees Fahrenheit
# 64.24 degrees Celsius =  147.63 degrees Fahrenheit
# 34.52 degrees Celsius =  94.14 degrees Fahrenheit
# 62.6 degrees Celsius =  144.68 degrees Fahrenheit
# 55.47 degrees Celsius =  131.85 degrees Fahrenheit
# 47.91 degrees Celsius =  118.24 degrees Fahrenheit
# 16.06 degrees Celsius =  60.91 degrees Fahrenheit
# 71.99 degrees Celsius =  161.58 degrees Fahrenheit
# 14.87 degrees Celsius =  58.77 degrees Fahrenheit
# -9.92 degrees Celsius =  14.14 degrees Fahrenheit
# 65.73 degrees Celsius =  150.31 degrees Fahrenheit
# 0.34 degrees Celsius =  32.61 degrees Fahrenheit
# 49.86 degrees Celsius =  121.75 degrees Fahrenheit
# 5.47 degrees Celsius =  41.85 degrees Fahrenheit
# -9.98 degrees Celsius =  14.04 degrees Fahrenheit
# 7.45 degrees Celsius =  45.41 degrees Fahrenheit
# 1.22 degrees Celsius =  34.2 degrees Fahrenheit
# 50.08 degrees Celsius =  122.14 degrees Fahrenheit
# -2.88 degrees Celsius =  26.82 degrees Fahrenheit
# 40.33 degrees Celsius =  104.59 degrees Fahrenheit
# 21.67 degrees Celsius =  71.01 degrees Fahrenheit
# -1.48 degrees Celsius =  29.34 degrees Fahrenheit
# 64.99 degrees Celsius =  148.98 degrees Fahrenheit
# -8.32 degrees Celsius =  17.02 degrees Fahrenheit
# -5.46 degrees Celsius =  22.17 degrees Fahrenheit
# 5.71 degrees Celsius =  42.28 degrees Fahrenheit
# 16.49 degrees Celsius =  61.68 degrees Fahrenheit
# 17.77 degrees Celsius =  63.99 degrees Fahrenheit
# 20.03 degrees Celsius =  68.05 degrees Fahrenheit
# 24.33 degrees Celsius =  75.79 degrees Fahrenheit
# 63.89 degrees Celsius =  147.0 degrees Fahrenheit
# 26.79 degrees Celsius =  80.22 degrees Fahrenheit
# 28.86 degrees Celsius =  83.95 degrees Fahrenheit
# 3.73 degrees Celsius =  38.71 degrees Fahrenheit
# -8.71 degrees Celsius =  16.32 degrees Fahrenheit
# 10.28 degrees Celsius =  50.5 degrees Fahrenheit
# 10.16 degrees Celsius =  50.29 degrees Fahrenheit
# 12.29 degrees Celsius =  54.12 degrees Fahrenheit
# -8.7 degrees Celsius =  16.34 degrees Fahrenheit
# 19.98 degrees Celsius =  67.96 degrees Fahrenheit
# 43.13 degrees Celsius =  109.63 degrees Fahrenheit
# -2.39 degrees Celsius =  27.7 degrees Fahrenheit
# 5.92 degrees Celsius =  42.66 degrees Fahrenheit
# 62.6 degrees Celsius =  144.68 degrees Fahrenheit
# 59.14 degrees Celsius =  138.45 degrees Fahrenheit
# 66.2 degrees Celsius =  151.16 degrees Fahrenheit
# 49.99 degrees Celsius =  121.98 degrees Fahrenheit
# 15.4 degrees Celsius =  59.72 degrees Fahrenheit
# 48.26 degrees Celsius =  118.87 degrees Fahrenheit
# 52.78 degrees Celsius =  127.0 degrees Fahrenheit
# 63.2 degrees Celsius =  145.76 degrees Fahrenheit
# 39.12 degrees Celsius =  102.42 degrees Fahrenheit
# 10.22 degrees Celsius =  50.4 degrees Fahrenheit
# -0.63 degrees Celsius =  30.87 degrees Fahrenheit
# 5.29 degrees Celsius =  41.52 degrees Fahrenheit
# 25.96 degrees Celsius =  78.73 degrees Fahrenheit
# 21.73 degrees Celsius =  71.11 degrees Fahrenheit

# %%
celsius_in = np.array(celsius_2,  dtype=float)
fahrenheit_out = np.array(fahrenheit_2,  dtype=float)

# %%
# %%time



l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

model = tf.keras.Sequential([l0])

model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))


history = model.fit(celsius_in, fahrenheit_out, epochs=500, verbose=False)
print("Finished training the model")


print("These are the layer variables, weight:",l0.get_weights()[0],", bias:",l0.get_weights()[1])
# Out:
# Finished training the model
# These are the layer variables, weight: [[1.8000077]] , bias: [31.999966]
# CPU times: user 23.3 s, sys: 1.14 s, total: 24.4 s
# Wall time: 25.3 s

# %%
input_data = np.array([[100.0]])
prediction = model.predict(input_data)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[212.00073]]

# %%
cel_to_far(100.0)
# Out:
# 212.0

# %% [markdown]
# ---
#
#
#
# ---

# %%
# %%time
l0 = tf.keras.layers.Dense(units=3, input_shape=[1])
l1 = tf.keras.layers.Dense(units=2)
l2 = tf.keras.layers.Dense(units=1)

model = tf.keras.Sequential([l0, l1, l2])

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

model.fit(celsius_in, fahrenheit_out, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model
# CPU times: user 26.4 s, sys: 1.19 s, total: 27.6 s
# Wall time: 30.5 s

# %%
input_data = np.array([[100.0]])
prediction = model.predict(input_data)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# [[212.33026]]

# %%
cel_to_far(100.0)
# Out:
# 212.0

# %%
print("These are the l0 variables, weight:",l0.get_weights()[0],", bias:",l0.get_weights()[1])
# Out:
# These are the l0 variables, weight: [[0.02412537 0.05257902 0.9566197 ]] , bias: [-1.2272239 -2.2362354  8.124777 ]

# %%
print("These are the l1 variables, weight:",l1.get_weights()[0],", bias:",l1.get_weights()[1])
# Out:
# These are the l1 variables, weight: [[ 0.10884047  0.16860354]
#  [-0.05955999 -0.03550115]
#  [-1.1391684   1.040245  ]] , bias: [-7.092278   3.7971578]

# %%
print("These are the l2 variables, weight:",l2.get_weights()[0],", bias:",l2.get_weights()[1])
# Out:
# These are the l2 variables, weight: [[-0.9983976 ]
#  [ 0.71638495]] , bias: [7.027283]
