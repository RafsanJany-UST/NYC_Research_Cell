# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
fb_master = pd.read_csv("/content/drive/MyDrive/Iqram Sir/fitabse_new/Fitabase_combined_data_s1-s39.csv")
hr_aee = pd.read_csv("/content/drive/MyDrive/Iqram Sir/fitabse_new/Fitabase_HR_aEE_MAX_wo_radompoints.csv")
hr_recovery = pd.read_excel("/content/drive/MyDrive/Iqram Sir/fitabse_new/HR_Recovery.xlsx")
all_info = pd.read_excel("/content/drive/MyDrive/Iqram Sir/fitabse_new/Wearables-REDCap-CRF_001-039.xlsx")

# %%
fb_master.head(3)
# Out:
#   Subject Condition Activity  Epoch Duration(min)  Epoch  nni_counter  \
# 0  002-JR      post    Light                   10      1           69
# 1  002-JR      post    Light                   10     10           64
# 2  002-JR      post    Light                   10    100           73
#
#      nni_mean  nni_min  nni_max    hr_mean  ...  ar_order  \
# 0  762.275362    731.0    810.0  78.784007  ...        16
# 1  752.296875    722.0    789.0  79.788063  ...        16
# 2  687.876712    638.0    740.0  87.334350  ...        16
#
#    ar_resampling_frequency  ar_interpolation       sd1        sd2  sd_ratio  \
# 0                        4             cubic  9.218160  31.496237  3.416760
# 1                        4             cubic  4.669096  20.671055  4.427208
# 2                        4             cubic  7.184087  33.772912  4.701072
#
#    ellipse_area    sampen  dfa_alpha1  dfa_alpha2
# 0    912.121745  1.264597    1.489948    0.919373
# 1    303.211229  0.816470         NaN         NaN
# 2    762.236923  1.339774    1.114245    1.234465
#
# [3 rows x 111 columns]

# %%
hr_aee.head(3)
# Out:
#   Patient_Id Condition  HR_MAX(BPM)  aEE_MAX(kJ/min)
# 0     001-JV       pre          126            70.39
# 1     001-JV      post          122            64.41
# 2     002-JR       pre          137            90.72

# %%
hr_recovery.head(3)
# Out:
#   Subject Condition    Segment  Max Heart Rate  1_min_HR_Recovery  \
# 0  001-JV       pre  Segment_1             NaN                  1
# 1  001-JV       pre  Segment_2             NaN                  1
# 2  001-JV       pre  Segment_3             NaN                  4
#
#    2_min_HR_Recovery  3_min_HR_Recovery  4_min_HR_Recovery  5_min_HR_Recovery
# 0                 11                 14               15.0               16.0
# 1                 14                 24               26.0                NaN
# 2                 14                 17                NaN                NaN

# %%
all_info.head(3)
# Out:
#    Record ID: Subject ID: Date of Subject Enrollment:  Final AMTS Score:   \
# 0           1      001-JV                  2021-12-02                 7.0
# 1           2      002-JR                  2021-12-07                 9.0
# 2           3      003-ES                  2021-12-29                 9.0
#
#   Did subject pass AMTS?              Ethnicity:               Race:  \
# 0                    Yes      Hispanic or Latino  Hispanic or Latino
# 1                    Yes      Hispanic or Latino               White
# 2                    Yes  Not Hispanic or Latino               White
#
#   Smoking Status:  If current or past, pack-year smoking history:  \
# 0            Past                                           260.0
# 1              No                                             NaN
# 2            Past                                            50.0
#
#   Alcohol use:  ...  Wound:.1  \
# 0          Yes  ...        No
# 1           No  ...        No
# 2           No  ...        No
#
#   Wound Complication Notes/Clavien-Dindo Assessment Grade:.1 Hematological:.1  \
# 0                                                NaN                       No
# 1                                                NaN                       No
# 2                                                NaN                       No
#
#    Hematological Complication Notes/Clavien-Dindo Assessment Grade:.1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Pain:.1  Pain Complication Notes/Clavien-Dindo Assessment Grade:.1  \
# 0       No                                                NaN
# 1       No                                                NaN
# 2       No                                                NaN
#
#    Complete?  Has this CRF been quality checked Date CRF was last checked:   \
# 0   Complete                                Yes                  2023-05-15
# 1   Complete                                Yes                  2023-05-15
# 2   Complete                                Yes                  2023-05-15
#
#    Complete?.1
# 0     Complete
# 1     Complete
# 2     Complete
#
# [3 rows x 337 columns]

# %%
hr_aee.head(2)
# Out:
#   Patient_Id Condition  HR_MAX(BPM)  aEE_MAX(kJ/min)
# 0     001-JV       pre          126            70.39
# 1     001-JV      post          122            64.41

# %%
hr_aee.columns
# Out:
# Index(['Patient_Id', 'Condition', 'HR_MAX(BPM)', 'aEE_MAX(kJ/min)'], dtype='object')

# %%
all_col = list(fb_master.columns)+list(all_info.columns)+list(hr_aee.columns)

# %%
#w
for i in list(hr_aee.columns):
  if i != "Condition":
    fb_master[i] = ''

# %%
def hr_aee_back(p_id, condition):
  li = []
  for i in list(hr_aee.columns):
    if i!="Patient_Id" and i!="Condition":
      li.append(list(hr_aee.query("Patient_Id == '"+p_id+"' and 	Condition == '"+condition+"'")[i]))
  return li

# %%
for row in range(fb_master.shape[0]):
  print(fb_master['Subject'][row])
  print(fb_master['Condition'][row])
  break
# Out:
# 002-JR
# post

# %%
fb_master.head()
# Out:
#   Subject Condition Activity  Epoch Duration(min)  Epoch  nni_counter  \
# 0  002-JR      post    Light                   10      1           69
# 1  002-JR      post    Light                   10     10           64
# 2  002-JR      post    Light                   10    100           73
# 3  002-JR      post    Light                   10    101           78
# 4  002-JR      post    Light                   10    102           66
#
#      nni_mean  nni_min  nni_max     hr_mean  ...       sd1        sd2  \
# 0  762.275362    731.0    810.0   78.784007  ...  9.218160  31.496237
# 1  752.296875    722.0    789.0   79.788063  ...  4.669096  20.671055
# 2  687.876712    638.0    740.0   87.334350  ...  7.184087  33.772912
# 3  585.282051    545.0    645.0  102.611992  ...  7.762769  24.640998
# 4  603.772727    582.0    645.0   99.417782  ...  6.771992  16.551658
#
#    sd_ratio  ellipse_area    sampen  dfa_alpha1  dfa_alpha2  Patient_Id  \
# 0  3.416760    912.121745  1.264597    1.489948    0.919373
# 1  4.427208    303.211229  0.816470         NaN         NaN
# 2  4.701072    762.236923  1.339774    1.114245    1.234465
# 3  3.174254    600.931310  1.734601    1.419047    0.660367
# 4  2.444134    352.133913  1.037243    1.458604   -0.181451
#
#    HR_MAX(BPM)  aEE_MAX(kJ/min)
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 114 columns]

# %%
hr_aee.head(2)
# Out:
#   Patient_Id Condition  HR_MAX(BPM)  aEE_MAX(kJ/min)
# 0     001-JV       pre          126            70.39
# 1     001-JV      post          122            64.41

# %%
hr_aee.columns
# Out:
# Index(['Patient_Id', 'Condition', 'HR_MAX(BPM)', 'aEE_MAX(kJ/min)'], dtype='object')

# %%
def hr_aee_back(p_id, condition):
  li = []
  for i in list(hr_aee.columns):
    if i!="Patient_Id" and i!="Condition":
      li.append(list(hr_aee.query("Patient_Id == '"+p_id+"' and 	Condition == '"+condition+"'")[i]))
  return li

# %%
hr_aee_back('001-JV','pre')
# Out:
# [[126], [70.39]]

# %%
list(hr_aee.query("Patient_Id == '"+'001-JV'+"' and 	Condition == '"+'pre'+"'"))
# Out:
# ['Patient_Id', 'Condition', 'HR_MAX(BPM)', 'aEE_MAX(kJ/min)']

# %%
hr_aee.loc[hr_aee['Patient_Id'] == '001-JV', hr_aee['Condition'] == 'pre' ]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-76-730a3c105304> in <cell line: 1>()
# ----> 1 hr_aee.loc[hr_aee['Patient_Id'] == '001-JV', hr_aee['Condition'] == 'pre' ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     922                 continue
#     923
# --> 924             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     925             # We should never have retval.ndim < self.ndim, as that should
#     926             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1290             return self._get_slice_axis(key, axis=axis)
#    1291         elif com.is_bool_indexer(key):
# -> 1292             return self._getbool_axis(key, axis=axis)
#    1293         elif is_list_like_indexer(key):
#    1294
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#    1089         # caller is responsible for ensuring non-None axis
#    1090         labels = self.obj._get_axis(axis)
# -> 1091         key = check_bool_indexer(labels, key)
#    1092         inds = key.nonzero()[0]
#    1093         return self.obj._take_with_is_copy(inds, axis=axis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2550         indexer = result.index.get_indexer_for(index)
#    2551         if -1 in indexer:
# -> 2552             raise IndexingError(
#    2553                 "Unalignable boolean Series provided as "
#    2554                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# Name: Patient_Id, Length: 72, dtype: bool
