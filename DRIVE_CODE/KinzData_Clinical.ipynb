# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
clinic_df = pd.read_csv("/content/drive/MyDrive/Signal_Data/KINZ/ClinicalData80.csv")
kinz_df = pd.read_csv("/content/drive/MyDrive/Signal_Data/KINZ/kinzData_panda_2024-05-06_12-24PM.csv")

# %%
clinic_df
# Out:
#    RecordID  Age     Sex               Ethnicity                       Race  \
# 0    001-LO   43  Female  Not Hispanic or Latino                      White
# 1    002-RJ   77  Female  Not Hispanic or Latino  Black or African American
# 2    003-RM   48    Male      Hispanic or Latino                      White
# 3    004-MF   54  Female      Hispanic or Latino                      White
# 4    005-GP   46    Male      Hispanic or Latino                      White
# ..      ...  ...     ...                     ...                        ...
# 74   076-AH   60    Male  Not Hispanic or Latino  Black or African American
# 75   077-SK   79    Male  Not Hispanic or Latino                      White
# 76   078-SM   81    Male  Not Hispanic or Latino                      White
# 77   079-KO   78  Female  Not Hispanic or Latino                      White
# 78   080-KO   89     NaN                     NaN                        NaN
#
#     ZipCode SmokingStatus PackyearSmokingHistory AlcoholUse  \
# 0       NaN            No                    NaN         No
# 1       NaN            No                    NaN         No
# 2       NaN          Past                      3         No
# 3       NaN          Past                      1         No
# 4       NaN            No                    NaN         No
# ..      ...           ...                    ...        ...
# 74  11236.0          Past                    NaN         No
# 75  12572.0          Past                  25.00        Yes
# 76  11516.0          Past                  30.00        Yes
# 77  11372.0            No                    NaN        Yes
# 78      NaN           NaN                    NaN        NaN
#
#     FrequencyInPastWeekOfDrinks  ... Complication3Description  \
# 0                           NaN  ...                      NaN
# 1                           NaN  ...      Numbness in fingers
# 2                           NaN  ...                      NaN
# 3                           NaN  ...                      NaN
# 4                           NaN  ...                      NaN
# ..                          ...  ...                      ...
# 74                          NaN  ...                      NaN
# 75                          3.3  ...                      NaN
# 76                          7.0  ...                      NaN
# 77                          7.0  ...                      NaN
# 78                          NaN  ...                      NaN
#
#    Complication4Type Complication4ClavienDindoAssessmentGrade  \
# 0                NaN                                      NaN
# 1                NaN                                      NaN
# 2                NaN                                      NaN
# 3                NaN                                      NaN
# 4                NaN                                      NaN
# ..               ...                                      ...
# 74               NaN                                      NaN
# 75               NaN                                      NaN
# 76               NaN                                      NaN
# 77               NaN                                      NaN
# 78               NaN                                      NaN
#
#    Complication4Description Complication5Type  \
# 0                       NaN               NaN
# 1                       NaN               NaN
# 2                       NaN               NaN
# 3                       NaN               NaN
# 4                       NaN               NaN
# ..                      ...               ...
# 74                      NaN               NaN
# 75                      NaN               NaN
# 76                      NaN               NaN
# 77                      NaN               NaN
# 78                      NaN               NaN
#
#    Complication5ClavienDindoAssessmentGrade Complication5Description  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 4                                       NaN                      NaN
# ..                                      ...                      ...
# 74                                      NaN                      NaN
# 75                                      NaN                      NaN
# 76                                      NaN                      NaN
# 77                                      NaN                      NaN
# 78                                      NaN                      NaN
#
#    ComprehensiveComplicationIndexScore AdditionalNotes   Complete6
# 0                                  0.0             NaN    Complete
# 1                                 15.0             NaN    Complete
# 2                                  8.7             NaN    Complete
# 3                                  0.0             NaN    Complete
# 4                                  0.0             NaN    Complete
# ..                                 ...             ...         ...
# 74                                 NaN             NaN  Incomplete
# 75                                 NaN             NaN  Incomplete
# 76                                 NaN             NaN  Incomplete
# 77                                 NaN             NaN  Incomplete
# 78                                 NaN             NaN  Incomplete
#
# [79 rows x 334 columns]

# %%
import matplotlib.pyplot as plt

# Select the data
batch_size = 100
column = "FOOT_RIGHT_Y"

data = kinz_df.loc[:batch_size, column]

# Create the line plot
plt.figure(figsize=(10, 5))  # Set the figure size
plt.plot(data.index, data.values, linestyle='-')  # Plot the data
plt.title(column+' Movement Over Time')  # Add a title
plt.xlabel('Index')  # X-axis label
plt.ylabel('ANKLE_LEFT_X')  # Y-axis label
plt.grid(True)  # Add a grid
plt.show()  # Display the plot

# %%
import pandas as pd


columns = kinz_df.columns.tolist()


body_parts = set(part[:-2] for part in columns if part.endswith(('_X', '_Y', '_Z')))
sorted_parts = sorted(body_parts)
new_columns = ['patientID', 'trial_num', 'walking_speed', 'timeStamps']  # Start with these fixed columns
for part in sorted_parts:

    for coord in ['_X', '_Y', '_Z']:
        new_columns.append(part + coord)
kinz_df = kinz_df[new_columns]

# %%
kinz_df
# Out:
#       patientID  trial_num walking_speed  timeStamps  ANKLE_LEFT_X  \
# 0        001-LO          1       Regular    0.000000    390.562805
# 1        001-LO          1       Regular    0.031953    450.613678
# 2        001-LO          1       Regular    0.064029    431.553619
# 3        001-LO          1       Regular    0.239935    461.244110
# 4        001-LO          1       Regular    0.271985    462.041687
# ...         ...        ...           ...         ...           ...
# 36978    080-TW          4          Fast    6.672006      0.126880
# 36979    080-TW          4          Fast    6.704002      0.966503
# 36980    080-TW          4          Fast    6.736022     37.078635
# 36981    080-TW          4          Fast    6.768004     73.147911
# 36982    080-TW          4          Fast    6.799995     89.195496
#
#        ANKLE_LEFT_Y  ANKLE_LEFT_Z  ANKLE_RIGHT_X  ANKLE_RIGHT_Y  \
# 0        602.859009   1100.335571     463.011200     632.787964
# 1        627.286072   1276.520630     482.768677     654.531128
# 2        644.666809   1368.638550     522.916382     679.347290
# 3        659.211304   1528.767090     644.572632     682.580811
# 4        661.941528   1535.726196     636.041260     666.786926
# ...             ...           ...            ...            ...
# 36978    446.535370   1090.030762    -175.127060     434.097626
# 36979    431.704987   1087.463257    -165.724731     431.496918
# 36980    385.959290   1084.058466    -113.419082     393.683144
# 36981    340.267883   1080.657715     -61.175507     355.914246
# 36982    328.054901   1085.735229     -48.422764     342.799194
#
#        ANKLE_RIGHT_Z  ...  THUMB_LEFT_Z  THUMB_RIGHT_X  THUMB_RIGHT_Y  \
# 0         861.115906  ...   1145.996216     564.766174     145.974594
# 1         785.082581  ...   1157.933228     592.330017     131.384872
# 2         774.065186  ...   1171.173462     639.781372     103.950005
# 3        1240.194946  ...   1209.790894     718.639771     154.724213
# 4        1293.354126  ...   1285.507080     745.663025     155.708374
# ...              ...  ...           ...            ...            ...
# 36978    1092.649170  ...    875.477295    -302.459106    -167.914749
# 36979    1075.524658  ...    856.007202    -308.187500    -176.329666
# 36980    1083.271381  ...    828.731496    -307.569259    -176.856063
# 36981    1091.008911  ...    801.488159    -306.951752    -177.381836
# 36982    1100.149536  ...    788.311035    -302.643433    -178.222916
#
#        THUMB_RIGHT_Z  WRIST_LEFT_X  WRIST_LEFT_Y  WRIST_LEFT_Z  WRIST_RIGHT_X  \
# 0        1083.058838    413.098236     -4.848353   1048.260864     591.701233
# 1        1081.694458    424.203186     53.901688   1039.679077     686.942322
# 2        1087.459351    422.456421     73.186546   1057.114258     746.073425
# 3        1271.734253    299.355225     68.522301   1184.870972     770.750427
# 4        1342.324951    269.003235     46.742737   1239.554077     784.686951
# ...              ...           ...           ...           ...            ...
# 36978     858.258667    195.830185   -223.843414    788.262939    -371.584137
# 36979     846.691711    194.798309   -232.748657    755.283325    -375.846252
# 36980     843.140807    117.694591   -216.364935    737.265767    -350.738825
# 36981     839.594116     40.682377   -200.000656    719.269592    -325.661194
# 36982     823.646545     18.439726   -193.796890    711.441406    -308.507111
#
#        WRIST_RIGHT_Y  WRIST_RIGHT_Z
# 0          95.389412     988.159851
# 1          95.910889    1071.759644
# 2          74.025307    1121.079712
# 3          55.768864    1316.004639
# 4          50.482513    1371.748047
# ...              ...            ...
# 36978    -232.415070     762.661682
# 36979    -229.469437     745.169312
# 36980    -215.533525     733.906983
# 36981    -201.614151     722.658020
# 36982    -196.044250     704.673035
#
# [36983 rows x 100 columns]

# %% [markdown]
# # Concatenation

# %%
import numpy as np
from tqdm import tqdm


kinz_np = kinz_df.values # converting to np array

new_kinz = []
not_found_sub = []




for i in tqdm(kinz_np):

  # some RecordId name formate is not matching with the main data file....So we have to re formate the name
  sep = i[0].split("-")
  if sep[0].isdigit():
    sub = i[0]
  else:
    sub  = sep[-1]+"-"+sep[0]

  #quearing the TotalFFIScore
  total_ffi_score = clinic_df[clinic_df["RecordID"]==sub]["TotalFFIScore"]

  # Check if total_ffi_score is not empty
  if not total_ffi_score.empty:
    new_row = np.append(i, total_ffi_score.iloc[0])
  else:
    not_found_sub.append(i[0])
    new_row = np.append(i, 'nan')  # Append 'nan' for missing values
    #print("Loop broke!!!")

  new_kinz.append(new_row)




kinz_np = np.array(new_kinz)
# Out:
# 100%|██████████| 36983/36983 [00:23<00:00, 1554.57it/s]

# %%
set(not_found_sub)
# Out:
# {'015-GE',
#  '021-GA',
#  '056-STs',
#  '064-JH',
#  '065-RC',
#  '066-SC',
#  '076-TH',
#  '080-TW',
#  'ss'}

# %%
"""
sub
clinic_df[clinic_df["RecordID"]=="GE-015"]["TotalFFIScore"]
"""
# Out:
# '\nsub\nclinic_df[clinic_df["RecordID"]=="GE-015"]["TotalFFIScore"]\n'

# %% [markdown]
# # Removing NaN

# %%
# Create a mask for rows containing NaN values
mask = np.any(kinz_np == 'nan', axis=1)

# Use the mask to select only the rows without NaN values
kinz_np = kinz_np[~mask]

np.where(kinz_np == 'nan')
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
kinz_np.shape
# Out:
# (32727, 101)

# %% [markdown]
# # Selecting `Fast` for walking speed

# %% [markdown]
# ## Valu Counts

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


def np_val_count(data,col):
  last_elements = data[:, col]
  value_counts = np.unique(last_elements, return_counts=True)
  for value, count in zip(*value_counts):
      print(f"Value: {value}, Count: {count}")





def eval(model,X_test,y_test):
  test_loss, test_mse = model.evaluate(X_test, y_test, verbose=0)
  y_pred = model.predict(X_test)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)
  rmse = np.sqrt(mse)
  r2 = r2_score(y_test, y_pred)

  print("Test MSE:", test_mse)
  print("Test Loss:", test_loss)
  print("Mean Absolute Error:", mae)
  print("Root Mean Squared Error:", rmse)
  print("R-squared Score:", r2)






col_code={
    "Prediction":'#003BCC',
    "Ground Truth":'#CC0900',
    "Nominal Model":'#117A65'
}



def pred_vs_act(pred,act):
  # plot BIS
  plt.figure(figsize=(10, 6))
  plt.plot(pred,label='Prediction',color=col_code['Prediction'])
  plt.plot(act,label='Ground Truth',color=col_code['Ground Truth'])


  plt.xlabel('Time (min)')
  plt.ylabel('BIS')
  plt.title('BIS')
  plt.legend()
  plt.show()

# %% [markdown]
# ## Queary

# %%
def np_Query(data,col_index,value):
  condition = data[:, col_index] == value
  indices = np.where(condition)[0]
  return kinz_np[indices]

# %%
kinz_np = np_Query(kinz_np,2,'Fast')
kinz_np
# Out:
# array([['001-LO', 3, 'Fast', ..., 120.7342300415039, 1084.9300537109375,
#         1.0],
#        ['001-LO', 3, 'Fast', ..., -50.20004653930664, 1345.118896484375,
#         1.0],
#        ['001-LO', 3, 'Fast', ..., -23.14031219482422, 1365.506591796875,
#         1.0],
#        ...,
#        ['079-KO', 4, 'Fast', ..., -183.87863159179688, 862.876953125,
#         1.0],
#        ['079-KO', 4, 'Fast', ..., -177.07972717285156, 834.868408203125,
#         1.0],
#        ['079-KO', 4, 'Fast', ..., -165.88893127441406, 776.75, 1.0]],
#       dtype=object)

# %% [markdown]
# # Spliting Training/Testing Subject wise

# %%
test_sub = []
train_sub = []
div_per = .55


for i in tqdm([0.0,1.0,2.0,3.0]):

  temp = np_Query(kinz_np,-1,i)

  sub_count = []
  last_elements = temp[:, 0]
  value_counts = np.unique(last_elements, return_counts=True)


  for value, count in zip(*value_counts):
      sub_count.append((value,count))

  total_sum = 0
  for item in sub_count:
      total_sum += item[1]

  percentage = total_sum*div_per

  sorted_data = sorted(sub_count, key=lambda x: x[-1])

  sum = 0
  for i in sorted_data:
    if sum < percentage:
      train_sub.append(i[0])
      sum = sum + i[1]
    else:
      test_sub.append(i[0])
      sum = sum + i[1]
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 53.73it/s]

# %%
sub_with_4 = ['051-BV', '067-MT']

# %%
train_sub.append(sub_with_4[0])
test_sub.append(sub_with_4[1])

# %%
matches = np.isin(kinz_np[:, 0], train_sub)
train_data = kinz_np[matches]
train_data.shape
# Out:
# (7842, 101)

# %%
matches = np.isin(kinz_np[:, 0], test_sub)
test_data = kinz_np[matches]
test_data.shape
# Out:
# (5577, 101)

# %% [markdown]
# # Spliting into Xtrain Xtest and ytrain and ytest

# %%
X_train  = train_data[:,4:100].astype(np.float64)
y_train = train_data[:,-1].astype(np.float64)

X_val  = test_data[:,4:100].astype(np.float64)
y_val = test_data[:,-1].astype(np.float64)

# %% [markdown]
# # Converting axis - x,y,z into single feature

# %%
X_train = X_train.reshape((X_train.shape[0], -1, 3))

X_val   = X_val.reshape((X_val.shape[0], -1, 3))

# %%
set(y_train)
# Out:
# {0.0, 1.0, 2.0, 3.0, 4.0}

# %%
set(y_val)
# Out:
# {0.0, 1.0, 2.0, 3.0, 4.0}

# %%
#
import matplotlib.pyplot as plt
def history_plot(history):
  plt.figure(figsize=(10, 5))
  plt.plot(history.history['loss'], label='Training MSE')
  plt.plot(history.history['val_loss'], label='Validation MSE')
  plt.xlabel('Epoch')
  plt.ylabel('MSE')
  plt.title('Training and Validation MSE')
  plt.legend()

# %%
# Example shape information (you'll need to adjust these based on your actual data dimensions)

n_timesteps = X_train.shape[1]     # Number of timesteps per sample
n_features = X_train.shape[2]      # Number of features per timestep

# %% [markdown]
# # Prototype Model _1

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping



model_lstm_1 = Sequential()
model_lstm_1.add(LSTM(50, input_shape=(n_timesteps, n_features)))
model_lstm_1.add(Dense(1, activation='linear'))


model_lstm_1.compile(optimizer='adam', loss='mse', metrics=['mse'])


early_stopping = EarlyStopping(monitor='val_mse', patience=5, verbose=1, mode='min', restore_best_weights=True)
history = model_lstm_1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-35b6ac5c3336> in <cell line: 17>()
#      15
#      16 early_stopping = EarlyStopping(monitor='val_mse', patience=5, verbose=1, mode='min', restore_best_weights=True)
# ---> 17 history = model_lstm_1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10, verbose=1, callbacks=[early_stopping])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 10, 3), found shape=(None, 32, 3)

# %%
history_plot(history)

# %%
eval(model_lstm_1,X_val,y_val)



pred = model_lstm_1.predict(X_val)
pred_vs_act(pred,y_val)
# Out:
# 175/175 [==============================] - 3s 10ms/step
# Test MSE: 1.3133641481399536
# Test Loss: 1.3133641481399536
# Mean Absolute Error: 0.8969386909541123
# Root Mean Squared Error: 1.1460211549416492
# R-squared Score: 0.0148967249463956
# 175/175 [==============================] - 1s 8ms/step

# %% [markdown]
# # Prototype Model _2
# Add dropout regularization

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Assuming X and y are defined and split into training and validation sets

# Define the LSTM model
model_lstm_2 = Sequential()
model_lstm_2.add(LSTM(100, return_sequences=True, input_shape=(n_timesteps, n_features)))  # 100 LSTM units
model_lstm_2.add(Dropout(0.2))  # Add dropout regularization
model_lstm_2.add(LSTM(50))  # Add another LSTM layer with 50 units
model_lstm_2.add(Dense(1, activation='linear'))


model_lstm_2.compile(optimizer='adam', loss='mse', metrics=['mse'])


early_stopping = EarlyStopping(monitor='val_mse', patience=5, verbose=1, mode='min', restore_best_weights=True)
history = model_lstm_2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 785/785 [==============================] - 41s 47ms/step - loss: 1.0228 - mse: 1.0228 - val_loss: 1.4156 - val_mse: 1.4156
# Epoch 2/100
# 785/785 [==============================] - 33s 42ms/step - loss: 0.9924 - mse: 0.9924 - val_loss: 1.5311 - val_mse: 1.5311
# Epoch 3/100
# 785/785 [==============================] - 33s 42ms/step - loss: 0.9875 - mse: 0.9875 - val_loss: 1.4554 - val_mse: 1.4554
# Epoch 4/100
# 785/785 [==============================] - 34s 44ms/step - loss: 0.9772 - mse: 0.9772 - val_loss: 1.4396 - val_mse: 1.4396
# Epoch 5/100
# 785/785 [==============================] - 34s 44ms/step - loss: 0.9417 - mse: 0.9417 - val_loss: 1.3988 - val_mse: 1.3988
# Epoch 6/100
# 785/785 [==============================] - 39s 49ms/step - loss: 0.9414 - mse: 0.9414 - val_loss: 1.5769 - val_mse: 1.5769
# Epoch 7/100
# 785/785 [==============================] - 36s 46ms/step - loss: 0.9201 - mse: 0.9201 - val_loss: 1.4475 - val_mse: 1.4475
# Epoch 8/100
# 785/785 [==============================] - 33s 42ms/step - loss: 0.9070 - mse: 0.9070 - val_loss: 1.4511 - val_mse: 1.4511
# Epoch 9/100
# 785/785 [==============================] - 34s 44ms/step - loss: 0.8924 - mse: 0.8924 - val_loss: 1.5232 - val_mse: 1.5232
# Epoch 10/100
# 785/785 [==============================] - ETA: 0s - loss: 0.8561 - mse: 0.8561Restoring model weights from the end of the best epoch: 5.
# 785/785 [==============================] - 39s 49ms/step - loss: 0.8561 - mse: 0.8561 - val_loss: 1.6982 - val_mse: 1.6982
# Epoch 10: early stopping

# %%
history_plot(history)

# %%
eval(model_lstm_2,X_val,y_val)



pred = model_lstm_2.predict(X_val)
pred_vs_act(pred,y_val)
# Out:
# 175/175 [==============================] - 4s 17ms/step
# Test MSE: 1.3987970352172852
# Test Loss: 1.3987970352172852
# Mean Absolute Error: 0.9037032083294095
# Root Mean Squared Error: 1.182707478900416
# R-squared Score: -0.049182842849639696
# 175/175 [==============================] - 3s 14ms/step

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten



model_lstm_3 = Sequential()
model_lstm_3.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))
model_lstm_3.add(MaxPooling1D(pool_size=2))
model_lstm_3.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model_lstm_3.add(MaxPooling1D(pool_size=2))
model_lstm_3.add(LSTM(100))
model_lstm_3.add(Dense(1, activation='linear'))



model_lstm_3.compile(optimizer='adam', loss='mse', metrics=['mse'])


early_stopping = EarlyStopping(monitor='val_mse', patience=5, verbose=1, mode='min', restore_best_weights=True)
history = model_lstm_3.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 785/785 [==============================] - 12s 12ms/step - loss: 1.1022 - mse: 1.1022 - val_loss: 1.3333 - val_mse: 1.3333
# Epoch 2/100
# 785/785 [==============================] - 9s 11ms/step - loss: 1.0922 - mse: 1.0922 - val_loss: 1.4175 - val_mse: 1.4175
# Epoch 3/100
# 785/785 [==============================] - 10s 12ms/step - loss: 1.0923 - mse: 1.0923 - val_loss: 1.3456 - val_mse: 1.3456
# Epoch 4/100
# 785/785 [==============================] - 9s 12ms/step - loss: 1.0875 - mse: 1.0875 - val_loss: 1.3393 - val_mse: 1.3393
# Epoch 5/100
# 785/785 [==============================] - 8s 10ms/step - loss: 1.0885 - mse: 1.0885 - val_loss: 1.3476 - val_mse: 1.3476
# Epoch 6/100
# 782/785 [============================>.] - ETA: 0s - loss: 1.0865 - mse: 1.0865Restoring model weights from the end of the best epoch: 1.
# 785/785 [==============================] - 10s 13ms/step - loss: 1.0882 - mse: 1.0882 - val_loss: 1.3392 - val_mse: 1.3392
# Epoch 6: early stopping

# %%
history_plot(history)

# %%
eval(model_lstm_3,X_val,y_val)



pred = model_lstm_3.predict(X_val)
pred_vs_act(pred,y_val)
# Out:
# 175/175 [==============================] - 1s 5ms/step
# Test MSE: 1.3333466053009033
# Test Loss: 1.3333466053009033
# Mean Absolute Error: 0.93198225306678
# Root Mean Squared Error: 1.1547059880267248
# R-squared Score: -9.056419719910558e-05
# 175/175 [==============================] - 1s 5ms/step

# %% [markdown]
# # ResNet model

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Add, GlobalAveragePooling1D, Dense
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping


def residual_block(x, filters, kernel_size, strides=1):
    y = Conv1D(filters, kernel_size, padding='same', strides=strides)(x)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Conv1D(filters, kernel_size, padding='same')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)

    if strides > 1:
        x = Conv1D(filters, 1, padding='same', strides=strides)(x)

    return Add()([x, y])

# Define the ResNet model
inputs = Input(shape=(n_timesteps, n_features))
x = Conv1D(64, 7, strides=2, padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

for _ in range(3):
    x = residual_block(x, 64, 3)

x = GlobalAveragePooling1D()(x)
outputs = (Dense(1, activation='linear'))(x)

model_resnet = Model(inputs, outputs)


model_resnet.compile(optimizer='adam', loss='mse', metrics=['mse'])

# EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_mse', patience=5, verbose=1, mode='min', restore_best_weights=True)
history = model_resnet.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=10, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 785/785 [==============================] - 17s 13ms/step - loss: 1.1400 - mse: 1.1400 - val_loss: 3.0758 - val_mse: 3.0758
# Epoch 2/100
# 785/785 [==============================] - 10s 13ms/step - loss: 0.9806 - mse: 0.9806 - val_loss: 1.5546 - val_mse: 1.5546
# Epoch 3/100
# 785/785 [==============================] - 13s 17ms/step - loss: 0.9161 - mse: 0.9161 - val_loss: 1.9290 - val_mse: 1.9290
# Epoch 4/100
# 785/785 [==============================] - 8s 11ms/step - loss: 0.8490 - mse: 0.8490 - val_loss: 1.3932 - val_mse: 1.3932
# Epoch 5/100
# 785/785 [==============================] - 10s 13ms/step - loss: 0.7921 - mse: 0.7921 - val_loss: 1.4333 - val_mse: 1.4333
# Epoch 6/100
# 785/785 [==============================] - 10s 13ms/step - loss: 0.7346 - mse: 0.7346 - val_loss: 1.6767 - val_mse: 1.6767
# Epoch 7/100
# 785/785 [==============================] - 10s 13ms/step - loss: 0.7106 - mse: 0.7106 - val_loss: 1.7522 - val_mse: 1.7522
# Epoch 8/100
# 785/785 [==============================] - 9s 11ms/step - loss: 0.6459 - mse: 0.6459 - val_loss: 1.5930 - val_mse: 1.5930
# Epoch 9/100
# 782/785 [============================>.] - ETA: 0s - loss: 0.6158 - mse: 0.6158Restoring model weights from the end of the best epoch: 4.
# 785/785 [==============================] - 11s 14ms/step - loss: 0.6156 - mse: 0.6156 - val_loss: 1.6598 - val_mse: 1.6598
# Epoch 9: early stopping

# %%
history_plot(history)

# %%
eval(model_resnet,X_val,y_val)



pred = model_resnet.predict(X_val)
pred_vs_act(pred,y_val)
# Out:
# 175/175 [==============================] - 1s 6ms/step
# Test MSE: 1.3932455778121948
# Test Loss: 1.3932455778121948
# Mean Absolute Error: 0.9345520814543068
# Root Mean Squared Error: 1.1803581806500518
# R-squared Score: -0.04501884556088953
# 175/175 [==============================] - 1s 4ms/step

# %%
pred_vs_act(np.floor(pred),act)
