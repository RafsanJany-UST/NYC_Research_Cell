# %%
! pip install pytorch

# %%
import torch
import torch.nn as nn

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flight_data = pd.read_csv("/content/EEG_HMC.csv")
flight_data.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  ...  Spectral Edge_Gamma_O2  PeakF_Gamma_O2
# 0           W               0  ...                      50              50
# 1           W               0  ...                      50              50
# 2           W               0  ...                      50              50
# 3           W               0  ...                      50              50
# 4           W               0  ...                      50              50
#
# [5 rows x 76 columns]
