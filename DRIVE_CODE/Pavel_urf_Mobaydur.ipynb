# %%
some = input("Enter a fab name: ")
# Out:
# Enter a fab name: rafssan jany

# %%
an jany
# Out:
# 'rafssan jany'

# %%
some[0:4]
# Out:
# 'rafs'

# %%
some[4:12]
# Out:
# 'san jany'

# %%
fixed = some[0:4]+some[5:12]

# %%
# Out:
# 'rafsan jany'

# %%
a= int(input())
b = int(input())


if (a>b):

  c = a+b
  print(a," is greater than ",b)
  print(c)



else:
  print(b," is greater than ",a)
# Out:
# 13
# 15
# 15  is greater than  13

# %%
a is greater b            (a>b)
a is less b               (a<b)
a is greater equal b      (a>=b)
a is less equal b         (a<=b)
a is equal b              (a==b)
a is not equal b          (a!=b)
