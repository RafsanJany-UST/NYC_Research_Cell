# %% [markdown]
# [Dataset](https://physionet.org/content/hmc-sleep-staging/1.0.0/)

# %% [markdown]
# https://notebook.community/mne-tools/mne-tools.github.io/dev/_downloads/e6b765a72099a336669c021aac76fd0a/plot_sleep
#
#
# https://github.com/paulvangentcom/heartrate_analysis_python/blob/master/examples/5_noisy_ECG/Analysing_Noisy_ECG.ipynb
#
#
# https://github.com/ankur219/ECG-Arrhythmia-classification
#
#
# https://github.com/MousaviSajad/SleepEEGNet
#
#
# https://github.com/akaraspt/deepsleepnet
#
#
#
#
# https://github.com/JunetaeKim/DWT-HPI
#
#
# https://github.com/NingXJ1999/GraphSleepNet
#
#
#
# https://github.com/ziyujia/MSTGCN
#
#
# https://github.com/antonior92/automatic-ecg-diagnosis

# %%
# !wget -r -N -c -np https://physionet.org/files/hmc-sleep-staging/1.0.0/

# %%
# !pip install mne
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 83.5 MB/s eta 0:00:00
# ...

# %%
file_1st = "/content/physionet.org/files/hmc-sleep-staging/1.0.0/recordings/SN001.edf"
file_2nd = "/content/physionet.org/files/hmc-sleep-staging/1.0.0/recordings/SN001_sleepscoring.edf"
file_3rd = "/content/physionet.org/files/hmc-sleep-staging/1.0.0/recordings/SN001_sleepscoring.txt"

# %%
import mne

data_signal = mne.io.read_raw_edf(file_1st,stim_channel='Event marker',
                                misc=['Temp rectal'])
raw_data = data_signal.get_data()
# you can get the metadata included in the file and a list of all channels:
info = data_signal.info
channels = data.ch_names
# Out:
# Extracting EDF parameters from /content/physionet.org/files/hmc-sleep-staging/1.0.0/recordings/SN001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
channels
# Out:
# ['EEG F4-M1',
#  'EEG C4-M1',
#  'EEG O2-M1',
#  'EEG C3-M2',
#  'EMG chin',
#  'EOG E1-M2',
#  'EOG E2-M2',
#  'ECG']

# %%
info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG F4-M1, EEG C4-M1, EEG O2-M1, EEG C3-M2, EMG chin, EOG E1-M2, ...
#  chs: 8 EEG
#  custom_ref_applied: False
#  highpass: 0.2 Hz
#  lowpass: 35.0 Hz
#  meas_date: 2001-01-01 23:59:30 UTC
#  nchan: 8
#  projs: []
#  sfreq: 256.0 Hz
# >

# %%
# %matplotlib inline

# %%
data_signal.plot(start=10, duration=10,
               scalings=dict(eeg=1e-4, resp=1e3, eog=1e-4, emg=1e-7,
                            misc=1e-1))
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
filt_raw=data_signal.copy().filter(l_freq=1., h_freq=None)
