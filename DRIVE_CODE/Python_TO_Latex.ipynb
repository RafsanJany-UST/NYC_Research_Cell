# %% [markdown]
# #Table

# %% [markdown]
# \begin{table}[ht]
# \caption{Nonlinear Model Results} % title of Table
# \centering % used for centering table
# \begin{tabular}{c c c c} % centered columns (4 columns)
# \hline\hline %inserts double horizontal lines
# Sleep Stage\ & Number Of Rows\\ [0.5ex] % inserts table
# %heading
# \hline % inserts single horizontal line
# W & 19355  \\ % inserting body of the table
# N1 & 11913  \\
# N2 & 39428 \\
# N3 & 21290 \\
# R & 16480  \\ [1ex] % [1ex] adds vertical space
# \hline %inserts single line
# \end{tabular}
# \label{table:nonlin} % is used to refer this table in the text
# \end{table}

# %% [markdown]
# \begin{figure}[H]
#     \hspace*{-0.4cm}
#      \includegraphics[width=1.1\linewidth,height=.45\linewidth,clip, trim = 0 3 70 3,]{Figures/RF_XG__67__KNN.png}
#     \caption{Accurate- RFF,XG; Prediction- KNN; Row Number-67}
#     \label{fig:RF_XG-KNN}
# \end{figure}
