# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("/content/drive/MyDrive/Iqram Sir/KOA_EMG_WOMAC__2022.08.08_Final.csv")

# %%
dataset.head(10)
# Out:
#    Patient ID Bone-Attribution  WOMAC_Pain WOMAC_Pain Grade  WOMAC_Stiffness  \
# 0       10193                X           8         Moderate                2
# 1       10193                X          10         Moderate                3
# 2       11407                O           7             Mild                4
# 3       11407                O           6             Mild                4
# 4       12435                X           4             Mild                2
# 5       12435                O          10         Moderate                4
# 6       12521                X           7             Mild                0
# 7       12521                X           6             Mild                2
# 8       12687                X          20           Severe                7
# 9       12687                X          20           Severe                7
#
#   WOMAC_Stiffness Grade  WOMAC_Physical function  \
# 0                  Mild                       30
# 1                  Mild                       29
# 2              Moderate                       31
# 3              Moderate                       31
# 4                  Mild                       17
# 5              Moderate                       33
# 6                  Mild                       12
# 7                  Mild                       45
# 8                Severe                       47
# 9                Severe                       47
#
#   WOMAC_MHhysical function Grade  WOMAC_total WOMAC Severity  ...    TA-G-100  \
# 0                       Moderate           40       Moderate  ...  234.689409
# 1                       Moderate           42       Moderate  ...  130.854095
# 2                       Moderate           42       Moderate  ...  109.781099
# 3                       Moderate           41       Moderate  ...  117.902928
# 4                           Mild           23           Mild  ...   76.648348
# 5                       Moderate           47       Moderate  ...   44.685556
# 6                           Mild           19           Mild  ...   65.433386
# 7                       Moderate           53       Moderate  ...  169.644154
# 8                       Moderate           74         Severe  ...  144.402551
# 9                       Moderate           74         Severe  ...  107.222917
#
#   Stance_CCI_TA-RF  Stance_CCI_G-MH Stance_CCI_TA-G Swing_CCI_TA-RF  \
# 0       115.016739        82.560104      129.779021      212.427472
# 1        80.799114       118.800065       87.596328      120.058278
# 2        64.522568       185.837798       53.250781      118.951867
# 3       157.259039       213.969267      126.550560      134.834096
# 4       158.726742       198.202890       94.353370      135.926913
# 5       147.257611        72.130138      197.046837       48.532762
# 6        86.971580       107.723821      106.343048       93.422362
# 7       112.746870       109.750454      131.151480      156.402708
# 8       223.637121       142.868454      166.702324      155.574614
# 9       139.496753       123.489941      101.890803      118.112704
#
#   Swing_CCI_G-MH  Swing_CCI_TA-G  swing/stance_cci(TA_RF)  \
# 0      35.934817      266.326016                 1.846927
# 1     131.061267      145.432434                 1.485886
# 2     119.206854      144.415087                 1.843570
# 3     168.262739      117.370956                 0.857401
# 4      82.676272       83.944362                 0.856358
# 5      29.851684       80.509844                 0.329577
# 6      64.138358      128.642708                 1.074171
# 7      68.811402      170.867378                 1.387202
# 8     109.404210      155.958741                 0.695656
# 9     102.404559      106.992896                 0.846706
#
#    swing/stance_cci(G-MH)  swing/stance_CCI(TA-G)
# 0                0.435256                2.052150
# 1                1.103209                1.660257
# 2                0.641456                2.711981
# 3                0.786387                0.927463
# 4                0.417129                0.889681
# 5                0.413859                0.408582
# 6                0.595396                1.209696
# 7                0.626981                1.302825
# 8                0.765769                0.935552
# 9                0.829254                1.050074
#
# [10 rows x 811 columns]

# %%
'''from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset.iloc[:, 1]=encoder.fit_transform(dataset.iloc[:, 1])'''
# Out:
# 'from sklearn.preprocessing import LabelEncoder\nencoder=LabelEncoder()\ndataset.iloc[:, 1]=encoder.fit_transform(dataset.iloc[:, 1])'

# %%
X = dataset.iloc[:, 16:]
y=dataset[['WOMAC_total']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=16)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)



from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0551d9244e65> in <module>()
#       9
#      10 from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# ---> 11 print(confusion_matrix(y_test, y_pred))
#      12 print(classification_report(y_test,y_pred))
#      13 print("Accurecy: ",accuracy_score(y_test, y_pred))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
