# %%
import pandas as pd
import numpy as np

data = 'https://raw.githubusercontent.com/RafsanJany-44/Thesis_Project/main/All_DATA/without_sn_and_Epoch/EEG_HMC.csv'
dataset = pd.read_csv(data)
X = dataset.iloc[:, 1:]
y = dataset.iloc[:, 0]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((72662, 75), (35789, 75))

# %%
print(X_test.shape[0])
# Out:
# 35789

# %%
X_train2=X_train
X_test2=X_test

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train =sc.fit_transform(X_train)

X_test =sc.fit_transform(X_test)


X_train = pd.DataFrame(X_train, index=X_train2.index, columns=X_train2.columns)
X_test = pd.DataFrame(X_test, index=X_test2.index, columns=X_test2.columns)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_class = KNeighborsClassifier(n_neighbors=7)
KNN_class.fit(X_train, y_train)
y_pred_KNN=KNN_class.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=125, random_state=0)
classifier.fit(X_train, y_train)
y_pred_RF=classifier.predict(X_test)

# %%
import xgboost as xgb
xgb_classifier = xgb.XGBClassifier(max_depth=14)
xgb_classifier.fit(X_train,y_train)
y_pred_XG = xgb_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("Accurecy KNN: ",accuracy_score(y_test, y_pred_KNN))
print("Accurecy RF: ",accuracy_score(y_test, y_pred_RF))
print("Accurecy XG: ",accuracy_score(y_test, y_pred_XG))
# Out:
# Accurecy KNN:  0.7467657660174915
# Accurecy RF:  0.7600380005029478
# Accurecy XG:  0.7751543770432255

# %% [markdown]
# **Row wise comparision**

# %%
from tqdm import tqdm
all=[]
none=[]
onlyRF=[]
onlyXG=[]
onlyKNN=[]

RFKNN=[]
RFXG=[]
KNNXG=[]
'''X_test.shape[0]'''

for i in tqdm(range(0,X_test.shape[0])):
  print("For:",i)
  ex_specie = np.array(X_test.iloc[i]).reshape(1,-1)
  knn=KNN_class.predict(ex_specie)[0]
  rf=classifier.predict(ex_specie)[0]
  xg=xgb_classifier.predict(X_test.iloc[[i]])[0]
  y=y_test.iloc[i]
  print("Prediction for KNN: ",knn)
  print("Prediction for RF: ",rf)
  print("Prediction for XG: ",xg)
  print("           Actual: ",y)
  
  if y==knn and y==rf and y==xg:
    all.append(i)
  
  elif y==knn and y!=rf and y!=xg:
    onlyKNN.append(i)
  
  elif y!=knn and y==rf and y!=xg:
    onlyRF.append(i)
  
  elif y!=knn and y!= rf and y==xg:
    onlyXG.append(i)
  
  elif y==knn and y==rf and y!=xg:
    RFKNN.append(i)
  
  elif y!=knn and y==rf and y==xg:
    RFXG.append(i)
  
  elif y==knn and y!=rf and y==xg:
    KNNXG.append(i)
  
  else:
    none.append(i)

dict={
    'all':all,
'none':none,
'onlyRF':onlyRF,
'onlyXG':onlyXG,
'onlyKNN':onlyKNN,

'RFKNN':RFKNN,
'RFXG':RFXG,
'KNNXG':KNNXG

    
}

# %%
for i in dict:
  print(i,":",dict[i])
  print("Length: ",len(dict[i]))
  print("Percent: ",len(dict[i])/1000)
# Out:
# all : [1, 2, 3, 9, 10, 11, 14, 15, 17, 20, 21, 24, 26, 27, 29, 30, 31, 34, 35, 36, 39, 41, 42, 45, 46, 50, 51, 52, 53, 54, 55, 59, 60, 61, 63, 64, 65, 66, 69, 70, 71, 73, 74, 75, 76, 80, 81, 82, 85, 86, 87, 90, 91, 93, 94, 97, 98, 102, 105, 106, 109, 111, 113, 115, 117, 121, 124, 125, 126, 127, 128, 130, 131, 132, 133, 136, 137, 138, 139, 140, 142, 143, 144, 145, 146, 147, 
# Length:  625
# Percent:  0.625
# none : [4, 7, 12, 22, 32, 38, 44, 58, 77, 83, 96, 101, 103, 114, 118, 123, 129, 134, 135, 151, 158, 171, 176, 183, 192, 193, 198, 199, 206, 210, 227, 234, 252, 256, 257, 262, 271, 280, 311, 312, 314, 319, 324, 329, 369, 377, 399, 401, 414, 418, 422, 426, 430, 436, 442, 448, 456, 469, 472, 473, 474, 476, 482, 484, 487, 489, 492, 498, 501, 503, 506, 507, 515, 548, 557, 576, 582, 592, 623, 631, 652, 671, 677, 685, 689, 698, 705, 707, 711, 716, 719, 722, 729, 731, 742, 748, 750, 752, 755, 760, 772, 787, 788, 790, 793, 795, 803, 825, 829, 832, 833, 837, 855, 865, 869, 888, 908, 913, 919, 925, 965, 981, 991, 992, 995]
# Length:  125
# Percent:  0.125
# onlyRF : [57, 108, 217, 220, 267, 285, 342, 543, 574, 583, 589, 621, 732, 853, 924]
# Length:  15
# Percent:  0.015
# onlyXG : [13, 25, 56, 99, 164, 184, 233, 307, 348, 358, 362, 397, 439, 460, 500, 575, 626, 727, 776, 819, 867, 883, 951, 979, 989]
# Length:  25
# Percent:  0.025
# onlyKNN : [0, 5, 28, 43, 47, 48, 79, 95, 100, 104, 110, 120, 141, 150, 173, 175, 187, 240, 247, 255, 258, 265, 270, 338, 355, 363, 376, 404, 409, 410, 413, 420, 467, 471, 493, 524, 536, 550, 561, 570, 598, 639, 645, 660, 670, 713, 737, 741, 761, 789, 800, 830, 862, 863, 872, 879, 887, 900, 906, 909, 920, 933, 961, 969]
# Length:  64
# Percent:  0.064
# RFKNN : [8, 33, 37, 112, 190, 208, 218, 237, 239, 269, 286, 345, 353, 359, 360, 423, 571, 610, 629, 653, 658, 666, 694, 783, 936]
# Length:  25
# Percent:  0.025
# RFXG : [6, 16, 18, 19, 23, 40, 49, 62, 67, 68, 78, 84, 89, 92, 107, 116, 119, 122, 149, 178, 180, 189, 201, 211, 221, 259, 281, 287, 289, 296, 310, 326, 336, 356, 364, 408, 415, 450, 454, 462, 481, 485, 490, 496, 497, 512, 517, 526, 531, 532, 533, 537, 553, 563, 567, 569, 594, 595, 601, 609, 615, 618, 632, 637, 644, 647, 649, 651, 661, 663, 667, 672, 675, 688, 704, 706, 710, 715, 743, 770, 775, 779, 780, 804, 814, 820, 821, 826, 838, 847, 852, 886, 931, 957, 964, 980, 986]
# Length:  97
# Percent:  0.097
# KNNXG : [72, 88, 228, 249, 297, 361, 398, 400, 416, 424, 511, 586, 603, 665, 701, 724, 725, 774, 782, 792, 824, 895, 966, 996]
# Length:  24
# Percent:  0.024

# %%
dict
# Out:
# dict
