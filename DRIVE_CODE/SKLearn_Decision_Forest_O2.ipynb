# %%
import pandas as pd
import numpy as np

# %%
data = 'https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM_O2.csv'

dataset = pd.read_csv(data)

# %%
dataset.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_O2  MedianF_Alpha_O2  MeanF_Alpha_O2  \
# 0        NREM         0.00023          10.61463        18.48195
# 1        NREM         0.00023          10.36488        18.10732
# 2        NREM         0.00025           9.74049        17.35805
# 3        NREM         0.00027           9.49073        17.60780
# 4        NREM         0.00036           9.24098        16.48390
#
#    Spectral Edge_Alpha_O2  PeakF_Alpha_O2  MeanP_Beta_O2  MedianF_Beta_O2  \
# 0                17.98244        10.73951        0.00034         18.23220
# 1                17.48293        10.24000        0.00032         18.10732
# 2                16.73366         9.86537        0.00031         17.23317
# 3                16.85854         8.11707        0.00033         17.73268
# 4                15.98439         8.11707        0.00039         15.98439
#
#    MeanF_Beta_O2  Spectral Edge_Beta_O2  ...  MeanP_Delta_O2  \
# 0       25.84976               28.47220  ...         0.00112
# ...

# %%
X = dataset.iloc[:, 1:76].values
y = dataset.iloc[:, 0].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((59694, 25), (29402, 25))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train =sc.fit_transform(X_train)

X_test =sc.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=20, random_state=0)
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)

# %%
from re import match
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,multilabel_confusion_matrix,ConfusionMatrixDisplay

def multi_accurecy(mat):
  acu=[]
  for i in mat:
    tp=i[0][0]
    fp=i[0][1]
    fn=i[1][0]
    tn=i[1][1]
    a=(tp+tn)/(tp+fn+tn+fn)
    acu.append(a)
  return acu


print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred,normalize=False))

print(multilabel_confusion_matrix(y_test,y_pred))
cm=multilabel_confusion_matrix(y_test,y_pred,labels=clf.classes_)
mat=multilabel_confusion_matrix(y_test,y_pred)

acureccy=multi_accurecy(mat)

print("Accurecy for NREM: ",acureccy[0])
print("Accurecy for REM: ",acureccy[1])

disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)
disp.plot()
plt.show()
# Out:
# [[23621   309]
#  [ 4565   907]]
#               precision    recall  f1-score   support
#
#         NREM       0.84      0.99      0.91     23930
#          REM       0.75      0.17      0.27      5472
#
#     accuracy                           0.83     29402
#    macro avg       0.79      0.58      0.59     29402
# weighted avg       0.82      0.83      0.79     29402
#
# Accurecy:  24528
# [[[  907  4565]
#   [  309 23621]]
#
#  [[23621   309]
#   [ 4565   907]]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-98d7f5e007c8> in <module>()
#      22
#      23 print(multilabel_confusion_matrix(y_test,y_pred))
# ---> 24 cm=multilabel_confusion_matrix(y_test,y_pred,labels=clf.classes_)
#      25 mat=multilabel_confusion_matrix(y_test,y_pred)
#      26
#
# AttributeError: 'SVC' object has no attribute 'classes_'

# %%
acu=[]
for i in mat:
  tp=i[0][0]
  fp=i[0][1]
  fn=i[1][0]
  tn=i[1][1]
  a=(tp)/(tp+fp)
  print(a)
  acu.append(a)
# Out:
# 0.16575292397660818
# 0.987087338069369
