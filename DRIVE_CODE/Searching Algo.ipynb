# %%
def graph(dict):
  import networkx as nx
  import matplotlib.pyplot as plt
  talika=[]
  for i in dict:
    a = ()
    for x in dict[i]:
        l = list(a)
        l.append(i)
        l.append(x)
        talika.append(tuple(l))
  G = nx.DiGraph()
  G.add_edges_from(talika)

  pos = nx.spring_layout(G)
  nx.draw_networkx_nodes(G, pos, cmap=plt.get_cmap('jet'), 
                        node_color = 'green', node_size = 1000)
  nx.draw_networkx_labels(G, pos)
  nx.draw_networkx_edges(G, pos,  arrows=True)
  nx.draw_networkx_edges(G, pos,  arrows=True)
  plt.show()

# %% [markdown]
# #Breadth First Search

# %%
dict={
    'A':['B','C'],
    'D':['B'],
    'E':['C','F'],
    'B':['H','G','F'],
    'C':['G'],
    'Z':["H"]
}

dict2={
    '0':['11','7','9'],
    '1':['10','8'],
    '2':['12','2'],
    '3':['2','7','4'],
    '4':[],
    '5':[],
    '6':['7','5'],
    '7':['0','11','3','6'],
    '8':['9','1','12'],
    '9':['8','10','0'],
    '10':['1','10'],
    '11':['0','7']
}

dict3={
    'a':['b','c'],
    'b':['d','e'],
    'c':['f','g'],
    'f':['k'],
    'g':[],
    'k':['l'],
    'd':['h','i'],
    'e':['j']
}


graph(dict3)

# %%
def BFS(dict,value):
  values=list(dict.keys())
  que=[values[0]]
  v=[]
  i=0

  while(True):
    if(que[i] not in values):
      break
    temp=dict[que[i]]
    for j in temp:
      if (j not in que):
        que.append(j)
    v.append(que[i])
    
    i+=1
    print("Que: ",que)
    print("Vis: ",v)
    print("\n")
BFS(dict3,6)
# Out:
# Que:  ['a', 'b', 'c']
# Vis:  ['a']
#
#
# Que:  ['a', 'b', 'c', 'd', 'e']
# Vis:  ['a', 'b']
#
#
# Que:  ['a', 'b', 'c', 'd', 'e', 'f', 'g']
# Vis:  ['a', 'b', 'c']
#
#
# Que:  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']
# Vis:  ['a', 'b', 'c', 'd']
#
#
# Que:  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Vis:  ['a', 'b', 'c', 'd', 'e']
#
#
# Que:  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
# Vis:  ['a', 'b', 'c', 'd', 'e', 'f']
#
#
# Que:  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
# Vis:  ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %% [markdown]
# #Depth First Search

# %%
dict3={
    'a':['b','c'],
    'b':['d','e'],
    'c':['f','g'],
    'f':['k'],
    'k':['l'],
    'd':['h','i'],
    'e':['j']
}


temp1= parent;

parent.append()

temp= childe;


def DFS(dict,value):
  values=list(dict.keys())
  que=[values[0]]
  v=[]
  i=0

  while(True):
    if(que[i] not in values):
      break
    temp=dict[que[i]]
    for j in temp:
      if (j not in que):
        que.append(j)
    v.append(que[i])
    
    i+=1
    print("Que: ",que)
    print("Vis: ",v)
    print("\n")
BFS(dict3,6)

# %%
print("hello world 1")
print("hello world 2")
print("hello world 3")
print("hello world 4")
print("hello world 5") asdfas 
print("hello world 6")
# Out:
#   File "<ipython-input-4-0b4b9ab79dbc>", line 5
#     print("hello world 5") asdfas
#                                 ^
# SyntaxError: invalid syntax
