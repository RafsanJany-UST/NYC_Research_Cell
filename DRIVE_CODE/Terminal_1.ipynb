# %% [markdown]
# #<font color = 'coral'>Step 0: Learn the usage of the tools.</font>
# Suggested: Learning the internal architecture of a machine learning algorithm is mendatory. But not in first.

# %% [markdown]
# #<font color = 'coral'>Step 0.1: Start with Classification Problem and Tabuler Dataset.</font>
# Kaggle could be a good sourch for dataset.

# %% [markdown]
# #<font color = 'coral'>Step 1: Start learning two libraries: 1. numpy 2.pandas</font>
# numpy and pandas are very basic libraries for data science.

# %% [markdown]
# #<font color = 'coral'>Step 2: Leearn to read csv/excel/json dataset.</font>

# %% [markdown]
# #<font color = 'coral'>Step 3: Learn Data Preprocessing.</font>
# Sometimes it is called Exploratory Data Analysis (EDA)

# %% [markdown]
# ##<font color = 'coral'>Step 3.1: Null value manipulation.</font>

# %% [markdown]
# ##<font color = 'coral'>Step 3.2: Encoding.</font>
# Object(str,char) -> int64, float64

# %% [markdown]
# ##<font color = 'coral'>Step 3.3: Balancing.</font>
# You can start with `imbalanced-learn` library.
# SMOTE is a popular method.

# %% [markdown]
# ##<font color = 'coral'>Step 3.3: Scaling.</font>
# 1. StandardScaler
# 2. MinMaxScaler

# %% [markdown]
# ##<font color = 'coral'>Step 3.4: Feature Selection.</font>
# 1. Filter Method
# 2. Pearson
# 3. ANOVA
# 4. Wrapper
# 5. Embedded
# 6. Permutation Importance<br>
# etc.

# %% [markdown]
# ##<font color = 'coral'>Step 3.5: Splitting.</font>
#
# X -> Features (Inputs)<br>
# y -> Target (Outputs)<br>
# <br>
# Train set -> X_train, y_train<br>
# Test set -> X_test, y_test

# %% [markdown]
# #<font color = 'coral'>Step 4: Implement Machine Learning Models.</font>
# 1. Decision Tree
# 2. Random Forest
# 3. KNN
# 4. Naive Bayes
# 5. Support Vector Machine
# 6. Bossting Algorithms<br>
# etc.<br>
#
# **Note**: `sklearn` library will provide most of the algorithms. This library is very impactful tool for machine learning.

# %% [markdown]
# ##<font color = 'coral'>Step 4.1: Model Training</font>

# %% [markdown]
# ##<font color = 'coral'>Step 4.2: Hyperparameter Tunning</font>
# 1. Grid First Search
# 2. Random First Search
# 3. Brute Force

# %% [markdown]
# ##<font color = 'coral'>Step 4.3: Cross Validation</font>

# %% [markdown]
# ##<font color = 'coral'>Step 4.1: Model Testing/Evaluation </font>

# %% [markdown]
# #<font color = 'coral'>Step 5: Result Visualization.</font>

# %% [markdown]
# ##<font color = 'coral'>Step 5.1: Confusion Matrix.</font>

# %% [markdown]
# ##<font color = 'coral'>Step 5.2: ROC/AUC Curve.</font>

# %% [markdown]
# #<font color = 'coral'>Step 6: Explainable AI (XAI).</font>
# 1. LIME
# 2. SHAPE
# 3. Accumulated Local Effects (ALE)
# 4. Contrastive Explanation Method (CEM)

# %% [markdown]
# #<font color = 'coral'>Step 7: Alwayes Be Passionate About <font size='7' color ='red'>**Exploration.**</font>
#
# **<font color='red'>Cause there is <font size='7'> No Ending Step.**
