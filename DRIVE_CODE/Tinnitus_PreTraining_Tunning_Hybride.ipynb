# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Function

# %%
# !pip install imbalanced-learn
# !pip install ipywidgets

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
import ipywidgets as widgets
from joblib import Parallel, delayed
from google.colab import files
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


def dataset_balance(X_temp, y_temp):
  smote = SMOTE()
  X_temp, y_temp= smote.fit_resample(X_temp, y_temp)
  return pd.concat([pd.DataFrame(X_temp), pd.DataFrame(y_temp)], axis=1)


def Xy_balance(X_temp, y_temp):
  smote = SMOTE()
  return smote.fit_resample(X_temp, y_temp)


def save_model(model,model_name):
 joblib.dump(model, model_name)
  

def load_model(model_name):
  return joblib.load(model_name)


def Search_Null(dataset):
  dic={}
  for col in list(dataset.columns):
    rows = []
    flage = 0
    for row in range(dataset.shape[0]):
      if str(dataset[col][row]) == "nan":
        rows.append(row)
        flage = 1
    if flage ==1:
      dic[col] = rows
  return dic



def divide_dataset(dataset,percentage,random_state = 0):
  rows,cols = dataset.shape
  if random_state == 0:
    return dataset.iloc[:int(rows*(percentage)),:]
  else:
    import random
    l_r = random.sample(range(0, rows), int(rows*(percentage)))
    return dataset.iloc[l_r,:]



def StandardScaleData(data):
  scaler = StandardScaler()
  scaler.fit(data)
  return  scaler.transform(data)



def MinMaxScaleData(data):
  scaler = MinMaxScaler()
  scaler.fit(data)
  return scaler.transform(data)


def tune_report_csv(model,dic,feat_selection_method,number_of_feat):

  tunning_type = []
  accuracy = []
  scaled_accuracy = []
  model_name = []
  feature_selection_method = []
  number_of_features = []

  li = ["Smote : NO    ; Scaling : Train(Standard)",
      "Smote : NO    ; Scaling : Train(MinMax)",
      "Smote : Train ; Scaling : Train(Standard)",
      "Smote : Train ; Scaling : Train(MinMax)",
      "Smote : All   ; Scaling : Train(Standard)",
      "Smote : All   ; Scaling : Train(MinMax)"]

  for i in list(dic.keys()):
    X_train, X_test, y_train, y_test = dic[i]
    
    if i in li and str(model[:3]) == "xgb":
      model.fit(X_train,y_train.values)
      y_pred = model.predict(X_test.values)
    else:
      model.fit(X_train,y_train)
      y_pred = model.predict(X_test)

    accu =accuracy_score(y_test, y_pred)
    scaled_accu =  float("{:.2f}".format(accu))
    print(i)
    print("Accurecy: ",scaled_accu)
    tunning_type.append(i)
    accuracy.append(accu)
    scaled_accuracy.append(scaled_accu)
    model_name.append(model)
    feature_selection_method.append(feat_selection_method)
    number_of_features.append(number_of_feat)
    
    print("------------------------------------------------------------------------------")
    print("------------------------------------------------------------------------------")

  csv_dic={
      "model_name"  : model_name,
      "tunning_type" : tunning_type,
      "accurecy"    : accuracy, 
      "scaled_accuracy" :scaled_accuracy,
      "feature_selection_method" : feature_selection_method,
      "number_of_features" : number_of_features
  }


  df = pd.DataFrame.from_dict(csv_dic)
  df.to_csv("/content/drive/MyDrive/Sleep Stage 5 class/Features_selection_result/"+feat_selection_method+"_"+str(number_of_feat)+"_"+str(model)+".csv",index = False)
  return "Tunning Data Report is Secured for this phase!!!"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (7.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.6.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.1 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (5.7.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.3)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.11.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.2.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.16.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.6.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (22.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.12.0)
# Installing collected packages: jedi
# Successfully installed jedi-0.18.2

# %% [markdown]
# #Starting

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Sleep Stage 5 class/EEG_HMC_FeatureExtraction_2023.01.19.csv")
print(dataset.shape)
dataset.dropna(axis = 0,how='any', inplace = True)
dataset = dataset.reset_index(drop = True)
"""df.to_csv("New_EEG_NullValueRemoved_HMC.csv",index = False)
dataset = pd.read_csv("New_EEG_NullValueRemoved_HMC.csv")"""
target = "Sleep Stage"
result = {}
print(dataset.shape)

#Encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset[target]=encoder.fit_transform(dataset[target])

#dataset = divide_dataset(dataset,0.04611,1)
#print(dataset.shape)
# Out:
# (108920, 52)
# (108450, 52)

# %% [markdown]
# ###Spliting into X and y

# %%
X =  dataset.loc[:,dataset.columns != target]  # removing Sleep Stage
X =  X.loc[:,X.columns != "Subject"]            # removing Status
X =  X.loc[:,X.columns != "Epoch"]             # removing Epoch
y = dataset[target]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108450 entries, 0 to 108449
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MeanP_Alpha_F4           108450 non-null  float64
#  1   MeanP_Beta_F4            108450 non-null  float64
#  2   MeanP_Theta_F4           108450 non-null  float64
#  3   MeanP_Delta_F4           108450 non-null  float64
#  4   MeanP_Gamma_F4           108450 non-null  float64
#  5   MeanP_Alpha_C4           108450 non-null  float64
#  6   MeanP_Beta_C4            108450 non-null  float64
#  7   MeanP_Theta_C4           108450 non-null  float64
#  8   MeanP_Delta_C4           108450 non-null  float64
#  9   MeanP_Gamma_C4           108450 non-null  float64
#  10  MeanP_Alpha_O2           108450 non-null  float64
#  11  MeanP_Beta_O2            108450 non-null  float64
#  12  MeanP_Theta_O2           108450 non-null  float64
#  13  MeanP_Delta_O2           108450 non-null  float64
#  14  MeanP_Gamma_O2           108450 non-null  float64
#  15  Total_P_F4               108450 non-null  float64
#  16  Total_P_C4               108450 non-null  float64
#  17  Total_P_O2               108450 non-null  float64
#  18  Relative_MeanP_Alpha_F4  108450 non-null  float64
#  19  Relative_MeanP_Beta_F4   108450 non-null  float64
#  20  Relative_MeanP_Theta_F4  108450 non-null  float64
#  21  Relative_MeanP_Delta_F4  108450 non-null  float64
#  22  Relative_MeanP_Gamma_F4  108450 non-null  float64
#  23  Relative_MeanP_Alpha_C4  108450 non-null  float64
#  24  Relative_MeanP_Beta_C4   108450 non-null  float64
#  25  Relative_MeanP_Theta_C4  108450 non-null  float64
#  26  Relative_MeanP_Delta_C4  108450 non-null  float64
#  27  Relative_MeanP_Gamma_C4  108450 non-null  float64
#  28  Relative_MeanP_Alpha_O2  108450 non-null  float64
#  29  Relative_MeanP_Beta_O2   108450 non-null  float64
#  30  Relative_MeanP_Theta_O2  108450 non-null  float64
#  31  Relative_MeanP_Delta_O2  108450 non-null  float64
#  32  Relative_MeanP_Gamma_O2  108450 non-null  float64
#  33  Relative_MeanP_Alpha_G   108450 non-null  float64
#  34  Relative_MeanP_Beta_G    108450 non-null  float64
#  35  Relative_MeanP_Theta_G   108450 non-null  float64
#  36  Relative_MeanP_Delta_G   108450 non-null  float64
#  37  Relative_MeanP_Gamma_G   108450 non-null  float64
#  38  DAR_F4                   108450 non-null  float64
#  39  DAR_C4                   108450 non-null  float64
#  40  DAR_O2                   108450 non-null  float64
#  41  DAR_G                    108450 non-null  float64
#  42  DTR_F4                   108450 non-null  float64
#  43  DTR_O2                   108450 non-null  float64
#  44  DTABR_F4                 108450 non-null  float64
#  45  DTABR_C4                 108450 non-null  float64
#  46  DTABR_O2                 108450 non-null  float64
#  47  DTABR_G                  108450 non-null  float64
#  48  P_G                      108450 non-null  float64
# dtypes: float64(49)
# memory usage: 40.5 MB

# %% [markdown]
# #Feature Selection

# %%
number_of_feat = 35

# %% [markdown]
# ###ANOVA with f classifciation

# %%
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import pandas as pd



fs = SelectKBest(score_func=f_classif, k=5)
fit = fs.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_ANOVA'] 

lyst = featureScores.nlargest(number_of_feat,'Score_ANOVA')

#lyst.to_csv('Filter_Method_ANOVA_with_f_classif.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "ANOVA"

# %% [markdown]
# ###Embedded Method

# %%
from sklearn.linear_model import LassoCV
reg = LassoCV()
reg.fit(X, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,y))
coef = pd.Series(reg.coef_, index = X.columns)

print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")

imp_coef = coef.sort_values()

list_of_feat=[]


for i in range(coef.shape[0]):
  if coef[i]!=0:
    list_of_feat.append(dataset.iloc[:0,i+3].name)
    
df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Embedded_Method.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]
selection_method = "Embedded"
# Out:
# Best alpha using built-in LassoCV: 1664496.378245
# Best score using built-in LassoCV: 0.000418
# Lasso picked 4 variables and eliminated the other 45 variables

# %% [markdown]
# ###Pearson's with f regression

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
import pandas as pd


fs = SelectKBest(score_func=f_regression, k=5)
fit = fs.fit(X,y)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_pearsons'] 


lyst = featureScores.nlargest(number_of_feat,'Score_pearsons')

#lyst.to_csv('Filter_Method_Pearson’s_with_f_regression.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "Pearson"

# %% [markdown]
# ###Sequential Feature Selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
sfs = SequentialFeatureSelector(knn, n_features_to_select=number_of_feat)
sfs.fit(X, y)
list_of_feat=[]
list_of_feat=list(sfs.get_feature_names_out(X.columns))

df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Filter_Method_Sequential_feat_Selection_KNN.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]

selection_method = "Sequential"

# %% [markdown]
# #Feature list

# %%
list_of_feat2=[   
'p2_gap_peak_amp_50ms',
'p2n2_gap_diff_20ms',
'p2n2_gap_diff_50ms',
'p2n2_interval_gap_50ms',
'n2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_by_total_20ms',
'n1_gap_peak_ms_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'n1p2_gap_no_gap_ratio_50ms',
'gap_auc_p2n2_UP_20ms',
'gap_auc_p2n2_UP_50ms',
'n2_gap_peak_ms_50ms',
'gap_auc_n1p2n2_20ms',
'n1p2_gap_diff_50ms',
'gap_auc_total_abs_20ms',
'n1_gap_peak_ms_50ms',
'n1p2_gap_no_gap_ratio_20ms',
'alpha_peak_auc_50ms',
'gamma_peak_freq_50ms',
'ABR_peak_auc_50ms'
    ]

print(len(list_of_feat2))

# %%
X=dataset[list_of_feat]
y=dataset[target]
print(X.shape)
# Out:
# (108450, 40)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108450 entries, 0 to 108449
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Relative_MeanP_Beta_C4   108450 non-null  float64
#  1   Relative_MeanP_Beta_G    108450 non-null  float64
#  2   Relative_MeanP_Beta_F4   108450 non-null  float64
#  3   Relative_MeanP_Beta_O2   108450 non-null  float64
#  4   Relative_MeanP_Delta_C4  108450 non-null  float64
#  5   Relative_MeanP_Delta_G   108450 non-null  float64
#  6   Relative_MeanP_Delta_F4  108450 non-null  float64
#  7   Relative_MeanP_Alpha_C4  108450 non-null  float64
#  8   Relative_MeanP_Alpha_G   108450 non-null  float64
#  9   Relative_MeanP_Alpha_O2  108450 non-null  float64
#  10  Relative_MeanP_Delta_O2  108450 non-null  float64
#  11  Relative_MeanP_Alpha_F4  108450 non-null  float64
#  12  Relative_MeanP_Theta_C4  108450 non-null  float64
#  13  Relative_MeanP_Theta_F4  108450 non-null  float64
#  14  Relative_MeanP_Theta_G   108450 non-null  float64
#  15  Relative_MeanP_Theta_O2  108450 non-null  float64
#  16  Relative_MeanP_Gamma_F4  108450 non-null  float64
#  17  Relative_MeanP_Gamma_G   108450 non-null  float64
#  18  Relative_MeanP_Gamma_C4  108450 non-null  float64
#  19  MeanP_Delta_O2           108450 non-null  float64
#  20  Total_P_O2               108450 non-null  float64
#  21  DTR_F4                   108450 non-null  float64
#  22  MeanP_Beta_F4            108450 non-null  float64
#  23  DTR_O2                   108450 non-null  float64
#  24  MeanP_Beta_O2            108450 non-null  float64
#  25  Relative_MeanP_Gamma_O2  108450 non-null  float64
#  26  MeanP_Delta_F4           108450 non-null  float64
#  27  MeanP_Delta_C4           108450 non-null  float64
#  28  Total_P_F4               108450 non-null  float64
#  29  P_G                      108450 non-null  float64
#  30  MeanP_Alpha_O2           108450 non-null  float64
#  31  MeanP_Theta_O2           108450 non-null  float64
#  32  MeanP_Alpha_C4           108450 non-null  float64
#  33  MeanP_Alpha_F4           108450 non-null  float64
#  34  Total_P_C4               108450 non-null  float64
#  35  MeanP_Theta_C4           108450 non-null  float64
#  36  MeanP_Theta_F4           108450 non-null  float64
#  37  MeanP_Gamma_F4           108450 non-null  float64
#  38  MeanP_Beta_C4            108450 non-null  float64
#  39  MeanP_Gamma_C4           108450 non-null  float64
# dtypes: float64(40)
# memory usage: 33.1 MB

# %% [markdown]
# #Tunning for Scalling and Data Balancing

# %% [markdown]
# ##Smote : NO
# ##Scaling : NO

# %%
def tune_1():
  X_new = X
  y_new = y
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : All Data (Standard)

# %%
def tune_2():
  X_new = StandardScaleData(X)
  y_new = y
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : All Data (MinMax)

# %%
def tune_3():
  X_new = MinMaxScaleData(X)
  y_new = y
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : Train (Stadard)

# %%
def tune_4():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : NO
# ##Scaling : Train (MinMax)

# %%
def tune_5():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : ALL
# ##Scaling : NO

# %%
def tune_6():
  X_new,y_new = Xy_balance(X,y)
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : Train
# ##Scaling : NO

# %%
def tune_7():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train,y_train = Xy_balance(X_train,y_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : Train
# ##Scaling : Train (Standard)

# %%
def tune_8():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train,y_train = Xy_balance(X_train,y_train)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : Train
# ##Scaling : Train (MixMax)

# %%
def tune_9():
  X_new = X
  y_new = y
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train,y_train = Xy_balance(X_train,y_train)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : Train (Standard)

# %%
def tune_10():
  X_new,y_new = Xy_balance(X,y)
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : Train (MixMax)

# %%
def tune_11():
  X_new,y_new = Xy_balance(X,y)
  X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : All (Standard)

# %%
def tune_12():
  X_new,y_new = Xy_balance(X,y)
  X_new = StandardScaleData(X_new)
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : All
# ##Scaling : ALL (MinMax)

# %%
def tune_13():
  X_new,y_new = Xy_balance(X,y)
  X_new = MinMaxScaleData(X_new)
  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Tunn Dictionary

# %%
tune_dic={
  "Smote : NO    ; Scaling : NO"                  : tune_1(),
  "Smote : NO    ; Scaling : All Data(Standard)"  : tune_2(),
  "Smote : NO    ; Scaling : All Data(MinMax)"    : tune_3(),
  #"Smote : NO    ; Scaling : Train(Standard)"     : tune_4(),
  #"Smote : NO    ; Scaling : Train(MinMax)"       : tune_5(),
  "Smote : ALL   ; Scaling : NO"                  : tune_6(),
  "Smote : Train ; Scaling : NO"                  : tune_7(),
  #"Smote : Train ; Scaling : Train(Standard)"     : tune_8(),
  #"Smote : Train ; Scaling : Train(MinMax)"       : tune_9(),
  #"Smote : All   ; Scaling : Train(Standard)"     : tune_10(),
  #"Smote : All   ; Scaling : Train(MinMax)"       : tune_11(),
  "Smote : All   ; Scaling : All(Standard)"       : tune_12(),
  "Smote : All   ; Scaling : All(MinMax)"        : tune_13()
}

# %% [markdown]
# ---

# %% [markdown]
# # **Training**

# %% [markdown]
# ##ADABOOST

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
ada_defult = AdaBoostClassifier(random_state=0)
tune_report_csv(ada_defult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.57
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.57
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.57
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.55
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.51
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.55
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.55
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 4min 17s, sys: 295 ms, total: 4min 18s
# Wall time: 4min 19s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##Graddient Boosting

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
gradBoost_default = GradientBoostingClassifier(random_state=0)

tune_report_csv(gradBoost_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.66
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.66
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.66
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.65
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.65
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 1h 50min 58s, sys: 6.4 s, total: 1h 51min 5s
# Wall time: 1h 51min 18s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ###Histogram-Based Gradient Boosting

# %%
# %%time
from sklearn.ensemble import HistGradientBoostingClassifier

hisgradBoost_default = HistGradientBoostingClassifier(random_state=0)

tune_report_csv(hisgradBoost_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.73
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.69
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.74
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.73
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 5min 11s, sys: 2.13 s, total: 5min 13s
# Wall time: 3min 7s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##Random Forest

# %%
# %%time
RanFor={}

from sklearn.ensemble import RandomForestClassifier
rf_default = RandomForestClassifier(random_state=0,n_jobs=-1)

tune_report_csv(rf_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.73
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.73
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.71
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.81
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.8
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 16min 55s, sys: 2.64 s, total: 16min 58s
# Wall time: 9min 57s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##XGB

# %%
# %%time
import xgboost as xgb
xgb_deafult = xgb.XGBClassifier(random_state=0,n_jobs=-1)

tune_report_csv(xgb_deafult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.63
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.6
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.63
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.63
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 25min 20s, sys: 2.67 s, total: 25min 23s
# Wall time: 14min 46s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
knn_default = KNeighborsClassifier(n_jobs = -1)

tune_report_csv(knn_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.52
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.67
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.46
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.73
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.71
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 21min 54s, sys: 4min 11s, total: 26min 6s
# Wall time: 21min 59s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##NB

# %%
# %%time
from sklearn.naive_bayes import GaussianNB

nb_deafult = GaussianNB()

tune_report_csv(nb_deafult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.31
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.31
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.31
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.35
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.31
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.35
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.35
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 1.1 s, sys: 71.9 ms, total: 1.17 s
# Wall time: 1.17 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##Tree algorithms

# %% [markdown]
# ###DecisionTreeRegressor

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
tune_report_csv(dtc,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.6
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.6
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.6
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.68
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.68
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.68
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 1min 18s, sys: 83.1 ms, total: 1min 18s
# Wall time: 1min 19s
# 'Tunning Data Report is Secured for this phase!!!'

# %%
# !pip install catboost

from catboost import CatBoostClassifier
#cat = CatBoostClassifier(task_type="GPU")
cat=CatBoostClassifier()

tune_report_csv(cat,tune_dic,selection_method,number_of_feat)
# Out:
# Streaming output truncated to the last 5000 lines.
# 24:	learn: 1.0195966	total: 3.83s	remaining: 2m 29s
# 25:	learn: 1.0149120	total: 3.98s	remaining: 2m 29s
# 26:	learn: 1.0102448	total: 4.1s	remaining: 2m 27s
# 27:	learn: 1.0049223	total: 4.25s	remaining: 2m 27s
# 28:	learn: 0.9995448	total: 4.39s	remaining: 2m 26s
# 29:	learn: 0.9945229	total: 4.56s	remaining: 2m 27s
# 30:	learn: 0.9902627	total: 4.7s	remaining: 2m 26s
# 31:	learn: 0.9868405	total: 4.84s	remaining: 2m 26s
# 32:	learn: 0.9829294	total: 4.99s	remaining: 2m 26s
# 33:	learn: 0.9799206	total: 5.12s	remaining: 2m 25s
# 34:	learn: 0.9762788	total: 5.28s	remaining: 2m 25s
# 35:	learn: 0.9728637	total: 5.46s	remaining: 2m 26s
# 36:	learn: 0.9694945	total: 5.59s	remaining: 2m 25s
# 37:	learn: 0.9665745	total: 5.73s	remaining: 2m 25s
# 38:	learn: 0.9637893	total: 5.86s	remaining: 2m 24s
# 39:	learn: 0.9610681	total: 6.02s	remaining: 2m 24s
# 40:	learn: 0.9587022	total: 6.16s	remaining: 2m 24s
# 41:	learn: 0.9562439	total: 6.3s	remaining: 2m 23s
# 42:	learn: 0.9543400	total: 6.43s	remaining: 2m 23s
# 43:	learn: 0.9507821	total: 6.61s	remaining: 2m 23s
# 44:	learn: 0.9481718	total: 6.76s	remaining: 2m 23s
# 45:	learn: 0.9465363	total: 6.91s	remaining: 2m 23s
# 46:	learn: 0.9444777	total: 7.05s	remaining: 2m 23s
# 47:	learn: 0.9418417	total: 7.2s	remaining: 2m 22s
# 48:	learn: 0.9395245	total: 7.34s	remaining: 2m 22s
# 49:	learn: 0.9374260	total: 7.47s	remaining: 2m 22s
# 50:	learn: 0.9350384	total: 7.73s	remaining: 2m 23s
# 51:	learn: 0.9323519	total: 8.01s	remaining: 2m 26s
# 52:	learn: 0.9300077	total: 8.28s	remaining: 2m 27s
# 53:	learn: 0.9285545	total: 8.5s	remaining: 2m 28s
# 54:	learn: 0.9264132	total: 8.81s	remaining: 2m 31s
# 55:	learn: 0.9246056	total: 9.07s	remaining: 2m 32s
# 56:	learn: 0.9228365	total: 9.35s	remaining: 2m 34s
# 57:	learn: 0.9208822	total: 9.66s	remaining: 2m 36s
# 58:	learn: 0.9192889	total: 9.9s	remaining: 2m 37s
# 59:	learn: 0.9174541	total: 10.2s	remaining: 2m 39s
# 60:	learn: 0.9161474	total: 10.4s	remaining: 2m 40s
# 61:	learn: 0.9147159	total: 10.7s	remaining: 2m 42s
# 62:	learn: 0.9122137	total: 11.1s	remaining: 2m 44s
# 63:	learn: 0.9104882	total: 11.3s	remaining: 2m 44s
# 64:	learn: 0.9093610	total: 11.4s	remaining: 2m 43s
# 65:	learn: 0.9079274	total: 11.5s	remaining: 2m 43s
# 66:	learn: 0.9061826	total: 11.7s	remaining: 2m 42s
# 67:	learn: 0.9050413	total: 11.8s	remaining: 2m 42s
# 68:	learn: 0.9036479	total: 12s	remaining: 2m 41s
# 69:	learn: 0.9020976	total: 12.1s	remaining: 2m 41s
# 70:	learn: 0.9004032	total: 12.3s	remaining: 2m 40s
# 71:	learn: 0.8987559	total: 12.4s	remaining: 2m 40s
# 72:	learn: 0.8972688	total: 12.6s	remaining: 2m 40s
# 73:	learn: 0.8964867	total: 12.7s	remaining: 2m 39s
# 74:	learn: 0.8945609	total: 12.9s	remaining: 2m 39s
# 75:	learn: 0.8932049	total: 13s	remaining: 2m 38s
# 76:	learn: 0.8917256	total: 13.2s	remaining: 2m 38s
# 77:	learn: 0.8904057	total: 13.4s	remaining: 2m 37s
# 78:	learn: 0.8890253	total: 13.5s	remaining: 2m 37s
# 79:	learn: 0.8880481	total: 13.7s	remaining: 2m 37s
# 80:	learn: 0.8866572	total: 13.8s	remaining: 2m 37s
# 81:	learn: 0.8856451	total: 14s	remaining: 2m 36s
# 82:	learn: 0.8844846	total: 14.1s	remaining: 2m 35s
# 83:	learn: 0.8829697	total: 14.3s	remaining: 2m 35s
# 84:	learn: 0.8818423	total: 14.4s	remaining: 2m 35s
# 85:	learn: 0.8807286	total: 14.6s	remaining: 2m 35s
# 86:	learn: 0.8799544	total: 14.8s	remaining: 2m 34s
# 87:	learn: 0.8790265	total: 14.9s	remaining: 2m 34s
# 88:	learn: 0.8779417	total: 15.1s	remaining: 2m 34s
# 89:	learn: 0.8770773	total: 15.2s	remaining: 2m 33s
# 90:	learn: 0.8753882	total: 15.4s	remaining: 2m 33s
# 91:	learn: 0.8738122	total: 15.5s	remaining: 2m 33s
# 92:	learn: 0.8726676	total: 15.7s	remaining: 2m 33s
# 93:	learn: 0.8714421	total: 15.9s	remaining: 2m 32s
# 94:	learn: 0.8704292	total: 16s	remaining: 2m 32s
# 95:	learn: 0.8692698	total: 16.2s	remaining: 2m 32s
# 96:	learn: 0.8680384	total: 16.4s	remaining: 2m 32s
# 97:	learn: 0.8668193	total: 16.5s	remaining: 2m 31s
# 98:	learn: 0.8654336	total: 16.7s	remaining: 2m 31s
# 99:	learn: 0.8644216	total: 16.8s	remaining: 2m 31s
# 100:	learn: 0.8636543	total: 16.9s	remaining: 2m 30s
# 101:	learn: 0.8627022	total: 17.1s	remaining: 2m 30s
# 102:	learn: 0.8618548	total: 17.2s	remaining: 2m 30s
# 103:	learn: 0.8606136	total: 17.4s	remaining: 2m 29s
# 104:	learn: 0.8593576	total: 17.6s	remaining: 2m 29s
# 105:	learn: 0.8582583	total: 17.7s	remaining: 2m 29s
# 106:	learn: 0.8573695	total: 17.9s	remaining: 2m 29s
# 107:	learn: 0.8563749	total: 18s	remaining: 2m 29s
# 108:	learn: 0.8554042	total: 18.2s	remaining: 2m 28s
# 109:	learn: 0.8546723	total: 18.3s	remaining: 2m 28s
# 110:	learn: 0.8537482	total: 18.5s	remaining: 2m 28s
# 111:	learn: 0.8524347	total: 18.7s	remaining: 2m 27s
# 112:	learn: 0.8510629	total: 18.8s	remaining: 2m 27s
# 113:	learn: 0.8503256	total: 19s	remaining: 2m 27s
# 114:	learn: 0.8496440	total: 19.1s	remaining: 2m 27s
# 115:	learn: 0.8491584	total: 19.2s	remaining: 2m 26s
# 116:	learn: 0.8483922	total: 19.4s	remaining: 2m 26s
# 117:	learn: 0.8477835	total: 19.5s	remaining: 2m 25s
# 118:	learn: 0.8467947	total: 19.7s	remaining: 2m 25s
# 119:	learn: 0.8455383	total: 19.8s	remaining: 2m 25s
# 120:	learn: 0.8447409	total: 20s	remaining: 2m 25s
# 121:	learn: 0.8437229	total: 20.1s	remaining: 2m 24s
# 122:	learn: 0.8427801	total: 20.3s	remaining: 2m 24s
# 123:	learn: 0.8413960	total: 20.5s	remaining: 2m 24s
# 124:	learn: 0.8396958	total: 20.7s	remaining: 2m 24s
# 125:	learn: 0.8389744	total: 20.8s	remaining: 2m 24s
# 126:	learn: 0.8375464	total: 21s	remaining: 2m 24s
# 127:	learn: 0.8367294	total: 21.1s	remaining: 2m 24s
# 128:	learn: 0.8360871	total: 21.4s	remaining: 2m 24s
# 129:	learn: 0.8350077	total: 21.7s	remaining: 2m 25s
# 130:	learn: 0.8344124	total: 21.9s	remaining: 2m 25s
# 131:	learn: 0.8338233	total: 22.2s	remaining: 2m 25s
# 132:	learn: 0.8330098	total: 22.5s	remaining: 2m 26s
# 133:	learn: 0.8319032	total: 22.8s	remaining: 2m 27s
# 134:	learn: 0.8311105	total: 23.1s	remaining: 2m 28s
# 135:	learn: 0.8300740	total: 23.4s	remaining: 2m 28s
# 136:	learn: 0.8294103	total: 23.6s	remaining: 2m 28s
# 137:	learn: 0.8285382	total: 23.9s	remaining: 2m 29s
# 138:	learn: 0.8275339	total: 24.2s	remaining: 2m 29s
# 139:	learn: 0.8268812	total: 24.4s	remaining: 2m 30s
# 140:	learn: 0.8258146	total: 24.7s	remaining: 2m 30s
# 141:	learn: 0.8250559	total: 24.9s	remaining: 2m 30s
# 142:	learn: 0.8244817	total: 25.1s	remaining: 2m 30s
# 143:	learn: 0.8234735	total: 25.2s	remaining: 2m 29s
# 144:	learn: 0.8224729	total: 25.4s	remaining: 2m 29s
# 145:	learn: 0.8216946	total: 25.5s	remaining: 2m 29s
# 146:	learn: 0.8206448	total: 25.7s	remaining: 2m 29s
# 147:	learn: 0.8196361	total: 25.9s	remaining: 2m 28s
# 148:	learn: 0.8189750	total: 26s	remaining: 2m 28s
# 149:	learn: 0.8179840	total: 26.1s	remaining: 2m 28s
# 150:	learn: 0.8171713	total: 26.3s	remaining: 2m 27s
# 151:	learn: 0.8163246	total: 26.4s	remaining: 2m 27s
# 152:	learn: 0.8155711	total: 26.6s	remaining: 2m 27s
# 153:	learn: 0.8147349	total: 26.7s	remaining: 2m 26s
# 154:	learn: 0.8140463	total: 26.9s	remaining: 2m 26s
# 155:	learn: 0.8134266	total: 27s	remaining: 2m 26s
# 156:	learn: 0.8125821	total: 27.2s	remaining: 2m 25s
# 157:	learn: 0.8118517	total: 27.3s	remaining: 2m 25s
# 158:	learn: 0.8113015	total: 27.4s	remaining: 2m 24s
# 159:	learn: 0.8101825	total: 27.6s	remaining: 2m 24s
# 160:	learn: 0.8095207	total: 27.7s	remaining: 2m 24s
# 161:	learn: 0.8088308	total: 27.8s	remaining: 2m 24s
# 162:	learn: 0.8080408	total: 28s	remaining: 2m 23s
# 163:	learn: 0.8073047	total: 28.1s	remaining: 2m 23s
# 164:	learn: 0.8066243	total: 28.3s	remaining: 2m 23s
# 165:	learn: 0.8059914	total: 28.4s	remaining: 2m 22s
# 166:	learn: 0.8051455	total: 28.6s	remaining: 2m 22s
# 167:	learn: 0.8044269	total: 28.8s	remaining: 2m 22s
# 168:	learn: 0.8037229	total: 28.9s	remaining: 2m 22s
# 169:	learn: 0.8029094	total: 29.1s	remaining: 2m 22s
# 170:	learn: 0.8023415	total: 29.2s	remaining: 2m 21s
# 171:	learn: 0.8020359	total: 29.3s	remaining: 2m 21s
# 172:	learn: 0.8011898	total: 29.5s	remaining: 2m 21s
# 173:	learn: 0.8003400	total: 29.7s	remaining: 2m 20s
# 174:	learn: 0.7994726	total: 29.9s	remaining: 2m 20s
# 175:	learn: 0.7987394	total: 30s	remaining: 2m 20s
# 176:	learn: 0.7983065	total: 30.1s	remaining: 2m 19s
# 177:	learn: 0.7977127	total: 30.2s	remaining: 2m 19s
# 178:	learn: 0.7965998	total: 30.4s	remaining: 2m 19s
# 179:	learn: 0.7955672	total: 30.6s	remaining: 2m 19s
# 180:	learn: 0.7944523	total: 30.8s	remaining: 2m 19s
# 181:	learn: 0.7936730	total: 30.9s	remaining: 2m 18s
# 182:	learn: 0.7927958	total: 31.1s	remaining: 2m 18s
# 183:	learn: 0.7922429	total: 31.2s	remaining: 2m 18s
# 184:	learn: 0.7916962	total: 31.3s	remaining: 2m 18s
# 185:	learn: 0.7911178	total: 31.5s	remaining: 2m 17s
# 186:	learn: 0.7904903	total: 31.6s	remaining: 2m 17s
# 187:	learn: 0.7900393	total: 31.8s	remaining: 2m 17s
# 188:	learn: 0.7893358	total: 31.9s	remaining: 2m 16s
# 189:	learn: 0.7886606	total: 32.1s	remaining: 2m 16s
# 190:	learn: 0.7878812	total: 32.2s	remaining: 2m 16s
# 191:	learn: 0.7875845	total: 32.4s	remaining: 2m 16s
# 192:	learn: 0.7872817	total: 32.5s	remaining: 2m 15s
# 193:	learn: 0.7866457	total: 32.6s	remaining: 2m 15s
# 194:	learn: 0.7860965	total: 32.8s	remaining: 2m 15s
# 195:	learn: 0.7854929	total: 32.9s	remaining: 2m 15s
# 196:	learn: 0.7848759	total: 33.1s	remaining: 2m 14s
# 197:	learn: 0.7843356	total: 33.2s	remaining: 2m 14s
# 198:	learn: 0.7833464	total: 33.4s	remaining: 2m 14s
# 199:	learn: 0.7825465	total: 33.6s	remaining: 2m 14s
# 200:	learn: 0.7820121	total: 33.7s	remaining: 2m 14s
# 201:	learn: 0.7815496	total: 33.9s	remaining: 2m 13s
# 202:	learn: 0.7809421	total: 34s	remaining: 2m 13s
# 203:	learn: 0.7802186	total: 34.2s	remaining: 2m 13s
# 204:	learn: 0.7797261	total: 34.3s	remaining: 2m 13s
# 205:	learn: 0.7790651	total: 34.5s	remaining: 2m 12s
# 206:	learn: 0.7784972	total: 34.6s	remaining: 2m 12s
# 207:	learn: 0.7779245	total: 34.7s	remaining: 2m 12s
# 208:	learn: 0.7772090	total: 35s	remaining: 2m 12s
# 209:	learn: 0.7765615	total: 35.2s	remaining: 2m 12s
# 210:	learn: 0.7759758	total: 35.5s	remaining: 2m 12s
# 211:	learn: 0.7755461	total: 35.8s	remaining: 2m 13s
# 212:	learn: 0.7750177	total: 36.1s	remaining: 2m 13s
# 213:	learn: 0.7743002	total: 36.4s	remaining: 2m 13s
# 214:	learn: 0.7740372	total: 36.6s	remaining: 2m 13s
# 215:	learn: 0.7733884	total: 36.8s	remaining: 2m 13s
# 216:	learn: 0.7728196	total: 37.1s	remaining: 2m 13s
# 217:	learn: 0.7722287	total: 37.4s	remaining: 2m 13s
# 218:	learn: 0.7716717	total: 37.6s	remaining: 2m 14s
# 219:	learn: 0.7711213	total: 37.9s	remaining: 2m 14s
# 220:	learn: 0.7704867	total: 38.2s	remaining: 2m 14s
# 221:	learn: 0.7698344	total: 38.5s	remaining: 2m 14s
# 222:	learn: 0.7695659	total: 38.6s	remaining: 2m 14s
# 223:	learn: 0.7688090	total: 38.8s	remaining: 2m 14s
# 224:	learn: 0.7682942	total: 38.9s	remaining: 2m 13s
# 225:	learn: 0.7677925	total: 39.1s	remaining: 2m 13s
# 226:	learn: 0.7672866	total: 39.2s	remaining: 2m 13s
# 227:	learn: 0.7665408	total: 39.4s	remaining: 2m 13s
# 228:	learn: 0.7660696	total: 39.6s	remaining: 2m 13s
# 229:	learn: 0.7653681	total: 39.8s	remaining: 2m 13s
# 230:	learn: 0.7647390	total: 39.9s	remaining: 2m 12s
# 231:	learn: 0.7643205	total: 40.1s	remaining: 2m 12s
# 232:	learn: 0.7638739	total: 40.2s	remaining: 2m 12s
# 233:	learn: 0.7634205	total: 40.4s	remaining: 2m 12s
# 234:	learn: 0.7629799	total: 40.7s	remaining: 2m 12s
# 235:	learn: 0.7623640	total: 40.9s	remaining: 2m 12s
# 236:	learn: 0.7619694	total: 41.2s	remaining: 2m 12s
# 237:	learn: 0.7614910	total: 41.4s	remaining: 2m 12s
# 238:	learn: 0.7610907	total: 41.7s	remaining: 2m 12s
# 239:	learn: 0.7607053	total: 42s	remaining: 2m 12s
# 240:	learn: 0.7604577	total: 42.2s	remaining: 2m 12s
# 241:	learn: 0.7596933	total: 42.5s	remaining: 2m 13s
# 242:	learn: 0.7591311	total: 42.8s	remaining: 2m 13s
# 243:	learn: 0.7587217	total: 43.1s	remaining: 2m 13s
# 244:	learn: 0.7581007	total: 43.4s	remaining: 2m 13s
# 245:	learn: 0.7575794	total: 43.6s	remaining: 2m 13s
# 246:	learn: 0.7570279	total: 43.9s	remaining: 2m 13s
# 247:	learn: 0.7565871	total: 44.1s	remaining: 2m 13s
# 248:	learn: 0.7564319	total: 44.2s	remaining: 2m 13s
# 249:	learn: 0.7557808	total: 44.4s	remaining: 2m 13s
# 250:	learn: 0.7555086	total: 44.5s	remaining: 2m 12s
# 251:	learn: 0.7551799	total: 44.6s	remaining: 2m 12s
# 252:	learn: 0.7548609	total: 44.8s	remaining: 2m 12s
# 253:	learn: 0.7541438	total: 44.9s	remaining: 2m 11s
# 254:	learn: 0.7536824	total: 45.1s	remaining: 2m 11s
# 255:	learn: 0.7533063	total: 45.2s	remaining: 2m 11s
# 256:	learn: 0.7529859	total: 45.4s	remaining: 2m 11s
# 257:	learn: 0.7524256	total: 45.5s	remaining: 2m 10s
# 258:	learn: 0.7517398	total: 45.7s	remaining: 2m 10s
# 259:	learn: 0.7512305	total: 45.9s	remaining: 2m 10s
# 260:	learn: 0.7507925	total: 46s	remaining: 2m 10s
# 261:	learn: 0.7506261	total: 46.1s	remaining: 2m 9s
# 262:	learn: 0.7500535	total: 46.3s	remaining: 2m 9s
# 263:	learn: 0.7496345	total: 46.5s	remaining: 2m 9s
# 264:	learn: 0.7493276	total: 46.6s	remaining: 2m 9s
# 265:	learn: 0.7487330	total: 46.8s	remaining: 2m 9s
# 266:	learn: 0.7481686	total: 47s	remaining: 2m 9s
# 267:	learn: 0.7479149	total: 47.1s	remaining: 2m 8s
# 268:	learn: 0.7476316	total: 47.2s	remaining: 2m 8s
# 269:	learn: 0.7474030	total: 47.4s	remaining: 2m 8s
# 270:	learn: 0.7469798	total: 47.5s	remaining: 2m 7s
# 271:	learn: 0.7465713	total: 47.7s	remaining: 2m 7s
# 272:	learn: 0.7461673	total: 47.9s	remaining: 2m 7s
# 273:	learn: 0.7458103	total: 48s	remaining: 2m 7s
# 274:	learn: 0.7453577	total: 48.2s	remaining: 2m 6s
# 275:	learn: 0.7449870	total: 48.3s	remaining: 2m 6s
# 276:	learn: 0.7446165	total: 48.5s	remaining: 2m 6s
# 277:	learn: 0.7440177	total: 48.8s	remaining: 2m 6s
# 278:	learn: 0.7436073	total: 49.1s	remaining: 2m 6s
# 279:	learn: 0.7434057	total: 49.3s	remaining: 2m 6s
# 280:	learn: 0.7428806	total: 49.6s	remaining: 2m 7s
# 281:	learn: 0.7423638	total: 50s	remaining: 2m 7s
# 282:	learn: 0.7419043	total: 50.3s	remaining: 2m 7s
# 283:	learn: 0.7417606	total: 50.5s	remaining: 2m 7s
# 284:	learn: 0.7412791	total: 50.8s	remaining: 2m 7s
# 285:	learn: 0.7410338	total: 51s	remaining: 2m 7s
# 286:	learn: 0.7402999	total: 51.4s	remaining: 2m 7s
# 287:	learn: 0.7399651	total: 51.6s	remaining: 2m 7s
# 288:	learn: 0.7395512	total: 51.9s	remaining: 2m 7s
# 289:	learn: 0.7392899	total: 52.1s	remaining: 2m 7s
# 290:	learn: 0.7388166	total: 52.3s	remaining: 2m 7s
# 291:	learn: 0.7385674	total: 52.5s	remaining: 2m 7s
# 292:	learn: 0.7380745	total: 52.7s	remaining: 2m 7s
# 293:	learn: 0.7375518	total: 52.8s	remaining: 2m 6s
# 294:	learn: 0.7371960	total: 53s	remaining: 2m 6s
# 295:	learn: 0.7366648	total: 53.1s	remaining: 2m 6s
# 296:	learn: 0.7360543	total: 53.3s	remaining: 2m 6s
# 297:	learn: 0.7354925	total: 53.5s	remaining: 2m 6s
# 298:	learn: 0.7351017	total: 53.6s	remaining: 2m 5s
# 299:	learn: 0.7345899	total: 53.8s	remaining: 2m 5s
# 300:	learn: 0.7342431	total: 53.9s	remaining: 2m 5s
# 301:	learn: 0.7339719	total: 54.1s	remaining: 2m 4s
# 302:	learn: 0.7336258	total: 54.2s	remaining: 2m 4s
# 303:	learn: 0.7334614	total: 54.4s	remaining: 2m 4s
# 304:	learn: 0.7331868	total: 54.5s	remaining: 2m 4s
# 305:	learn: 0.7328462	total: 54.6s	remaining: 2m 3s
# 306:	learn: 0.7324771	total: 54.8s	remaining: 2m 3s
# 307:	learn: 0.7322348	total: 54.9s	remaining: 2m 3s
# 308:	learn: 0.7318285	total: 55.1s	remaining: 2m 3s
# 309:	learn: 0.7315502	total: 55.2s	remaining: 2m 2s
# 310:	learn: 0.7311174	total: 55.4s	remaining: 2m 2s
# 311:	learn: 0.7308254	total: 55.5s	remaining: 2m 2s
# 312:	learn: 0.7304913	total: 55.6s	remaining: 2m 2s
# 313:	learn: 0.7300902	total: 55.8s	remaining: 2m 1s
# 314:	learn: 0.7296236	total: 55.9s	remaining: 2m 1s
# 315:	learn: 0.7292628	total: 56.1s	remaining: 2m 1s
# 316:	learn: 0.7288445	total: 56.2s	remaining: 2m 1s
# 317:	learn: 0.7283091	total: 56.4s	remaining: 2m
# 318:	learn: 0.7279664	total: 56.5s	remaining: 2m
# 319:	learn: 0.7277361	total: 56.7s	remaining: 2m
# 320:	learn: 0.7272747	total: 56.8s	remaining: 2m
# 321:	learn: 0.7268342	total: 57s	remaining: 1m 59s
# 322:	learn: 0.7265113	total: 57.1s	remaining: 1m 59s
# 323:	learn: 0.7260870	total: 57.3s	remaining: 1m 59s
# 324:	learn: 0.7256812	total: 57.4s	remaining: 1m 59s
# 325:	learn: 0.7253134	total: 57.6s	remaining: 1m 59s
# 326:	learn: 0.7249487	total: 57.8s	remaining: 1m 58s
# 327:	learn: 0.7247068	total: 57.9s	remaining: 1m 58s
# 328:	learn: 0.7243055	total: 58.1s	remaining: 1m 58s
# 329:	learn: 0.7240704	total: 58.2s	remaining: 1m 58s
# 330:	learn: 0.7236288	total: 58.4s	remaining: 1m 57s
# 331:	learn: 0.7234146	total: 58.5s	remaining: 1m 57s
# 332:	learn: 0.7229488	total: 58.6s	remaining: 1m 57s
# 333:	learn: 0.7225404	total: 58.8s	remaining: 1m 57s
# 334:	learn: 0.7222990	total: 58.9s	remaining: 1m 56s
# 335:	learn: 0.7218350	total: 59.1s	remaining: 1m 56s
# 336:	learn: 0.7215033	total: 59.3s	remaining: 1m 56s
# 337:	learn: 0.7210305	total: 59.4s	remaining: 1m 56s
# 338:	learn: 0.7206663	total: 59.6s	remaining: 1m 56s
# 339:	learn: 0.7203082	total: 59.7s	remaining: 1m 55s
# 340:	learn: 0.7200953	total: 59.8s	remaining: 1m 55s
# 341:	learn: 0.7197558	total: 1m	remaining: 1m 55s
# 342:	learn: 0.7194963	total: 1m	remaining: 1m 55s
# 343:	learn: 0.7192334	total: 1m	remaining: 1m 54s
# 344:	learn: 0.7191306	total: 1m	remaining: 1m 54s
# 345:	learn: 0.7188370	total: 1m	remaining: 1m 54s
# 346:	learn: 0.7184496	total: 1m	remaining: 1m 54s
# 347:	learn: 0.7181078	total: 1m	remaining: 1m 54s
# 348:	learn: 0.7178859	total: 1m	remaining: 1m 53s
# 349:	learn: 0.7175466	total: 1m 1s	remaining: 1m 53s
# 350:	learn: 0.7173468	total: 1m 1s	remaining: 1m 53s
# 351:	learn: 0.7171225	total: 1m 1s	remaining: 1m 53s
# 352:	learn: 0.7168875	total: 1m 1s	remaining: 1m 52s
# 353:	learn: 0.7165653	total: 1m 1s	remaining: 1m 52s
# 354:	learn: 0.7162426	total: 1m 1s	remaining: 1m 52s
# 355:	learn: 0.7160259	total: 1m 1s	remaining: 1m 52s
# 356:	learn: 0.7158270	total: 1m 2s	remaining: 1m 51s
# 357:	learn: 0.7153760	total: 1m 2s	remaining: 1m 51s
# 358:	learn: 0.7148388	total: 1m 2s	remaining: 1m 51s
# 359:	learn: 0.7143200	total: 1m 2s	remaining: 1m 51s
# 360:	learn: 0.7140356	total: 1m 3s	remaining: 1m 51s
# 361:	learn: 0.7136859	total: 1m 3s	remaining: 1m 51s
# 362:	learn: 0.7134370	total: 1m 3s	remaining: 1m 51s
# 363:	learn: 0.7131838	total: 1m 3s	remaining: 1m 51s
# 364:	learn: 0.7128771	total: 1m 4s	remaining: 1m 51s
# 365:	learn: 0.7126505	total: 1m 4s	remaining: 1m 51s
# 366:	learn: 0.7122870	total: 1m 4s	remaining: 1m 51s
# 367:	learn: 0.7120932	total: 1m 4s	remaining: 1m 51s
# 368:	learn: 0.7116102	total: 1m 5s	remaining: 1m 51s
# 369:	learn: 0.7113143	total: 1m 5s	remaining: 1m 51s
# 370:	learn: 0.7110093	total: 1m 5s	remaining: 1m 51s
# 371:	learn: 0.7107626	total: 1m 6s	remaining: 1m 51s
# 372:	learn: 0.7106006	total: 1m 6s	remaining: 1m 51s
# 373:	learn: 0.7102635	total: 1m 6s	remaining: 1m 50s
# 374:	learn: 0.7099946	total: 1m 6s	remaining: 1m 50s
# 375:	learn: 0.7097567	total: 1m 6s	remaining: 1m 50s
# 376:	learn: 0.7095393	total: 1m 6s	remaining: 1m 50s
# 377:	learn: 0.7093948	total: 1m 6s	remaining: 1m 49s
# 378:	learn: 0.7091146	total: 1m 6s	remaining: 1m 49s
# 379:	learn: 0.7086745	total: 1m 7s	remaining: 1m 49s
# 380:	learn: 0.7083611	total: 1m 7s	remaining: 1m 49s
# 381:	learn: 0.7081375	total: 1m 7s	remaining: 1m 48s
# 382:	learn: 0.7078987	total: 1m 7s	remaining: 1m 48s
# 383:	learn: 0.7075527	total: 1m 7s	remaining: 1m 48s
# 384:	learn: 0.7071202	total: 1m 7s	remaining: 1m 48s
# 385:	learn: 0.7066170	total: 1m 7s	remaining: 1m 48s
# 386:	learn: 0.7065002	total: 1m 8s	remaining: 1m 47s
# 387:	learn: 0.7061323	total: 1m 8s	remaining: 1m 47s
# 388:	learn: 0.7057961	total: 1m 8s	remaining: 1m 47s
# 389:	learn: 0.7056376	total: 1m 8s	remaining: 1m 47s
# 390:	learn: 0.7053009	total: 1m 8s	remaining: 1m 46s
# 391:	learn: 0.7049557	total: 1m 8s	remaining: 1m 46s
# 392:	learn: 0.7048075	total: 1m 8s	remaining: 1m 46s
# 393:	learn: 0.7041462	total: 1m 9s	remaining: 1m 46s
# 394:	learn: 0.7038410	total: 1m 9s	remaining: 1m 46s
# 395:	learn: 0.7036651	total: 1m 9s	remaining: 1m 45s
# 396:	learn: 0.7033639	total: 1m 9s	remaining: 1m 45s
# 397:	learn: 0.7030071	total: 1m 9s	remaining: 1m 45s
# 398:	learn: 0.7026347	total: 1m 9s	remaining: 1m 45s
# 399:	learn: 0.7024654	total: 1m 9s	remaining: 1m 44s
# 400:	learn: 0.7023309	total: 1m 10s	remaining: 1m 44s
# 401:	learn: 0.7020328	total: 1m 10s	remaining: 1m 44s
# 402:	learn: 0.7017167	total: 1m 10s	remaining: 1m 44s
# 403:	learn: 0.7015049	total: 1m 10s	remaining: 1m 44s
# 404:	learn: 0.7013269	total: 1m 10s	remaining: 1m 43s
# 405:	learn: 0.7010626	total: 1m 10s	remaining: 1m 43s
# 406:	learn: 0.7009146	total: 1m 10s	remaining: 1m 43s
# 407:	learn: 0.7005209	total: 1m 11s	remaining: 1m 43s
# 408:	learn: 0.7002806	total: 1m 11s	remaining: 1m 43s
# 409:	learn: 0.7000513	total: 1m 11s	remaining: 1m 42s
# 410:	learn: 0.6998360	total: 1m 11s	remaining: 1m 42s
# 411:	learn: 0.6993820	total: 1m 11s	remaining: 1m 42s
# 412:	learn: 0.6992359	total: 1m 11s	remaining: 1m 42s
# 413:	learn: 0.6990015	total: 1m 11s	remaining: 1m 41s
# 414:	learn: 0.6988406	total: 1m 12s	remaining: 1m 41s
# 415:	learn: 0.6984048	total: 1m 12s	remaining: 1m 41s
# 416:	learn: 0.6981195	total: 1m 12s	remaining: 1m 41s
# 417:	learn: 0.6977188	total: 1m 12s	remaining: 1m 41s
# 418:	learn: 0.6974814	total: 1m 12s	remaining: 1m 40s
# 419:	learn: 0.6970876	total: 1m 12s	remaining: 1m 40s
# 420:	learn: 0.6968779	total: 1m 13s	remaining: 1m 40s
# 421:	learn: 0.6965809	total: 1m 13s	remaining: 1m 40s
# 422:	learn: 0.6961790	total: 1m 13s	remaining: 1m 40s
# 423:	learn: 0.6957729	total: 1m 13s	remaining: 1m 39s
# 424:	learn: 0.6953474	total: 1m 13s	remaining: 1m 39s
# 425:	learn: 0.6951359	total: 1m 13s	remaining: 1m 39s
# 426:	learn: 0.6947700	total: 1m 13s	remaining: 1m 39s
# 427:	learn: 0.6944572	total: 1m 14s	remaining: 1m 39s
# 428:	learn: 0.6942584	total: 1m 14s	remaining: 1m 38s
# 429:	learn: 0.6939335	total: 1m 14s	remaining: 1m 38s
# 430:	learn: 0.6938011	total: 1m 14s	remaining: 1m 38s
# 431:	learn: 0.6936062	total: 1m 14s	remaining: 1m 38s
# 432:	learn: 0.6933328	total: 1m 14s	remaining: 1m 38s
# 433:	learn: 0.6930903	total: 1m 15s	remaining: 1m 37s
# 434:	learn: 0.6929496	total: 1m 15s	remaining: 1m 37s
# 435:	learn: 0.6926573	total: 1m 15s	remaining: 1m 37s
# 436:	learn: 0.6924613	total: 1m 15s	remaining: 1m 37s
# 437:	learn: 0.6923196	total: 1m 15s	remaining: 1m 36s
# 438:	learn: 0.6921640	total: 1m 15s	remaining: 1m 36s
# 439:	learn: 0.6919827	total: 1m 15s	remaining: 1m 36s
# 440:	learn: 0.6918060	total: 1m 16s	remaining: 1m 36s
# 441:	learn: 0.6915209	total: 1m 16s	remaining: 1m 36s
# 442:	learn: 0.6912262	total: 1m 16s	remaining: 1m 36s
# 443:	learn: 0.6910092	total: 1m 16s	remaining: 1m 36s
# 444:	learn: 0.6907540	total: 1m 17s	remaining: 1m 36s
# 445:	learn: 0.6904747	total: 1m 17s	remaining: 1m 36s
# 446:	learn: 0.6903060	total: 1m 17s	remaining: 1m 36s
# 447:	learn: 0.6900824	total: 1m 17s	remaining: 1m 35s
# 448:	learn: 0.6897833	total: 1m 18s	remaining: 1m 35s
# 449:	learn: 0.6896372	total: 1m 18s	remaining: 1m 35s
# 450:	learn: 0.6894831	total: 1m 18s	remaining: 1m 35s
# 451:	learn: 0.6892119	total: 1m 19s	remaining: 1m 35s
# 452:	learn: 0.6890502	total: 1m 19s	remaining: 1m 35s
# 453:	learn: 0.6887100	total: 1m 19s	remaining: 1m 35s
# 454:	learn: 0.6883087	total: 1m 19s	remaining: 1m 35s
# 455:	learn: 0.6880296	total: 1m 19s	remaining: 1m 35s
# 456:	learn: 0.6878130	total: 1m 20s	remaining: 1m 35s
# 457:	learn: 0.6876226	total: 1m 20s	remaining: 1m 34s
# 458:	learn: 0.6873152	total: 1m 20s	remaining: 1m 34s
# 459:	learn: 0.6871689	total: 1m 20s	remaining: 1m 34s
# 460:	learn: 0.6868009	total: 1m 20s	remaining: 1m 34s
# 461:	learn: 0.6866228	total: 1m 20s	remaining: 1m 34s
# 462:	learn: 0.6863207	total: 1m 21s	remaining: 1m 34s
# 463:	learn: 0.6861701	total: 1m 21s	remaining: 1m 34s
# 464:	learn: 0.6858017	total: 1m 21s	remaining: 1m 33s
# 465:	learn: 0.6855379	total: 1m 21s	remaining: 1m 33s
# 466:	learn: 0.6854446	total: 1m 21s	remaining: 1m 33s
# 467:	learn: 0.6850780	total: 1m 22s	remaining: 1m 33s
# 468:	learn: 0.6848459	total: 1m 22s	remaining: 1m 33s
# 469:	learn: 0.6845652	total: 1m 22s	remaining: 1m 33s
# 470:	learn: 0.6842561	total: 1m 22s	remaining: 1m 33s
# 471:	learn: 0.6840428	total: 1m 23s	remaining: 1m 32s
# 472:	learn: 0.6837178	total: 1m 23s	remaining: 1m 32s
# 473:	learn: 0.6832470	total: 1m 23s	remaining: 1m 32s
# 474:	learn: 0.6828975	total: 1m 23s	remaining: 1m 32s
# 475:	learn: 0.6828073	total: 1m 23s	remaining: 1m 32s
# 476:	learn: 0.6825409	total: 1m 24s	remaining: 1m 32s
# 477:	learn: 0.6821663	total: 1m 24s	remaining: 1m 31s
# 478:	learn: 0.6816965	total: 1m 24s	remaining: 1m 31s
# 479:	learn: 0.6812792	total: 1m 24s	remaining: 1m 31s
# 480:	learn: 0.6810615	total: 1m 24s	remaining: 1m 31s
# 481:	learn: 0.6808748	total: 1m 25s	remaining: 1m 31s
# 482:	learn: 0.6805236	total: 1m 25s	remaining: 1m 31s
# 483:	learn: 0.6804287	total: 1m 25s	remaining: 1m 31s
# 484:	learn: 0.6802862	total: 1m 25s	remaining: 1m 30s
# 485:	learn: 0.6801405	total: 1m 25s	remaining: 1m 30s
# 486:	learn: 0.6799577	total: 1m 25s	remaining: 1m 30s
# 487:	learn: 0.6795446	total: 1m 26s	remaining: 1m 30s
# 488:	learn: 0.6793599	total: 1m 26s	remaining: 1m 30s
# 489:	learn: 0.6790401	total: 1m 26s	remaining: 1m 30s
# 490:	learn: 0.6788418	total: 1m 27s	remaining: 1m 30s
# 491:	learn: 0.6785955	total: 1m 27s	remaining: 1m 30s
# 492:	learn: 0.6785107	total: 1m 27s	remaining: 1m 29s
# 493:	learn: 0.6781706	total: 1m 27s	remaining: 1m 29s
# 494:	learn: 0.6779588	total: 1m 27s	remaining: 1m 29s
# 495:	learn: 0.6778909	total: 1m 27s	remaining: 1m 29s
# 496:	learn: 0.6776211	total: 1m 28s	remaining: 1m 29s
# 497:	learn: 0.6774994	total: 1m 28s	remaining: 1m 28s
# 498:	learn: 0.6773391	total: 1m 28s	remaining: 1m 28s
# 499:	learn: 0.6772090	total: 1m 28s	remaining: 1m 28s
# 500:	learn: 0.6769986	total: 1m 28s	remaining: 1m 28s
# 501:	learn: 0.6769220	total: 1m 28s	remaining: 1m 27s
# 502:	learn: 0.6767635	total: 1m 28s	remaining: 1m 27s
# 503:	learn: 0.6765932	total: 1m 28s	remaining: 1m 27s
# 504:	learn: 0.6763243	total: 1m 29s	remaining: 1m 27s
# 505:	learn: 0.6761791	total: 1m 29s	remaining: 1m 27s
# 506:	learn: 0.6756838	total: 1m 29s	remaining: 1m 26s
# 507:	learn: 0.6753705	total: 1m 29s	remaining: 1m 26s
# 508:	learn: 0.6749703	total: 1m 29s	remaining: 1m 26s
# 509:	learn: 0.6748057	total: 1m 30s	remaining: 1m 26s
# 510:	learn: 0.6746293	total: 1m 30s	remaining: 1m 26s
# 511:	learn: 0.6744970	total: 1m 30s	remaining: 1m 26s
# 512:	learn: 0.6742404	total: 1m 30s	remaining: 1m 26s
# 513:	learn: 0.6739414	total: 1m 31s	remaining: 1m 26s
# 514:	learn: 0.6734580	total: 1m 31s	remaining: 1m 26s
# 515:	learn: 0.6733118	total: 1m 31s	remaining: 1m 26s
# 516:	learn: 0.6731629	total: 1m 31s	remaining: 1m 25s
# 517:	learn: 0.6729601	total: 1m 32s	remaining: 1m 25s
# 518:	learn: 0.6726778	total: 1m 32s	remaining: 1m 25s
# 519:	learn: 0.6723654	total: 1m 32s	remaining: 1m 25s
# 520:	learn: 0.6721845	total: 1m 32s	remaining: 1m 25s
# 521:	learn: 0.6719170	total: 1m 33s	remaining: 1m 25s
# 522:	learn: 0.6716703	total: 1m 33s	remaining: 1m 25s
# 523:	learn: 0.6713816	total: 1m 33s	remaining: 1m 25s
# 524:	learn: 0.6710855	total: 1m 33s	remaining: 1m 24s
# 525:	learn: 0.6708249	total: 1m 33s	remaining: 1m 24s
# 526:	learn: 0.6706285	total: 1m 34s	remaining: 1m 24s
# 527:	learn: 0.6704919	total: 1m 34s	remaining: 1m 24s
# 528:	learn: 0.6703735	total: 1m 34s	remaining: 1m 23s
# 529:	learn: 0.6701514	total: 1m 34s	remaining: 1m 23s
# 530:	learn: 0.6697862	total: 1m 34s	remaining: 1m 23s
# 531:	learn: 0.6694760	total: 1m 34s	remaining: 1m 23s
# 532:	learn: 0.6693401	total: 1m 34s	remaining: 1m 23s
# 533:	learn: 0.6692421	total: 1m 35s	remaining: 1m 22s
# 534:	learn: 0.6689903	total: 1m 35s	remaining: 1m 22s
# 535:	learn: 0.6686914	total: 1m 35s	remaining: 1m 22s
# 536:	learn: 0.6685915	total: 1m 35s	remaining: 1m 22s
# 537:	learn: 0.6684000	total: 1m 35s	remaining: 1m 22s
# 538:	learn: 0.6681414	total: 1m 35s	remaining: 1m 21s
# 539:	learn: 0.6680523	total: 1m 35s	remaining: 1m 21s
# 540:	learn: 0.6679381	total: 1m 36s	remaining: 1m 21s
# 541:	learn: 0.6676786	total: 1m 36s	remaining: 1m 21s
# 542:	learn: 0.6675917	total: 1m 36s	remaining: 1m 21s
# 543:	learn: 0.6672710	total: 1m 36s	remaining: 1m 20s
# 544:	learn: 0.6670266	total: 1m 36s	remaining: 1m 20s
# 545:	learn: 0.6667992	total: 1m 36s	remaining: 1m 20s
# 546:	learn: 0.6666152	total: 1m 36s	remaining: 1m 20s
# 547:	learn: 0.6662412	total: 1m 37s	remaining: 1m 20s
# 548:	learn: 0.6660718	total: 1m 37s	remaining: 1m 19s
# 549:	learn: 0.6659127	total: 1m 37s	remaining: 1m 19s
# 550:	learn: 0.6656718	total: 1m 37s	remaining: 1m 19s
# 551:	learn: 0.6655200	total: 1m 37s	remaining: 1m 19s
# 552:	learn: 0.6653058	total: 1m 37s	remaining: 1m 19s
# 553:	learn: 0.6651322	total: 1m 37s	remaining: 1m 18s
# 554:	learn: 0.6649350	total: 1m 38s	remaining: 1m 18s
# 555:	learn: 0.6646060	total: 1m 38s	remaining: 1m 18s
# 556:	learn: 0.6644395	total: 1m 38s	remaining: 1m 18s
# 557:	learn: 0.6640680	total: 1m 38s	remaining: 1m 18s
# 558:	learn: 0.6639093	total: 1m 38s	remaining: 1m 17s
# 559:	learn: 0.6636465	total: 1m 38s	remaining: 1m 17s
# 560:	learn: 0.6635880	total: 1m 38s	remaining: 1m 17s
# 561:	learn: 0.6633249	total: 1m 39s	remaining: 1m 17s
# 562:	learn: 0.6631377	total: 1m 39s	remaining: 1m 17s
# 563:	learn: 0.6630222	total: 1m 39s	remaining: 1m 16s
# 564:	learn: 0.6628407	total: 1m 39s	remaining: 1m 16s
# 565:	learn: 0.6625651	total: 1m 39s	remaining: 1m 16s
# 566:	learn: 0.6622976	total: 1m 39s	remaining: 1m 16s
# 567:	learn: 0.6619635	total: 1m 40s	remaining: 1m 16s
# 568:	learn: 0.6618018	total: 1m 40s	remaining: 1m 15s
# 569:	learn: 0.6616905	total: 1m 40s	remaining: 1m 15s
# 570:	learn: 0.6614733	total: 1m 40s	remaining: 1m 15s
# 571:	learn: 0.6613886	total: 1m 40s	remaining: 1m 15s
# 572:	learn: 0.6612550	total: 1m 40s	remaining: 1m 15s
# 573:	learn: 0.6611673	total: 1m 40s	remaining: 1m 14s
# 574:	learn: 0.6609909	total: 1m 41s	remaining: 1m 14s
# 575:	learn: 0.6608923	total: 1m 41s	remaining: 1m 14s
# 576:	learn: 0.6605158	total: 1m 41s	remaining: 1m 14s
# 577:	learn: 0.6604480	total: 1m 41s	remaining: 1m 14s
# 578:	learn: 0.6602620	total: 1m 41s	remaining: 1m 13s
# 579:	learn: 0.6599982	total: 1m 41s	remaining: 1m 13s
# 580:	learn: 0.6596708	total: 1m 41s	remaining: 1m 13s
# 581:	learn: 0.6593581	total: 1m 42s	remaining: 1m 13s
# 582:	learn: 0.6591629	total: 1m 42s	remaining: 1m 13s
# 583:	learn: 0.6590309	total: 1m 42s	remaining: 1m 12s
# 584:	learn: 0.6588512	total: 1m 42s	remaining: 1m 12s
# 585:	learn: 0.6585940	total: 1m 42s	remaining: 1m 12s
# 586:	learn: 0.6583905	total: 1m 42s	remaining: 1m 12s
# 587:	learn: 0.6583132	total: 1m 42s	remaining: 1m 12s
# 588:	learn: 0.6581983	total: 1m 42s	remaining: 1m 11s
# 589:	learn: 0.6579842	total: 1m 43s	remaining: 1m 11s
# 590:	learn: 0.6578064	total: 1m 43s	remaining: 1m 11s
# 591:	learn: 0.6575848	total: 1m 43s	remaining: 1m 11s
# 592:	learn: 0.6575093	total: 1m 43s	remaining: 1m 11s
# 593:	learn: 0.6572238	total: 1m 44s	remaining: 1m 11s
# 594:	learn: 0.6570124	total: 1m 44s	remaining: 1m 11s
# 595:	learn: 0.6568401	total: 1m 44s	remaining: 1m 10s
# 596:	learn: 0.6565500	total: 1m 45s	remaining: 1m 10s
# 597:	learn: 0.6563349	total: 1m 45s	remaining: 1m 10s
# 598:	learn: 0.6560737	total: 1m 45s	remaining: 1m 10s
# 599:	learn: 0.6557993	total: 1m 45s	remaining: 1m 10s
# 600:	learn: 0.6555032	total: 1m 46s	remaining: 1m 10s
# 601:	learn: 0.6551604	total: 1m 46s	remaining: 1m 10s
# 602:	learn: 0.6548343	total: 1m 46s	remaining: 1m 10s
# 603:	learn: 0.6546661	total: 1m 46s	remaining: 1m 10s
# 604:	learn: 0.6545924	total: 1m 47s	remaining: 1m 9s
# 605:	learn: 0.6544442	total: 1m 47s	remaining: 1m 9s
# 606:	learn: 0.6541174	total: 1m 47s	remaining: 1m 9s
# 607:	learn: 0.6539059	total: 1m 47s	remaining: 1m 9s
# 608:	learn: 0.6536143	total: 1m 47s	remaining: 1m 9s
# 609:	learn: 0.6534997	total: 1m 47s	remaining: 1m 8s
# 610:	learn: 0.6532556	total: 1m 48s	remaining: 1m 8s
# 611:	learn: 0.6530639	total: 1m 48s	remaining: 1m 8s
# 612:	learn: 0.6530208	total: 1m 48s	remaining: 1m 8s
# 613:	learn: 0.6527190	total: 1m 48s	remaining: 1m 8s
# 614:	learn: 0.6524759	total: 1m 48s	remaining: 1m 7s
# 615:	learn: 0.6523126	total: 1m 48s	remaining: 1m 7s
# 616:	learn: 0.6522215	total: 1m 48s	remaining: 1m 7s
# 617:	learn: 0.6520859	total: 1m 48s	remaining: 1m 7s
# 618:	learn: 0.6518413	total: 1m 49s	remaining: 1m 7s
# 619:	learn: 0.6516881	total: 1m 49s	remaining: 1m 6s
# 620:	learn: 0.6516047	total: 1m 49s	remaining: 1m 6s
# 621:	learn: 0.6514000	total: 1m 49s	remaining: 1m 6s
# 622:	learn: 0.6513487	total: 1m 49s	remaining: 1m 6s
# 623:	learn: 0.6511396	total: 1m 49s	remaining: 1m 6s
# 624:	learn: 0.6509379	total: 1m 49s	remaining: 1m 5s
# 625:	learn: 0.6507870	total: 1m 50s	remaining: 1m 5s
# 626:	learn: 0.6505676	total: 1m 50s	remaining: 1m 5s
# 627:	learn: 0.6504723	total: 1m 50s	remaining: 1m 5s
# 628:	learn: 0.6503688	total: 1m 50s	remaining: 1m 5s
# 629:	learn: 0.6501802	total: 1m 50s	remaining: 1m 4s
# 630:	learn: 0.6500332	total: 1m 50s	remaining: 1m 4s
# 631:	learn: 0.6497928	total: 1m 50s	remaining: 1m 4s
# 632:	learn: 0.6496463	total: 1m 51s	remaining: 1m 4s
# 633:	learn: 0.6495517	total: 1m 51s	remaining: 1m 4s
# 634:	learn: 0.6493611	total: 1m 51s	remaining: 1m 4s
# 635:	learn: 0.6491915	total: 1m 51s	remaining: 1m 3s
# 636:	learn: 0.6490199	total: 1m 51s	remaining: 1m 3s
# 637:	learn: 0.6489120	total: 1m 51s	remaining: 1m 3s
# 638:	learn: 0.6488541	total: 1m 51s	remaining: 1m 3s
# 639:	learn: 0.6487070	total: 1m 52s	remaining: 1m 3s
# 640:	learn: 0.6485799	total: 1m 52s	remaining: 1m 2s
# 641:	learn: 0.6483280	total: 1m 52s	remaining: 1m 2s
# 642:	learn: 0.6481537	total: 1m 52s	remaining: 1m 2s
# 643:	learn: 0.6480182	total: 1m 52s	remaining: 1m 2s
# 644:	learn: 0.6478253	total: 1m 52s	remaining: 1m 2s
# 645:	learn: 0.6477119	total: 1m 52s	remaining: 1m 1s
# 646:	learn: 0.6474541	total: 1m 53s	remaining: 1m 1s
# 647:	learn: 0.6473114	total: 1m 53s	remaining: 1m 1s
# 648:	learn: 0.6470498	total: 1m 53s	remaining: 1m 1s
# 649:	learn: 0.6468995	total: 1m 53s	remaining: 1m 1s
# 650:	learn: 0.6468227	total: 1m 53s	remaining: 1m
# 651:	learn: 0.6467236	total: 1m 53s	remaining: 1m
# 652:	learn: 0.6464900	total: 1m 54s	remaining: 1m
# 653:	learn: 0.6461427	total: 1m 54s	remaining: 1m
# 654:	learn: 0.6460305	total: 1m 54s	remaining: 1m
# 655:	learn: 0.6457888	total: 1m 54s	remaining: 1m
# 656:	learn: 0.6455025	total: 1m 54s	remaining: 59.9s
# 657:	learn: 0.6452893	total: 1m 54s	remaining: 59.7s
# 658:	learn: 0.6451826	total: 1m 54s	remaining: 59.5s
# 659:	learn: 0.6449626	total: 1m 55s	remaining: 59.3s
# 660:	learn: 0.6448551	total: 1m 55s	remaining: 59.1s
# 661:	learn: 0.6446247	total: 1m 55s	remaining: 58.9s
# 662:	learn: 0.6443862	total: 1m 55s	remaining: 58.7s
# 663:	learn: 0.6442503	total: 1m 55s	remaining: 58.5s
# 664:	learn: 0.6441046	total: 1m 55s	remaining: 58.3s
# 665:	learn: 0.6438502	total: 1m 55s	remaining: 58.1s
# 666:	learn: 0.6436987	total: 1m 56s	remaining: 57.9s
# 667:	learn: 0.6434495	total: 1m 56s	remaining: 57.7s
# 668:	learn: 0.6432876	total: 1m 56s	remaining: 57.6s
# 669:	learn: 0.6431386	total: 1m 56s	remaining: 57.4s
# 670:	learn: 0.6429729	total: 1m 56s	remaining: 57.2s
# 671:	learn: 0.6428836	total: 1m 56s	remaining: 57s
# 672:	learn: 0.6426792	total: 1m 56s	remaining: 56.8s
# 673:	learn: 0.6425169	total: 1m 56s	remaining: 56.6s
# 674:	learn: 0.6422577	total: 1m 57s	remaining: 56.4s
# 675:	learn: 0.6420997	total: 1m 57s	remaining: 56.2s
# 676:	learn: 0.6419009	total: 1m 57s	remaining: 56.1s
# 677:	learn: 0.6416859	total: 1m 57s	remaining: 56s
# 678:	learn: 0.6416111	total: 1m 58s	remaining: 55.8s
# 679:	learn: 0.6415075	total: 1m 58s	remaining: 55.7s
# 680:	learn: 0.6414325	total: 1m 58s	remaining: 55.5s
# 681:	learn: 0.6413375	total: 1m 58s	remaining: 55.4s
# 682:	learn: 0.6410925	total: 1m 59s	remaining: 55.3s
# 683:	learn: 0.6409230	total: 1m 59s	remaining: 55.1s
# 684:	learn: 0.6407729	total: 1m 59s	remaining: 55s
# 685:	learn: 0.6405124	total: 1m 59s	remaining: 54.9s
# 686:	learn: 0.6401359	total: 2m	remaining: 54.8s
# 687:	learn: 0.6398966	total: 2m	remaining: 54.6s
# 688:	learn: 0.6396734	total: 2m	remaining: 54.5s
# 689:	learn: 0.6395004	total: 2m	remaining: 54.3s
# 690:	learn: 0.6393879	total: 2m 1s	remaining: 54.2s
# 691:	learn: 0.6392914	total: 2m 1s	remaining: 54s
# 692:	learn: 0.6392045	total: 2m 1s	remaining: 53.8s
# 693:	learn: 0.6389974	total: 2m 1s	remaining: 53.6s
# 694:	learn: 0.6388606	total: 2m 1s	remaining: 53.4s
# 695:	learn: 0.6387148	total: 2m 1s	remaining: 53.2s
# 696:	learn: 0.6386245	total: 2m 1s	remaining: 53s
# 697:	learn: 0.6384648	total: 2m 2s	remaining: 52.8s
# 698:	learn: 0.6382511	total: 2m 2s	remaining: 52.6s
# 699:	learn: 0.6380044	total: 2m 2s	remaining: 52.4s
# 700:	learn: 0.6377261	total: 2m 2s	remaining: 52.2s
# 701:	learn: 0.6375825	total: 2m 2s	remaining: 52s
# 702:	learn: 0.6373673	total: 2m 2s	remaining: 51.9s
# 703:	learn: 0.6373040	total: 2m 2s	remaining: 51.7s
# 704:	learn: 0.6370628	total: 2m 3s	remaining: 51.5s
# 705:	learn: 0.6369487	total: 2m 3s	remaining: 51.3s
# 706:	learn: 0.6368663	total: 2m 3s	remaining: 51.1s
# 707:	learn: 0.6367328	total: 2m 3s	remaining: 50.9s
# 708:	learn: 0.6366708	total: 2m 3s	remaining: 50.7s
# 709:	learn: 0.6365638	total: 2m 3s	remaining: 50.5s
# 710:	learn: 0.6363105	total: 2m 3s	remaining: 50.3s
# 711:	learn: 0.6360941	total: 2m 3s	remaining: 50.1s
# 712:	learn: 0.6359119	total: 2m 4s	remaining: 49.9s
# 713:	learn: 0.6357720	total: 2m 4s	remaining: 49.8s
# 714:	learn: 0.6355586	total: 2m 4s	remaining: 49.6s
# 715:	learn: 0.6354186	total: 2m 4s	remaining: 49.4s
# 716:	learn: 0.6352317	total: 2m 4s	remaining: 49.2s
# 717:	learn: 0.6349961	total: 2m 4s	remaining: 49s
# 718:	learn: 0.6348022	total: 2m 4s	remaining: 48.8s
# 719:	learn: 0.6346597	total: 2m 5s	remaining: 48.6s
# 720:	learn: 0.6344193	total: 2m 5s	remaining: 48.5s
# 721:	learn: 0.6342804	total: 2m 5s	remaining: 48.3s
# 722:	learn: 0.6340687	total: 2m 5s	remaining: 48.1s
# 723:	learn: 0.6338496	total: 2m 5s	remaining: 47.9s
# 724:	learn: 0.6337785	total: 2m 5s	remaining: 47.7s
# 725:	learn: 0.6337065	total: 2m 5s	remaining: 47.5s
# 726:	learn: 0.6335579	total: 2m 6s	remaining: 47.3s
# 727:	learn: 0.6332889	total: 2m 6s	remaining: 47.2s
# 728:	learn: 0.6332043	total: 2m 6s	remaining: 47s
# 729:	learn: 0.6330784	total: 2m 6s	remaining: 46.8s
# 730:	learn: 0.6328758	total: 2m 6s	remaining: 46.6s
# 731:	learn: 0.6327454	total: 2m 6s	remaining: 46.4s
# 732:	learn: 0.6325257	total: 2m 6s	remaining: 46.3s
# 733:	learn: 0.6321997	total: 2m 7s	remaining: 46.1s
# 734:	learn: 0.6320332	total: 2m 7s	remaining: 45.9s
# 735:	learn: 0.6317772	total: 2m 7s	remaining: 45.7s
# 736:	learn: 0.6315014	total: 2m 7s	remaining: 45.5s
# 737:	learn: 0.6313659	total: 2m 7s	remaining: 45.4s
# 738:	learn: 0.6311463	total: 2m 7s	remaining: 45.2s
# 739:	learn: 0.6310202	total: 2m 8s	remaining: 45s
# 740:	learn: 0.6307843	total: 2m 8s	remaining: 44.8s
# 741:	learn: 0.6306468	total: 2m 8s	remaining: 44.6s
# 742:	learn: 0.6305074	total: 2m 8s	remaining: 44.4s
# 743:	learn: 0.6303318	total: 2m 8s	remaining: 44.3s
# 744:	learn: 0.6302610	total: 2m 8s	remaining: 44.1s
# 745:	learn: 0.6301130	total: 2m 8s	remaining: 43.9s
# 746:	learn: 0.6298876	total: 2m 9s	remaining: 43.7s
# 747:	learn: 0.6297793	total: 2m 9s	remaining: 43.5s
# 748:	learn: 0.6296203	total: 2m 9s	remaining: 43.3s
# 749:	learn: 0.6294317	total: 2m 9s	remaining: 43.1s
# 750:	learn: 0.6292960	total: 2m 9s	remaining: 43s
# 751:	learn: 0.6292066	total: 2m 9s	remaining: 42.8s
# 752:	learn: 0.6290264	total: 2m 9s	remaining: 42.6s
# 753:	learn: 0.6288725	total: 2m 9s	remaining: 42.4s
# 754:	learn: 0.6286892	total: 2m 10s	remaining: 42.2s
# 755:	learn: 0.6285872	total: 2m 10s	remaining: 42s
# 756:	learn: 0.6283811	total: 2m 10s	remaining: 41.8s
# 757:	learn: 0.6283303	total: 2m 10s	remaining: 41.7s
# 758:	learn: 0.6282106	total: 2m 10s	remaining: 41.5s
# 759:	learn: 0.6280798	total: 2m 10s	remaining: 41.3s
# 760:	learn: 0.6278535	total: 2m 10s	remaining: 41.1s
# 761:	learn: 0.6276430	total: 2m 11s	remaining: 41s
# 762:	learn: 0.6274234	total: 2m 11s	remaining: 40.8s
# 763:	learn: 0.6273054	total: 2m 11s	remaining: 40.7s
# 764:	learn: 0.6270492	total: 2m 12s	remaining: 40.6s
# 765:	learn: 0.6269737	total: 2m 12s	remaining: 40.4s
# 766:	learn: 0.6268363	total: 2m 12s	remaining: 40.3s
# 767:	learn: 0.6265212	total: 2m 12s	remaining: 40.1s
# 768:	learn: 0.6263571	total: 2m 13s	remaining: 40s
# 769:	learn: 0.6262559	total: 2m 13s	remaining: 39.8s
# 770:	learn: 0.6260660	total: 2m 13s	remaining: 39.7s
# 771:	learn: 0.6258103	total: 2m 13s	remaining: 39.5s
# 772:	learn: 0.6256418	total: 2m 14s	remaining: 39.4s
# 773:	learn: 0.6255743	total: 2m 14s	remaining: 39.2s
# 774:	learn: 0.6253514	total: 2m 14s	remaining: 39.1s
# 775:	learn: 0.6251224	total: 2m 14s	remaining: 38.9s
# 776:	learn: 0.6250374	total: 2m 14s	remaining: 38.7s
# 777:	learn: 0.6249525	total: 2m 15s	remaining: 38.5s
# 778:	learn: 0.6247958	total: 2m 15s	remaining: 38.4s
# 779:	learn: 0.6247449	total: 2m 15s	remaining: 38.2s
# 780:	learn: 0.6245409	total: 2m 15s	remaining: 38s
# 781:	learn: 0.6243499	total: 2m 15s	remaining: 37.8s
# 782:	learn: 0.6241421	total: 2m 15s	remaining: 37.7s
# 783:	learn: 0.6240751	total: 2m 16s	remaining: 37.5s
# 784:	learn: 0.6238922	total: 2m 16s	remaining: 37.3s
# 785:	learn: 0.6236662	total: 2m 16s	remaining: 37.1s
# 786:	learn: 0.6234393	total: 2m 16s	remaining: 36.9s
# 787:	learn: 0.6233103	total: 2m 16s	remaining: 36.7s
# 788:	learn: 0.6232406	total: 2m 16s	remaining: 36.6s
# 789:	learn: 0.6231279	total: 2m 16s	remaining: 36.4s
# 790:	learn: 0.6227527	total: 2m 17s	remaining: 36.2s
# 791:	learn: 0.6225948	total: 2m 17s	remaining: 36s
# 792:	learn: 0.6223956	total: 2m 17s	remaining: 35.8s
# 793:	learn: 0.6223096	total: 2m 17s	remaining: 35.6s
# 794:	learn: 0.6221217	total: 2m 17s	remaining: 35.5s
# 795:	learn: 0.6219265	total: 2m 17s	remaining: 35.3s
# 796:	learn: 0.6218543	total: 2m 17s	remaining: 35.1s
# 797:	learn: 0.6216829	total: 2m 17s	remaining: 34.9s
# 798:	learn: 0.6214292	total: 2m 18s	remaining: 34.8s
# 799:	learn: 0.6213813	total: 2m 18s	remaining: 34.6s
# 800:	learn: 0.6212508	total: 2m 18s	remaining: 34.4s
# 801:	learn: 0.6209989	total: 2m 18s	remaining: 34.2s
# 802:	learn: 0.6208955	total: 2m 18s	remaining: 34s
# 803:	learn: 0.6208127	total: 2m 18s	remaining: 33.8s
# 804:	learn: 0.6207414	total: 2m 18s	remaining: 33.7s
# 805:	learn: 0.6205439	total: 2m 19s	remaining: 33.5s
# 806:	learn: 0.6202819	total: 2m 19s	remaining: 33.3s
# 807:	learn: 0.6199812	total: 2m 19s	remaining: 33.1s
# 808:	learn: 0.6198090	total: 2m 19s	remaining: 32.9s
# 809:	learn: 0.6195808	total: 2m 19s	remaining: 32.8s
# 810:	learn: 0.6194804	total: 2m 19s	remaining: 32.6s
# 811:	learn: 0.6193325	total: 2m 20s	remaining: 32.4s
# 812:	learn: 0.6192653	total: 2m 20s	remaining: 32.2s
# 813:	learn: 0.6190496	total: 2m 20s	remaining: 32.1s
# 814:	learn: 0.6189095	total: 2m 20s	remaining: 31.9s
# 815:	learn: 0.6187476	total: 2m 20s	remaining: 31.7s
# 816:	learn: 0.6185539	total: 2m 20s	remaining: 31.5s
# 817:	learn: 0.6183956	total: 2m 20s	remaining: 31.3s
# 818:	learn: 0.6182597	total: 2m 21s	remaining: 31.2s
# 819:	learn: 0.6181532	total: 2m 21s	remaining: 31s
# 820:	learn: 0.6179513	total: 2m 21s	remaining: 30.8s
# 821:	learn: 0.6177480	total: 2m 21s	remaining: 30.6s
# 822:	learn: 0.6174869	total: 2m 21s	remaining: 30.5s
# 823:	learn: 0.6174201	total: 2m 21s	remaining: 30.3s
# 824:	learn: 0.6173269	total: 2m 21s	remaining: 30.1s
# 825:	learn: 0.6172479	total: 2m 22s	remaining: 29.9s
# 826:	learn: 0.6170561	total: 2m 22s	remaining: 29.7s
# 827:	learn: 0.6169160	total: 2m 22s	remaining: 29.6s
# 828:	learn: 0.6168485	total: 2m 22s	remaining: 29.4s
# 829:	learn: 0.6167796	total: 2m 22s	remaining: 29.2s
# 830:	learn: 0.6166705	total: 2m 22s	remaining: 29s
# 831:	learn: 0.6166006	total: 2m 22s	remaining: 28.8s
# 832:	learn: 0.6165583	total: 2m 22s	remaining: 28.7s
# 833:	learn: 0.6164192	total: 2m 23s	remaining: 28.5s
# 834:	learn: 0.6163439	total: 2m 23s	remaining: 28.3s
# 835:	learn: 0.6161986	total: 2m 23s	remaining: 28.1s
# 836:	learn: 0.6161093	total: 2m 23s	remaining: 28s
# 837:	learn: 0.6160052	total: 2m 23s	remaining: 27.8s
# 838:	learn: 0.6159311	total: 2m 23s	remaining: 27.6s
# 839:	learn: 0.6158013	total: 2m 23s	remaining: 27.4s
# 840:	learn: 0.6156368	total: 2m 24s	remaining: 27.2s
# 841:	learn: 0.6154826	total: 2m 24s	remaining: 27.1s
# 842:	learn: 0.6153537	total: 2m 24s	remaining: 26.9s
# 843:	learn: 0.6150741	total: 2m 24s	remaining: 26.7s
# 844:	learn: 0.6149525	total: 2m 24s	remaining: 26.5s
# 845:	learn: 0.6148644	total: 2m 24s	remaining: 26.4s
# 846:	learn: 0.6146890	total: 2m 25s	remaining: 26.2s
# 847:	learn: 0.6145169	total: 2m 25s	remaining: 26.1s
# 848:	learn: 0.6143833	total: 2m 25s	remaining: 25.9s
# 849:	learn: 0.6142672	total: 2m 26s	remaining: 25.8s
# 850:	learn: 0.6141810	total: 2m 26s	remaining: 25.6s
# 851:	learn: 0.6139746	total: 2m 26s	remaining: 25.4s
# 852:	learn: 0.6138809	total: 2m 26s	remaining: 25.3s
# 853:	learn: 0.6137756	total: 2m 26s	remaining: 25.1s
# 854:	learn: 0.6136493	total: 2m 27s	remaining: 25s
# 855:	learn: 0.6135152	total: 2m 27s	remaining: 24.8s
# 856:	learn: 0.6134624	total: 2m 27s	remaining: 24.6s
# 857:	learn: 0.6133019	total: 2m 28s	remaining: 24.5s
# 858:	learn: 0.6131689	total: 2m 28s	remaining: 24.3s
# 859:	learn: 0.6130819	total: 2m 28s	remaining: 24.2s
# 860:	learn: 0.6129260	total: 2m 28s	remaining: 24s
# 861:	learn: 0.6127234	total: 2m 28s	remaining: 23.8s
# 862:	learn: 0.6126076	total: 2m 28s	remaining: 23.6s
# 863:	learn: 0.6124736	total: 2m 28s	remaining: 23.4s
# 864:	learn: 0.6123915	total: 2m 29s	remaining: 23.3s
# 865:	learn: 0.6123148	total: 2m 29s	remaining: 23.1s
# 866:	learn: 0.6120713	total: 2m 29s	remaining: 22.9s
# 867:	learn: 0.6119698	total: 2m 29s	remaining: 22.7s
# 868:	learn: 0.6118167	total: 2m 29s	remaining: 22.6s
# 869:	learn: 0.6117433	total: 2m 29s	remaining: 22.4s
# 870:	learn: 0.6116788	total: 2m 29s	remaining: 22.2s
# 871:	learn: 0.6114439	total: 2m 29s	remaining: 22s
# 872:	learn: 0.6113178	total: 2m 30s	remaining: 21.8s
# 873:	learn: 0.6112082	total: 2m 30s	remaining: 21.7s
# 874:	learn: 0.6111325	total: 2m 30s	remaining: 21.5s
# 875:	learn: 0.6110681	total: 2m 30s	remaining: 21.3s
# 876:	learn: 0.6109361	total: 2m 30s	remaining: 21.1s
# 877:	learn: 0.6108584	total: 2m 30s	remaining: 21s
# 878:	learn: 0.6106748	total: 2m 30s	remaining: 20.8s
# 879:	learn: 0.6105354	total: 2m 31s	remaining: 20.6s
# 880:	learn: 0.6102896	total: 2m 31s	remaining: 20.4s
# 881:	learn: 0.6101325	total: 2m 31s	remaining: 20.3s
# 882:	learn: 0.6100705	total: 2m 31s	remaining: 20.1s
# 883:	learn: 0.6099204	total: 2m 31s	remaining: 19.9s
# 884:	learn: 0.6097912	total: 2m 31s	remaining: 19.7s
# 885:	learn: 0.6096985	total: 2m 32s	remaining: 19.6s
# 886:	learn: 0.6095272	total: 2m 32s	remaining: 19.4s
# 887:	learn: 0.6092918	total: 2m 32s	remaining: 19.2s
# 888:	learn: 0.6091913	total: 2m 32s	remaining: 19s
# 889:	learn: 0.6091329	total: 2m 32s	remaining: 18.9s
# 890:	learn: 0.6089840	total: 2m 32s	remaining: 18.7s
# 891:	learn: 0.6087133	total: 2m 32s	remaining: 18.5s
# 892:	learn: 0.6084852	total: 2m 33s	remaining: 18.3s
# 893:	learn: 0.6083392	total: 2m 33s	remaining: 18.2s
# 894:	learn: 0.6081812	total: 2m 33s	remaining: 18s
# 895:	learn: 0.6079868	total: 2m 33s	remaining: 17.8s
# 896:	learn: 0.6079211	total: 2m 33s	remaining: 17.6s
# 897:	learn: 0.6077695	total: 2m 33s	remaining: 17.5s
# 898:	learn: 0.6075517	total: 2m 34s	remaining: 17.3s
# 899:	learn: 0.6074042	total: 2m 34s	remaining: 17.1s
# 900:	learn: 0.6073138	total: 2m 34s	remaining: 17s
# 901:	learn: 0.6071919	total: 2m 34s	remaining: 16.8s
# 902:	learn: 0.6070570	total: 2m 34s	remaining: 16.6s
# 903:	learn: 0.6069643	total: 2m 34s	remaining: 16.4s
# 904:	learn: 0.6067403	total: 2m 34s	remaining: 16.3s
# 905:	learn: 0.6066279	total: 2m 35s	remaining: 16.1s
# 906:	learn: 0.6065038	total: 2m 35s	remaining: 15.9s
# 907:	learn: 0.6064179	total: 2m 35s	remaining: 15.7s
# 908:	learn: 0.6062586	total: 2m 35s	remaining: 15.6s
# 909:	learn: 0.6061112	total: 2m 35s	remaining: 15.4s
# 910:	learn: 0.6059924	total: 2m 35s	remaining: 15.2s
# 911:	learn: 0.6058680	total: 2m 35s	remaining: 15s
# 912:	learn: 0.6058054	total: 2m 36s	remaining: 14.9s
# 913:	learn: 0.6055864	total: 2m 36s	remaining: 14.7s
# 914:	learn: 0.6054376	total: 2m 36s	remaining: 14.5s
# 915:	learn: 0.6053035	total: 2m 36s	remaining: 14.4s
# 916:	learn: 0.6050959	total: 2m 36s	remaining: 14.2s
# 917:	learn: 0.6049124	total: 2m 36s	remaining: 14s
# 918:	learn: 0.6048119	total: 2m 37s	remaining: 13.8s
# 919:	learn: 0.6047069	total: 2m 37s	remaining: 13.7s
# 920:	learn: 0.6046052	total: 2m 37s	remaining: 13.5s
# 921:	learn: 0.6044612	total: 2m 37s	remaining: 13.3s
# 922:	learn: 0.6043273	total: 2m 37s	remaining: 13.1s
# 923:	learn: 0.6042015	total: 2m 37s	remaining: 13s
# 924:	learn: 0.6041335	total: 2m 37s	remaining: 12.8s
# 925:	learn: 0.6039698	total: 2m 38s	remaining: 12.6s
# 926:	learn: 0.6038973	total: 2m 38s	remaining: 12.5s
# 927:	learn: 0.6037947	total: 2m 38s	remaining: 12.3s
# 928:	learn: 0.6036640	total: 2m 38s	remaining: 12.1s
# 929:	learn: 0.6035915	total: 2m 38s	remaining: 12s
# 930:	learn: 0.6034866	total: 2m 39s	remaining: 11.8s
# 931:	learn: 0.6034314	total: 2m 39s	remaining: 11.6s
# ...
# 702:	learn: 0.6366391	total: 3m 14s	remaining: 1m 22s
# 703:	learn: 0.6365279	total: 3m 14s	remaining: 1m 21s
# 704:	learn: 0.6363564	total: 3m 14s	remaining: 1m 21s
# 705:	learn: 0.6362047	total: 3m 14s	remaining: 1m 21s
# 706:	learn: 0.6360215	total: 3m 15s	remaining: 1m 20s
# 707:	learn: 0.6358204	total: 3m 15s	remaining: 1m 20s
# 708:	learn: 0.6357082	total: 3m 15s	remaining: 1m 20s
# 709:	learn: 0.6355364	total: 3m 15s	remaining: 1m 19s
# 710:	learn: 0.6351952	total: 3m 16s	remaining: 1m 19s
# 711:	learn: 0.6350955	total: 3m 16s	remaining: 1m 19s
# 712:	learn: 0.6348532	total: 3m 16s	remaining: 1m 19s
# 713:	learn: 0.6347202	total: 3m 16s	remaining: 1m 18s
# 714:	learn: 0.6345681	total: 3m 16s	remaining: 1m 18s
# 715:	learn: 0.6343552	total: 3m 17s	remaining: 1m 18s
# 716:	learn: 0.6342339	total: 3m 17s	remaining: 1m 17s
# 717:	learn: 0.6340408	total: 3m 17s	remaining: 1m 17s
# 718:	learn: 0.6339811	total: 3m 17s	remaining: 1m 17s
# 719:	learn: 0.6337071	total: 3m 18s	remaining: 1m 17s
# 720:	learn: 0.6335119	total: 3m 18s	remaining: 1m 16s
# 721:	learn: 0.6332593	total: 3m 18s	remaining: 1m 16s
# 722:	learn: 0.6330929	total: 3m 18s	remaining: 1m 16s
# 723:	learn: 0.6328644	total: 3m 19s	remaining: 1m 15s
# 724:	learn: 0.6326171	total: 3m 19s	remaining: 1m 15s
# 725:	learn: 0.6324533	total: 3m 19s	remaining: 1m 15s
# 726:	learn: 0.6322372	total: 3m 19s	remaining: 1m 15s
# 727:	learn: 0.6320331	total: 3m 20s	remaining: 1m 14s
# 728:	learn: 0.6318854	total: 3m 20s	remaining: 1m 14s
# 729:	learn: 0.6316883	total: 3m 20s	remaining: 1m 14s
# 730:	learn: 0.6314300	total: 3m 20s	remaining: 1m 13s
# 731:	learn: 0.6310066	total: 3m 21s	remaining: 1m 13s
# 732:	learn: 0.6308752	total: 3m 21s	remaining: 1m 13s
# 733:	learn: 0.6306308	total: 3m 21s	remaining: 1m 13s
# 734:	learn: 0.6304534	total: 3m 21s	remaining: 1m 12s
# 735:	learn: 0.6303443	total: 3m 22s	remaining: 1m 12s
# 736:	learn: 0.6301306	total: 3m 22s	remaining: 1m 12s
# 737:	learn: 0.6298844	total: 3m 22s	remaining: 1m 11s
# 738:	learn: 0.6297624	total: 3m 22s	remaining: 1m 11s
# 739:	learn: 0.6294833	total: 3m 23s	remaining: 1m 11s
# 740:	learn: 0.6293999	total: 3m 23s	remaining: 1m 11s
# 741:	learn: 0.6291339	total: 3m 23s	remaining: 1m 10s
# 742:	learn: 0.6288967	total: 3m 23s	remaining: 1m 10s
# 743:	learn: 0.6285510	total: 3m 24s	remaining: 1m 10s
# 744:	learn: 0.6283152	total: 3m 24s	remaining: 1m 10s
# 745:	learn: 0.6280969	total: 3m 25s	remaining: 1m 9s
# 746:	learn: 0.6279036	total: 3m 25s	remaining: 1m 9s
# 747:	learn: 0.6278416	total: 3m 26s	remaining: 1m 9s
# 748:	learn: 0.6277039	total: 3m 26s	remaining: 1m 9s
# 749:	learn: 0.6275846	total: 3m 26s	remaining: 1m 8s
# 750:	learn: 0.6274250	total: 3m 27s	remaining: 1m 8s
# 751:	learn: 0.6272528	total: 3m 27s	remaining: 1m 8s
# 752:	learn: 0.6268221	total: 3m 28s	remaining: 1m 8s
# 753:	learn: 0.6265688	total: 3m 28s	remaining: 1m 8s
# 754:	learn: 0.6264953	total: 3m 28s	remaining: 1m 7s
# 755:	learn: 0.6264080	total: 3m 28s	remaining: 1m 7s
# 756:	learn: 0.6260408	total: 3m 29s	remaining: 1m 7s
# 757:	learn: 0.6258380	total: 3m 29s	remaining: 1m 6s
# 758:	learn: 0.6257387	total: 3m 29s	remaining: 1m 6s
# 759:	learn: 0.6255935	total: 3m 29s	remaining: 1m 6s
# 760:	learn: 0.6254247	total: 3m 30s	remaining: 1m 5s
# 761:	learn: 0.6252761	total: 3m 30s	remaining: 1m 5s
# 762:	learn: 0.6249429	total: 3m 30s	remaining: 1m 5s
# 763:	learn: 0.6247920	total: 3m 30s	remaining: 1m 5s
# 764:	learn: 0.6246193	total: 3m 31s	remaining: 1m 4s
# 765:	learn: 0.6243460	total: 3m 31s	remaining: 1m 4s
# 766:	learn: 0.6240915	total: 3m 31s	remaining: 1m 4s
# 767:	learn: 0.6239162	total: 3m 31s	remaining: 1m 3s
# 768:	learn: 0.6237349	total: 3m 32s	remaining: 1m 3s
# 769:	learn: 0.6235081	total: 3m 32s	remaining: 1m 3s
# 770:	learn: 0.6233170	total: 3m 32s	remaining: 1m 3s
# 771:	learn: 0.6230812	total: 3m 32s	remaining: 1m 2s
# 772:	learn: 0.6229064	total: 3m 33s	remaining: 1m 2s
# 773:	learn: 0.6227035	total: 3m 33s	remaining: 1m 2s
# 774:	learn: 0.6225390	total: 3m 33s	remaining: 1m 2s
# 775:	learn: 0.6224208	total: 3m 33s	remaining: 1m 1s
# 776:	learn: 0.6222555	total: 3m 34s	remaining: 1m 1s
# 777:	learn: 0.6220716	total: 3m 34s	remaining: 1m 1s
# 778:	learn: 0.6219211	total: 3m 34s	remaining: 1m
# 779:	learn: 0.6217171	total: 3m 34s	remaining: 1m
# 780:	learn: 0.6215107	total: 3m 35s	remaining: 1m
# 781:	learn: 0.6213165	total: 3m 35s	remaining: 1m
# 782:	learn: 0.6211539	total: 3m 35s	remaining: 59.8s
# 783:	learn: 0.6210300	total: 3m 35s	remaining: 59.5s
# 784:	learn: 0.6209530	total: 3m 36s	remaining: 59.2s
# 785:	learn: 0.6207900	total: 3m 36s	remaining: 58.9s
# 786:	learn: 0.6205512	total: 3m 36s	remaining: 58.6s
# 787:	learn: 0.6203471	total: 3m 36s	remaining: 58.4s
# 788:	learn: 0.6201989	total: 3m 37s	remaining: 58.1s
# 789:	learn: 0.6200062	total: 3m 37s	remaining: 57.8s
# 790:	learn: 0.6198930	total: 3m 37s	remaining: 57.5s
# 791:	learn: 0.6196477	total: 3m 37s	remaining: 57.2s
# 792:	learn: 0.6194793	total: 3m 38s	remaining: 56.9s
# 793:	learn: 0.6193620	total: 3m 38s	remaining: 56.7s
# 794:	learn: 0.6191804	total: 3m 38s	remaining: 56.5s
# 795:	learn: 0.6189697	total: 3m 39s	remaining: 56.2s
# 796:	learn: 0.6188754	total: 3m 39s	remaining: 56s
# 797:	learn: 0.6187400	total: 3m 40s	remaining: 55.7s
# 798:	learn: 0.6185220	total: 3m 40s	remaining: 55.5s
# 799:	learn: 0.6182999	total: 3m 41s	remaining: 55.3s
# 800:	learn: 0.6181623	total: 3m 41s	remaining: 55s
# 801:	learn: 0.6179410	total: 3m 41s	remaining: 54.8s
# 802:	learn: 0.6177249	total: 3m 42s	remaining: 54.5s
# 803:	learn: 0.6174934	total: 3m 42s	remaining: 54.2s
# 804:	learn: 0.6174399	total: 3m 42s	remaining: 53.9s
# 805:	learn: 0.6172323	total: 3m 42s	remaining: 53.7s
# 806:	learn: 0.6170875	total: 3m 43s	remaining: 53.4s
# 807:	learn: 0.6169802	total: 3m 43s	remaining: 53.1s
# 808:	learn: 0.6168059	total: 3m 43s	remaining: 52.8s
# 809:	learn: 0.6165637	total: 3m 43s	remaining: 52.5s
# 810:	learn: 0.6163197	total: 3m 44s	remaining: 52.2s
# 811:	learn: 0.6162012	total: 3m 44s	remaining: 51.9s
# 812:	learn: 0.6160950	total: 3m 44s	remaining: 51.6s
# 813:	learn: 0.6159529	total: 3m 44s	remaining: 51.3s
# 814:	learn: 0.6158161	total: 3m 44s	remaining: 51.1s
# 815:	learn: 0.6156396	total: 3m 45s	remaining: 50.8s
# 816:	learn: 0.6155607	total: 3m 45s	remaining: 50.5s
# 817:	learn: 0.6153620	total: 3m 45s	remaining: 50.2s
# 818:	learn: 0.6151867	total: 3m 46s	remaining: 50s
# 819:	learn: 0.6150346	total: 3m 46s	remaining: 49.7s
# 820:	learn: 0.6149131	total: 3m 46s	remaining: 49.4s
# 821:	learn: 0.6148021	total: 3m 46s	remaining: 49.1s
# 822:	learn: 0.6145762	total: 3m 46s	remaining: 48.8s
# 823:	learn: 0.6144364	total: 3m 47s	remaining: 48.5s
# 824:	learn: 0.6142367	total: 3m 47s	remaining: 48.2s
# 825:	learn: 0.6140740	total: 3m 47s	remaining: 48s
# 826:	learn: 0.6139785	total: 3m 47s	remaining: 47.7s
# 827:	learn: 0.6138857	total: 3m 48s	remaining: 47.4s
# 828:	learn: 0.6137309	total: 3m 48s	remaining: 47.1s
# 829:	learn: 0.6135863	total: 3m 48s	remaining: 46.8s
# 830:	learn: 0.6134865	total: 3m 48s	remaining: 46.5s
# 831:	learn: 0.6132905	total: 3m 49s	remaining: 46.2s
# 832:	learn: 0.6130999	total: 3m 49s	remaining: 46s
# 833:	learn: 0.6130162	total: 3m 49s	remaining: 45.7s
# 834:	learn: 0.6129394	total: 3m 49s	remaining: 45.4s
# 835:	learn: 0.6127678	total: 3m 49s	remaining: 45.1s
# 836:	learn: 0.6125803	total: 3m 50s	remaining: 44.8s
# 837:	learn: 0.6124050	total: 3m 50s	remaining: 44.5s
# 838:	learn: 0.6121645	total: 3m 50s	remaining: 44.3s
# 839:	learn: 0.6118716	total: 3m 50s	remaining: 44s
# 840:	learn: 0.6116624	total: 3m 51s	remaining: 43.7s
# 841:	learn: 0.6115923	total: 3m 51s	remaining: 43.4s
# 842:	learn: 0.6113873	total: 3m 51s	remaining: 43.2s
# 843:	learn: 0.6111974	total: 3m 52s	remaining: 42.9s
# 844:	learn: 0.6110013	total: 3m 52s	remaining: 42.7s
# 845:	learn: 0.6109286	total: 3m 53s	remaining: 42.4s
# 846:	learn: 0.6108054	total: 3m 53s	remaining: 42.2s
# 847:	learn: 0.6106313	total: 3m 53s	remaining: 41.9s
# 848:	learn: 0.6104865	total: 3m 54s	remaining: 41.7s
# 849:	learn: 0.6103914	total: 3m 54s	remaining: 41.4s
# 850:	learn: 0.6102964	total: 3m 55s	remaining: 41.2s
# 851:	learn: 0.6101782	total: 3m 55s	remaining: 40.9s
# 852:	learn: 0.6100724	total: 3m 55s	remaining: 40.6s
# 853:	learn: 0.6098867	total: 3m 55s	remaining: 40.3s
# 854:	learn: 0.6097529	total: 3m 56s	remaining: 40s
# 855:	learn: 0.6095198	total: 3m 56s	remaining: 39.8s
# 856:	learn: 0.6093544	total: 3m 56s	remaining: 39.5s
# 857:	learn: 0.6092021	total: 3m 56s	remaining: 39.2s
# 858:	learn: 0.6090835	total: 3m 57s	remaining: 38.9s
# 859:	learn: 0.6089394	total: 3m 57s	remaining: 38.6s
# 860:	learn: 0.6088141	total: 3m 57s	remaining: 38.3s
# 861:	learn: 0.6087269	total: 3m 57s	remaining: 38.1s
# 862:	learn: 0.6085811	total: 3m 57s	remaining: 37.8s
# 863:	learn: 0.6084928	total: 3m 58s	remaining: 37.5s
# 864:	learn: 0.6082830	total: 3m 58s	remaining: 37.2s
# 865:	learn: 0.6081540	total: 3m 58s	remaining: 36.9s
# 866:	learn: 0.6079811	total: 3m 58s	remaining: 36.6s
# 867:	learn: 0.6078705	total: 3m 59s	remaining: 36.4s
# 868:	learn: 0.6076557	total: 3m 59s	remaining: 36.1s
# 869:	learn: 0.6075761	total: 3m 59s	remaining: 35.8s
# 870:	learn: 0.6074683	total: 3m 59s	remaining: 35.5s
# 871:	learn: 0.6073874	total: 4m	remaining: 35.2s
# 872:	learn: 0.6073132	total: 4m	remaining: 35s
# 873:	learn: 0.6071566	total: 4m	remaining: 34.7s
# 874:	learn: 0.6069115	total: 4m	remaining: 34.4s
# 875:	learn: 0.6067548	total: 4m	remaining: 34.1s
# 876:	learn: 0.6066102	total: 4m 1s	remaining: 33.8s
# 877:	learn: 0.6064350	total: 4m 1s	remaining: 33.6s
# 878:	learn: 0.6063288	total: 4m 1s	remaining: 33.3s
# 879:	learn: 0.6060894	total: 4m 1s	remaining: 33s
# 880:	learn: 0.6059287	total: 4m 2s	remaining: 32.7s
# 881:	learn: 0.6057629	total: 4m 2s	remaining: 32.4s
# 882:	learn: 0.6056099	total: 4m 2s	remaining: 32.1s
# 883:	learn: 0.6054623	total: 4m 2s	remaining: 31.9s
# 884:	learn: 0.6052485	total: 4m 3s	remaining: 31.6s
# 885:	learn: 0.6051532	total: 4m 3s	remaining: 31.3s
# 886:	learn: 0.6050010	total: 4m 3s	remaining: 31s
# 887:	learn: 0.6048839	total: 4m 3s	remaining: 30.7s
# 888:	learn: 0.6048156	total: 4m 3s	remaining: 30.5s
# 889:	learn: 0.6046581	total: 4m 4s	remaining: 30.2s
# 890:	learn: 0.6044156	total: 4m 4s	remaining: 29.9s
# 891:	learn: 0.6043300	total: 4m 4s	remaining: 29.6s
# 892:	learn: 0.6040979	total: 4m 4s	remaining: 29.3s
# 893:	learn: 0.6038621	total: 4m 5s	remaining: 29.1s
# 894:	learn: 0.6037242	total: 4m 5s	remaining: 28.8s
# 895:	learn: 0.6036369	total: 4m 5s	remaining: 28.5s
# 896:	learn: 0.6035652	total: 4m 5s	remaining: 28.2s
# 897:	learn: 0.6033663	total: 4m 6s	remaining: 28s
# 898:	learn: 0.6031773	total: 4m 6s	remaining: 27.7s
# 899:	learn: 0.6030372	total: 4m 7s	remaining: 27.5s
# 900:	learn: 0.6027907	total: 4m 7s	remaining: 27.2s
# 901:	learn: 0.6026837	total: 4m 8s	remaining: 27s
# 902:	learn: 0.6025042	total: 4m 8s	remaining: 26.7s
# 903:	learn: 0.6024157	total: 4m 9s	remaining: 26.5s
# 904:	learn: 0.6022172	total: 4m 9s	remaining: 26.2s
# 905:	learn: 0.6020985	total: 4m 9s	remaining: 25.9s
# 906:	learn: 0.6019651	total: 4m 9s	remaining: 25.6s
# 907:	learn: 0.6018495	total: 4m 10s	remaining: 25.4s
# 908:	learn: 0.6015464	total: 4m 10s	remaining: 25.1s
# 909:	learn: 0.6014659	total: 4m 10s	remaining: 24.8s
# 910:	learn: 0.6011804	total: 4m 11s	remaining: 24.5s
# 911:	learn: 0.6010356	total: 4m 11s	remaining: 24.2s
# 912:	learn: 0.6009006	total: 4m 11s	remaining: 24s
# 913:	learn: 0.6007768	total: 4m 11s	remaining: 23.7s
# 914:	learn: 0.6005985	total: 4m 11s	remaining: 23.4s
# 915:	learn: 0.6004401	total: 4m 12s	remaining: 23.1s
# 916:	learn: 0.6002693	total: 4m 12s	remaining: 22.8s
# 917:	learn: 0.6000462	total: 4m 12s	remaining: 22.6s
# 918:	learn: 0.5999107	total: 4m 12s	remaining: 22.3s
# 919:	learn: 0.5997592	total: 4m 13s	remaining: 22s
# 920:	learn: 0.5995883	total: 4m 13s	remaining: 21.7s
# 921:	learn: 0.5993780	total: 4m 13s	remaining: 21.5s
# 922:	learn: 0.5992795	total: 4m 13s	remaining: 21.2s
# 923:	learn: 0.5990440	total: 4m 14s	remaining: 20.9s
# 924:	learn: 0.5989314	total: 4m 14s	remaining: 20.6s
# 925:	learn: 0.5987354	total: 4m 14s	remaining: 20.3s
# 926:	learn: 0.5985609	total: 4m 14s	remaining: 20.1s
# 927:	learn: 0.5983779	total: 4m 15s	remaining: 19.8s
# 928:	learn: 0.5982693	total: 4m 15s	remaining: 19.5s
# 929:	learn: 0.5981896	total: 4m 15s	remaining: 19.2s
# 930:	learn: 0.5980599	total: 4m 15s	remaining: 19s
# 931:	learn: 0.5979104	total: 4m 16s	remaining: 18.7s
# 932:	learn: 0.5978040	total: 4m 16s	remaining: 18.4s
# 933:	learn: 0.5976839	total: 4m 16s	remaining: 18.1s
# 934:	learn: 0.5976324	total: 4m 16s	remaining: 17.8s
# 935:	learn: 0.5975695	total: 4m 16s	remaining: 17.6s
# 936:	learn: 0.5974167	total: 4m 17s	remaining: 17.3s
# 937:	learn: 0.5972669	total: 4m 17s	remaining: 17s
# 938:	learn: 0.5971696	total: 4m 17s	remaining: 16.7s
# 939:	learn: 0.5971098	total: 4m 17s	remaining: 16.4s
# 940:	learn: 0.5970186	total: 4m 17s	remaining: 16.2s
# 941:	learn: 0.5968094	total: 4m 18s	remaining: 15.9s
# 942:	learn: 0.5967059	total: 4m 18s	remaining: 15.6s
# 943:	learn: 0.5966046	total: 4m 18s	remaining: 15.3s
# 944:	learn: 0.5964865	total: 4m 18s	remaining: 15.1s
# 945:	learn: 0.5963031	total: 4m 19s	remaining: 14.8s
# 946:	learn: 0.5962653	total: 4m 19s	remaining: 14.5s
# 947:	learn: 0.5961937	total: 4m 19s	remaining: 14.2s
# 948:	learn: 0.5960553	total: 4m 19s	remaining: 14s
# 949:	learn: 0.5958981	total: 4m 20s	remaining: 13.7s
# 950:	learn: 0.5957455	total: 4m 20s	remaining: 13.4s
# 951:	learn: 0.5955668	total: 4m 21s	remaining: 13.2s
# 952:	learn: 0.5953778	total: 4m 21s	remaining: 12.9s
# 953:	learn: 0.5952354	total: 4m 22s	remaining: 12.6s
# 954:	learn: 0.5950754	total: 4m 22s	remaining: 12.4s
# 955:	learn: 0.5949529	total: 4m 22s	remaining: 12.1s
# 956:	learn: 0.5948143	total: 4m 23s	remaining: 11.8s
# 957:	learn: 0.5946596	total: 4m 23s	remaining: 11.6s
# 958:	learn: 0.5944264	total: 4m 23s	remaining: 11.3s
# 959:	learn: 0.5943712	total: 4m 23s	remaining: 11s
# 960:	learn: 0.5942610	total: 4m 24s	remaining: 10.7s
# 961:	learn: 0.5940398	total: 4m 24s	remaining: 10.4s
# 962:	learn: 0.5938814	total: 4m 24s	remaining: 10.2s
# 963:	learn: 0.5937736	total: 4m 24s	remaining: 9.89s
# 964:	learn: 0.5936120	total: 4m 25s	remaining: 9.62s
# 965:	learn: 0.5934888	total: 4m 25s	remaining: 9.34s
# 966:	learn: 0.5933086	total: 4m 25s	remaining: 9.06s
# 967:	learn: 0.5931364	total: 4m 25s	remaining: 8.79s
# 968:	learn: 0.5929862	total: 4m 26s	remaining: 8.52s
# 969:	learn: 0.5928533	total: 4m 26s	remaining: 8.24s
# 970:	learn: 0.5927483	total: 4m 26s	remaining: 7.96s
# 971:	learn: 0.5926552	total: 4m 26s	remaining: 7.68s
# 972:	learn: 0.5925815	total: 4m 26s	remaining: 7.41s
# 973:	learn: 0.5924467	total: 4m 27s	remaining: 7.13s
# 974:	learn: 0.5923036	total: 4m 27s	remaining: 6.86s
# 975:	learn: 0.5921228	total: 4m 27s	remaining: 6.58s
# 976:	learn: 0.5920061	total: 4m 27s	remaining: 6.31s
# 977:	learn: 0.5918770	total: 4m 28s	remaining: 6.03s
# 978:	learn: 0.5916827	total: 4m 28s	remaining: 5.76s
# 979:	learn: 0.5915272	total: 4m 28s	remaining: 5.48s
# 980:	learn: 0.5913743	total: 4m 28s	remaining: 5.21s
# 981:	learn: 0.5913060	total: 4m 29s	remaining: 4.93s
# 982:	learn: 0.5911282	total: 4m 29s	remaining: 4.66s
# 983:	learn: 0.5908802	total: 4m 29s	remaining: 4.38s
# 984:	learn: 0.5907914	total: 4m 29s	remaining: 4.11s
# 985:	learn: 0.5906259	total: 4m 30s	remaining: 3.83s
# 986:	learn: 0.5905446	total: 4m 30s	remaining: 3.56s
# 987:	learn: 0.5904161	total: 4m 30s	remaining: 3.29s
# 988:	learn: 0.5903331	total: 4m 30s	remaining: 3.01s
# 989:	learn: 0.5901529	total: 4m 30s	remaining: 2.74s
# 990:	learn: 0.5899950	total: 4m 31s	remaining: 2.46s
# 991:	learn: 0.5898149	total: 4m 31s	remaining: 2.19s
# 992:	learn: 0.5896237	total: 4m 31s	remaining: 1.92s
# 993:	learn: 0.5895123	total: 4m 31s	remaining: 1.64s
# 994:	learn: 0.5893136	total: 4m 32s	remaining: 1.37s
# 995:	learn: 0.5891789	total: 4m 32s	remaining: 1.09s
# 996:	learn: 0.5891207	total: 4m 32s	remaining: 820ms
# 997:	learn: 0.5889689	total: 4m 32s	remaining: 547ms
# 998:	learn: 0.5887956	total: 4m 33s	remaining: 273ms
# 999:	learn: 0.5887031	total: 4m 33s	remaining: 0us
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.75
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# #Result Analysis

# %%
import pandas as pd
import os
import glob


csv_files = glob.glob(os.path.join("/content/non_random", "*.csv"))

final_dataset = pd.DataFrame()

for f in csv_files:
            df_temp = pd.read_csv(f)
            final_dataset = final_dataset.append(df_temp, ignore_index=True)

# %% [markdown]
# ##Sorting according to accuracy

# %%
final_dataset = final_dataset.sort_values("accurecy",ascending=False,kind="mergesort")
final_dataset = final_dataset.reset_index(drop = True)

# %% [markdown]
# ##Saving

# %%
final_dataset.to_csv("Final.csv",index=False)
