# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM.csv")

# %%
dataset.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0        NREM         0.00034          10.11512        17.85756
# 1        NREM         0.00035          10.73951        17.60780
# 2        NREM         0.00035           9.36585        17.60780
# 3        NREM         0.00050          10.36488        16.60878
# 4        NREM         0.00072           9.36585        15.98439
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293        10.24000        0.00047         17.73268
# 1                17.10829         9.11610        0.00048         16.85854
# 2                16.98341         9.24098        0.00042         17.35805
# 3                15.85951         7.99220        0.00053         15.48488
# 4                15.48488         7.99220        0.00067         15.11024
#
#    MeanF_Beta_F4  Spectral Edge_Beta_F4  ...  MeanP_Delta_O2  \
# 0       25.35024               27.47317  ...         0.00112
# 1       25.22537               26.97366  ...         0.00070
# 2       26.09951               28.47220  ...         0.00077
# 3       24.10146               25.72488  ...         0.00130
# 4       22.22829               23.22732  ...         0.00123
#
#    MedianF_Delta_O2  MeanF_Delta_O2  Spectral Edge_Delta_O2  PeakF_Delta_O2  \
# 0           0.74927         6.36878                 2.87220         0.62439
# 1           0.99902         6.86829                 3.62146         0.74927
# 2           1.49854         6.49366                 4.12098         0.74927
# 3           1.87317         6.11902                 3.74634         0.37463
# 4           1.49854         6.61854                 3.74634         0.74927
#
#    MeanP_Gamma_O2  MedianF_Gamma_O2  MeanF_Gamma_O2  Spectral Edge_Gamma_O2  \
# 0        0.000076          32.71805        43.83220                49.95122
# 1        0.000072          32.09366        44.33171                49.95122
# 2        0.000069          33.09268        43.95707                49.95122
# 3        0.000070          31.59415        42.83317                49.95122
# 4        0.000060          29.47122        45.08098                49.95122
#
#    PeakF_Gamma_O2
# 0        49.95122
# 1        49.95122
# 2        49.95122
# 3        49.95122
# 4        49.95122
#
# [5 rows x 76 columns]

# %%
X = dataset.iloc[:, 1:]
y = dataset.iloc[:, 0]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
 
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import AdaBoostClassifier

classifier = AdaBoostClassifier(random_state=0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
# Out:
# [[13706   754]
#  [ 1554  1806]]
#               precision    recall  f1-score   support
#
#         NREM       0.90      0.95      0.92     14460
#          REM       0.71      0.54      0.61      3360
#
#     accuracy                           0.87     17820
#    macro avg       0.80      0.74      0.77     17820
# weighted avg       0.86      0.87      0.86     17820
#
# Accurecy:  0.8704826038159371

# %%
from sklearn.ensemble import AdaBoostClassifier
N=100
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = AdaBoostClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt
#plot the relationship between K and the testing accuracy
plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



# 55/100 round completed......................... Accurecy: 0.8701459034792368
# 56/100 round completed......................... Accurecy: 0.8709876543209877
# 57/100 round completed......................... Accurecy: 0.871324354657688
# 58/100 round completed......................... Accurecy: 0.8707631874298541
# 59/100 round completed......................... Accurecy: 0.8709315375982043
# 60/100 round completed......................... Accurecy: 0.8713804713804714
# 61/100 round completed......................... Accurecy: 0.8714365881032548
# 62/100 round completed......................... Accurecy: 0.8718294051627385
# 63/100 round completed......................... Accurecy: 0.8712682379349046
# 64/100 round completed......................... Accurecy: 0.8721099887766555
# 65/100 round completed......................... Accurecy: 0.8721661054994388
# 66/100 round completed......................... Accurecy: 0.8738496071829405
# 67/100 round completed......................... Accurecy: 0.8727272727272727
# 68/100 round completed......................... Accurecy: 0.8727272727272727
# 69/100 round completed......................... Accurecy: 0.8734567901234568
# 70/100 round completed......................... Accurecy: 0.8738496071829405
# 71/100 round completed......................... Accurecy: 0.8742985409652076
# 72/100 round completed......................... Accurecy: 0.8741863075196409
# 73/100 round completed......................... Accurecy: 0.8751402918069585
# 74/100 round completed......................... Accurecy: 0.8745791245791246
# 75/100 round completed......................... Accurecy: 0.874635241301908
# 76/100 round completed......................... Accurecy: 0.8747474747474747
# 77/100 round completed......................... Accurecy: 0.8745791245791246
# 78/100 round completed......................... Accurecy: 0.874354657687991
# 79/100 round completed......................... Accurecy: 0.8757014590347924
# 80/100 round completed......................... Accurecy: 0.874354657687991
# 81/100 round completed......................... Accurecy: 0.8741863075196409
# 82/100 round completed......................... Accurecy: 0.8748597081930415
# 83/100 round completed......................... Accurecy: 0.8757014590347924
# 84/100 round completed......................... Accurecy: 0.874635241301908
# 85/100 round completed......................... Accurecy: 0.8751402918069585
# 86/100 round completed......................... Accurecy: 0.8749158249158249
# 87/100 round completed......................... Accurecy: 0.8759259259259259
# 88/100 round completed......................... Accurecy: 0.8764309764309764
# 89/100 round completed......................... Accurecy: 0.8772727272727273
# 90/100 round completed......................... Accurecy: 0.8769921436588103
# 91/100 round completed......................... Accurecy: 0.8767115600448934
# 92/100 round completed......................... Accurecy: 0.877104377104377
# 93/100 round completed......................... Accurecy: 0.8770482603815937
# 94/100 round completed......................... Accurecy: 0.8768237934904601
# 95/100 round completed......................... Accurecy: 0.8769921436588103
# 96/100 round completed......................... Accurecy: 0.8768799102132435
# 97/100 round completed......................... Accurecy: 0.8772166105499439
# 98/100 round completed......................... Accurecy: 0.8776094276094276
# 99/100 round completed......................... Accurecy: 0.8774971941638608
# 100/100 round completed......................... Accurecy: 0.8774971941638608
# The best n_estimators:
# 98

# %%
from sklearn.ensemble import AdaBoostClassifier

classifier = AdaBoostClassifier(n_estimators=best_estimator,random_state=0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
# Out:
# [[13678   782]
#  [ 1399  1961]]
#               precision    recall  f1-score   support
#
#         NREM       0.91      0.95      0.93     14460
#          REM       0.71      0.58      0.64      3360
#
#     accuracy                           0.88     17820
#    macro avg       0.81      0.76      0.78     17820
# weighted avg       0.87      0.88      0.87     17820
#
# Accurecy:  0.8776094276094276
