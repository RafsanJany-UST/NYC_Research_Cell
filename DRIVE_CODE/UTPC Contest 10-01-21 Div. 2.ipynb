# %% [markdown]
# #A

# %%
t,g=input().split()
talika=[]
for i in range(1,int(t)+1):
    talika.append(i)
if g=='a':
  print(*talika)
else:
  talika.sort(reverse=True)
  print(*talika)
# Out:
# 4 d
# 4 3 2 1

# %% [markdown]
# #B

# %%
n=list(map(int,input().split()))
k=list(map(int,input().split()))
if (max(k)<n[1]):
  print("Easy Win!")
else:
  print("Difficult Loss")
# Out:
# 3 4
# 1 2 3
# Easy Win!
