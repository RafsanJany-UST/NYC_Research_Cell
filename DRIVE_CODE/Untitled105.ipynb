# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tqdm.notebook import tqdm

def Search_Some(dataset,some):
  dic={}
  for col in tqdm(list(dataset.columns)):
    rows = []
    flage = 0
  
    for row in range(dataset.shape[0]):
      if str(dataset[col][row]) == some:
        rows.append(row)
        flage = 1
    if flage ==1:
      dic[col] = rows
  
  return dic

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Sleep Stage 5 class/old docs/EEG_HMC_FeatureExtraction_2023.01.19.csv')

# %%
df.head()
# Out:
#   Subject Sleep Stage  Epoch  MeanP_Alpha_F4  MeanP_Beta_F4  MeanP_Theta_F4  \
# 0   SN002           W      0         0.00051        0.00071         0.00121
# 1   SN002           W      1         0.00040        0.00051         0.00062
# 2   SN002           W      2         0.00036        0.00047         0.00059
# 3   SN002           W      3         0.00035        0.00047         0.00043
# 4   SN002           W      4         0.00033        0.00043         0.00053
#
#    MeanP_Delta_F4  MeanP_Gamma_F4  MeanP_Alpha_C4  MeanP_Beta_C4  ...  DAR_C4  \
# 0         0.01070        0.000240         0.00041        0.00067  ...    8.61
# 1         0.00539        0.000120         0.00038        0.00052  ...    6.26
# 2         0.00967        0.000100         0.00036        0.00049  ...    8.67
# 3         0.00228        0.000110         0.00036        0.00053  ...    4.00
# 4         0.00436        0.000094         0.00031        0.00043  ...    4.81
#
# ...

# %%
df.shape
# Out:
# (108920, 52)

# %%
df = df.loc[:,df.columns != "Subject"]
df = df.loc[:,df.columns != "Epoch"]

# %%
df.head()
# Out:
#   Sleep Stage  MeanP_Alpha_F4  MeanP_Beta_F4  MeanP_Theta_F4  MeanP_Delta_F4  \
# 0           W         0.00051        0.00071         0.00121         0.01070
# 1           W         0.00040        0.00051         0.00062         0.00539
# 2           W         0.00036        0.00047         0.00059         0.00967
# 3           W         0.00035        0.00047         0.00043         0.00228
# 4           W         0.00033        0.00043         0.00053         0.00436
#
#    MeanP_Gamma_F4  MeanP_Alpha_C4  MeanP_Beta_C4  MeanP_Theta_C4  \
# 0        0.000240         0.00041        0.00067         0.00061
# 1        0.000120         0.00038        0.00052         0.00046
# 2        0.000100         0.00036        0.00049         0.00044
# 3        0.000110         0.00036        0.00053         0.00040
# 4        0.000094         0.00031        0.00043         0.00038
#
#    MeanP_Delta_C4  ...  DAR_C4  DAR_O2  DAR_G  DTR_F4  DTR_O2  DTABR_F4  \
# ...

# %%
d = Search_Some(df,'nan')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5627075660fe> in <cell line: 1>()
# ----> 1 d = Search_Some(df,'nan')
#
# NameError: name 'Search_Some' is not defined

# %%
df.describe()
# Out:
#        MeanP_Alpha_F4  MeanP_Beta_F4  MeanP_Theta_F4  MeanP_Delta_F4  \
# count    1.089200e+05  108920.000000    1.089200e+05    1.089200e+05
# mean     1.311837e-03       0.001247    2.607244e-03    2.431503e-02
# std      1.229675e-02       0.007996    2.915802e-02    1.426558e-01
# min      4.590000e-52       0.000000    2.290000e-41    2.290000e-40
# 25%      3.700000e-04       0.000310    5.800000e-04    2.290000e-03
# 50%      5.900000e-04       0.000480    9.400000e-04    5.060000e-03
# 75%      9.400000e-04       0.000790    1.550000e-03    1.200000e-02
# max      1.030000e+00       0.578000    2.100000e+00    7.820000e+00
#
#        MeanP_Gamma_F4  MeanP_Alpha_C4  MeanP_Beta_C4  MeanP_Theta_C4  \
# count   108920.000000    1.089200e+05  108450.000000    1.084500e+05
# mean         0.000697    1.716932e-03       0.003518    3.112729e-03
# std          0.007936    1.550973e-02       0.049057    3.179811e-02
# ...
