# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install glob2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from glob import glob
import os
import pandas as pd

# %%
path = '/content/drive/MyDrive/Iqram Sir/argent'

# %%
for i in sorted(glob(path+"/*")):
  print(i.split("_")[2],i.split("_")[4],i.split("_")[-1])
# Out:
# Extreme post condition.csv
# Heavy post condition.csv
# Heavy post 1.csv
# Heavy pre condition.csv
# Heavy pre 1.csv
# Moderate post condition.csv
# Moderate post 1.csv
# Moderate post 2.csv
# Moderate pre condition.csv
# Moderate pre 1.csv
# Moderate pre 2.csv
# Moderate pre 3.csv

# %%
i.split("_")[2]
# Out:
# 'Heavy'

# %%
i.split("_")[4]
# Out:
# 'pre'

# %%
i.split("_")[-1].split(".")[0]
# Out:
# '3'

# %%
dic_sub={
    "Subject" : [],
    "Condition" : [i.split("_")[4]],
    "Activity" : [i.split("_")[2]],
    "Epoch":[i.split("_")[-1].split(".")[0]]
}

# %%
dic_sub
# Out:
# {'Subject': [], 'Condition': ['pre'], 'Activity': ['Moderate'], 'Epoch': ['3']}
