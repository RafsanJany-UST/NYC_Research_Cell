# %%
s="applee"

l=len(s)
if(l<4):
  print(str)

elif l>=4:
  j=1
  s2=""
  if (l%2==0):
    m1=(l/2)
    m2=m1+1
    for i in s:
      if(j==m1 or j==m2):
        s2=s2+str(ord(i))+" "
      else:
        s2=s2+i+" "
      j+=1

print(s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d6bcefc20b02> in <module>()
#      13     for i in s:
#      14       if(j==m1 or j==m2):
# ---> 15         s2=s2+str(ord(i))+" "
#      16       else:
#      17         s2=s2+i+" "
#
# TypeError: 'str' object is not callable

# %%
type(ord("h"))
# Out:
# int
