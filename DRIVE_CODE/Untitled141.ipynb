# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
hr_aee = pd.read_csv("/content/drive/MyDrive/Iqram Sir/fitabse_new/Fitabase_HR_aEE_MAX_08.17.2023.csv")
py_hrv = pd.read_csv("/content/drive/MyDrive/Iqram Sir/fitabse_new/Fitabase_combined_data_S01-S56.csv")
hr_recov = pd.read_csv("/content/drive/MyDrive/Iqram Sir/fitabse_new/HR_Recovery_S01-S56_08.21.2023.csv")
all_info = pd.read_csv("/content/drive/MyDrive/Iqram Sir/fitabse_new/Wearables-REDCap-CRF_S01-S56.csv")

# %%
hr_aee
# Out:
#     Patient_Id Condition  HR_MAX(BPM)  aEE_MAX(kJ/min)
# 0       001-JV       pre          149            92.01
# 1       001-JV      post          149            90.95
# 2       002-JR       pre          137            84.60
# 3       002-JR      post          145            83.55
# 4       003-ES       pre          130            39.44
# ..         ...       ...          ...              ...
# 97      054-CW      post          140            43.80
# 98      055-AM       pre          137            56.05
# 99      055-AM      post          169            67.50
# 100     056-UF       pre          146            51.12
# 101     056-UF      post          147            59.40
#
# [102 rows x 4 columns]

# %%
all_info
# Out:
#     record_id2 subject_id enrollment_date  amts  amts_pass  ethnicity  race  \
# 0            1     001-JV      2021-12-02   7.0        1.0        1.0   4.0
# 1            2     002-JR      2021-12-07   9.0        1.0        1.0   6.0
# 2            3     003-ES      2021-12-29   9.0        1.0        2.0   6.0
# 3            4     004-LY      2022-12-31   9.0        1.0        2.0   6.0
# 4            5     005-DF      2022-01-12   8.0        1.0        2.0   6.0
# 5            6     006-MK      2022-02-13   9.0        1.0        2.0   6.0
# 6            7     007-DD      2022-02-01   8.0        1.0        2.0   2.0
# 7            8     008-KL      2022-03-24   8.0        1.0        2.0   6.0
# 8            9        NaN             NaN   NaN        NaN        NaN   NaN
# 9           10     010-ML      2022-03-01   9.0        1.0        2.0   6.0
# 10          11     011-CR      2022-04-11   9.0        1.0        2.0   3.0
# ...

# %%
for i in list(all_info.columns):
  if i != "subject_id" and i != "record_id2":
    hr_aee[i] = ''

# %%
def all_info_back(p_id):
  li = []
  for i in list(all_info.columns):
    if i != "subject_id" and i != "record_id2":
      li.append((i,list(all_info.query("subject_id == '"+p_id+"'")[i])))
  return li

# %%
hr_aee_index = 0


hr_aee_subject = hr_aee["Patient_Id"][hr_aee_index]
infos = all_info_back(hr_aee_subject)

for i in infos:
  hr_aee[i[0]][hr_aee_index] = i[1][0]
# Out:
# <ipython-input-46-eeacaead73d3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hr_aee[i[0]][hr_aee_index] = i[1][0]

# %%
hr_aee
