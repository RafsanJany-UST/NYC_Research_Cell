# %%
import pandas as pd
import numpy as np

data_git_files  = ['']

# %%
df  = pd.read_excel('https://raw.githubusercontent.com/FahmidaNourin/CSE_299/blob/main/Excel_Fahmida_5.xlsx')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/RafsanJany-44/Machine-School/main/datasets/HMC_WITH_BIOM.csv')

# %%
df
# Out:
#       Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0               W        0.000510           8.74146        18.48195
# 1               W        0.000400          10.24000        17.48293
# 2               W        0.000360           9.74049        17.98244
# 3               W        0.000350          10.11512        17.60780
# 4               W        0.000330           9.74049        17.60780
# ...           ...             ...               ...             ...
# 20405           W        0.001710          12.48780        21.10439
# 20406           W        0.001670           9.86537        19.73073
# 20407           W        0.002210           9.86537        17.85756
# 20408           W        0.000005           9.11610        20.72976
# 20409           W        0.000014          10.11512        17.98244
#
#        Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# ...
