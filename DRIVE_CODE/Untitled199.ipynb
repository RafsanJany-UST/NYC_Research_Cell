# %%
from pycimg import CImg
import numpy as np

# Load an image from a file
img = CImg(path)
# Access pixel data as a numpy array
arr = img.asarray()

# Modify pixel values (e.g., set pixels in the upper left 100x100 rectangle to 0)
arr[:100, :100] = 0

# Display the modified image
img.display()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-89532d7ceafa> in <cell line: 5>()
#       3
#       4 # Load an image from a file
# ----> 5 img = CImg(path)
#       6 # Access pixel data as a numpy array
#       7 arr = img.asarray()
#
# /usr/local/lib/python3.10/dist-packages/pycimg/pycimg.py in __init__(self, *args, **kwargs)
#     118         if len(args) == 1:
#     119             if isinstance(args[0], str):
# --> 120                 self.load(args[0])
#     121             elif isinstance(args[0], np.ndarray):
#     122                 self.fromarray(args[0])
#
# /usr/local/lib/python3.10/dist-packages/pycimg/pycimg.py in wrapper(*args, **kwargs)
#     257                     else:
#     258                         cargs.append(arg)
# --> 259                 r = func(*cargs, **kwargs)
#     260                 if isinstance(r, CImg_uint8)   or \
# ...

# %%
# !pip install pycimg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 4.2 MB/s eta 0:00:00
# ...

# %%
path='/content/drive/MyDrive/00000/80094.cimg'

# %%
import cv2

# Read the image
image = cv2.imread(path, cv2.IMREAD_ANYCOLOR)

# Display the image (you can customize this part)
cv2.imshow('CImg Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-5-77970b4b1e36> in <cell line: 7>()
#       5
#       6 # Display the image (you can customize this part)
# ----> 7 cv2.imshow('CImg Image', image)
#       8 cv2.waitKey(0)
#       9 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from cimg import CImg

# Load the .cimg image
cimg_path = path
image = CImg(cimg_path)

# Save as JPG
jpg_path = 'output.jpg'
image.save_jpeg(jpg_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-b504ba06abb0> in <cell line: 1>()
# ----> 1 from cimg import CImg
#       2
#       3 # Load the .cimg image
#       4 cimg_path = path
#       5 image = CImg(cimg_path)
#
# ModuleNotFoundError: No module named 'cimg'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
