# %%
# !pip install docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53895 sha256=8471b211dae27860db8f110a1719770a6a6a1eae5f4e919852aca6cbe4212f55
#   Stored in directory: /root/.cache/pip/wheels/81/f5/1d/e09ba2c1907a43a4146d1189ae4733ca1a3bfe27ee39507767
# Successfully built docx
# ...

# %%
# !pip install exceptions
# Out:
# ERROR: Could not find a version that satisfies the requirement exceptions (from versions: none)
# ERROR: No matching distribution found for exceptions

# %%
from docx import Document

# Create a new Document
doc = Document()

# Add the title
doc.add_heading('Monopoly Economics Questions and Answers', level=1)

# Add the questions and answers to the document
qa_pairs = [
    ("1. Refer to Exhibit 9-5. The demand schedule and cost schedule for a monopolist are provided. Which output level maximizes profit?",
     "Answer: C) 4.\n\nExplanation: To determine the profit-maximizing output level, we need to find the quantity where marginal revenue (MR) equals marginal cost (MC). Here's how we can do it:\n\n"
     "1. Total Revenue (TR): TR is calculated by multiplying the price by the quantity.\n"
     "TR = P × Q\n\n"
     "2. Marginal Revenue (MR): MR is the change in TR when an additional unit is sold.\n"
     "MR = ΔTR / ΔQ\n\n"
     "3. Total Cost (TC): TC is given directly in the table.\n\n"
     "4. Profit: Profit is calculated by subtracting TC from TR.\n"
     "Profit = TR - TC\n\n"
     "From this calculation, profit is maximized at quantities 3 and 4, both yielding a profit of 12. However, since the question specifies an output level, the best answer would be quantity 4 as it is a clear profit-maximizing point."),
    ("2. According to the information provided in Exhibit 9-7, if the Rudd Ice Company is a monopoly and is currently charging a price of $6, what would you advise Rudd to do?",
     "Answer: B) Increase price and decrease output.\n\nExplanation: In a monopoly, the profit-maximizing condition is where MR equals MC. From the graph in Exhibit 9-7, if the current price is $6, it suggests the company is operating at a point where MR < MC because the price is relatively low compared to the optimal price seen in the graph. Therefore, to maximize profit, Rudd Ice Company should increase the price and decrease output to reach the point where MR = MC, thereby maximizing profit."),
    ("3. By calculating the data provided in Exhibit 9-5, how much is the profit if the firm decides to produce 7 units?",
     "Answer: A) 0.\n\nExplanation: To calculate the profit for producing 7 units, we need to use the following formulas:\n\n"
     "1. Total Revenue (TR): TR = Price × Quantity\n"
     "For 7 units, the price is $4.\n"
     "TR = 4 × 7 = 28\n\n"
     "2. Total Cost (TC): TC is given as $28 for 7 units.\n\n"
     "3. Profit: Profit = TR - TC\n"
     "Profit = 28 - 28 = 0\n\n"
     "Thus, the profit for producing 7 units is $0."),
    ("4. According to the information provided in Exhibit 9-7, if the Rudd Ice Company is a monopoly and is currently charging a price of $10, what would you advise Rudd to do?",
     "Answer: C) Decrease price and increase output.\n\nExplanation: The profit-maximizing condition for a monopolist is where Marginal Revenue (MR) equals Marginal Cost (MC). According to Exhibit 9-7, at a price of $10, the firm is likely producing less than the profit-maximizing output. By decreasing the price, the firm moves down the demand curve, which increases the quantity sold. As the quantity increases, MR approaches MC, thereby maximizing profit."),
    ("5. When the monopolist is maximizing total profit in Exhibit 9-6, the average total cost of producing that output level is:",
     "Answer: D) $8.\n\nExplanation: From the graph in Exhibit 9-6:\n"
     "- The monopolist maximizes profit where MR = MC. This point occurs at a quantity of around 6 units.\n"
     "- At this quantity, the corresponding ATC is shown on the graph to be $8."),
    ("6. At any point where a monopolist's marginal revenue is positive, the downward-sloping straight-line demand curve is:",
     "Answer: B) Elastic but not perfectly elastic.\n\nExplanation: For a monopolist:\n"
     "- When MR is positive, the demand curve is in the elastic range. This means that a decrease in price will lead to a proportionally larger increase in quantity demanded.\n"
     "- Therefore, the demand curve is elastic but not perfectly elastic, which means the elasticity is greater than 1 but finite."),
    ("7. To maximize its profit, a monopoly should choose a price where demand is:",
     "Answer: A) Elastic.\n\nExplanation: A monopoly maximizes profit by operating in the elastic portion of the demand curve where MR is positive, ensuring that any increase in quantity increases TR."),
    ("8. For a monopolist with a downward-sloping demand curve:",
     "Answer: D) As price decreases, marginal revenue decreases.\n\nExplanation: In a monopoly, the MR curve lies below the demand curve. When the price decreases, the additional revenue from selling one more unit (MR) also decreases. This is because the price reduction applies to all units sold, not just the marginal unit, reducing the additional revenue generated by selling one more unit."),
    ("9. Refer to Exhibit 9-2. Using the rule that focuses on the marginal approach to maximizing profits, the monopolist maximizes profit by choosing price equal to:",
     "Answer: B) $20.\n\nExplanation: To determine the profit-maximizing price, we need to calculate the marginal cost (MC) and marginal revenue (MR) and find where MR equals MC.\n\n"
     "1. Total Cost (TC): TC is given directly in the table.\n\n"
     "2. Marginal Cost (MC): MC is the change in TC divided by the change in quantity (Q).\n"
     "MC = ΔTC / ΔQ\n\n"
     "Given the data, the monopolist maximizes profit where MR = MC: At Q = 2, MR (from 30 to 20) is closest to MC of 10.\n"
     "Thus, the profit-maximizing price is $20."),
    ("10. As shown in Exhibit 9-8, if the monopolist produces the profit-maximizing output, total revenue is the rectangular area:",
     "Answer: D) OQ2DP4.\n\nExplanation: To find the total revenue at the profit-maximizing output, we need to identify the area that represents TR on the graph:\n"
     "- Profit-Maximizing Output: The profit-maximizing output occurs where MR = MC, which is at quantity Q2.\n"
     "- Total Revenue (TR): TR is represented by the price (P4) multiplied by the quantity (Q2).\n"
     "Therefore, the total revenue is the rectangular area OQ2DP4. This area captures the total revenue by multiplying the optimal quantity (Q2) by the corresponding price (P4)."),
    ("11. Which of the following is not associated with the monopoly market structure?",
     "Answer: A) Many sellers.\n\nExplanation: A monopoly market structure has the following characteristics:\n"
     "- A Single Seller: There is only one seller in the market, which means the firm is the industry.\n"
     "- A Unique Product: The product offered by the monopolist has no close substitutes, making it unique in the market.\n"
     "- Impossible Entry: High barriers to entry prevent other firms from entering the market and competing with the monopolist.\n"
     "Since a monopoly involves a single seller with unique products and high barriers to entry, the characteristic 'many sellers' is not associated with a monopoly market structure. Monopolies, by definition, lack competition, and the presence of many sellers would indicate a competitive market rather than a monopoly."),
    ("12. A monopolist faces a downward-sloping demand curve because:",
     "Answer: D) The entire market demand curve is the monopolist's demand curve.\n\nExplanation: In a monopoly, the firm is the sole provider of the good or service. Therefore, the market demand curve for the product is the demand curve that the monopolist faces. This demand curve is downward-sloping because as the monopolist lowers the price, the quantity demanded increases, and vice versa."),
    ("13. Which of the following factors is not a barrier limiting the entry of potential competitors into a market?",
     "Answer: B) An inelastic demand for a product.\n\nExplanation: Barriers to entry in a monopoly include legally enforced rights, economies of scale, and ownership of a vital resource. These factors prevent other firms from entering the market and competing with the monopolist. An inelastic demand for a product does not prevent other firms from entering the market; it simply describes how the quantity demanded responds to price changes."),
    ("14. Both a perfectly competitive firm and a monopolist:",
     "Answer: B) Maximize profit by setting marginal cost equal to marginal revenue.\n\nExplanation: Both types of firms maximize profit by producing the quantity where marginal cost (MC) equals marginal revenue (MR). This condition ensures that the cost of producing an additional unit is exactly covered by the revenue it generates, maximizing profit."),
    ("15. An industry is said to be a natural monopoly when:",
     "Answer: D) Long-run average cost continues to decline as the quantity of output increases.\n\nExplanation: A natural monopoly occurs when a single firm can supply the entire market at a lower cost than multiple firms due to economies of scale. This means that as the firm's production increases, the long-run average cost per unit decreases, making it more cost-effective for one large firm to serve the entire market."),
    ("16. A monopoly is:",
     "Answer: B) The only seller of a good for which there are no good substitutes in a market with high barriers to entry.\n\nExplanation: A monopoly is defined as a market structure where there is only one seller of a unique product with no close substitutes, and there are high barriers to entry that prevent other firms from entering the market and competing."),
    ("17. For a monopolist:",
     "Answer: B) Price is above marginal revenue.\n\nExplanation: In a monopoly, the demand curve is downward-sloping, and the marginal revenue curve lies below the demand curve. This means that for each additional unit sold, the price must be reduced, not only for the additional unit but for all previous units sold. As a result, the price is higher than the marginal revenue."),
    ("18. Under both perfect competition and monopoly, a firm:",
     "Answer: B) Maximizes profit by setting marginal cost equal to marginal revenue.\n\nExplanation: Both types of firms maximize profit by producing the quantity where marginal cost (MC) equals marginal revenue (MR). This condition ensures that the cost of producing an additional unit is exactly covered by the revenue it generates, maximizing profit."),
    ("19. A natural monopoly is a market where:",
     "Answer: C) A single large firm can produce the entire market output at a lower per-unit cost than a group of smaller firms.\n\nExplanation: A natural monopoly occurs when a single firm can produce the entire market output more efficiently than multiple smaller firms due to economies of scale. This means that as the firm's production increases, its average total cost decreases, making it more cost-effective for one large firm to serve the entire market."),
    ("20. Which of the following is true for a monopolist but not for a firm in perfect competition?",
     "Answer: A) The marginal revenue curve is downward-sloping.\n\nExplanation: For a monopolist, the marginal revenue (MR) curve slopes downward because the monopolist must lower the price to sell additional units, affecting the revenue from all units sold. In contrast, a firm in perfect competition faces a perfectly elastic demand curve where MR equals price, and the MR curve is horizontal."),
    ("21. A monopolist will maximize profits by:",
     "Answer: C) Producing the output where marginal revenue equals marginal cost, just as a perfectly competitive firm will.\n\nExplanation: Both monopolists and firms in perfect competition maximize profit by producing the quantity where marginal revenue (MR) equals marginal cost (MC). This ensures that the cost of producing the last unit is exactly covered by the revenue it generates, maximizing profit."),
    ("22. A monopoly:",
     "Answer: D) Must lower price in order to increase output.\n\nExplanation: A monopolist faces a downward-sloping demand curve, meaning that to sell additional units, the monopolist must lower the price. This price reduction applies to all units sold, not just the additional unit, which is why the marginal revenue is less than the price. Therefore, to increase output, a monopoly must lower the price."),
    ("23. In Exhibit 9-3, how much vaccine should GeneTech produce to maximize its profit?",
     "Answer: C) Between 400 and 500 doses per hour.\n\nExplanation: To maximize profit, a monopolist produces the quantity where marginal revenue (MR) equals marginal cost (MC). We can analyze the graph to find this point.\n"
     "1. Marginal Cost (MC): The MC curve is upward sloping.\n"
     "2. Marginal Revenue (MR): The MR curve is downward sloping.\n\n"
     "We need to find the quantity where these two curves intersect. From the graph:\n"
     "- The MC and MR curves intersect between the quantities of 400 and 500 doses per hour (4 and 5 on the x-axis, where each unit represents hundreds of doses).\n\n"
     "Therefore, the quantity that maximizes profit for GeneTech is between 400 and 500 doses per hour. This is the point where the additional cost of producing one more dose (MC) equals the additional revenue generated from selling that dose (MR). Thus, GeneTech should produce between 400 and 500 doses per hour to maximize its profit.")
]

# Add the questions and answers to the document
for i, (question, answer) in enumerate(qa_pairs, start=1):
    doc.add_heading(f"Question {i}", level=2)
    doc.add_paragraph(question)
    doc.add_paragraph(answer)
    doc.add_paragraph("\n")

# Save the document
file_path = "Monopoly_Economics_QA.docx"
doc.save(file_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-662c244334a1> in <cell line: 1>()
# ----> 1 from docx import Document
#       2
#       3 # Create a new Document
#       4 doc = Document()
#       5
#
# /usr/local/lib/python3.10/dist-packages/docx.py in <module>
#      28     TAGS = {}
#      29
# ---> 30 from exceptions import PendingDeprecationWarning
#      31 from warnings import warn
#      32
#
# ModuleNotFoundError: No module named 'exceptions'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
