# %%
#i=int(input())
talika=list(map(int,input().split()))
count=0
for i in talika:
  if i%2==0 and talika.index(i)%2==0:
    count+=1
  elif i%2!=0 and talika.index(i)%2!=0:
    count+=1
print(count)
# Out:
# 2 4 7 8 10
# 2
