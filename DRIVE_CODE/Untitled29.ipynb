# %%
# !pip install --user --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.21.5)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')


data = pd.read_csv('/content/drive/MyDrive/Thesis_Data/EEG_HMC_underscore.csv')
data.dropna(axis=0, subset=['Sleep_Stage'], inplace=True)
y = data.Sleep_Stage
X = data.drop(['Sleep_Stage'], axis=1).select_dtypes(exclude=['object'])
train_X, test_X, train_y, test_y = train_test_split(X.to_numpy(), y.to_numpy(), test_size=0.25)

my_imputer = Imputer()
train_X = my_imputer.fit_transform(train_X)
test_X = my_imputer.transform(test_X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f03fc45ea3a7> in <module>()
#      11 train_X, test_X, train_y, test_y = train_test_split(X.to_numpy(), y.to_numpy(), test_size=0.25)
#      12
# ---> 13 my_imputer = Imputer()
#      14 train_X = my_imputer.fit_transform(train_X)
#      15 test_X = my_imputer.transform(test_X)
#
# NameError: name 'Imputer' is not defined

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor()
# Add silent=True to avoid printing out updates with each cycle
my_model.fit(train_X, train_y, verbose=False)
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Collecting xgboost
#   Downloading xgboost-1.5.2-py3-none-manylinux2014_x86_64.whl (173.6 MB)
#      |████████████████████████████████| 173.6 MB 6.3 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.5)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed xgboost-1.5.2

# %%
# make predictions
predictions = my_model.predict(test_X)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, test_y)))

# %%
my_model = XGBRegressor(n_estimators=1000)
my_model.fit(train_X, train_y, early_stopping_rounds=5, 
             eval_set=[(test_X, test_y)], verbose=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bf78387f205a> in <module>()
#       1 # load data
# ----> 2 dataset = numpy.loadtxt('/content/drive/MyDrive/Thesis_Data/EEG_HMC_underscore.csv',delimiter=",")
#
# NameError: name 'numpy' is not defined

# %%
my_model = XGBRegressor(n_estimators=1000, learning_rate=0.05)
my_model.fit(train_X, train_y, early_stopping_rounds=5, 
             eval_set=[(test_X, test_y)], verbose=False)

# %%
# split data into train and test sets
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)

# %%
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
