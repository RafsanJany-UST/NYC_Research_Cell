# %%
#TASK5
class Employee:
  def __init__(self,name,workingPeriod):
    self.name=name
    self.workingPeriod=workingPeriod
  @classmethod
  def employeedByJoiningYear(cls,name,year):
    return clas(name,(2021-year))
  @classmethod
  def experiencedCheck(workingPeriod,gender):
    if workPeriod < 3:
      if gender is  "male":
        print('he is not experienced')

      elif gender is "female":
        print("she is not experienced")


employee1 = Employee('Dororo', 3)
employee2 = Employee.employeedByJoiningYear(cls,name, 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8112dd2ac002> in <module>()
#      19
#      20 employee1 = Employee('Dororo', 3)
# ---> 21 employee2 = Employee.employeedByJoiningYear(cls,name, 2016)
#      22 print(employee1.workingPeriod)
#      23 print(employee2.workingPeriod)
#
# NameError: name 'cls' is not defined
