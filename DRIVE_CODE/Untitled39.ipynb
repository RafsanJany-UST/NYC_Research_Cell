# %%
import csv
import decimal
i=0
with open("/content/EEG_HMC_underscore.csv", 'r') as a:
    csv_reader=csv.reader(a)
    
    with open("new.csv", 'w', newline='') as new_file:
        csv_writer=csv.writer(new_file)
        count=1
        for item in csv_reader:
            talika=[]
            if count==1:
                for j in item:
                    i+=1
                    count+=1
                    talika.append(j)
                    if i==26:
                        talika+=['MeanP_DAR_F4','MedianF_DAR_F4','MeanF_DAR_F4','Spectral Edge_DAR_F4', 'PeakF_DAR_F4','MeanP_DTR_F4','MedianF_DTR_F4','MeanF_DTR_F4','Spectral Edge_DTR_F4', 'PeakF_DTR_F4','MeanP_DTABR_F4','MedianF_DTABR_F4','MeanF_DTABR_F4','Spectral Edge_DTABR_F4', 'PeakF_DTABR_F4']
                    elif i==51:
                        talika+=['MeanP_DAR_C4','MedianF_DAR_C4','MeanF_DAR_C4','Spectral Edge_DAR_C4', 'PeakF_DAR_C4','MeanP_DTR_C4','MedianF_DTR_C4','MeanF_DTR_C4','Spectral Edge_DTR_C4', 'PeakF_DTR_C4','MeanP_DTABR_C4','MedianF_DTABR_C4','MeanF_DTABR_C4','Spectral Edge_DTABR_C4', 'PeakF_DTABR_C4']
                    elif i==76:
                        talika+=['MeanP_DAR_O2','MedianF_DAR_O2','MeanF_DAR_O2','Spectral Edge_DAR_O2', 'PeakF_DAR_O2','MeanP_DTR_O2','MedianF_DTR_O2','MeanF_DTR_O2','Spectral Edge_DTR_O2', 'PeakF_DTR_O2','MeanP_DTABR_O2','MedianF_DTABR_O2','MeanF_DTABR_O2','Spectral Edge_DTABR_O2', 'PeakF_DTABR_O2']
            else:
                for j in item :
                    i+=1
                    
                    if 27<=i<=31 or 67<=i<=71 or 107<=i<=111:
                        x=round((float(item[i-11])/float(item[i-26])),5)
                        talika.append(x)
                    elif 32<=i<=36 or 72<=i<=76 or 112<=i<=116:
                      try:
                        x=round((float(item[i-11])/float(item[i-16])),5)
                        talika.append(x)
                      except ZeroDivisionError:
                        print(item[i-11],item[i-16])
                        print("Division by Zero!")
                    elif 37<=i<=40 or 77<=i<=81 or 117<=i<=121:
                        x=round(((float(item[i-11])+float(item[i-16]))/(float(item[i-26])+float(item[i-21]))),5)
                        talika.append(x)
                    else:
                        talika.append(j)
            csv_writer.writerow(talika)
            i=0
# Out:
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# Division by Zero!
# 2.29E-41 0.0
# ...

# %%
import numpy
import pandas as pd
dataset=pd.read_csv("/content/EEG_HMC_underscore.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108451 entries, 0 to 108450
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Sleep_Stage             108451 non-null  object
#  1   MeanP_Alpha_F4          108451 non-null  float64
#  2   MedianF_Alpha_F4        108451 non-null  float64
#  3   MeanF_Alpha_F4          108451 non-null  float64
#  4   Spectral Edge_Alpha_F4  108451 non-null  float64
#  5   PeakF_Alpha_F4          108451 non-null  float64
#  6   MeanP_Beta_F4           108451 non-null  float64
#  7   MedianF_Beta_F4         108451 non-null  float64
#  8   MeanF_Beta_F4           108451 non-null  float64
#  9   Spectral Edge_Beta_F4   108451 non-null  float64
#  10  PeakF_Beta_F4           108451 non-null  float64
#  11  MeanP_Theta_F4          108451 non-null  float64
#  12  MedianF_Theta_F4        108451 non-null  float64
# ...
