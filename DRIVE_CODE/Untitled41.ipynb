# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# data
df = pd.DataFrame({
    'x_axis': [2,3,4,5,3,2,5,6],
    'y_axis': [7,8,6,9,4,3,5,6]
})

# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='.')
plt.show()
