# %%
def show_def():

  d={
      1:{"Functions":"key_search(dict,value)","Returns":"Key"},
      2:{"Functions":"value_sort(dict,type=False)","Returns":"Dictionary"},
      3:{"Functions":"key_sort(dict,type=False)","Returns":"Dictionary"},
      4:{"Functions":"to_json(dict,file_name_or_path)","Returns":"Null"},
      5:{"Functions":"from_json(file_name_or_path)","Returns":None},
      6:{"Functions":"show_def()","Returns":None}
  }
  for i in d:
    print(i,": ",d[i],end="\n")
    print()
show_def()
# Out:
# 1 :  {'Functions': 'key_search(dict,value)', 'Returns': 'Key'}
#
# 2 :  {'Functions': 'value_sort(dict,type=False)', 'Returns': 'Dictionary'}
#
# 3 :  {'Functions': 'key_sort(dict,type=False)', 'Returns': 'Dictionary'}
#
# 4 :  {'Functions': 'to_json(dict,file_name_or_path)', 'Returns': 'Null'}
#
# 5 :  {'Functions': 'from_json(file_name_or_path)', 'Returns': 'Dictionary'}
#
# 6 :  {'Functions': 'show_def()', 'Returns': None}

# %%
# !pip install dictRysan
# Out:
# Collecting dictRysan
#   Downloading https://files.pythonhosted.org/packages/f2/cd/77570f15ecd01ae8b4fdad0f62c36d645606acf47bf2381bfc9ec821c367/dictRysan-1.1.1-py3-none-any.whl
# Installing collected packages: dictRysan
# Successfully installed dictRysan-1.1.1

# %%
import dictRysan as r

# %%
Functions

1. key_search(dict,value)
2. value_sort(dict,type=False)
3. key_sort(dict,type=False)
4. to_json(dict,file_name_or_path)
5. from_json(file_name_or_path)


Description
1. key_search(dict,value):


    Motivation :  Searching a key trough its value.
    Peramitters: Take Tow permitter. a dictionary and a value.
    Returns:     Returns the corresponding key for the given value.


2.value_sort(dict,type=False)


    Motivation : sorting a dictionary according to its values.
    Peramitters: Take Tow permitter. a dictionary and searching order(True or False).
    Returns    : Sorted dictionary.


3.key_sort(dict,type=False)


    Motivation : sorting a dictionary according to its keys.
    Peramitters: Take Tow permitter. a dictionary and searching order(True or False).
    Returns    : Sorted dictionary..


4.to_json(dict,file_name_or_path)


    Motivation : converting dictionary into a .json file
    Peramitters: Take Tow permitter. a dictionary and the file name with .json extension or the path to save.
    Returns    :  No return.


5.from_json(file_name_or_path)

    Motivation : converting a .json file into a .dictionary
    Peramitters: Take inly the file name with .json extension or the path.
    Returns    :  a dictionary.
