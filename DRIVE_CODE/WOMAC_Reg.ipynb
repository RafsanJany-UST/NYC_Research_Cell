# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("/content/drive/MyDrive/Iqram Sir/Latest/KOA_EMG_WOMAC__2022.08.16_Final_WO-tempo-spatial.csv")

# %%
dataset.head(10)
# Out:
#    Patient ID  WOMAC_total WOMAC Severity  CCI_TA-RF  CCI_G-MH  CCI_TA-MH  \
# 0       10193           40       Moderate      144.9      66.0      108.1
# 1       10193           42       Moderate       99.1     123.6       98.9
# 2       11407           42       Moderate       90.4     160.1       80.7
# 3       11407           41       Moderate      146.6     196.2      136.4
# 4       12435           23           Mild      147.9     153.5       85.9
# 5       12435           47       Moderate       99.4      55.4       93.6
# 6       12521           19           Mild       90.0      91.0       92.0
# 7       12521           53       Moderate      133.5      93.6      121.1
# 8       12687           74         Severe      193.3     130.3      207.0
# 9       12687           74         Severe      129.5     115.1       88.9
#
#    CCI_G-RF  CCI_TA-G  CCI_MH-RF  CCI_L-H  ...    TA-G-100  Stance_CCI_TA-RF  \
# 0      86.2     171.7       87.1    183.8  ...  234.689409        115.016739
# 1     123.6     109.4      145.9    215.6  ...  130.854095         80.799114
# 2     164.8      88.5      110.4    217.2  ...  109.781099         64.522568
# 3     184.8     123.0      106.3    293.3  ...  117.902928        157.259039
# 4     305.4      90.3       40.4    268.2  ...   76.648348        158.726742
# 5      58.7     150.9      108.4    145.9  ...   44.685556        147.257611
# 6      88.7     115.0      136.7    174.1  ...   65.433386         86.971580
# 7     100.7     146.5      100.4    214.5  ...  169.644154        112.746870
# 8     129.6     162.9      140.1    295.2  ...  144.402551        223.637121
# 9     180.9     103.8       79.0    229.5  ...  107.222917        139.496753
#
#    Stance_CCI_G-MH  Stance_CCI_TA-G  Swing_CCI_TA-RF  Swing_CCI_G-MH  \
# 0        82.560104       129.779021       212.427472       35.934817
# 1       118.800065        87.596328       120.058278      131.061267
# 2       185.837798        53.250781       118.951867      119.206854
# 3       213.969267       126.550560       134.834096      168.262739
# 4       198.202890        94.353370       135.926913       82.676272
# 5        72.130138       197.046837        48.532762       29.851684
# 6       107.723821       106.343048        93.422362       64.138358
# 7       109.750454       131.151480       156.402708       68.811402
# 8       142.868454       166.702324       155.574614      109.404210
# 9       123.489941       101.890803       118.112704      102.404559
#
#    Swing_CCI_TA-G  swing/stance_cci(TA_RF)  swing/stance_cci(G-MH)  \
# 0      266.326016                 1.846927                0.435256
# 1      145.432434                 1.485886                1.103209
# 2      144.415087                 1.843570                0.641456
# 3      117.370956                 0.857401                0.786387
# 4       83.944362                 0.856358                0.417129
# 5       80.509844                 0.329577                0.413859
# 6      128.642708                 1.074171                0.595396
# 7      170.867378                 1.387202                0.626981
# 8      155.958741                 0.695656                0.765769
# 9      106.992896                 0.846706                0.829254
#
#    swing/stance_CCI(TA-G)
# 0                2.052150
# 1                1.660257
# 2                2.711981
# 3                0.927463
# 4                0.889681
# 5                0.408582
# 6                1.209696
# 7                1.302825
# 8                0.935552
# 9                1.050074
#
# [10 rows x 785 columns]

# %%
dataset.shape
# Out:
# (150, 785)

# %%
X = dataset.iloc[:,3:]
y = dataset.iloc[:, 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

ref = LinearRegression()
log.fit(X_train, y_train)
y_pred = log.predict(X_test)

# %%
print(y_pred.shape)
# Out:
# (30,)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -2.8701995578947614

# %%
r_sq = model.score(x, y)
print(r_sq)
# Out:
# 0.10700997970639947
