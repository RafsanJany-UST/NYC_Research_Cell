# %% [markdown]
# #Lets Make a Traditional Program

# %%
celsius = [-40, -10,  0,  8, 15, 22,  38]

# %%
def cel_to_far(c):
  f = c * (9/5) + 32
  return f

# %%
fahrenheit = []
for i in celsius:
  fahrenheit.append(cel_to_far(i))

print(fahrenheit)
# Out:
# [-40.0, 14.0, 32.0, 46.4, 59.0, 71.6, 100.4]

# %%
for i,c in enumerate(celsius):
  print(c,"degrees Celsius = ", fahrenheit[i],"degrees Fahrenheit")
# Out:
# -40 degrees Celsius =  -40.0 degrees Fahrenheit
# -10 degrees Celsius =  14.0 degrees Fahrenheit
# 0 degrees Celsius =  32.0 degrees Fahrenheit
# 8 degrees Celsius =  46.4 degrees Fahrenheit
# 15 degrees Celsius =  59.0 degrees Fahrenheit
# 22 degrees Celsius =  71.6 degrees Fahrenheit
# 38 degrees Celsius =  100.4 degrees Fahrenheit

# %% [markdown]
# ##Lets Do the Job
#
# So we have the input and the output. Our Algorithm or formula is f=c*(9/5)+32. Lets make a Nural Network which can detect the algorithm with our inputdata (<i>celsius</i>) and outputdata (<i>fahrenheit</i>).

# %%
import numpy as np

# %% [markdown]
# Make Numpy Dataset

# %%
celsius_in = np.array(celsius,  dtype=float)
fahrenheit_out = np.array(fahrenheit,  dtype=float)

# %% [markdown]
# ## Create the model

# %%
import tensorflow as tf
#import logging
#logger = tf.get_logger()
#logger.setLevel(logging.ERROR)

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

#model = tf.keras.Sequential(
#    tf.keras.layers.Dense(units=1, input_shape=[1])
#)"""

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
# %%time
history = model.fit(celsius_in, fahrenheit_out, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model
# CPU times: user 2.27 s, sys: 112 ms, total: 2.39 s
# Wall time: 3.39 s

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## Use the model to predict values

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 107ms/step
# [[211.5857]]

# %% [markdown]
# #Actual Value

# %%
cel_to_far(100.0)
# Out:
# 212.0

# %% [markdown]
# ## Looking at the layer weights and bias

# %%
print("These are the layer variables, weight:",l0.get_weights()[0],", bias:",l0.get_weights()[1])
# Out:
# These are the layer variables, weight: [[1.823067]] , bias: [29.278984]

# %% [markdown]
# ---
#
# ---

# %%
import random


celsius_2 = []
fahrenheit_2=[]

for i in range(500):
  c_scaled=  float("{:.2f}".format(random.uniform(-10.5, 75)))
  celsius_2.append(c_scaled)
  f_scaled = float("{:.2f}".format(cel_to_far(c_scaled)))
  fahrenheit_2.append(f_scaled)

# %%
for i,c in enumerate(celsius_2):
  print(c,"degrees Celsius = ", fahrenheit_2[i],"degrees Fahrenheit")
# Out:
# 17.45 degrees Celsius =  63.41 degrees Fahrenheit
# 12.74 degrees Celsius =  54.93 degrees Fahrenheit
# 44.76 degrees Celsius =  112.57 degrees Fahrenheit
# 6.99 degrees Celsius =  44.58 degrees Fahrenheit
# 7.78 degrees Celsius =  46.0 degrees Fahrenheit
# 33.33 degrees Celsius =  91.99 degrees Fahrenheit
# 62.47 degrees Celsius =  144.45 degrees Fahrenheit
# 38.69 degrees Celsius =  101.64 degrees Fahrenheit
# 16.58 degrees Celsius =  61.84 degrees Fahrenheit
# 57.0 degrees Celsius =  134.6 degrees Fahrenheit
# 63.15 degrees Celsius =  145.67 degrees Fahrenheit
# 19.2 degrees Celsius =  66.56 degrees Fahrenheit
# -6.46 degrees Celsius =  20.37 degrees Fahrenheit
# 22.41 degrees Celsius =  72.34 degrees Fahrenheit
# 66.01 degrees Celsius =  150.82 degrees Fahrenheit
# 64.94 degrees Celsius =  148.89 degrees Fahrenheit
# 3.78 degrees Celsius =  38.8 degrees Fahrenheit
# 60.39 degrees Celsius =  140.7 degrees Fahrenheit
# 42.76 degrees Celsius =  108.97 degrees Fahrenheit
# 27.81 degrees Celsius =  82.06 degrees Fahrenheit
# 55.69 degrees Celsius =  132.24 degrees Fahrenheit
# 55.07 degrees Celsius =  131.13 degrees Fahrenheit
# -7.68 degrees Celsius =  18.18 degrees Fahrenheit
# 47.67 degrees Celsius =  117.81 degrees Fahrenheit
# 6.58 degrees Celsius =  43.84 degrees Fahrenheit
# -7.23 degrees Celsius =  18.99 degrees Fahrenheit
# 0.93 degrees Celsius =  33.67 degrees Fahrenheit
# 72.0 degrees Celsius =  161.6 degrees Fahrenheit
# 17.53 degrees Celsius =  63.55 degrees Fahrenheit
# -4.16 degrees Celsius =  24.51 degrees Fahrenheit
# 37.19 degrees Celsius =  98.94 degrees Fahrenheit
# 73.06 degrees Celsius =  163.51 degrees Fahrenheit
# 41.76 degrees Celsius =  107.17 degrees Fahrenheit
# 54.75 degrees Celsius =  130.55 degrees Fahrenheit
# -2.66 degrees Celsius =  27.21 degrees Fahrenheit
# 42.33 degrees Celsius =  108.19 degrees Fahrenheit
# 32.56 degrees Celsius =  90.61 degrees Fahrenheit
# -2.49 degrees Celsius =  27.52 degrees Fahrenheit
# 54.25 degrees Celsius =  129.65 degrees Fahrenheit
# 48.76 degrees Celsius =  119.77 degrees Fahrenheit
# 61.56 degrees Celsius =  142.81 degrees Fahrenheit
# 46.82 degrees Celsius =  116.28 degrees Fahrenheit
# 56.65 degrees Celsius =  133.97 degrees Fahrenheit
# 44.7 degrees Celsius =  112.46 degrees Fahrenheit
# 43.58 degrees Celsius =  110.44 degrees Fahrenheit
# -2.89 degrees Celsius =  26.8 degrees Fahrenheit
# 29.05 degrees Celsius =  84.29 degrees Fahrenheit
# 22.78 degrees Celsius =  73.0 degrees Fahrenheit
# 46.19 degrees Celsius =  115.14 degrees Fahrenheit
# 3.49 degrees Celsius =  38.28 degrees Fahrenheit
# -6.53 degrees Celsius =  20.25 degrees Fahrenheit
# -1.75 degrees Celsius =  28.85 degrees Fahrenheit
# 31.41 degrees Celsius =  88.54 degrees Fahrenheit
# 61.85 degrees Celsius =  143.33 degrees Fahrenheit
# -6.93 degrees Celsius =  19.53 degrees Fahrenheit
# -2.26 degrees Celsius =  27.93 degrees Fahrenheit
# 53.91 degrees Celsius =  129.04 degrees Fahrenheit
# 21.57 degrees Celsius =  70.83 degrees Fahrenheit
# 37.49 degrees Celsius =  99.48 degrees Fahrenheit
# 69.01 degrees Celsius =  156.22 degrees Fahrenheit
# 16.04 degrees Celsius =  60.87 degrees Fahrenheit
# 30.47 degrees Celsius =  86.85 degrees Fahrenheit
# 10.37 degrees Celsius =  50.67 degrees Fahrenheit
# 17.81 degrees Celsius =  64.06 degrees Fahrenheit
# 72.42 degrees Celsius =  162.36 degrees Fahrenheit
# 43.78 degrees Celsius =  110.8 degrees Fahrenheit
# 53.11 degrees Celsius =  127.6 degrees Fahrenheit
# 72.29 degrees Celsius =  162.12 degrees Fahrenheit
# 30.98 degrees Celsius =  87.76 degrees Fahrenheit
# -2.18 degrees Celsius =  28.08 degrees Fahrenheit
# 61.31 degrees Celsius =  142.36 degrees Fahrenheit
# 5.77 degrees Celsius =  42.39 degrees Fahrenheit
# 5.1 degrees Celsius =  41.18 degrees Fahrenheit
# 19.36 degrees Celsius =  66.85 degrees Fahrenheit
# 28.15 degrees Celsius =  82.67 degrees Fahrenheit
# 48.28 degrees Celsius =  118.9 degrees Fahrenheit
# 44.13 degrees Celsius =  111.43 degrees Fahrenheit
# -6.18 degrees Celsius =  20.88 degrees Fahrenheit
# 51.55 degrees Celsius =  124.79 degrees Fahrenheit
# 27.29 degrees Celsius =  81.12 degrees Fahrenheit
# 4.57 degrees Celsius =  40.23 degrees Fahrenheit
# -1.6 degrees Celsius =  29.12 degrees Fahrenheit
# 62.36 degrees Celsius =  144.25 degrees Fahrenheit
# 62.8 degrees Celsius =  145.04 degrees Fahrenheit
# 42.46 degrees Celsius =  108.43 degrees Fahrenheit
# 74.26 degrees Celsius =  165.67 degrees Fahrenheit
# 48.18 degrees Celsius =  118.72 degrees Fahrenheit
# 42.54 degrees Celsius =  108.57 degrees Fahrenheit
# 59.68 degrees Celsius =  139.42 degrees Fahrenheit
# 9.67 degrees Celsius =  49.41 degrees Fahrenheit
# 6.79 degrees Celsius =  44.22 degrees Fahrenheit
# 46.5 degrees Celsius =  115.7 degrees Fahrenheit
# 14.21 degrees Celsius =  57.58 degrees Fahrenheit
# 40.54 degrees Celsius =  104.97 degrees Fahrenheit
# 72.06 degrees Celsius =  161.71 degrees Fahrenheit
# 11.29 degrees Celsius =  52.32 degrees Fahrenheit
# 12.5 degrees Celsius =  54.5 degrees Fahrenheit
# 59.46 degrees Celsius =  139.03 degrees Fahrenheit
# 2.53 degrees Celsius =  36.55 degrees Fahrenheit
# -1.13 degrees Celsius =  29.97 degrees Fahrenheit
# -9.75 degrees Celsius =  14.45 degrees Fahrenheit
# 13.48 degrees Celsius =  56.26 degrees Fahrenheit
# 40.92 degrees Celsius =  105.66 degrees Fahrenheit
# 11.53 degrees Celsius =  52.75 degrees Fahrenheit
# 26.18 degrees Celsius =  79.12 degrees Fahrenheit
# 55.13 degrees Celsius =  131.23 degrees Fahrenheit
# 28.2 degrees Celsius =  82.76 degrees Fahrenheit
# 60.07 degrees Celsius =  140.13 degrees Fahrenheit
# 12.95 degrees Celsius =  55.31 degrees Fahrenheit
# 18.28 degrees Celsius =  64.9 degrees Fahrenheit
# 33.27 degrees Celsius =  91.89 degrees Fahrenheit
# 43.02 degrees Celsius =  109.44 degrees Fahrenheit
# 14.05 degrees Celsius =  57.29 degrees Fahrenheit
# 70.64 degrees Celsius =  159.15 degrees Fahrenheit
# 59.79 degrees Celsius =  139.62 degrees Fahrenheit
# 62.6 degrees Celsius =  144.68 degrees Fahrenheit
# 40.45 degrees Celsius =  104.81 degrees Fahrenheit
# 44.55 degrees Celsius =  112.19 degrees Fahrenheit
# 73.39 degrees Celsius =  164.1 degrees Fahrenheit
# 47.67 degrees Celsius =  117.81 degrees Fahrenheit
# 3.41 degrees Celsius =  38.14 degrees Fahrenheit
# 38.81 degrees Celsius =  101.86 degrees Fahrenheit
# 12.64 degrees Celsius =  54.75 degrees Fahrenheit
# -8.1 degrees Celsius =  17.42 degrees Fahrenheit
# 34.93 degrees Celsius =  94.87 degrees Fahrenheit
# 36.61 degrees Celsius =  97.9 degrees Fahrenheit
# 53.92 degrees Celsius =  129.06 degrees Fahrenheit
# 67.43 degrees Celsius =  153.37 degrees Fahrenheit
# 52.8 degrees Celsius =  127.04 degrees Fahrenheit
# 67.84 degrees Celsius =  154.11 degrees Fahrenheit
# 23.97 degrees Celsius =  75.15 degrees Fahrenheit
# 51.23 degrees Celsius =  124.21 degrees Fahrenheit
# 57.28 degrees Celsius =  135.1 degrees Fahrenheit
# 0.63 degrees Celsius =  33.13 degrees Fahrenheit
# 58.1 degrees Celsius =  136.58 degrees Fahrenheit
# 6.8 degrees Celsius =  44.24 degrees Fahrenheit
# 16.1 degrees Celsius =  60.98 degrees Fahrenheit
# 42.27 degrees Celsius =  108.09 degrees Fahrenheit
# 52.51 degrees Celsius =  126.52 degrees Fahrenheit
# 44.43 degrees Celsius =  111.97 degrees Fahrenheit
# 17.57 degrees Celsius =  63.63 degrees Fahrenheit
# 69.08 degrees Celsius =  156.34 degrees Fahrenheit
# 43.82 degrees Celsius =  110.88 degrees Fahrenheit
# 69.38 degrees Celsius =  156.88 degrees Fahrenheit
# -7.12 degrees Celsius =  19.18 degrees Fahrenheit
# -8.42 degrees Celsius =  16.84 degrees Fahrenheit
# 17.27 degrees Celsius =  63.09 degrees Fahrenheit
# 38.03 degrees Celsius =  100.45 degrees Fahrenheit
# 66.15 degrees Celsius =  151.07 degrees Fahrenheit
# 15.62 degrees Celsius =  60.12 degrees Fahrenheit
# 37.05 degrees Celsius =  98.69 degrees Fahrenheit
# -2.7 degrees Celsius =  27.14 degrees Fahrenheit
# -4.33 degrees Celsius =  24.21 degrees Fahrenheit
# 18.89 degrees Celsius =  66.0 degrees Fahrenheit
# 55.97 degrees Celsius =  132.75 degrees Fahrenheit
# 62.45 degrees Celsius =  144.41 degrees Fahrenheit
# 50.54 degrees Celsius =  122.97 degrees Fahrenheit
# 49.02 degrees Celsius =  120.24 degrees Fahrenheit
# 42.75 degrees Celsius =  108.95 degrees Fahrenheit
# 71.55 degrees Celsius =  160.79 degrees Fahrenheit
# -0.14 degrees Celsius =  31.75 degrees Fahrenheit
# 33.59 degrees Celsius =  92.46 degrees Fahrenheit
# 5.68 degrees Celsius =  42.22 degrees Fahrenheit
# 0.85 degrees Celsius =  33.53 degrees Fahrenheit
# 40.67 degrees Celsius =  105.21 degrees Fahrenheit
# 19.59 degrees Celsius =  67.26 degrees Fahrenheit
# 17.2 degrees Celsius =  62.96 degrees Fahrenheit
# 55.95 degrees Celsius =  132.71 degrees Fahrenheit
# 53.96 degrees Celsius =  129.13 degrees Fahrenheit
# 22.65 degrees Celsius =  72.77 degrees Fahrenheit
# 23.35 degrees Celsius =  74.03 degrees Fahrenheit
# 19.25 degrees Celsius =  66.65 degrees Fahrenheit
# 11.19 degrees Celsius =  52.14 degrees Fahrenheit
# 62.28 degrees Celsius =  144.1 degrees Fahrenheit
# 8.86 degrees Celsius =  47.95 degrees Fahrenheit
# 2.28 degrees Celsius =  36.1 degrees Fahrenheit
# 8.71 degrees Celsius =  47.68 degrees Fahrenheit
# 54.09 degrees Celsius =  129.36 degrees Fahrenheit
# 2.78 degrees Celsius =  37.0 degrees Fahrenheit
# 3.44 degrees Celsius =  38.19 degrees Fahrenheit
# 69.32 degrees Celsius =  156.78 degrees Fahrenheit
# 63.55 degrees Celsius =  146.39 degrees Fahrenheit
# -9.38 degrees Celsius =  15.12 degrees Fahrenheit
# 46.7 degrees Celsius =  116.06 degrees Fahrenheit
# 51.77 degrees Celsius =  125.19 degrees Fahrenheit
# 41.97 degrees Celsius =  107.55 degrees Fahrenheit
# 12.69 degrees Celsius =  54.84 degrees Fahrenheit
# 55.03 degrees Celsius =  131.05 degrees Fahrenheit
# 8.48 degrees Celsius =  47.26 degrees Fahrenheit
# 4.94 degrees Celsius =  40.89 degrees Fahrenheit
# 7.93 degrees Celsius =  46.27 degrees Fahrenheit
# 6.03 degrees Celsius =  42.85 degrees Fahrenheit
# 10.02 degrees Celsius =  50.04 degrees Fahrenheit
# 72.06 degrees Celsius =  161.71 degrees Fahrenheit
# 49.07 degrees Celsius =  120.33 degrees Fahrenheit
# -3.19 degrees Celsius =  26.26 degrees Fahrenheit
# 34.19 degrees Celsius =  93.54 degrees Fahrenheit
# 9.66 degrees Celsius =  49.39 degrees Fahrenheit
# 14.2 degrees Celsius =  57.56 degrees Fahrenheit
# -2.08 degrees Celsius =  28.26 degrees Fahrenheit
# 15.67 degrees Celsius =  60.21 degrees Fahrenheit
# 65.1 degrees Celsius =  149.18 degrees Fahrenheit
# 66.79 degrees Celsius =  152.22 degrees Fahrenheit
# 18.48 degrees Celsius =  65.26 degrees Fahrenheit
# 21.92 degrees Celsius =  71.46 degrees Fahrenheit
# -9.94 degrees Celsius =  14.11 degrees Fahrenheit
# -9.39 degrees Celsius =  15.1 degrees Fahrenheit
# 62.48 degrees Celsius =  144.46 degrees Fahrenheit
# -1.81 degrees Celsius =  28.74 degrees Fahrenheit
# 28.98 degrees Celsius =  84.16 degrees Fahrenheit
# 66.63 degrees Celsius =  151.93 degrees Fahrenheit
# 10.85 degrees Celsius =  51.53 degrees Fahrenheit
# 31.11 degrees Celsius =  88.0 degrees Fahrenheit
# 30.91 degrees Celsius =  87.64 degrees Fahrenheit
# -2.58 degrees Celsius =  27.36 degrees Fahrenheit
# 11.86 degrees Celsius =  53.35 degrees Fahrenheit
# -9.71 degrees Celsius =  14.52 degrees Fahrenheit
# 41.57 degrees Celsius =  106.83 degrees Fahrenheit
# -0.73 degrees Celsius =  30.69 degrees Fahrenheit
# 30.72 degrees Celsius =  87.3 degrees Fahrenheit
# -8.5 degrees Celsius =  16.7 degrees Fahrenheit
# 73.75 degrees Celsius =  164.75 degrees Fahrenheit
# -9.25 degrees Celsius =  15.35 degrees Fahrenheit
# 44.25 degrees Celsius =  111.65 degrees Fahrenheit
# 39.08 degrees Celsius =  102.34 degrees Fahrenheit
# 64.89 degrees Celsius =  148.8 degrees Fahrenheit
# 43.97 degrees Celsius =  111.15 degrees Fahrenheit
# -0.11 degrees Celsius =  31.8 degrees Fahrenheit
# 47.03 degrees Celsius =  116.65 degrees Fahrenheit
# 7.16 degrees Celsius =  44.89 degrees Fahrenheit
# 14.32 degrees Celsius =  57.78 degrees Fahrenheit
# 36.02 degrees Celsius =  96.84 degrees Fahrenheit
# -6.24 degrees Celsius =  20.77 degrees Fahrenheit
# 51.94 degrees Celsius =  125.49 degrees Fahrenheit
# 44.06 degrees Celsius =  111.31 degrees Fahrenheit
# -10.34 degrees Celsius =  13.39 degrees Fahrenheit
# 3.48 degrees Celsius =  38.26 degrees Fahrenheit
# 42.02 degrees Celsius =  107.64 degrees Fahrenheit
# 68.87 degrees Celsius =  155.97 degrees Fahrenheit
# 59.8 degrees Celsius =  139.64 degrees Fahrenheit
# 60.77 degrees Celsius =  141.39 degrees Fahrenheit
# -9.88 degrees Celsius =  14.22 degrees Fahrenheit
# 4.43 degrees Celsius =  39.97 degrees Fahrenheit
# 19.08 degrees Celsius =  66.34 degrees Fahrenheit
# 62.97 degrees Celsius =  145.35 degrees Fahrenheit
# 67.16 degrees Celsius =  152.89 degrees Fahrenheit
# 20.63 degrees Celsius =  69.13 degrees Fahrenheit
# 44.29 degrees Celsius =  111.72 degrees Fahrenheit
# 9.75 degrees Celsius =  49.55 degrees Fahrenheit
# 28.14 degrees Celsius =  82.65 degrees Fahrenheit
# 29.18 degrees Celsius =  84.52 degrees Fahrenheit
# 18.99 degrees Celsius =  66.18 degrees Fahrenheit
# 24.07 degrees Celsius =  75.33 degrees Fahrenheit
# 70.43 degrees Celsius =  158.77 degrees Fahrenheit
# 34.85 degrees Celsius =  94.73 degrees Fahrenheit
# 28.83 degrees Celsius =  83.89 degrees Fahrenheit
# 27.24 degrees Celsius =  81.03 degrees Fahrenheit
# 52.07 degrees Celsius =  125.73 degrees Fahrenheit
# 52.91 degrees Celsius =  127.24 degrees Fahrenheit
# 11.24 degrees Celsius =  52.23 degrees Fahrenheit
# 57.36 degrees Celsius =  135.25 degrees Fahrenheit
# 22.58 degrees Celsius =  72.64 degrees Fahrenheit
# 17.48 degrees Celsius =  63.46 degrees Fahrenheit
# -1.06 degrees Celsius =  30.09 degrees Fahrenheit
# 9.58 degrees Celsius =  49.24 degrees Fahrenheit
# 28.87 degrees Celsius =  83.97 degrees Fahrenheit
# 40.37 degrees Celsius =  104.67 degrees Fahrenheit
# -3.71 degrees Celsius =  25.32 degrees Fahrenheit
# 6.22 degrees Celsius =  43.2 degrees Fahrenheit
# 73.42 degrees Celsius =  164.16 degrees Fahrenheit
# 27.65 degrees Celsius =  81.77 degrees Fahrenheit
# -7.51 degrees Celsius =  18.48 degrees Fahrenheit
# 47.56 degrees Celsius =  117.61 degrees Fahrenheit
# 27.19 degrees Celsius =  80.94 degrees Fahrenheit
# 38.96 degrees Celsius =  102.13 degrees Fahrenheit
# -3.81 degrees Celsius =  25.14 degrees Fahrenheit
# 31.55 degrees Celsius =  88.79 degrees Fahrenheit
# 32.7 degrees Celsius =  90.86 degrees Fahrenheit
# 30.85 degrees Celsius =  87.53 degrees Fahrenheit
# 56.07 degrees Celsius =  132.93 degrees Fahrenheit
# 21.93 degrees Celsius =  71.47 degrees Fahrenheit
# 74.12 degrees Celsius =  165.42 degrees Fahrenheit
# -2.75 degrees Celsius =  27.05 degrees Fahrenheit
# 2.86 degrees Celsius =  37.15 degrees Fahrenheit
# 33.4 degrees Celsius =  92.12 degrees Fahrenheit
# 47.5 degrees Celsius =  117.5 degrees Fahrenheit
# 45.15 degrees Celsius =  113.27 degrees Fahrenheit
# 9.59 degrees Celsius =  49.26 degrees Fahrenheit
# -0.13 degrees Celsius =  31.77 degrees Fahrenheit
# 33.55 degrees Celsius =  92.39 degrees Fahrenheit
# 49.74 degrees Celsius =  121.53 degrees Fahrenheit
# 4.31 degrees Celsius =  39.76 degrees Fahrenheit
# 13.59 degrees Celsius =  56.46 degrees Fahrenheit
# 68.02 degrees Celsius =  154.44 degrees Fahrenheit
# 34.75 degrees Celsius =  94.55 degrees Fahrenheit
# 40.7 degrees Celsius =  105.26 degrees Fahrenheit
# 49.86 degrees Celsius =  121.75 degrees Fahrenheit
# 31.11 degrees Celsius =  88.0 degrees Fahrenheit
# 27.01 degrees Celsius =  80.62 degrees Fahrenheit
# 7.59 degrees Celsius =  45.66 degrees Fahrenheit
# 62.8 degrees Celsius =  145.04 degrees Fahrenheit
# 45.62 degrees Celsius =  114.12 degrees Fahrenheit
# 1.25 degrees Celsius =  34.25 degrees Fahrenheit
# 27.46 degrees Celsius =  81.43 degrees Fahrenheit
# -8.78 degrees Celsius =  16.2 degrees Fahrenheit
# 33.66 degrees Celsius =  92.59 degrees Fahrenheit
# -0.96 degrees Celsius =  30.27 degrees Fahrenheit
# -0.42 degrees Celsius =  31.24 degrees Fahrenheit
# 56.35 degrees Celsius =  133.43 degrees Fahrenheit
# 7.98 degrees Celsius =  46.36 degrees Fahrenheit
# -1.79 degrees Celsius =  28.78 degrees Fahrenheit
# -0.63 degrees Celsius =  30.87 degrees Fahrenheit
# 65.31 degrees Celsius =  149.56 degrees Fahrenheit
# 36.52 degrees Celsius =  97.74 degrees Fahrenheit
# 9.22 degrees Celsius =  48.6 degrees Fahrenheit
# -5.9 degrees Celsius =  21.38 degrees Fahrenheit
# 15.46 degrees Celsius =  59.83 degrees Fahrenheit
# 58.02 degrees Celsius =  136.44 degrees Fahrenheit
# 63.36 degrees Celsius =  146.05 degrees Fahrenheit
# 49.2 degrees Celsius =  120.56 degrees Fahrenheit
# 50.75 degrees Celsius =  123.35 degrees Fahrenheit
# 11.74 degrees Celsius =  53.13 degrees Fahrenheit
# 6.91 degrees Celsius =  44.44 degrees Fahrenheit
# 9.49 degrees Celsius =  49.08 degrees Fahrenheit
# 36.85 degrees Celsius =  98.33 degrees Fahrenheit
# 53.96 degrees Celsius =  129.13 degrees Fahrenheit
# 10.69 degrees Celsius =  51.24 degrees Fahrenheit
# 51.37 degrees Celsius =  124.47 degrees Fahrenheit
# 62.78 degrees Celsius =  145.0 degrees Fahrenheit
# 9.33 degrees Celsius =  48.79 degrees Fahrenheit
# 71.96 degrees Celsius =  161.53 degrees Fahrenheit
# 35.79 degrees Celsius =  96.42 degrees Fahrenheit
# 28.7 degrees Celsius =  83.66 degrees Fahrenheit
# 15.58 degrees Celsius =  60.04 degrees Fahrenheit
# 22.11 degrees Celsius =  71.8 degrees Fahrenheit
# 56.34 degrees Celsius =  133.41 degrees Fahrenheit
# 53.35 degrees Celsius =  128.03 degrees Fahrenheit
# 34.37 degrees Celsius =  93.87 degrees Fahrenheit
# 55.96 degrees Celsius =  132.73 degrees Fahrenheit
# 30.03 degrees Celsius =  86.05 degrees Fahrenheit
# 46.41 degrees Celsius =  115.54 degrees Fahrenheit
# 35.06 degrees Celsius =  95.11 degrees Fahrenheit
# 44.65 degrees Celsius =  112.37 degrees Fahrenheit

# %%
celsius_in = np.array(celsius_2,  dtype=float)
fahrenheit_out = np.array(fahrenheit_2,  dtype=float)

# %%
# %%time



l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

model = tf.keras.Sequential([l0])

model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))


history = model.fit(celsius_in, fahrenheit_out, epochs=500, verbose=False)
print("Finished training the model")


print("These are the layer variables, weight:",l0.get_weights()[0],", bias:",l0.get_weights()[1])
# Out:
# Finished training the model
# These are the layer variables, weight: [[1.8002787]] , bias: [31.999651]
# CPU times: user 12.8 s, sys: 790 ms, total: 13.6 s
# Wall time: 21.1 s

# %%
print("For 100.0 Celsius: ",model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 100ms/step
# For 100.0 Celsius:  [[212.02751]]

# %%
cel_to_far(100.0)
# Out:
# 212.0

# %% [markdown]
# ---
#
#
#
# ---

# %%
# %%time
l0 = tf.keras.layers.Dense(units=3, input_shape=[1])
l1 = tf.keras.layers.Dense(units=2)
l2 = tf.keras.layers.Dense(units=1)

model = tf.keras.Sequential([l0, l1, l2])

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

model.fit(celsius_in, fahrenheit_out, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model
# CPU times: user 15.5 s, sys: 783 ms, total: 16.3 s
# Wall time: 14.2 s

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 125ms/step
# [[212.00977]]

# %%
cel_to_far(100.0)
# Out:
# 212.0

# %%
print("These are the l0 variables, weight:",l0.get_weights()[0],", bias:",l0.get_weights()[1])
# Out:
# These are the l0 variables, weight: [[-0.06410411  0.43000367  0.9748266 ]] , bias: [3.2478411 4.150941  7.9135914]

# %%
print("These are the l1 variables, weight:",l1.get_weights()[0],", bias:",l1.get_weights()[1])
# Out:
# These are the l1 variables, weight: [[-0.03778414  0.3670368 ]
#  [ 0.67187357 -0.67732304]
#  [ 1.2949616   0.26731485]] , bias: [8.049116  3.1600413]

# %%
print("These are the l2 variables, weight:",l2.get_weights()[0],", bias:",l2.get_weights()[1])
# Out:
# These are the l2 variables, weight: [[1.1598291 ]
#  [0.03554465]] , bias: [7.5569797]
