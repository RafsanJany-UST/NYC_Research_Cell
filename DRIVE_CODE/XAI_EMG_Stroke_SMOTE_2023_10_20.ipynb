# %%
"""CMD = "wget https://raw.githubusercontent.com/Diyago/"\
  "GAN-for-tabular-data/master/requirements.txt"

# !{CMD}
# !pip install -r requirements.txt
# !pip install tabgan
# !pip install tensorflow"""
# Out:
# 'CMD = "wget https://raw.githubusercontent.com/Diyago/"  "GAN-for-tabular-data/master/requirements.txt"\n\n!{CMD}\n!pip install -r requirements.txt\n!pip install tabgan\n!pip install tensorflow'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
dataset=pd.read_excel("/content/EMG_Stroke_1.xlsx")

#dataset=pd.read_excel("/content/drive/MyDrive/Publications/EMG Stroke/Data/EMG_Stroke_1.xlsx")

classes = np.array(sorted(list(set(dataset.iloc[:, 1]))))
result = {}

# %%
set(list(dataset['Status']))
# Out:
# {'Control', 'Stroke'}

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset.iloc[:, 0]=encoder.fit_transform(dataset.iloc[:, 1])

# %%
set(list(dataset['Status']))
# Out:
# {'Control', 'Stroke'}

# %%
X = dataset.iloc[:,2:]
y = dataset.iloc[:, 0]
col=list(dataset.iloc[0:0,2:])

# %%
X
# Out:
#      MDF_BICEP_FEM_LT  MNF_BICEP_FEM_LT  PKF_BICEPFEM_LT  MNP_BICEP_FEM_LT  \
# 0           62.926827        183.658531        59.268291          0.001781
# 1           67.317071        175.609751        15.365853          0.003445
# 2           84.878046        191.707311        10.243902          0.005324
# 3           10.243902        160.243898         7.317073          0.003761
# 4           13.902439        147.073166         6.585366          0.007078
# ..                ...               ...              ...               ...
# 373         13.902432        152.926756         8.048777          0.000434
# 374         32.195107        179.268207        11.707311          0.000265
# 375         14.634139        160.975533        10.243898          0.000382
# 376         10.243898        152.195049         7.317070          0.004303
# 377         12.439018        120.731650        12.439018          0.011104
#
#      TP_BICEP_FEM_LT  MDF_BICEP_FEM_RT  MNF_BICEP_FEM_RT  PKF_BICEP_FEM_RT  \
# 0           1.825106         88.536583        203.414628         54.878047
# 1           3.530884         98.048778        207.073165         64.390242
# 2           5.457119         88.536583        199.756092         10.975609
# 3           3.855294         24.878048        192.439019          8.048780
# 4           7.254462         55.609754        148.536581         16.829268
# ..               ...               ...               ...               ...
# 373         0.445275          8.048777         57.804850          7.317070
# 374         0.271432          8.780484         53.414609          6.585363
# 375         0.391040          8.780484         35.853641          7.317070
# 376         4.410924         11.707311         38.048762          8.780484
# 377        11.381557          9.512191         43.170711          7.317070
#
#      MNP_BICEP_FEM_RT  TP_BICEP_FEM_RT  MDF_LAT_GASTRO_LT  MNF_LAT_GASTRO_LT  \
# 0            0.001770         1.814557         111.951216         187.317068
# 1            0.002374         2.433352          57.804876         188.780482
# 2            0.005711         5.853517          27.073170         179.999995
# 3            0.004579         4.693017          38.780487         183.658531
# 4            0.002487         2.548960         110.487802         213.658530
# ..                ...              ...                ...                ...
# 373          0.331949       340.247783         115.609701         203.414537
# 374          0.242454       248.515460         118.536529         199.024295
# 375          0.456689       468.106572         107.560924         194.634054
# 376          0.176679       181.096091          14.634139         188.048691
# 377          0.022083        22.635327          59.268264         190.243812
#
#      PKF_LAT_GASTRO_LT  MNP_LAT_GASTRO_LT  TP_LAT_GASTRO_LT  \
# 0           100.975607           0.003372          3.456223
# 1             5.853658           0.002010          2.060074
# 2             8.780488           0.005159          5.288125
# 3             5.121951           0.000906          0.928694
# 4           107.560972           0.002733          2.800849
# ..                 ...                ...               ...
# 373          59.999971           0.000205          0.210085
# 374          65.121920           0.000233          0.239107
# 375          98.048734           0.000219          0.223969
# 376          13.170725           0.001780          1.824840
# 377           5.121949           0.003231          3.311971
#
#      MDF_LAT_GASTRO_RT  MNF_LAT_GASTRO_RT  PKF_LAT_GASTRO_RT  \
# 0            98.780485         172.682922          62.195120
# 1           100.243899         199.756092         144.878044
# 2            29.268292         163.902434           9.512195
# 3            12.439024         152.926825           5.121951
# 4            72.439022         154.390239          44.634145
# ..                 ...                ...                ...
# 373          72.438990         182.926742          16.097553
# 374          38.048762         188.048691           9.512191
# 375          56.341437         190.975519          14.634139
# 376          62.195092         186.585277          10.243898
# 377          81.951180         174.146258          84.878008
#
#      MNP_LAT_GASTRO_RT  TP_LAT_GASTRO_RT
# 0             0.011208         11.487837
# 1             0.001281          1.312815
# 2             0.003675          3.767115
# 3             0.005100          5.226992
# 4             0.002725          2.792952
# ..                 ...               ...
# 373           0.000180          0.184714
# 374           0.000221          0.226852
# 375           0.000190          0.195196
# 376           0.000389          0.398552
# 377           0.001152          1.180724
#
# [378 rows x 20 columns]

# %% [markdown]
# #Feature Selection

# %% [markdown]
# # **Filter Method**

# %% [markdown]
# You can remove it. I added for not to input all the features for every runtime

# %%
from sklearn.feature_selection import SelectKBest
bestfeatures_1 = SelectKBest(k=10)
fit = bestfeatures_1.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores1 = pd.concat([dfcolumns,dfscores],axis=1)
featureScores1.columns = ['Specs','Score']

# %%
number_of_feat=int(input("Number Of Best Features: "))
# Out:
# Number Of Best Features: 10

# %%
imp=featureScores1.nlargest(number_of_feat,'Score')
print(imp)
# Out:
#                 Specs      Score
# 19   TP_LAT_GASTRO_RT  11.896853
# 14   TP_LAT_GASTRO_LT   8.448660
# 13  MNP_LAT_GASTRO_LT   8.448660
# 9     TP_BICEP_FEM_RT   7.648430
# 8    MNP_BICEP_FEM_RT   7.648430
# 15  MDF_LAT_GASTRO_RT   7.568313
# 6    MNF_BICEP_FEM_RT   7.371348
# 4     TP_BICEP_FEM_LT   6.659378
# 3    MNP_BICEP_FEM_LT   6.659378
# 1    MNF_BICEP_FEM_LT   5.759630

# %%
list_of_feat1=[]

for i in range(number_of_feat):
  list_of_feat1.append(imp.iloc[:,0:].values[i][0])

# %% [markdown]
# # **Manual Features**

# %%
list_of_feat2=[

'p2n2_gap_diff_50ms',
'p2_gap_peak_amp_50ms',
'p2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'n1_gap_peak_amp_50ms',
'n2_gap_peak_amp_20ms',
'n1p2_gap_no_gap_ratio_age-norm_20ms',
'n1p2_gap_diff_50ms',
'gamma_freq_20ms',
'total_auc_50ms',
'gap_auc_p2n2_UP_20ms',
'gap_auc_n1p2_UP_50ms',
'gap_auc_n1p2_LO_50ms',
'n1p2_gap_diff_20ms',
'gap_auc_p2n2_UP_50ms',
'ABR_peak_auc_50ms'

    ]

print(len(list_of_feat2))
# Out:
# 16

# %%
list_of_feat3=[
'p2_gap_peak_amp_50ms',
'p2n2_gap_diff_20ms',
'p2n2_gap_diff_50ms',
'n2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_by_total_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'n1p2_gap_no_gap_ratio_age-norm_50ms',
'gap_auc_p2n2_UP_20ms',
'gap_auc_p2n2_UP_50ms',
'gap_auc_n1p2n2_20ms',
'n1p2_gap_diff_50ms',
'n1p2_gap_diff_20ms',
'gap_auc_total_abs_20ms',
'n1p2_gap_no_gap_ratio_age-norm_20ms',
'alpha_peak_auc_50ms',
'ABR_peak_auc_50ms'
    ]

print(len(list_of_feat3))
# Out:
# 16

# %%
X_new = dataset[list_of_feat1]
y_new = dataset.iloc[:, 0]

# %% [markdown]
# ## Data Partition

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.25, random_state = 0)

# %%
'''
X_train=X_new.iloc[:134,:]
X_test=X_new.iloc[134:,:]
y_train=y_new.iloc[:134]
y_test=y_new.iloc[134:]
'''
# Out:
# '\nX_train=X_new.iloc[:134,:]\nX_test=X_new.iloc[134:,:]\ny_train=y_new.iloc[:134]\ny_test=y_new.iloc[134:]\n'

# %%
X_train
# Out:
#      TP_LAT_GASTRO_RT  TP_LAT_GASTRO_LT  MNP_LAT_GASTRO_LT  TP_BICEP_FEM_RT  \
# 286          0.109099          0.173279           0.000169       326.631998
# 92           4.651477          4.773113           0.004657         8.869302
# 212          4.094212          2.355519           0.002298         0.917185
# 198          0.381652          0.926954           0.000904         0.850130
# 283          0.191963          3.412821           0.003330         0.753525
# ..                ...               ...                ...              ...
# 323          1.470870          9.330302           0.009103         4.525812
# 192          4.264294          0.942744           0.000920        25.677960
# 117          8.632223          2.883091           0.002813         3.844661
# 47           1.145638          2.961097           0.002889         2.435655
# 172          1.208815          2.000020           0.001951         9.514144
#
#      MNP_BICEP_FEM_RT  MDF_LAT_GASTRO_RT  MNF_BICEP_FEM_RT  TP_BICEP_FEM_LT  \
# 286          0.318665          98.048734         42.439004         0.165746
# 92           0.008653          11.707317        182.195117         2.881239
# 212          0.000895          39.512176        160.243826         1.234110
# 198          0.000829          58.536557        174.877965         2.343678
# 283          0.000735          59.999971        165.365775         0.907861
# ..                ...                ...               ...              ...
# 323          0.004415          15.365846        130.975547         5.662525
# 192          0.025052          71.707283        196.097467         6.196687
# 117          0.003751          11.707317        169.024385         3.379626
# 47           0.002376          79.756095        187.317068         4.536168
# 172          0.009282          70.975608         94.390241         3.541023
#
#      MNP_BICEP_FEM_LT  MNF_BICEP_FEM_LT
# 286          0.000162        199.024295
# 92           0.002811        185.853653
# 212          0.001204        155.853584
# 198          0.002287        155.121877
# 283          0.000886        163.170654
# ..                ...               ...
# 323          0.005524        124.390185
# 192          0.006046        143.414566
# 117          0.003297        139.756093
# 47           0.004426        178.536580
# 172          0.003455        144.146337
#
# [283 rows x 10 columns]

# %%
X_test
# Out:
#      TP_LAT_GASTRO_RT  TP_LAT_GASTRO_LT  MNP_LAT_GASTRO_LT  TP_BICEP_FEM_RT  \
# 366         69.183750         63.085111           0.061546      1663.285594
# 155          5.144256          1.819363           0.001775         6.680490
# 313          5.605819          1.563568           0.001525         2.496613
# 269          7.453504          2.162149           0.002109         0.506037
# 221          0.049921          0.068449           0.000067         0.068149
# ..                ...               ...                ...              ...
# 21           7.387023          2.730435           0.002664         9.622186
# 234          0.787338          0.380166           0.000371         4.613985
# 216          1.942183          1.577738           0.001539        45.153091
# 49           0.317016          0.411177           0.000401         0.814729
# 206          2.279147          0.749011           0.000731         2.161354
#
#      MNP_BICEP_FEM_RT  MDF_LAT_GASTRO_RT  MNF_BICEP_FEM_RT  TP_BICEP_FEM_LT  \
# 366          1.622718          12.439018        449.999785        59.780400
# 155          0.006518          49.024389        143.414630         1.594898
# 313          0.002436          90.731664        144.877980         2.674826
# 269          0.000494          13.902432        169.024310         0.050030
# 221          0.000066         118.536529        193.170640         0.739062
# ..                ...                ...               ...              ...
# 21           0.009387          46.829267        130.243899         4.367116
# 234          0.004501          13.902432        109.756045         1.446016
# 216          0.044052          21.951209         35.853641         8.190399
# 49           0.000795         100.243899        158.048776         1.341647
# 206          0.002109           6.585363         99.512148         1.849203
#
#      MNP_BICEP_FEM_LT  MNF_BICEP_FEM_LT
# 366          0.058322        133.902375
# 155          0.001556        188.780482
# 313          0.002610        182.195035
# 269          0.000049        193.170640
# 221          0.000721        216.585263
# ..                ...               ...
# 21           0.004261        201.951213
# 234          0.001411        141.219445
# 216          0.007991        211.463314
# 49           0.001309        147.073166
# 206          0.001804        185.853570
#
# [95 rows x 10 columns]

# %%
'''
from tabgan.sampler import GANGenerator
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

gen_x, gen_y = GANGenerator(gen_x_times=1.1, cat_cols=None,
           bot_filter_quantile=0.001, top_filter_quantile=0.999, \
              is_post_process=True,
           adversarial_model_params={
               "metrics": "rmse", "max_depth": 2, "max_bin": 100,
               "learning_rate": 0.02, "random_state": \
                42, "n_estimators": 600,
           }, pregeneration_frac=2, only_generated_data=False,\
           gan_params = {"batch_size": 600, "patience": 25, \
          "epochs" : 60,}).generate_data_pipe(pd.DataFrame(X_train), pd.DataFrame(y_train),\
          pd.DataFrame(X_test), deep_copy=True, only_adversarial=False, \
          use_adversarial=True)

X_train = X_train.append(gen_x)
y_train = y_train.append(gen_y)
'''
# Out:
# '\nfrom tabgan.sampler import GANGenerator\nimport pandas as pd\nimport numpy as np\nfrom sklearn.model_selection import train_test_split\n\ngen_x, gen_y = GANGenerator(gen_x_times=1.1, cat_cols=None,\n           bot_filter_quantile=0.001, top_filter_quantile=0.999,               is_post_process=True,\n           adversarial_model_params={\n               "metrics": "rmse", "max_depth": 2, "max_bin": 100,\n               "learning_rate": 0.02, "random_state":                 42, "n_estimators": 600,\n           }, pregeneration_frac=2, only_generated_data=False,           gan_params = {"batch_size": 600, "patience": 25,           "epochs" : 60,}).generate_data_pipe(pd.DataFrame(X_train), pd.DataFrame(y_train),          pd.DataFrame(X_test), deep_copy=True, only_adversarial=False,           use_adversarial=True)\n\nX_train = X_train.append(gen_x)\ny_train = y_train.append(gen_y)\n'

# %% [markdown]
# # **SMOTE**

# %%
# !pip install imbalanced-learn
from tqdm.notebook import tqdm
from imblearn.over_sampling import SMOTE
import statistics as st

def balance(X_temp, y_temp):
  smote = SMOTE()
  X_temp, y_temp= smote.fit_resample(X_temp, y_temp)
  return pd.concat([pd.DataFrame(X_temp), pd.DataFrame(y_temp)], axis=1)



def models_check_box(models):
  import ipywidgets as widgets
  from IPython.display import display
  new_keys=[]
  for i in models:
    i=widgets.Checkbox(
      value=False,
      description=str(i),
      disabled=False,
      indent=False
      )
    display(i)
    new_keys.append(i)
  return new_keys


def Search_Some(dataset,some):
  dic={}
  for col in tqdm(list(dataset.columns)):
    rows = []
    flage = 0
    for row in range(dataset.shape[0]):
      if str(dataset[col][row]) == some:
        rows.append(row)
        flage = 1
    if flage ==1:
      dic[col] = rows

  return dic






def find_stat_classwise(dataframe,col,target_col,temp_tar,stat_type='median'):
  print("Calculating-",col,"|| Target-",temp_tar)
  list_1 = []
  for row in range(dataframe.shape[0]):
      if str(dataframe[col][row]) != 'nan' and str(dataframe[target_col][row]) == temp_tar:
        list_1.append(dataframe[col][row])

  try:
    if stat_type == 'median':
      return st.median(list_1)
    elif stat_type == 'mean':
      return st.mean(list_1)
    elif stat_type == 'mode':
      return st.mode(list_1)

  except:
    print("No Class exist")
    return 'nan'



def clsswise_null_rmv(df,target_cls,stat_type='median'):

  cls = list(set(df[target_cls]))

  refine = []
  print("Processing Null Dictionary.....")
  d_null = Search_Some(df,'nan')

  print("Replacing Nan vlues with ",stat_type,".....")
  for col in tqdm(d_null):
    for c in cls:
      m = find_stat_classwise(df,col,target_cls,c,stat_type)
      refine.append([col,c,m])

  for i in refine:
    print(i)
    for row in tqdm(range(df.shape[0])):
      if str(df[i[0]][row]) == 'nan' and str(df[target_cls][row]) == i[1]:
        df.at[row,i[0]] = i[2]

  return df
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)

# %%
smote = SMOTE()
X_train, y_train= smote.fit_resample(X_train, y_train)

# %% [markdown]
# ###ANOVA with f classifciation

# %%
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import pandas as pd



fs = SelectKBest(score_func=f_classif, k=5)
fit = fs.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_ANOVA']

lyst = featureScores.nlargest(number_of_feat,'Score_ANOVA')

#lyst.to_csv('Filter_Method_ANOVA_with_f_classif.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "ANOVA"

# %% [markdown]
# #ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_defult = AdaBoostClassifier(random_state=0)
ada_defult.fit(X_train, y_train)
y_pred = ada_defult.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(ada_defult,1,'AdaBoostClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[32 18]
#  [14 31]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67        50
#            1       0.63      0.69      0.66        45
#
#     accuracy                           0.66        95
#    macro avg       0.66      0.66      0.66        95
# weighted avg       0.67      0.66      0.66        95
#
# Accurecy:  0.6631578947368421

# %%
from sklearn.ensemble import AdaBoostClassifier
N=200
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = AdaBoostClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt
#plot the relationship between K and the testing accuracy
plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/200 round completed......................... Accurecy: 0.5684210526315789
# 2/200 round completed......................... Accurecy: 0.5263157894736842
# 3/200 round completed......................... Accurecy: 0.5473684210526316
# 4/200 round completed......................... Accurecy: 0.5578947368421052
# 5/200 round completed......................... Accurecy: 0.5684210526315789
# 6/200 round completed......................... Accurecy: 0.6526315789473685
# 7/200 round completed......................... Accurecy: 0.5368421052631579
# 8/200 round completed......................... Accurecy: 0.6526315789473685
# 9/200 round completed......................... Accurecy: 0.6105263157894737
# 10/200 round completed......................... Accurecy: 0.6631578947368421
# 11/200 round completed......................... Accurecy: 0.6526315789473685
# 12/200 round completed......................... Accurecy: 0.6
# 13/200 round completed......................... Accurecy: 0.6631578947368421
# 14/200 round completed......................... Accurecy: 0.6631578947368421
# 15/200 round completed......................... Accurecy: 0.6631578947368421
# 16/200 round completed......................... Accurecy: 0.6526315789473685
# 17/200 round completed......................... Accurecy: 0.6736842105263158
# 18/200 round completed......................... Accurecy: 0.6631578947368421
# 19/200 round completed......................... Accurecy: 0.6526315789473685
# 20/200 round completed......................... Accurecy: 0.6631578947368421
# 21/200 round completed......................... Accurecy: 0.7052631578947368
# 22/200 round completed......................... Accurecy: 0.6631578947368421
# 23/200 round completed......................... Accurecy: 0.6736842105263158
# 24/200 round completed......................... Accurecy: 0.6526315789473685
# 25/200 round completed......................... Accurecy: 0.6736842105263158
# 26/200 round completed......................... Accurecy: 0.6631578947368421
# 27/200 round completed......................... Accurecy: 0.6736842105263158
# 28/200 round completed......................... Accurecy: 0.6631578947368421
# 29/200 round completed......................... Accurecy: 0.6526315789473685
# 30/200 round completed......................... Accurecy: 0.6421052631578947
# 31/200 round completed......................... Accurecy: 0.631578947368421
# 32/200 round completed......................... Accurecy: 0.631578947368421
# 33/200 round completed......................... Accurecy: 0.6421052631578947
# 34/200 round completed......................... Accurecy: 0.6421052631578947
# 35/200 round completed......................... Accurecy: 0.6631578947368421
# 36/200 round completed......................... Accurecy: 0.6526315789473685
# 37/200 round completed......................... Accurecy: 0.6631578947368421
# 38/200 round completed......................... Accurecy: 0.6736842105263158
# 39/200 round completed......................... Accurecy: 0.6736842105263158
# 40/200 round completed......................... Accurecy: 0.6947368421052632
# 41/200 round completed......................... Accurecy: 0.6947368421052632
# 42/200 round completed......................... Accurecy: 0.6947368421052632
# 43/200 round completed......................... Accurecy: 0.6947368421052632
# 44/200 round completed......................... Accurecy: 0.6947368421052632
# 45/200 round completed......................... Accurecy: 0.6526315789473685
# 46/200 round completed......................... Accurecy: 0.6631578947368421
# 47/200 round completed......................... Accurecy: 0.6631578947368421
# 48/200 round completed......................... Accurecy: 0.6631578947368421
# 49/200 round completed......................... Accurecy: 0.6526315789473685
# 50/200 round completed......................... Accurecy: 0.6631578947368421
# 51/200 round completed......................... Accurecy: 0.6421052631578947
# 52/200 round completed......................... Accurecy: 0.6526315789473685
# 53/200 round completed......................... Accurecy: 0.6631578947368421
# 54/200 round completed......................... Accurecy: 0.6631578947368421
# 55/200 round completed......................... Accurecy: 0.6631578947368421
# 56/200 round completed......................... Accurecy: 0.6631578947368421
# 57/200 round completed......................... Accurecy: 0.6526315789473685
# 58/200 round completed......................... Accurecy: 0.6736842105263158
# 59/200 round completed......................... Accurecy: 0.6736842105263158
# 60/200 round completed......................... Accurecy: 0.6631578947368421
# 61/200 round completed......................... Accurecy: 0.6736842105263158
# 62/200 round completed......................... Accurecy: 0.6631578947368421
# 63/200 round completed......................... Accurecy: 0.6736842105263158
# 64/200 round completed......................... Accurecy: 0.6631578947368421
# 65/200 round completed......................... Accurecy: 0.6421052631578947
# 66/200 round completed......................... Accurecy: 0.6421052631578947
# 67/200 round completed......................... Accurecy: 0.6421052631578947
# 68/200 round completed......................... Accurecy: 0.6736842105263158
# 69/200 round completed......................... Accurecy: 0.6421052631578947
# 70/200 round completed......................... Accurecy: 0.6631578947368421
# 71/200 round completed......................... Accurecy: 0.6526315789473685
# 72/200 round completed......................... Accurecy: 0.6526315789473685
# 73/200 round completed......................... Accurecy: 0.6526315789473685
# 74/200 round completed......................... Accurecy: 0.6526315789473685
# 75/200 round completed......................... Accurecy: 0.6421052631578947
# 76/200 round completed......................... Accurecy: 0.6421052631578947
# 77/200 round completed......................... Accurecy: 0.6526315789473685
# 78/200 round completed......................... Accurecy: 0.6631578947368421
# 79/200 round completed......................... Accurecy: 0.6631578947368421
# 80/200 round completed......................... Accurecy: 0.6631578947368421
# 81/200 round completed......................... Accurecy: 0.6631578947368421
# 82/200 round completed......................... Accurecy: 0.6631578947368421
# 83/200 round completed......................... Accurecy: 0.6631578947368421
# 84/200 round completed......................... Accurecy: 0.6631578947368421
# 85/200 round completed......................... Accurecy: 0.6736842105263158
# 86/200 round completed......................... Accurecy: 0.6736842105263158
# 87/200 round completed......................... Accurecy: 0.6526315789473685
# 88/200 round completed......................... Accurecy: 0.6631578947368421
# 89/200 round completed......................... Accurecy: 0.6736842105263158
# 90/200 round completed......................... Accurecy: 0.6631578947368421
# 91/200 round completed......................... Accurecy: 0.6631578947368421
# 92/200 round completed......................... Accurecy: 0.6631578947368421
# 93/200 round completed......................... Accurecy: 0.6631578947368421
# 94/200 round completed......................... Accurecy: 0.6526315789473685
# 95/200 round completed......................... Accurecy: 0.6631578947368421
# 96/200 round completed......................... Accurecy: 0.6421052631578947
# 97/200 round completed......................... Accurecy: 0.6526315789473685
# 98/200 round completed......................... Accurecy: 0.6526315789473685
# 99/200 round completed......................... Accurecy: 0.6421052631578947
# 100/200 round completed......................... Accurecy: 0.6631578947368421
# 101/200 round completed......................... Accurecy: 0.6526315789473685
# 102/200 round completed......................... Accurecy: 0.6526315789473685
# 103/200 round completed......................... Accurecy: 0.6526315789473685
# 104/200 round completed......................... Accurecy: 0.6421052631578947
# 105/200 round completed......................... Accurecy: 0.6526315789473685
# 106/200 round completed......................... Accurecy: 0.6526315789473685
# 107/200 round completed......................... Accurecy: 0.6526315789473685
# 108/200 round completed......................... Accurecy: 0.6526315789473685
# 109/200 round completed......................... Accurecy: 0.6631578947368421
# 110/200 round completed......................... Accurecy: 0.6526315789473685
# 111/200 round completed......................... Accurecy: 0.6631578947368421
# 112/200 round completed......................... Accurecy: 0.6631578947368421
# 113/200 round completed......................... Accurecy: 0.6631578947368421
# 114/200 round completed......................... Accurecy: 0.6631578947368421
# 115/200 round completed......................... Accurecy: 0.6631578947368421
# 116/200 round completed......................... Accurecy: 0.6631578947368421
# 117/200 round completed......................... Accurecy: 0.6526315789473685
# 118/200 round completed......................... Accurecy: 0.6421052631578947
# 119/200 round completed......................... Accurecy: 0.6421052631578947
# 120/200 round completed......................... Accurecy: 0.6421052631578947
# 121/200 round completed......................... Accurecy: 0.6526315789473685
# 122/200 round completed......................... Accurecy: 0.6526315789473685
# 123/200 round completed......................... Accurecy: 0.6421052631578947
# 124/200 round completed......................... Accurecy: 0.6421052631578947
# 125/200 round completed......................... Accurecy: 0.6526315789473685
# 126/200 round completed......................... Accurecy: 0.6526315789473685
# 127/200 round completed......................... Accurecy: 0.6526315789473685
# 128/200 round completed......................... Accurecy: 0.6421052631578947
# 129/200 round completed......................... Accurecy: 0.6526315789473685
# 130/200 round completed......................... Accurecy: 0.6421052631578947
# 131/200 round completed......................... Accurecy: 0.6526315789473685
# 132/200 round completed......................... Accurecy: 0.631578947368421
# 133/200 round completed......................... Accurecy: 0.631578947368421
# 134/200 round completed......................... Accurecy: 0.631578947368421
# 135/200 round completed......................... Accurecy: 0.631578947368421
# 136/200 round completed......................... Accurecy: 0.6421052631578947
# 137/200 round completed......................... Accurecy: 0.631578947368421
# 138/200 round completed......................... Accurecy: 0.631578947368421
# 139/200 round completed......................... Accurecy: 0.631578947368421
# 140/200 round completed......................... Accurecy: 0.631578947368421
# 141/200 round completed......................... Accurecy: 0.631578947368421
# 142/200 round completed......................... Accurecy: 0.6526315789473685
# 143/200 round completed......................... Accurecy: 0.6526315789473685
# 144/200 round completed......................... Accurecy: 0.6526315789473685
# 145/200 round completed......................... Accurecy: 0.6421052631578947
# 146/200 round completed......................... Accurecy: 0.6526315789473685
# 147/200 round completed......................... Accurecy: 0.6526315789473685
# 148/200 round completed......................... Accurecy: 0.6631578947368421
# 149/200 round completed......................... Accurecy: 0.6526315789473685
# 150/200 round completed......................... Accurecy: 0.6631578947368421
# 151/200 round completed......................... Accurecy: 0.6631578947368421
# 152/200 round completed......................... Accurecy: 0.6631578947368421
# 153/200 round completed......................... Accurecy: 0.6631578947368421
# 154/200 round completed......................... Accurecy: 0.6736842105263158
# 155/200 round completed......................... Accurecy: 0.6736842105263158
# 156/200 round completed......................... Accurecy: 0.6736842105263158
# 157/200 round completed......................... Accurecy: 0.6631578947368421
# 158/200 round completed......................... Accurecy: 0.6736842105263158
# 159/200 round completed......................... Accurecy: 0.6736842105263158
# 160/200 round completed......................... Accurecy: 0.6736842105263158
# 161/200 round completed......................... Accurecy: 0.6736842105263158
# 162/200 round completed......................... Accurecy: 0.6842105263157895
# 163/200 round completed......................... Accurecy: 0.6842105263157895
# 164/200 round completed......................... Accurecy: 0.6736842105263158
# 165/200 round completed......................... Accurecy: 0.6842105263157895
# 166/200 round completed......................... Accurecy: 0.6736842105263158
# 167/200 round completed......................... Accurecy: 0.6736842105263158
# 168/200 round completed......................... Accurecy: 0.6736842105263158
# 169/200 round completed......................... Accurecy: 0.6736842105263158
# 170/200 round completed......................... Accurecy: 0.6736842105263158
# 171/200 round completed......................... Accurecy: 0.6842105263157895
# 172/200 round completed......................... Accurecy: 0.6736842105263158
# 173/200 round completed......................... Accurecy: 0.6842105263157895
# 174/200 round completed......................... Accurecy: 0.6736842105263158
# 175/200 round completed......................... Accurecy: 0.6842105263157895
# 176/200 round completed......................... Accurecy: 0.6736842105263158
# 177/200 round completed......................... Accurecy: 0.6736842105263158
# 178/200 round completed......................... Accurecy: 0.6842105263157895
# 179/200 round completed......................... Accurecy: 0.6736842105263158
# 180/200 round completed......................... Accurecy: 0.6736842105263158
# 181/200 round completed......................... Accurecy: 0.6631578947368421
# 182/200 round completed......................... Accurecy: 0.6631578947368421
# 183/200 round completed......................... Accurecy: 0.6526315789473685
# 184/200 round completed......................... Accurecy: 0.6526315789473685
# 185/200 round completed......................... Accurecy: 0.6526315789473685
# 186/200 round completed......................... Accurecy: 0.6526315789473685
# 187/200 round completed......................... Accurecy: 0.6526315789473685
# 188/200 round completed......................... Accurecy: 0.6526315789473685
# 189/200 round completed......................... Accurecy: 0.6526315789473685
# 190/200 round completed......................... Accurecy: 0.6526315789473685
# 191/200 round completed......................... Accurecy: 0.6526315789473685
# 192/200 round completed......................... Accurecy: 0.6526315789473685
# 193/200 round completed......................... Accurecy: 0.6526315789473685
# 194/200 round completed......................... Accurecy: 0.6631578947368421
# 195/200 round completed......................... Accurecy: 0.631578947368421
# 196/200 round completed......................... Accurecy: 0.631578947368421
# 197/200 round completed......................... Accurecy: 0.631578947368421
# 198/200 round completed......................... Accurecy: 0.631578947368421
# 199/200 round completed......................... Accurecy: 0.631578947368421
# 200/200 round completed......................... Accurecy: 0.631578947368421
# The best n_estimators:
# 21

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_best_estimator = AdaBoostClassifier(n_estimators=best_estimator,random_state=0)
ada_best_estimator.fit(X_train, y_train)
y_pred = ada_best_estimator.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(ada_best_estimator,1,'AdaBoostClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [11 34]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        50
#            1       0.67      0.76      0.71        45
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.71      0.71        95
# weighted avg       0.71      0.71      0.71        95
#
# Accurecy:  0.7052631578947368

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Graddient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold

gradBoost_default = GradientBoostingClassifier(random_state=0)
gradBoost_default.fit(X_train, y_train)
y_pred = gradBoost_default.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(gradBoost_default,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[31 19]
#  [12 33]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.62      0.67        50
#            1       0.63      0.73      0.68        45
#
#     accuracy                           0.67        95
#    macro avg       0.68      0.68      0.67        95
# weighted avg       0.68      0.67      0.67        95
#
# Accurecy:  0.6736842105263158

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = GradientBoostingClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/150 round completed......................... Accurecy: 0.5578947368421052
# 2/150 round completed......................... Accurecy: 0.5578947368421052
# 3/150 round completed......................... Accurecy: 0.5684210526315789
# 4/150 round completed......................... Accurecy: 0.5578947368421052
# 5/150 round completed......................... Accurecy: 0.5789473684210527
# 6/150 round completed......................... Accurecy: 0.6
# 7/150 round completed......................... Accurecy: 0.5894736842105263
# 8/150 round completed......................... Accurecy: 0.5894736842105263
# 9/150 round completed......................... Accurecy: 0.5894736842105263
# 10/150 round completed......................... Accurecy: 0.5894736842105263
# 11/150 round completed......................... Accurecy: 0.5789473684210527
# 12/150 round completed......................... Accurecy: 0.5894736842105263
# 13/150 round completed......................... Accurecy: 0.5894736842105263
# 14/150 round completed......................... Accurecy: 0.5894736842105263
# 15/150 round completed......................... Accurecy: 0.5894736842105263
# 16/150 round completed......................... Accurecy: 0.5894736842105263
# 17/150 round completed......................... Accurecy: 0.5894736842105263
# 18/150 round completed......................... Accurecy: 0.6
# 19/150 round completed......................... Accurecy: 0.6
# 20/150 round completed......................... Accurecy: 0.6105263157894737
# 21/150 round completed......................... Accurecy: 0.6105263157894737
# 22/150 round completed......................... Accurecy: 0.5789473684210527
# 23/150 round completed......................... Accurecy: 0.6
# 24/150 round completed......................... Accurecy: 0.5894736842105263
# 25/150 round completed......................... Accurecy: 0.6
# 26/150 round completed......................... Accurecy: 0.6
# 27/150 round completed......................... Accurecy: 0.5789473684210527
# 28/150 round completed......................... Accurecy: 0.6105263157894737
# 29/150 round completed......................... Accurecy: 0.6
# 30/150 round completed......................... Accurecy: 0.6
# 31/150 round completed......................... Accurecy: 0.6
# 32/150 round completed......................... Accurecy: 0.6105263157894737
# 33/150 round completed......................... Accurecy: 0.6105263157894737
# 34/150 round completed......................... Accurecy: 0.6105263157894737
# 35/150 round completed......................... Accurecy: 0.6105263157894737
# 36/150 round completed......................... Accurecy: 0.6105263157894737
# 37/150 round completed......................... Accurecy: 0.6105263157894737
# 38/150 round completed......................... Accurecy: 0.6210526315789474
# 39/150 round completed......................... Accurecy: 0.6210526315789474
# 40/150 round completed......................... Accurecy: 0.6210526315789474
# 41/150 round completed......................... Accurecy: 0.6210526315789474
# 42/150 round completed......................... Accurecy: 0.631578947368421
# 43/150 round completed......................... Accurecy: 0.631578947368421
# 44/150 round completed......................... Accurecy: 0.631578947368421
# 45/150 round completed......................... Accurecy: 0.631578947368421
# 46/150 round completed......................... Accurecy: 0.631578947368421
# 47/150 round completed......................... Accurecy: 0.631578947368421
# 48/150 round completed......................... Accurecy: 0.631578947368421
# 49/150 round completed......................... Accurecy: 0.631578947368421
# 50/150 round completed......................... Accurecy: 0.631578947368421
# 51/150 round completed......................... Accurecy: 0.631578947368421
# 52/150 round completed......................... Accurecy: 0.631578947368421
# 53/150 round completed......................... Accurecy: 0.631578947368421
# 54/150 round completed......................... Accurecy: 0.6421052631578947
# 55/150 round completed......................... Accurecy: 0.631578947368421
# 56/150 round completed......................... Accurecy: 0.631578947368421
# 57/150 round completed......................... Accurecy: 0.631578947368421
# 58/150 round completed......................... Accurecy: 0.6210526315789474
# 59/150 round completed......................... Accurecy: 0.6210526315789474
# 60/150 round completed......................... Accurecy: 0.6210526315789474
# 61/150 round completed......................... Accurecy: 0.631578947368421
# 62/150 round completed......................... Accurecy: 0.631578947368421
# 63/150 round completed......................... Accurecy: 0.631578947368421
# 64/150 round completed......................... Accurecy: 0.6421052631578947
# 65/150 round completed......................... Accurecy: 0.631578947368421
# 66/150 round completed......................... Accurecy: 0.6421052631578947
# 67/150 round completed......................... Accurecy: 0.6421052631578947
# 68/150 round completed......................... Accurecy: 0.6210526315789474
# 69/150 round completed......................... Accurecy: 0.631578947368421
# 70/150 round completed......................... Accurecy: 0.631578947368421
# 71/150 round completed......................... Accurecy: 0.631578947368421
# 72/150 round completed......................... Accurecy: 0.631578947368421
# 73/150 round completed......................... Accurecy: 0.631578947368421
# 74/150 round completed......................... Accurecy: 0.631578947368421
# 75/150 round completed......................... Accurecy: 0.631578947368421
# 76/150 round completed......................... Accurecy: 0.631578947368421
# 77/150 round completed......................... Accurecy: 0.6421052631578947
# 78/150 round completed......................... Accurecy: 0.6421052631578947
# 79/150 round completed......................... Accurecy: 0.6631578947368421
# 80/150 round completed......................... Accurecy: 0.6631578947368421
# 81/150 round completed......................... Accurecy: 0.6526315789473685
# 82/150 round completed......................... Accurecy: 0.6421052631578947
# 83/150 round completed......................... Accurecy: 0.6421052631578947
# 84/150 round completed......................... Accurecy: 0.6526315789473685
# 85/150 round completed......................... Accurecy: 0.6631578947368421
# 86/150 round completed......................... Accurecy: 0.6421052631578947
# 87/150 round completed......................... Accurecy: 0.6421052631578947
# 88/150 round completed......................... Accurecy: 0.6421052631578947
# 89/150 round completed......................... Accurecy: 0.6631578947368421
# 90/150 round completed......................... Accurecy: 0.6631578947368421
# 91/150 round completed......................... Accurecy: 0.6526315789473685
# 92/150 round completed......................... Accurecy: 0.6526315789473685
# 93/150 round completed......................... Accurecy: 0.6526315789473685
# 94/150 round completed......................... Accurecy: 0.6526315789473685
# 95/150 round completed......................... Accurecy: 0.6526315789473685
# 96/150 round completed......................... Accurecy: 0.6526315789473685
# 97/150 round completed......................... Accurecy: 0.6526315789473685
# 98/150 round completed......................... Accurecy: 0.6526315789473685
# 99/150 round completed......................... Accurecy: 0.6631578947368421
# 100/150 round completed......................... Accurecy: 0.6736842105263158
# 101/150 round completed......................... Accurecy: 0.6736842105263158
# 102/150 round completed......................... Accurecy: 0.6736842105263158
# 103/150 round completed......................... Accurecy: 0.6631578947368421
# 104/150 round completed......................... Accurecy: 0.6631578947368421
# 105/150 round completed......................... Accurecy: 0.6631578947368421
# 106/150 round completed......................... Accurecy: 0.6526315789473685
# 107/150 round completed......................... Accurecy: 0.6631578947368421
# 108/150 round completed......................... Accurecy: 0.6736842105263158
# 109/150 round completed......................... Accurecy: 0.6736842105263158
# 110/150 round completed......................... Accurecy: 0.6736842105263158
# 111/150 round completed......................... Accurecy: 0.6736842105263158
# 112/150 round completed......................... Accurecy: 0.6736842105263158
# 113/150 round completed......................... Accurecy: 0.6736842105263158
# 114/150 round completed......................... Accurecy: 0.6736842105263158
# 115/150 round completed......................... Accurecy: 0.6842105263157895
# 116/150 round completed......................... Accurecy: 0.6842105263157895
# 117/150 round completed......................... Accurecy: 0.6842105263157895
# 118/150 round completed......................... Accurecy: 0.6842105263157895
# 119/150 round completed......................... Accurecy: 0.6736842105263158
# 120/150 round completed......................... Accurecy: 0.6736842105263158
# 121/150 round completed......................... Accurecy: 0.6736842105263158
# 122/150 round completed......................... Accurecy: 0.6631578947368421
# 123/150 round completed......................... Accurecy: 0.6631578947368421
# 124/150 round completed......................... Accurecy: 0.6526315789473685
# 125/150 round completed......................... Accurecy: 0.6526315789473685
# 126/150 round completed......................... Accurecy: 0.6736842105263158
# 127/150 round completed......................... Accurecy: 0.6842105263157895
# 128/150 round completed......................... Accurecy: 0.6842105263157895
# 129/150 round completed......................... Accurecy: 0.6736842105263158
# 130/150 round completed......................... Accurecy: 0.6842105263157895
# 131/150 round completed......................... Accurecy: 0.6842105263157895
# 132/150 round completed......................... Accurecy: 0.6842105263157895
# 133/150 round completed......................... Accurecy: 0.6947368421052632
# 134/150 round completed......................... Accurecy: 0.6947368421052632
# 135/150 round completed......................... Accurecy: 0.6947368421052632
# 136/150 round completed......................... Accurecy: 0.6842105263157895
# 137/150 round completed......................... Accurecy: 0.6842105263157895
# 138/150 round completed......................... Accurecy: 0.6736842105263158
# 139/150 round completed......................... Accurecy: 0.6736842105263158
# 140/150 round completed......................... Accurecy: 0.6842105263157895
# 141/150 round completed......................... Accurecy: 0.7052631578947368
# 142/150 round completed......................... Accurecy: 0.6842105263157895
# 143/150 round completed......................... Accurecy: 0.6842105263157895
# 144/150 round completed......................... Accurecy: 0.6842105263157895
# 145/150 round completed......................... Accurecy: 0.6842105263157895
# 146/150 round completed......................... Accurecy: 0.6947368421052632
# 147/150 round completed......................... Accurecy: 0.6947368421052632
# 148/150 round completed......................... Accurecy: 0.6947368421052632
# 149/150 round completed......................... Accurecy: 0.6947368421052632
# 150/150 round completed......................... Accurecy: 0.6947368421052632
# The best n_estimators:
# 141

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=30
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = GradientBoostingClassifier(max_depth=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/30 round completed......................... Accurecy: 0.6
# 2/30 round completed......................... Accurecy: 0.6421052631578947
# 3/30 round completed......................... Accurecy: 0.6736842105263158
# 4/30 round completed......................... Accurecy: 0.6736842105263158
# 5/30 round completed......................... Accurecy: 0.6631578947368421
# 6/30 round completed......................... Accurecy: 0.6421052631578947
# 7/30 round completed......................... Accurecy: 0.6947368421052632
# 8/30 round completed......................... Accurecy: 0.6947368421052632
# 9/30 round completed......................... Accurecy: 0.6631578947368421
# 10/30 round completed......................... Accurecy: 0.6842105263157895
# 11/30 round completed......................... Accurecy: 0.7052631578947368
# 12/30 round completed......................... Accurecy: 0.6947368421052632
# 13/30 round completed......................... Accurecy: 0.6842105263157895
# 14/30 round completed......................... Accurecy: 0.6842105263157895
# 15/30 round completed......................... Accurecy: 0.6842105263157895
# 16/30 round completed......................... Accurecy: 0.6842105263157895
# 17/30 round completed......................... Accurecy: 0.6842105263157895
# 18/30 round completed......................... Accurecy: 0.6842105263157895
# 19/30 round completed......................... Accurecy: 0.6842105263157895
# 20/30 round completed......................... Accurecy: 0.6842105263157895
# 21/30 round completed......................... Accurecy: 0.6842105263157895
# 22/30 round completed......................... Accurecy: 0.6842105263157895
# 23/30 round completed......................... Accurecy: 0.6842105263157895
# 24/30 round completed......................... Accurecy: 0.6842105263157895
# 25/30 round completed......................... Accurecy: 0.6842105263157895
# 26/30 round completed......................... Accurecy: 0.6842105263157895
# 27/30 round completed......................... Accurecy: 0.6842105263157895
# 28/30 round completed......................... Accurecy: 0.6842105263157895
# 29/30 round completed......................... Accurecy: 0.6842105263157895
# 30/30 round completed......................... Accurecy: 0.6842105263157895
# The best Depth:
# 11

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_estimator = GradientBoostingClassifier(n_estimators=best_estimator,random_state=0)
gradBoost_estimator.fit(X_train, y_train)
y_pred = gradBoost_estimator.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(gradBoost_estimator,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [11 34]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        50
#            1       0.67      0.76      0.71        45
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.71      0.71        95
# weighted avg       0.71      0.71      0.71        95
#
# Accurecy:  0.7052631578947368

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_depth = GradientBoostingClassifier(max_depth=best_depth,random_state=0)
gradBoost_depth.fit(X_train, y_train)
y_pred = gradBoost_depth.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))

result[(gradBoost_depth,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [11 34]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        50
#            1       0.67      0.76      0.71        45
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.71      0.71        95
# weighted avg       0.71      0.71      0.71        95
#
# Accurecy:  0.7052631578947368

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_all = GradientBoostingClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
gradBoost_all.fit(X_train, y_train)
y_pred = gradBoost_all.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))

result[(gradBoost_all,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [11 34]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        50
#            1       0.67      0.76      0.71        45
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.71      0.71        95
# weighted avg       0.71      0.71      0.71        95
#
# Accurecy:  0.7052631578947368

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_default = RandomForestClassifier(random_state=0)
rf_default.fit(X_train, y_train)
y_pred=rf_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_default,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [11 34]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        50
#            1       0.67      0.76      0.71        45
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.71      0.71        95
# weighted avg       0.71      0.71      0.71        95
#
# Accurecy:  0.7052631578947368

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = RandomForestClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/150 round completed......................... Accurecy: 0.5684210526315789
# 2/150 round completed......................... Accurecy: 0.6631578947368421
# 3/150 round completed......................... Accurecy: 0.6947368421052632
# 4/150 round completed......................... Accurecy: 0.6947368421052632
# 5/150 round completed......................... Accurecy: 0.6947368421052632
# 6/150 round completed......................... Accurecy: 0.6947368421052632
# 7/150 round completed......................... Accurecy: 0.6947368421052632
# 8/150 round completed......................... Accurecy: 0.7157894736842105
# 9/150 round completed......................... Accurecy: 0.6842105263157895
# 10/150 round completed......................... Accurecy: 0.7052631578947368
# 11/150 round completed......................... Accurecy: 0.6947368421052632
# 12/150 round completed......................... Accurecy: 0.7157894736842105
# 13/150 round completed......................... Accurecy: 0.7157894736842105
# 14/150 round completed......................... Accurecy: 0.7052631578947368
# 15/150 round completed......................... Accurecy: 0.6947368421052632
# 16/150 round completed......................... Accurecy: 0.7052631578947368
# 17/150 round completed......................... Accurecy: 0.6947368421052632
# 18/150 round completed......................... Accurecy: 0.6842105263157895
# 19/150 round completed......................... Accurecy: 0.6947368421052632
# 20/150 round completed......................... Accurecy: 0.6842105263157895
# 21/150 round completed......................... Accurecy: 0.6947368421052632
# 22/150 round completed......................... Accurecy: 0.6947368421052632
# 23/150 round completed......................... Accurecy: 0.6947368421052632
# 24/150 round completed......................... Accurecy: 0.6842105263157895
# 25/150 round completed......................... Accurecy: 0.6947368421052632
# 26/150 round completed......................... Accurecy: 0.6842105263157895
# 27/150 round completed......................... Accurecy: 0.6736842105263158
# 28/150 round completed......................... Accurecy: 0.6736842105263158
# 29/150 round completed......................... Accurecy: 0.6736842105263158
# 30/150 round completed......................... Accurecy: 0.6736842105263158
# 31/150 round completed......................... Accurecy: 0.6947368421052632
# 32/150 round completed......................... Accurecy: 0.6842105263157895
# 33/150 round completed......................... Accurecy: 0.6947368421052632
# 34/150 round completed......................... Accurecy: 0.6736842105263158
# 35/150 round completed......................... Accurecy: 0.6736842105263158
# 36/150 round completed......................... Accurecy: 0.6631578947368421
# 37/150 round completed......................... Accurecy: 0.6736842105263158
# 38/150 round completed......................... Accurecy: 0.6842105263157895
# 39/150 round completed......................... Accurecy: 0.7052631578947368
# 40/150 round completed......................... Accurecy: 0.7052631578947368
# 41/150 round completed......................... Accurecy: 0.6842105263157895
# 42/150 round completed......................... Accurecy: 0.6947368421052632
# 43/150 round completed......................... Accurecy: 0.6947368421052632
# 44/150 round completed......................... Accurecy: 0.6947368421052632
# 45/150 round completed......................... Accurecy: 0.6842105263157895
# 46/150 round completed......................... Accurecy: 0.6736842105263158
# 47/150 round completed......................... Accurecy: 0.6842105263157895
# 48/150 round completed......................... Accurecy: 0.6842105263157895
# 49/150 round completed......................... Accurecy: 0.7052631578947368
# 50/150 round completed......................... Accurecy: 0.6947368421052632
# 51/150 round completed......................... Accurecy: 0.7052631578947368
# 52/150 round completed......................... Accurecy: 0.7052631578947368
# 53/150 round completed......................... Accurecy: 0.7052631578947368
# 54/150 round completed......................... Accurecy: 0.7052631578947368
# 55/150 round completed......................... Accurecy: 0.7157894736842105
# 56/150 round completed......................... Accurecy: 0.6947368421052632
# 57/150 round completed......................... Accurecy: 0.7157894736842105
# 58/150 round completed......................... Accurecy: 0.7052631578947368
# 59/150 round completed......................... Accurecy: 0.7052631578947368
# 60/150 round completed......................... Accurecy: 0.7052631578947368
# 61/150 round completed......................... Accurecy: 0.7157894736842105
# 62/150 round completed......................... Accurecy: 0.6947368421052632
# 63/150 round completed......................... Accurecy: 0.6947368421052632
# 64/150 round completed......................... Accurecy: 0.6842105263157895
# 65/150 round completed......................... Accurecy: 0.6947368421052632
# 66/150 round completed......................... Accurecy: 0.6842105263157895
# 67/150 round completed......................... Accurecy: 0.6947368421052632
# 68/150 round completed......................... Accurecy: 0.6842105263157895
# 69/150 round completed......................... Accurecy: 0.6842105263157895
# 70/150 round completed......................... Accurecy: 0.6842105263157895
# 71/150 round completed......................... Accurecy: 0.6842105263157895
# 72/150 round completed......................... Accurecy: 0.6842105263157895
# 73/150 round completed......................... Accurecy: 0.7052631578947368
# 74/150 round completed......................... Accurecy: 0.6842105263157895
# 75/150 round completed......................... Accurecy: 0.6842105263157895
# 76/150 round completed......................... Accurecy: 0.6947368421052632
# 77/150 round completed......................... Accurecy: 0.7052631578947368
# 78/150 round completed......................... Accurecy: 0.7052631578947368
# 79/150 round completed......................... Accurecy: 0.7157894736842105
# 80/150 round completed......................... Accurecy: 0.6947368421052632
# 81/150 round completed......................... Accurecy: 0.7157894736842105
# 82/150 round completed......................... Accurecy: 0.7157894736842105
# 83/150 round completed......................... Accurecy: 0.7157894736842105
# 84/150 round completed......................... Accurecy: 0.7157894736842105
# 85/150 round completed......................... Accurecy: 0.7157894736842105
# 86/150 round completed......................... Accurecy: 0.7157894736842105
# 87/150 round completed......................... Accurecy: 0.7157894736842105
# 88/150 round completed......................... Accurecy: 0.7052631578947368
# 89/150 round completed......................... Accurecy: 0.7052631578947368
# 90/150 round completed......................... Accurecy: 0.7052631578947368
# 91/150 round completed......................... Accurecy: 0.7052631578947368
# 92/150 round completed......................... Accurecy: 0.7052631578947368
# 93/150 round completed......................... Accurecy: 0.6947368421052632
# 94/150 round completed......................... Accurecy: 0.6947368421052632
# 95/150 round completed......................... Accurecy: 0.6947368421052632
# 96/150 round completed......................... Accurecy: 0.6947368421052632
# 97/150 round completed......................... Accurecy: 0.6947368421052632
# 98/150 round completed......................... Accurecy: 0.6947368421052632
# 99/150 round completed......................... Accurecy: 0.6947368421052632
# 100/150 round completed......................... Accurecy: 0.7052631578947368
# 101/150 round completed......................... Accurecy: 0.6947368421052632
# 102/150 round completed......................... Accurecy: 0.6947368421052632
# 103/150 round completed......................... Accurecy: 0.6947368421052632
# 104/150 round completed......................... Accurecy: 0.6947368421052632
# 105/150 round completed......................... Accurecy: 0.6842105263157895
# 106/150 round completed......................... Accurecy: 0.6842105263157895
# 107/150 round completed......................... Accurecy: 0.6842105263157895
# 108/150 round completed......................... Accurecy: 0.6947368421052632
# 109/150 round completed......................... Accurecy: 0.6842105263157895
# 110/150 round completed......................... Accurecy: 0.6947368421052632
# 111/150 round completed......................... Accurecy: 0.6736842105263158
# 112/150 round completed......................... Accurecy: 0.6842105263157895
# 113/150 round completed......................... Accurecy: 0.6842105263157895
# 114/150 round completed......................... Accurecy: 0.6842105263157895
# 115/150 round completed......................... Accurecy: 0.6736842105263158
# 116/150 round completed......................... Accurecy: 0.6736842105263158
# 117/150 round completed......................... Accurecy: 0.6631578947368421
# 118/150 round completed......................... Accurecy: 0.6736842105263158
# 119/150 round completed......................... Accurecy: 0.6736842105263158
# 120/150 round completed......................... Accurecy: 0.6842105263157895
# 121/150 round completed......................... Accurecy: 0.6842105263157895
# 122/150 round completed......................... Accurecy: 0.6947368421052632
# 123/150 round completed......................... Accurecy: 0.6842105263157895
# 124/150 round completed......................... Accurecy: 0.6947368421052632
# 125/150 round completed......................... Accurecy: 0.6947368421052632
# 126/150 round completed......................... Accurecy: 0.6947368421052632
# 127/150 round completed......................... Accurecy: 0.6947368421052632
# 128/150 round completed......................... Accurecy: 0.6947368421052632
# 129/150 round completed......................... Accurecy: 0.6842105263157895
# 130/150 round completed......................... Accurecy: 0.6947368421052632
# 131/150 round completed......................... Accurecy: 0.6842105263157895
# 132/150 round completed......................... Accurecy: 0.6842105263157895
# 133/150 round completed......................... Accurecy: 0.6842105263157895
# 134/150 round completed......................... Accurecy: 0.6842105263157895
# 135/150 round completed......................... Accurecy: 0.6842105263157895
# 136/150 round completed......................... Accurecy: 0.6947368421052632
# 137/150 round completed......................... Accurecy: 0.6947368421052632
# 138/150 round completed......................... Accurecy: 0.7052631578947368
# 139/150 round completed......................... Accurecy: 0.6842105263157895
# 140/150 round completed......................... Accurecy: 0.6947368421052632
# 141/150 round completed......................... Accurecy: 0.6947368421052632
# 142/150 round completed......................... Accurecy: 0.6947368421052632
# 143/150 round completed......................... Accurecy: 0.6947368421052632
# 144/150 round completed......................... Accurecy: 0.6947368421052632
# 145/150 round completed......................... Accurecy: 0.6947368421052632
# 146/150 round completed......................... Accurecy: 0.7052631578947368
# 147/150 round completed......................... Accurecy: 0.6842105263157895
# 148/150 round completed......................... Accurecy: 0.7052631578947368
# 149/150 round completed......................... Accurecy: 0.6947368421052632
# 150/150 round completed......................... Accurecy: 0.7157894736842105
# The best n_estimators:
# 8

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = RandomForestClassifier(max_depth=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/150 round completed......................... Accurecy: 0.5789473684210527
# 2/150 round completed......................... Accurecy: 0.5473684210526316
# 3/150 round completed......................... Accurecy: 0.5789473684210527
# 4/150 round completed......................... Accurecy: 0.6
# 5/150 round completed......................... Accurecy: 0.6
# 6/150 round completed......................... Accurecy: 0.6105263157894737
# 7/150 round completed......................... Accurecy: 0.6421052631578947
# 8/150 round completed......................... Accurecy: 0.6736842105263158
# 9/150 round completed......................... Accurecy: 0.6526315789473685
# 10/150 round completed......................... Accurecy: 0.6736842105263158
# 11/150 round completed......................... Accurecy: 0.7052631578947368
# 12/150 round completed......................... Accurecy: 0.6842105263157895
# 13/150 round completed......................... Accurecy: 0.6947368421052632
# 14/150 round completed......................... Accurecy: 0.7052631578947368
# 15/150 round completed......................... Accurecy: 0.7052631578947368
# 16/150 round completed......................... Accurecy: 0.7052631578947368
# 17/150 round completed......................... Accurecy: 0.7052631578947368
# 18/150 round completed......................... Accurecy: 0.7052631578947368
# 19/150 round completed......................... Accurecy: 0.7052631578947368
# 20/150 round completed......................... Accurecy: 0.7052631578947368
# 21/150 round completed......................... Accurecy: 0.7052631578947368
# 22/150 round completed......................... Accurecy: 0.7052631578947368
# 23/150 round completed......................... Accurecy: 0.7052631578947368
# 24/150 round completed......................... Accurecy: 0.7052631578947368
# 25/150 round completed......................... Accurecy: 0.7052631578947368
# 26/150 round completed......................... Accurecy: 0.7052631578947368
# 27/150 round completed......................... Accurecy: 0.7052631578947368
# 28/150 round completed......................... Accurecy: 0.7052631578947368
# 29/150 round completed......................... Accurecy: 0.7052631578947368
# 30/150 round completed......................... Accurecy: 0.7052631578947368
# 31/150 round completed......................... Accurecy: 0.7052631578947368
# 32/150 round completed......................... Accurecy: 0.7052631578947368
# 33/150 round completed......................... Accurecy: 0.7052631578947368
# 34/150 round completed......................... Accurecy: 0.7052631578947368
# 35/150 round completed......................... Accurecy: 0.7052631578947368
# 36/150 round completed......................... Accurecy: 0.7052631578947368
# 37/150 round completed......................... Accurecy: 0.7052631578947368
# 38/150 round completed......................... Accurecy: 0.7052631578947368
# 39/150 round completed......................... Accurecy: 0.7052631578947368
# 40/150 round completed......................... Accurecy: 0.7052631578947368
# 41/150 round completed......................... Accurecy: 0.7052631578947368
# 42/150 round completed......................... Accurecy: 0.7052631578947368
# 43/150 round completed......................... Accurecy: 0.7052631578947368
# 44/150 round completed......................... Accurecy: 0.7052631578947368
# 45/150 round completed......................... Accurecy: 0.7052631578947368
# 46/150 round completed......................... Accurecy: 0.7052631578947368
# 47/150 round completed......................... Accurecy: 0.7052631578947368
# 48/150 round completed......................... Accurecy: 0.7052631578947368
# 49/150 round completed......................... Accurecy: 0.7052631578947368
# 50/150 round completed......................... Accurecy: 0.7052631578947368
# 51/150 round completed......................... Accurecy: 0.7052631578947368
# 52/150 round completed......................... Accurecy: 0.7052631578947368
# 53/150 round completed......................... Accurecy: 0.7052631578947368
# 54/150 round completed......................... Accurecy: 0.7052631578947368
# 55/150 round completed......................... Accurecy: 0.7052631578947368
# 56/150 round completed......................... Accurecy: 0.7052631578947368
# 57/150 round completed......................... Accurecy: 0.7052631578947368
# 58/150 round completed......................... Accurecy: 0.7052631578947368
# 59/150 round completed......................... Accurecy: 0.7052631578947368
# 60/150 round completed......................... Accurecy: 0.7052631578947368
# 61/150 round completed......................... Accurecy: 0.7052631578947368
# 62/150 round completed......................... Accurecy: 0.7052631578947368
# 63/150 round completed......................... Accurecy: 0.7052631578947368
# 64/150 round completed......................... Accurecy: 0.7052631578947368
# 65/150 round completed......................... Accurecy: 0.7052631578947368
# 66/150 round completed......................... Accurecy: 0.7052631578947368
# 67/150 round completed......................... Accurecy: 0.7052631578947368
# 68/150 round completed......................... Accurecy: 0.7052631578947368
# 69/150 round completed......................... Accurecy: 0.7052631578947368
# 70/150 round completed......................... Accurecy: 0.7052631578947368
# 71/150 round completed......................... Accurecy: 0.7052631578947368
# 72/150 round completed......................... Accurecy: 0.7052631578947368
# 73/150 round completed......................... Accurecy: 0.7052631578947368
# 74/150 round completed......................... Accurecy: 0.7052631578947368
# 75/150 round completed......................... Accurecy: 0.7052631578947368
# 76/150 round completed......................... Accurecy: 0.7052631578947368
# 77/150 round completed......................... Accurecy: 0.7052631578947368
# 78/150 round completed......................... Accurecy: 0.7052631578947368
# 79/150 round completed......................... Accurecy: 0.7052631578947368
# 80/150 round completed......................... Accurecy: 0.7052631578947368
# 81/150 round completed......................... Accurecy: 0.7052631578947368
# 82/150 round completed......................... Accurecy: 0.7052631578947368
# 83/150 round completed......................... Accurecy: 0.7052631578947368
# 84/150 round completed......................... Accurecy: 0.7052631578947368
# 85/150 round completed......................... Accurecy: 0.7052631578947368
# 86/150 round completed......................... Accurecy: 0.7052631578947368
# 87/150 round completed......................... Accurecy: 0.7052631578947368
# 88/150 round completed......................... Accurecy: 0.7052631578947368
# 89/150 round completed......................... Accurecy: 0.7052631578947368
# 90/150 round completed......................... Accurecy: 0.7052631578947368
# 91/150 round completed......................... Accurecy: 0.7052631578947368
# 92/150 round completed......................... Accurecy: 0.7052631578947368
# 93/150 round completed......................... Accurecy: 0.7052631578947368
# 94/150 round completed......................... Accurecy: 0.7052631578947368
# 95/150 round completed......................... Accurecy: 0.7052631578947368
# 96/150 round completed......................... Accurecy: 0.7052631578947368
# 97/150 round completed......................... Accurecy: 0.7052631578947368
# 98/150 round completed......................... Accurecy: 0.7052631578947368
# 99/150 round completed......................... Accurecy: 0.7052631578947368
# 100/150 round completed......................... Accurecy: 0.7052631578947368
# 101/150 round completed......................... Accurecy: 0.7052631578947368
# 102/150 round completed......................... Accurecy: 0.7052631578947368
# 103/150 round completed......................... Accurecy: 0.7052631578947368
# 104/150 round completed......................... Accurecy: 0.7052631578947368
# 105/150 round completed......................... Accurecy: 0.7052631578947368
# 106/150 round completed......................... Accurecy: 0.7052631578947368
# 107/150 round completed......................... Accurecy: 0.7052631578947368
# 108/150 round completed......................... Accurecy: 0.7052631578947368
# 109/150 round completed......................... Accurecy: 0.7052631578947368
# 110/150 round completed......................... Accurecy: 0.7052631578947368
# 111/150 round completed......................... Accurecy: 0.7052631578947368
# 112/150 round completed......................... Accurecy: 0.7052631578947368
# 113/150 round completed......................... Accurecy: 0.7052631578947368
# 114/150 round completed......................... Accurecy: 0.7052631578947368
# 115/150 round completed......................... Accurecy: 0.7052631578947368
# 116/150 round completed......................... Accurecy: 0.7052631578947368
# 117/150 round completed......................... Accurecy: 0.7052631578947368
# 118/150 round completed......................... Accurecy: 0.7052631578947368
# 119/150 round completed......................... Accurecy: 0.7052631578947368
# 120/150 round completed......................... Accurecy: 0.7052631578947368
# 121/150 round completed......................... Accurecy: 0.7052631578947368
# 122/150 round completed......................... Accurecy: 0.7052631578947368
# 123/150 round completed......................... Accurecy: 0.7052631578947368
# 124/150 round completed......................... Accurecy: 0.7052631578947368
# 125/150 round completed......................... Accurecy: 0.7052631578947368
# 126/150 round completed......................... Accurecy: 0.7052631578947368
# 127/150 round completed......................... Accurecy: 0.7052631578947368
# 128/150 round completed......................... Accurecy: 0.7052631578947368
# 129/150 round completed......................... Accurecy: 0.7052631578947368
# 130/150 round completed......................... Accurecy: 0.7052631578947368
# 131/150 round completed......................... Accurecy: 0.7052631578947368
# 132/150 round completed......................... Accurecy: 0.7052631578947368
# 133/150 round completed......................... Accurecy: 0.7052631578947368
# 134/150 round completed......................... Accurecy: 0.7052631578947368
# 135/150 round completed......................... Accurecy: 0.7052631578947368
# 136/150 round completed......................... Accurecy: 0.7052631578947368
# 137/150 round completed......................... Accurecy: 0.7052631578947368
# 138/150 round completed......................... Accurecy: 0.7052631578947368
# 139/150 round completed......................... Accurecy: 0.7052631578947368
# 140/150 round completed......................... Accurecy: 0.7052631578947368
# 141/150 round completed......................... Accurecy: 0.7052631578947368
# 142/150 round completed......................... Accurecy: 0.7052631578947368
# 143/150 round completed......................... Accurecy: 0.7052631578947368
# 144/150 round completed......................... Accurecy: 0.7052631578947368
# 145/150 round completed......................... Accurecy: 0.7052631578947368
# 146/150 round completed......................... Accurecy: 0.7052631578947368
# 147/150 round completed......................... Accurecy: 0.7052631578947368
# 148/150 round completed......................... Accurecy: 0.7052631578947368
# 149/150 round completed......................... Accurecy: 0.7052631578947368
# 150/150 round completed......................... Accurecy: 0.7052631578947368
# The best Depth:
# 11

# %%
from sklearn.ensemble import RandomForestClassifier
rf_estimator = RandomForestClassifier(n_estimators=best_estimator,random_state=0)
rf_estimator.fit(X_train, y_train)
y_pred=rf_estimator.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_estimator,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[35 15]
#  [12 33]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        50
#            1       0.69      0.73      0.71        45
#
#     accuracy                           0.72        95
#    macro avg       0.72      0.72      0.72        95
# weighted avg       0.72      0.72      0.72        95
#
# Accurecy:  0.7157894736842105

# %%
from sklearn.ensemble import RandomForestClassifier
rf_depth = RandomForestClassifier(max_depth=best_depth,random_state=0)
rf_depth.fit(X_train, y_train)
y_pred=rf_depth.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_depth,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [11 34]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.66      0.70        50
#            1       0.67      0.76      0.71        45
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.71      0.71        95
# weighted avg       0.71      0.71      0.71        95
#
# Accurecy:  0.7052631578947368

# %%
from sklearn.ensemble import RandomForestClassifier
rf_all = RandomForestClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
rf_all.fit(X_train, y_train)
y_pred=rf_all.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_all,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[33 17]
#  [14 31]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68        50
#            1       0.65      0.69      0.67        45
#
#     accuracy                           0.67        95
#    macro avg       0.67      0.67      0.67        95
# weighted avg       0.68      0.67      0.67        95
#
# Accurecy:  0.6736842105263158

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #XGB

# %%
import xgboost as xgb
xgb_deafult = xgb.XGBClassifier(random_state=0)
xgb_deafult.fit(X_train,y_train)
y_pred = xgb_deafult.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_deafult,4,'xgboost')]=accuracy_score(y_test, y_pred)
# Out:
# [[35 15]
#  [10 35]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        50
#            1       0.70      0.78      0.74        45
#
#     accuracy                           0.74        95
#    macro avg       0.74      0.74      0.74        95
# weighted avg       0.74      0.74      0.74        95
#
# Accurecy:  0.7368421052631579

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score
N=250
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  xgb_classifier = xgb.XGBClassifier(n_estimators=k,random_state=0)
  xgb_classifier.fit(X_train, y_train)
  y_pred=xgb_classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/250 round completed......................... Accurecy: 0.6421052631578947
# 2/250 round completed......................... Accurecy: 0.6210526315789474
# 3/250 round completed......................... Accurecy: 0.6421052631578947
# 4/250 round completed......................... Accurecy: 0.6526315789473685
# 5/250 round completed......................... Accurecy: 0.6631578947368421
# 6/250 round completed......................... Accurecy: 0.6631578947368421
# 7/250 round completed......................... Accurecy: 0.6947368421052632
# 8/250 round completed......................... Accurecy: 0.6842105263157895
# 9/250 round completed......................... Accurecy: 0.6736842105263158
# 10/250 round completed......................... Accurecy: 0.6736842105263158
# 11/250 round completed......................... Accurecy: 0.6526315789473685
# 12/250 round completed......................... Accurecy: 0.6526315789473685
# 13/250 round completed......................... Accurecy: 0.6526315789473685
# 14/250 round completed......................... Accurecy: 0.6631578947368421
# 15/250 round completed......................... Accurecy: 0.6631578947368421
# 16/250 round completed......................... Accurecy: 0.6736842105263158
# 17/250 round completed......................... Accurecy: 0.7157894736842105
# 18/250 round completed......................... Accurecy: 0.7263157894736842
# 19/250 round completed......................... Accurecy: 0.7157894736842105
# 20/250 round completed......................... Accurecy: 0.7052631578947368
# 21/250 round completed......................... Accurecy: 0.7157894736842105
# 22/250 round completed......................... Accurecy: 0.6947368421052632
# 23/250 round completed......................... Accurecy: 0.7157894736842105
# 24/250 round completed......................... Accurecy: 0.7157894736842105
# 25/250 round completed......................... Accurecy: 0.7157894736842105
# 26/250 round completed......................... Accurecy: 0.7157894736842105
# 27/250 round completed......................... Accurecy: 0.7368421052631579
# 28/250 round completed......................... Accurecy: 0.7263157894736842
# 29/250 round completed......................... Accurecy: 0.7263157894736842
# 30/250 round completed......................... Accurecy: 0.7263157894736842
# 31/250 round completed......................... Accurecy: 0.7157894736842105
# 32/250 round completed......................... Accurecy: 0.7263157894736842
# 33/250 round completed......................... Accurecy: 0.7263157894736842
# 34/250 round completed......................... Accurecy: 0.7263157894736842
# 35/250 round completed......................... Accurecy: 0.7263157894736842
# 36/250 round completed......................... Accurecy: 0.7263157894736842
# 37/250 round completed......................... Accurecy: 0.7263157894736842
# 38/250 round completed......................... Accurecy: 0.7263157894736842
# 39/250 round completed......................... Accurecy: 0.7263157894736842
# 40/250 round completed......................... Accurecy: 0.7263157894736842
# 41/250 round completed......................... Accurecy: 0.7368421052631579
# 42/250 round completed......................... Accurecy: 0.7368421052631579
# 43/250 round completed......................... Accurecy: 0.7263157894736842
# 44/250 round completed......................... Accurecy: 0.7263157894736842
# 45/250 round completed......................... Accurecy: 0.7157894736842105
# 46/250 round completed......................... Accurecy: 0.7263157894736842
# 47/250 round completed......................... Accurecy: 0.7263157894736842
# 48/250 round completed......................... Accurecy: 0.7263157894736842
# 49/250 round completed......................... Accurecy: 0.7263157894736842
# 50/250 round completed......................... Accurecy: 0.7263157894736842
# 51/250 round completed......................... Accurecy: 0.7368421052631579
# 52/250 round completed......................... Accurecy: 0.7368421052631579
# 53/250 round completed......................... Accurecy: 0.7368421052631579
# 54/250 round completed......................... Accurecy: 0.7263157894736842
# 55/250 round completed......................... Accurecy: 0.7263157894736842
# 56/250 round completed......................... Accurecy: 0.7263157894736842
# 57/250 round completed......................... Accurecy: 0.7263157894736842
# 58/250 round completed......................... Accurecy: 0.7263157894736842
# 59/250 round completed......................... Accurecy: 0.7263157894736842
# 60/250 round completed......................... Accurecy: 0.7263157894736842
# 61/250 round completed......................... Accurecy: 0.7263157894736842
# 62/250 round completed......................... Accurecy: 0.7263157894736842
# 63/250 round completed......................... Accurecy: 0.7263157894736842
# 64/250 round completed......................... Accurecy: 0.7263157894736842
# 65/250 round completed......................... Accurecy: 0.7263157894736842
# 66/250 round completed......................... Accurecy: 0.7263157894736842
# 67/250 round completed......................... Accurecy: 0.7263157894736842
# 68/250 round completed......................... Accurecy: 0.7157894736842105
# 69/250 round completed......................... Accurecy: 0.7157894736842105
# 70/250 round completed......................... Accurecy: 0.7263157894736842
# 71/250 round completed......................... Accurecy: 0.7157894736842105
# 72/250 round completed......................... Accurecy: 0.7157894736842105
# 73/250 round completed......................... Accurecy: 0.7157894736842105
# 74/250 round completed......................... Accurecy: 0.7157894736842105
# 75/250 round completed......................... Accurecy: 0.7263157894736842
# 76/250 round completed......................... Accurecy: 0.7263157894736842
# 77/250 round completed......................... Accurecy: 0.7368421052631579
# 78/250 round completed......................... Accurecy: 0.7263157894736842
# 79/250 round completed......................... Accurecy: 0.7368421052631579
# 80/250 round completed......................... Accurecy: 0.7263157894736842
# 81/250 round completed......................... Accurecy: 0.7263157894736842
# 82/250 round completed......................... Accurecy: 0.7263157894736842
# 83/250 round completed......................... Accurecy: 0.7263157894736842
# 84/250 round completed......................... Accurecy: 0.7263157894736842
# 85/250 round completed......................... Accurecy: 0.7157894736842105
# 86/250 round completed......................... Accurecy: 0.7157894736842105
# 87/250 round completed......................... Accurecy: 0.7157894736842105
# 88/250 round completed......................... Accurecy: 0.7157894736842105
# 89/250 round completed......................... Accurecy: 0.7368421052631579
# 90/250 round completed......................... Accurecy: 0.7368421052631579
# 91/250 round completed......................... Accurecy: 0.7368421052631579
# 92/250 round completed......................... Accurecy: 0.7263157894736842
# 93/250 round completed......................... Accurecy: 0.7263157894736842
# 94/250 round completed......................... Accurecy: 0.7263157894736842
# 95/250 round completed......................... Accurecy: 0.7263157894736842
# 96/250 round completed......................... Accurecy: 0.7368421052631579
# 97/250 round completed......................... Accurecy: 0.7263157894736842
# 98/250 round completed......................... Accurecy: 0.7368421052631579
# 99/250 round completed......................... Accurecy: 0.7368421052631579
# 100/250 round completed......................... Accurecy: 0.7368421052631579
# 101/250 round completed......................... Accurecy: 0.7368421052631579
# 102/250 round completed......................... Accurecy: 0.7368421052631579
# 103/250 round completed......................... Accurecy: 0.7368421052631579
# 104/250 round completed......................... Accurecy: 0.7368421052631579
# 105/250 round completed......................... Accurecy: 0.7368421052631579
# 106/250 round completed......................... Accurecy: 0.7368421052631579
# 107/250 round completed......................... Accurecy: 0.7368421052631579
# 108/250 round completed......................... Accurecy: 0.7263157894736842
# 109/250 round completed......................... Accurecy: 0.7368421052631579
# 110/250 round completed......................... Accurecy: 0.7263157894736842
# 111/250 round completed......................... Accurecy: 0.7263157894736842
# 112/250 round completed......................... Accurecy: 0.7263157894736842
# 113/250 round completed......................... Accurecy: 0.7263157894736842
# 114/250 round completed......................... Accurecy: 0.7157894736842105
# 115/250 round completed......................... Accurecy: 0.7157894736842105
# 116/250 round completed......................... Accurecy: 0.7157894736842105
# 117/250 round completed......................... Accurecy: 0.7263157894736842
# 118/250 round completed......................... Accurecy: 0.7157894736842105
# 119/250 round completed......................... Accurecy: 0.7263157894736842
# 120/250 round completed......................... Accurecy: 0.7157894736842105
# 121/250 round completed......................... Accurecy: 0.7157894736842105
# 122/250 round completed......................... Accurecy: 0.7263157894736842
# 123/250 round completed......................... Accurecy: 0.7263157894736842
# 124/250 round completed......................... Accurecy: 0.7263157894736842
# 125/250 round completed......................... Accurecy: 0.7157894736842105
# 126/250 round completed......................... Accurecy: 0.7263157894736842
# 127/250 round completed......................... Accurecy: 0.7157894736842105
# 128/250 round completed......................... Accurecy: 0.7263157894736842
# 129/250 round completed......................... Accurecy: 0.7263157894736842
# 130/250 round completed......................... Accurecy: 0.7263157894736842
# 131/250 round completed......................... Accurecy: 0.7263157894736842
# 132/250 round completed......................... Accurecy: 0.7263157894736842
# 133/250 round completed......................... Accurecy: 0.7368421052631579
# 134/250 round completed......................... Accurecy: 0.7263157894736842
# 135/250 round completed......................... Accurecy: 0.7368421052631579
# 136/250 round completed......................... Accurecy: 0.7368421052631579
# 137/250 round completed......................... Accurecy: 0.7368421052631579
# 138/250 round completed......................... Accurecy: 0.7368421052631579
# 139/250 round completed......................... Accurecy: 0.7368421052631579
# 140/250 round completed......................... Accurecy: 0.7368421052631579
# 141/250 round completed......................... Accurecy: 0.7368421052631579
# 142/250 round completed......................... Accurecy: 0.7263157894736842
# 143/250 round completed......................... Accurecy: 0.7263157894736842
# 144/250 round completed......................... Accurecy: 0.7263157894736842
# 145/250 round completed......................... Accurecy: 0.7263157894736842
# 146/250 round completed......................... Accurecy: 0.7368421052631579
# 147/250 round completed......................... Accurecy: 0.7368421052631579
# 148/250 round completed......................... Accurecy: 0.7368421052631579
# 149/250 round completed......................... Accurecy: 0.7368421052631579
# 150/250 round completed......................... Accurecy: 0.7368421052631579
# 151/250 round completed......................... Accurecy: 0.7368421052631579
# 152/250 round completed......................... Accurecy: 0.7368421052631579
# 153/250 round completed......................... Accurecy: 0.7368421052631579
# 154/250 round completed......................... Accurecy: 0.7368421052631579
# 155/250 round completed......................... Accurecy: 0.7368421052631579
# 156/250 round completed......................... Accurecy: 0.7368421052631579
# 157/250 round completed......................... Accurecy: 0.7473684210526316
# 158/250 round completed......................... Accurecy: 0.7473684210526316
# 159/250 round completed......................... Accurecy: 0.7473684210526316
# 160/250 round completed......................... Accurecy: 0.7473684210526316
# 161/250 round completed......................... Accurecy: 0.7473684210526316
# 162/250 round completed......................... Accurecy: 0.7368421052631579
# 163/250 round completed......................... Accurecy: 0.7473684210526316
# 164/250 round completed......................... Accurecy: 0.7368421052631579
# 165/250 round completed......................... Accurecy: 0.7473684210526316
# 166/250 round completed......................... Accurecy: 0.7368421052631579
# 167/250 round completed......................... Accurecy: 0.7473684210526316
# 168/250 round completed......................... Accurecy: 0.7473684210526316
# 169/250 round completed......................... Accurecy: 0.7473684210526316
# 170/250 round completed......................... Accurecy: 0.7368421052631579
# 171/250 round completed......................... Accurecy: 0.7473684210526316
# 172/250 round completed......................... Accurecy: 0.7473684210526316
# 173/250 round completed......................... Accurecy: 0.7473684210526316
# 174/250 round completed......................... Accurecy: 0.7473684210526316
# 175/250 round completed......................... Accurecy: 0.7473684210526316
# 176/250 round completed......................... Accurecy: 0.7473684210526316
# 177/250 round completed......................... Accurecy: 0.7473684210526316
# 178/250 round completed......................... Accurecy: 0.7473684210526316
# 179/250 round completed......................... Accurecy: 0.7473684210526316
# 180/250 round completed......................... Accurecy: 0.7473684210526316
# 181/250 round completed......................... Accurecy: 0.7473684210526316
# 182/250 round completed......................... Accurecy: 0.7473684210526316
# 183/250 round completed......................... Accurecy: 0.7473684210526316
# 184/250 round completed......................... Accurecy: 0.7473684210526316
# 185/250 round completed......................... Accurecy: 0.7473684210526316
# 186/250 round completed......................... Accurecy: 0.7473684210526316
# 187/250 round completed......................... Accurecy: 0.7473684210526316
# 188/250 round completed......................... Accurecy: 0.7473684210526316
# 189/250 round completed......................... Accurecy: 0.7473684210526316
# 190/250 round completed......................... Accurecy: 0.7473684210526316
# 191/250 round completed......................... Accurecy: 0.7473684210526316
# 192/250 round completed......................... Accurecy: 0.7473684210526316
# 193/250 round completed......................... Accurecy: 0.7473684210526316
# 194/250 round completed......................... Accurecy: 0.7368421052631579
# 195/250 round completed......................... Accurecy: 0.7368421052631579
# 196/250 round completed......................... Accurecy: 0.7368421052631579
# 197/250 round completed......................... Accurecy: 0.7368421052631579
# 198/250 round completed......................... Accurecy: 0.7368421052631579
# 199/250 round completed......................... Accurecy: 0.7368421052631579
# 200/250 round completed......................... Accurecy: 0.7473684210526316
# 201/250 round completed......................... Accurecy: 0.7473684210526316
# 202/250 round completed......................... Accurecy: 0.7473684210526316
# 203/250 round completed......................... Accurecy: 0.7473684210526316
# 204/250 round completed......................... Accurecy: 0.7368421052631579
# 205/250 round completed......................... Accurecy: 0.7473684210526316
# 206/250 round completed......................... Accurecy: 0.7368421052631579
# 207/250 round completed......................... Accurecy: 0.7473684210526316
# 208/250 round completed......................... Accurecy: 0.7473684210526316
# 209/250 round completed......................... Accurecy: 0.7473684210526316
# 210/250 round completed......................... Accurecy: 0.7473684210526316
# 211/250 round completed......................... Accurecy: 0.7473684210526316
# 212/250 round completed......................... Accurecy: 0.7473684210526316
# 213/250 round completed......................... Accurecy: 0.7473684210526316
# 214/250 round completed......................... Accurecy: 0.7368421052631579
# 215/250 round completed......................... Accurecy: 0.7368421052631579
# 216/250 round completed......................... Accurecy: 0.7368421052631579
# 217/250 round completed......................... Accurecy: 0.7473684210526316
# 218/250 round completed......................... Accurecy: 0.7473684210526316
# 219/250 round completed......................... Accurecy: 0.7473684210526316
# 220/250 round completed......................... Accurecy: 0.7368421052631579
# 221/250 round completed......................... Accurecy: 0.7368421052631579
# 222/250 round completed......................... Accurecy: 0.7368421052631579
# 223/250 round completed......................... Accurecy: 0.7368421052631579
# 224/250 round completed......................... Accurecy: 0.7368421052631579
# 225/250 round completed......................... Accurecy: 0.7473684210526316
# 226/250 round completed......................... Accurecy: 0.7368421052631579
# 227/250 round completed......................... Accurecy: 0.7368421052631579
# 228/250 round completed......................... Accurecy: 0.7368421052631579
# 229/250 round completed......................... Accurecy: 0.7368421052631579
# 230/250 round completed......................... Accurecy: 0.7368421052631579
# 231/250 round completed......................... Accurecy: 0.7368421052631579
# 232/250 round completed......................... Accurecy: 0.7368421052631579
# 233/250 round completed......................... Accurecy: 0.7368421052631579
# 234/250 round completed......................... Accurecy: 0.7368421052631579
# 235/250 round completed......................... Accurecy: 0.7368421052631579
# 236/250 round completed......................... Accurecy: 0.7368421052631579
# 237/250 round completed......................... Accurecy: 0.7368421052631579
# 238/250 round completed......................... Accurecy: 0.7368421052631579
# 239/250 round completed......................... Accurecy: 0.7368421052631579
# 240/250 round completed......................... Accurecy: 0.7473684210526316
# 241/250 round completed......................... Accurecy: 0.7368421052631579
# 242/250 round completed......................... Accurecy: 0.7368421052631579
# 243/250 round completed......................... Accurecy: 0.7368421052631579
# 244/250 round completed......................... Accurecy: 0.7368421052631579
# 245/250 round completed......................... Accurecy: 0.7368421052631579
# 246/250 round completed......................... Accurecy: 0.7368421052631579
# 247/250 round completed......................... Accurecy: 0.7368421052631579
# 248/250 round completed......................... Accurecy: 0.7368421052631579
# 249/250 round completed......................... Accurecy: 0.7368421052631579
# 250/250 round completed......................... Accurecy: 0.7368421052631579
# The best n_estimators:
# 157

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score
N=250
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  xgb_classifier = xgb.XGBClassifier(max_depth=k,random_state=0)
  xgb_classifier.fit(X_train, y_train)
  y_pred=xgb_classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/250 round completed......................... Accurecy: 0.631578947368421
# 2/250 round completed......................... Accurecy: 0.6736842105263158
# 3/250 round completed......................... Accurecy: 0.7263157894736842
# 4/250 round completed......................... Accurecy: 0.7263157894736842
# 5/250 round completed......................... Accurecy: 0.7473684210526316
# 6/250 round completed......................... Accurecy: 0.7368421052631579
# 7/250 round completed......................... Accurecy: 0.7578947368421053
# 8/250 round completed......................... Accurecy: 0.7157894736842105
# 9/250 round completed......................... Accurecy: 0.6947368421052632
# 10/250 round completed......................... Accurecy: 0.7052631578947368
# 11/250 round completed......................... Accurecy: 0.7052631578947368
# 12/250 round completed......................... Accurecy: 0.7052631578947368
# 13/250 round completed......................... Accurecy: 0.7052631578947368
# 14/250 round completed......................... Accurecy: 0.7052631578947368
# 15/250 round completed......................... Accurecy: 0.7052631578947368
# 16/250 round completed......................... Accurecy: 0.7052631578947368
# 17/250 round completed......................... Accurecy: 0.7052631578947368
# 18/250 round completed......................... Accurecy: 0.7052631578947368
# 19/250 round completed......................... Accurecy: 0.7052631578947368
# 20/250 round completed......................... Accurecy: 0.7052631578947368
# 21/250 round completed......................... Accurecy: 0.7052631578947368
# 22/250 round completed......................... Accurecy: 0.7052631578947368
# 23/250 round completed......................... Accurecy: 0.7052631578947368
# 24/250 round completed......................... Accurecy: 0.7052631578947368
# 25/250 round completed......................... Accurecy: 0.7052631578947368
# 26/250 round completed......................... Accurecy: 0.7052631578947368
# 27/250 round completed......................... Accurecy: 0.7052631578947368
# 28/250 round completed......................... Accurecy: 0.7052631578947368
# 29/250 round completed......................... Accurecy: 0.7052631578947368
# 30/250 round completed......................... Accurecy: 0.7052631578947368
# 31/250 round completed......................... Accurecy: 0.7052631578947368
# 32/250 round completed......................... Accurecy: 0.7052631578947368
# 33/250 round completed......................... Accurecy: 0.7052631578947368
# 34/250 round completed......................... Accurecy: 0.7052631578947368
# 35/250 round completed......................... Accurecy: 0.7052631578947368
# 36/250 round completed......................... Accurecy: 0.7052631578947368
# 37/250 round completed......................... Accurecy: 0.7052631578947368
# 38/250 round completed......................... Accurecy: 0.7052631578947368
# 39/250 round completed......................... Accurecy: 0.7052631578947368
# 40/250 round completed......................... Accurecy: 0.7052631578947368
# 41/250 round completed......................... Accurecy: 0.7052631578947368
# 42/250 round completed......................... Accurecy: 0.7052631578947368
# 43/250 round completed......................... Accurecy: 0.7052631578947368
# 44/250 round completed......................... Accurecy: 0.7052631578947368
# 45/250 round completed......................... Accurecy: 0.7052631578947368
# 46/250 round completed......................... Accurecy: 0.7052631578947368
# 47/250 round completed......................... Accurecy: 0.7052631578947368
# 48/250 round completed......................... Accurecy: 0.7052631578947368
# 49/250 round completed......................... Accurecy: 0.7052631578947368
# 50/250 round completed......................... Accurecy: 0.7052631578947368
# 51/250 round completed......................... Accurecy: 0.7052631578947368
# 52/250 round completed......................... Accurecy: 0.7052631578947368
# 53/250 round completed......................... Accurecy: 0.7052631578947368
# 54/250 round completed......................... Accurecy: 0.7052631578947368
# 55/250 round completed......................... Accurecy: 0.7052631578947368
# 56/250 round completed......................... Accurecy: 0.7052631578947368
# 57/250 round completed......................... Accurecy: 0.7052631578947368
# 58/250 round completed......................... Accurecy: 0.7052631578947368
# 59/250 round completed......................... Accurecy: 0.7052631578947368
# 60/250 round completed......................... Accurecy: 0.7052631578947368
# 61/250 round completed......................... Accurecy: 0.7052631578947368
# 62/250 round completed......................... Accurecy: 0.7052631578947368
# 63/250 round completed......................... Accurecy: 0.7052631578947368
# 64/250 round completed......................... Accurecy: 0.7052631578947368
# 65/250 round completed......................... Accurecy: 0.7052631578947368
# 66/250 round completed......................... Accurecy: 0.7052631578947368
# 67/250 round completed......................... Accurecy: 0.7052631578947368
# 68/250 round completed......................... Accurecy: 0.7052631578947368
# 69/250 round completed......................... Accurecy: 0.7052631578947368
# 70/250 round completed......................... Accurecy: 0.7052631578947368
# 71/250 round completed......................... Accurecy: 0.7052631578947368
# 72/250 round completed......................... Accurecy: 0.7052631578947368
# 73/250 round completed......................... Accurecy: 0.7052631578947368
# 74/250 round completed......................... Accurecy: 0.7052631578947368
# 75/250 round completed......................... Accurecy: 0.7052631578947368
# 76/250 round completed......................... Accurecy: 0.7052631578947368
# 77/250 round completed......................... Accurecy: 0.7052631578947368
# 78/250 round completed......................... Accurecy: 0.7052631578947368
# 79/250 round completed......................... Accurecy: 0.7052631578947368
# 80/250 round completed......................... Accurecy: 0.7052631578947368
# 81/250 round completed......................... Accurecy: 0.7052631578947368
# 82/250 round completed......................... Accurecy: 0.7052631578947368
# 83/250 round completed......................... Accurecy: 0.7052631578947368
# 84/250 round completed......................... Accurecy: 0.7052631578947368
# 85/250 round completed......................... Accurecy: 0.7052631578947368
# 86/250 round completed......................... Accurecy: 0.7052631578947368
# 87/250 round completed......................... Accurecy: 0.7052631578947368
# 88/250 round completed......................... Accurecy: 0.7052631578947368
# 89/250 round completed......................... Accurecy: 0.7052631578947368
# 90/250 round completed......................... Accurecy: 0.7052631578947368
# 91/250 round completed......................... Accurecy: 0.7052631578947368
# 92/250 round completed......................... Accurecy: 0.7052631578947368
# 93/250 round completed......................... Accurecy: 0.7052631578947368
# 94/250 round completed......................... Accurecy: 0.7052631578947368
# 95/250 round completed......................... Accurecy: 0.7052631578947368
# 96/250 round completed......................... Accurecy: 0.7052631578947368
# 97/250 round completed......................... Accurecy: 0.7052631578947368
# 98/250 round completed......................... Accurecy: 0.7052631578947368
# 99/250 round completed......................... Accurecy: 0.7052631578947368
# 100/250 round completed......................... Accurecy: 0.7052631578947368
# 101/250 round completed......................... Accurecy: 0.7052631578947368
# 102/250 round completed......................... Accurecy: 0.7052631578947368
# 103/250 round completed......................... Accurecy: 0.7052631578947368
# 104/250 round completed......................... Accurecy: 0.7052631578947368
# 105/250 round completed......................... Accurecy: 0.7052631578947368
# 106/250 round completed......................... Accurecy: 0.7052631578947368
# 107/250 round completed......................... Accurecy: 0.7052631578947368
# 108/250 round completed......................... Accurecy: 0.7052631578947368
# 109/250 round completed......................... Accurecy: 0.7052631578947368
# 110/250 round completed......................... Accurecy: 0.7052631578947368
# 111/250 round completed......................... Accurecy: 0.7052631578947368
# 112/250 round completed......................... Accurecy: 0.7052631578947368
# 113/250 round completed......................... Accurecy: 0.7052631578947368
# 114/250 round completed......................... Accurecy: 0.7052631578947368
# 115/250 round completed......................... Accurecy: 0.7052631578947368
# 116/250 round completed......................... Accurecy: 0.7052631578947368
# 117/250 round completed......................... Accurecy: 0.7052631578947368
# 118/250 round completed......................... Accurecy: 0.7052631578947368
# 119/250 round completed......................... Accurecy: 0.7052631578947368
# 120/250 round completed......................... Accurecy: 0.7052631578947368
# 121/250 round completed......................... Accurecy: 0.7052631578947368
# 122/250 round completed......................... Accurecy: 0.7052631578947368
# 123/250 round completed......................... Accurecy: 0.7052631578947368
# 124/250 round completed......................... Accurecy: 0.7052631578947368
# 125/250 round completed......................... Accurecy: 0.7052631578947368
# 126/250 round completed......................... Accurecy: 0.7052631578947368
# 127/250 round completed......................... Accurecy: 0.7052631578947368
# 128/250 round completed......................... Accurecy: 0.7052631578947368
# 129/250 round completed......................... Accurecy: 0.7052631578947368
# 130/250 round completed......................... Accurecy: 0.7052631578947368
# 131/250 round completed......................... Accurecy: 0.7052631578947368
# 132/250 round completed......................... Accurecy: 0.7052631578947368
# 133/250 round completed......................... Accurecy: 0.7052631578947368
# 134/250 round completed......................... Accurecy: 0.7052631578947368
# 135/250 round completed......................... Accurecy: 0.7052631578947368
# 136/250 round completed......................... Accurecy: 0.7052631578947368
# 137/250 round completed......................... Accurecy: 0.7052631578947368
# 138/250 round completed......................... Accurecy: 0.7052631578947368
# 139/250 round completed......................... Accurecy: 0.7052631578947368
# 140/250 round completed......................... Accurecy: 0.7052631578947368
# 141/250 round completed......................... Accurecy: 0.7052631578947368
# 142/250 round completed......................... Accurecy: 0.7052631578947368
# 143/250 round completed......................... Accurecy: 0.7052631578947368
# 144/250 round completed......................... Accurecy: 0.7052631578947368
# 145/250 round completed......................... Accurecy: 0.7052631578947368
# 146/250 round completed......................... Accurecy: 0.7052631578947368
# 147/250 round completed......................... Accurecy: 0.7052631578947368
# 148/250 round completed......................... Accurecy: 0.7052631578947368
# 149/250 round completed......................... Accurecy: 0.7052631578947368
# 150/250 round completed......................... Accurecy: 0.7052631578947368
# 151/250 round completed......................... Accurecy: 0.7052631578947368
# 152/250 round completed......................... Accurecy: 0.7052631578947368
# 153/250 round completed......................... Accurecy: 0.7052631578947368
# 154/250 round completed......................... Accurecy: 0.7052631578947368
# 155/250 round completed......................... Accurecy: 0.7052631578947368
# 156/250 round completed......................... Accurecy: 0.7052631578947368
# 157/250 round completed......................... Accurecy: 0.7052631578947368
# 158/250 round completed......................... Accurecy: 0.7052631578947368
# 159/250 round completed......................... Accurecy: 0.7052631578947368
# 160/250 round completed......................... Accurecy: 0.7052631578947368
# 161/250 round completed......................... Accurecy: 0.7052631578947368
# 162/250 round completed......................... Accurecy: 0.7052631578947368
# 163/250 round completed......................... Accurecy: 0.7052631578947368
# 164/250 round completed......................... Accurecy: 0.7052631578947368
# 165/250 round completed......................... Accurecy: 0.7052631578947368
# 166/250 round completed......................... Accurecy: 0.7052631578947368
# 167/250 round completed......................... Accurecy: 0.7052631578947368
# 168/250 round completed......................... Accurecy: 0.7052631578947368
# 169/250 round completed......................... Accurecy: 0.7052631578947368
# 170/250 round completed......................... Accurecy: 0.7052631578947368
# 171/250 round completed......................... Accurecy: 0.7052631578947368
# 172/250 round completed......................... Accurecy: 0.7052631578947368
# 173/250 round completed......................... Accurecy: 0.7052631578947368
# 174/250 round completed......................... Accurecy: 0.7052631578947368
# 175/250 round completed......................... Accurecy: 0.7052631578947368
# 176/250 round completed......................... Accurecy: 0.7052631578947368
# 177/250 round completed......................... Accurecy: 0.7052631578947368
# 178/250 round completed......................... Accurecy: 0.7052631578947368
# 179/250 round completed......................... Accurecy: 0.7052631578947368
# 180/250 round completed......................... Accurecy: 0.7052631578947368
# 181/250 round completed......................... Accurecy: 0.7052631578947368
# 182/250 round completed......................... Accurecy: 0.7052631578947368
# 183/250 round completed......................... Accurecy: 0.7052631578947368
# 184/250 round completed......................... Accurecy: 0.7052631578947368
# 185/250 round completed......................... Accurecy: 0.7052631578947368
# 186/250 round completed......................... Accurecy: 0.7052631578947368
# 187/250 round completed......................... Accurecy: 0.7052631578947368
# 188/250 round completed......................... Accurecy: 0.7052631578947368
# 189/250 round completed......................... Accurecy: 0.7052631578947368
# 190/250 round completed......................... Accurecy: 0.7052631578947368
# 191/250 round completed......................... Accurecy: 0.7052631578947368
# 192/250 round completed......................... Accurecy: 0.7052631578947368
# 193/250 round completed......................... Accurecy: 0.7052631578947368
# 194/250 round completed......................... Accurecy: 0.7052631578947368
# 195/250 round completed......................... Accurecy: 0.7052631578947368
# 196/250 round completed......................... Accurecy: 0.7052631578947368
# 197/250 round completed......................... Accurecy: 0.7052631578947368
# 198/250 round completed......................... Accurecy: 0.7052631578947368
# 199/250 round completed......................... Accurecy: 0.7052631578947368
# 200/250 round completed......................... Accurecy: 0.7052631578947368
# 201/250 round completed......................... Accurecy: 0.7052631578947368
# 202/250 round completed......................... Accurecy: 0.7052631578947368
# 203/250 round completed......................... Accurecy: 0.7052631578947368
# 204/250 round completed......................... Accurecy: 0.7052631578947368
# 205/250 round completed......................... Accurecy: 0.7052631578947368
# 206/250 round completed......................... Accurecy: 0.7052631578947368
# 207/250 round completed......................... Accurecy: 0.7052631578947368
# 208/250 round completed......................... Accurecy: 0.7052631578947368
# 209/250 round completed......................... Accurecy: 0.7052631578947368
# 210/250 round completed......................... Accurecy: 0.7052631578947368
# 211/250 round completed......................... Accurecy: 0.7052631578947368
# 212/250 round completed......................... Accurecy: 0.7052631578947368
# 213/250 round completed......................... Accurecy: 0.7052631578947368
# 214/250 round completed......................... Accurecy: 0.7052631578947368
# 215/250 round completed......................... Accurecy: 0.7052631578947368
# 216/250 round completed......................... Accurecy: 0.7052631578947368
# 217/250 round completed......................... Accurecy: 0.7052631578947368
# 218/250 round completed......................... Accurecy: 0.7052631578947368
# 219/250 round completed......................... Accurecy: 0.7052631578947368
# 220/250 round completed......................... Accurecy: 0.7052631578947368
# 221/250 round completed......................... Accurecy: 0.7052631578947368
# 222/250 round completed......................... Accurecy: 0.7052631578947368
# 223/250 round completed......................... Accurecy: 0.7052631578947368
# 224/250 round completed......................... Accurecy: 0.7052631578947368
# 225/250 round completed......................... Accurecy: 0.7052631578947368
# 226/250 round completed......................... Accurecy: 0.7052631578947368
# 227/250 round completed......................... Accurecy: 0.7052631578947368
# 228/250 round completed......................... Accurecy: 0.7052631578947368
# 229/250 round completed......................... Accurecy: 0.7052631578947368
# 230/250 round completed......................... Accurecy: 0.7052631578947368
# 231/250 round completed......................... Accurecy: 0.7052631578947368
# 232/250 round completed......................... Accurecy: 0.7052631578947368
# 233/250 round completed......................... Accurecy: 0.7052631578947368
# 234/250 round completed......................... Accurecy: 0.7052631578947368
# 235/250 round completed......................... Accurecy: 0.7052631578947368
# 236/250 round completed......................... Accurecy: 0.7052631578947368
# 237/250 round completed......................... Accurecy: 0.7052631578947368
# 238/250 round completed......................... Accurecy: 0.7052631578947368
# 239/250 round completed......................... Accurecy: 0.7052631578947368
# 240/250 round completed......................... Accurecy: 0.7052631578947368
# 241/250 round completed......................... Accurecy: 0.7052631578947368
# 242/250 round completed......................... Accurecy: 0.7052631578947368
# 243/250 round completed......................... Accurecy: 0.7052631578947368
# 244/250 round completed......................... Accurecy: 0.7052631578947368
# 245/250 round completed......................... Accurecy: 0.7052631578947368
# 246/250 round completed......................... Accurecy: 0.7052631578947368
# 247/250 round completed......................... Accurecy: 0.7052631578947368
# 248/250 round completed......................... Accurecy: 0.7052631578947368
# 249/250 round completed......................... Accurecy: 0.7052631578947368
# 250/250 round completed......................... Accurecy: 0.7052631578947368
# The best depth:
# 7

# %%
import xgboost as xgb
xgb_depth = xgb.XGBClassifier(max_depth=best_depth,random_state=0)
xgb_depth.fit(X_train,y_train)
y_pred = xgb_depth.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_depth,4,'xgboost')]=accuracy_score(y_test, y_pred)
print(xgb_depth)
# Out:
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...)

# %%
import xgboost as xgb
xgb_estimator = xgb.XGBClassifier(n_estimators=best_estimator,random_state=0)
xgb_estimator.fit(X_train,y_train)
y_pred = xgb_estimator.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_estimator,4,'xgboost')]=accuracy_score(y_test, y_pred)
print(xgb_estimator)
# Out:
# [[36 14]
#  [10 35]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75        50
#            1       0.71      0.78      0.74        45
#
#     accuracy                           0.75        95
#    macro avg       0.75      0.75      0.75        95
# weighted avg       0.75      0.75      0.75        95
#
# Accurecy:  0.7473684210526316
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...)

# %%
import xgboost as xgb
xgb_all = xgb.XGBClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
xgb_all.fit(X_train,y_train)
y_pred = xgb_all.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_all,4,'xgboost')]=accuracy_score(y_test, y_pred)
# Out:
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_default = KNeighborsClassifier()
knn_default.fit(X_train, y_train)
y_pred=knn_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(knn_default,5,'KNeighborsClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[30 20]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.60      0.67        50
#            1       0.64      0.80      0.71        45
#
#     accuracy                           0.69        95
#    macro avg       0.71      0.70      0.69        95
# weighted avg       0.71      0.69      0.69        95
#
# Accurecy:  0.6947368421052632

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
Neighbors=105
k_range = range (1,Neighbors+1)
scores={}
scores_list = []
for k in k_range:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred=knn.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(Neighbors)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best=list(scores.keys())[scores_list.index(max(scores_list))]
print(best)
# Out:
# 1/105 round completed......................... Accurecy: 0.6526315789473685
# 2/105 round completed......................... Accurecy: 0.6736842105263158
# 3/105 round completed......................... Accurecy: 0.6736842105263158
# 4/105 round completed......................... Accurecy: 0.7052631578947368
# 5/105 round completed......................... Accurecy: 0.6947368421052632
# 6/105 round completed......................... Accurecy: 0.7052631578947368
# 7/105 round completed......................... Accurecy: 0.6736842105263158
# 8/105 round completed......................... Accurecy: 0.6631578947368421
# 9/105 round completed......................... Accurecy: 0.6210526315789474
# 10/105 round completed......................... Accurecy: 0.6421052631578947
# 11/105 round completed......................... Accurecy: 0.631578947368421
# 12/105 round completed......................... Accurecy: 0.6421052631578947
# 13/105 round completed......................... Accurecy: 0.631578947368421
# 14/105 round completed......................... Accurecy: 0.631578947368421
# 15/105 round completed......................... Accurecy: 0.6210526315789474
# 16/105 round completed......................... Accurecy: 0.6105263157894737
# 17/105 round completed......................... Accurecy: 0.6105263157894737
# 18/105 round completed......................... Accurecy: 0.6105263157894737
# 19/105 round completed......................... Accurecy: 0.6105263157894737
# 20/105 round completed......................... Accurecy: 0.6105263157894737
# 21/105 round completed......................... Accurecy: 0.6
# 22/105 round completed......................... Accurecy: 0.6
# 23/105 round completed......................... Accurecy: 0.5894736842105263
# 24/105 round completed......................... Accurecy: 0.6
# 25/105 round completed......................... Accurecy: 0.6
# 26/105 round completed......................... Accurecy: 0.6105263157894737
# 27/105 round completed......................... Accurecy: 0.6
# 28/105 round completed......................... Accurecy: 0.6105263157894737
# 29/105 round completed......................... Accurecy: 0.6105263157894737
# 30/105 round completed......................... Accurecy: 0.6210526315789474
# 31/105 round completed......................... Accurecy: 0.6
# 32/105 round completed......................... Accurecy: 0.6
# 33/105 round completed......................... Accurecy: 0.5789473684210527
# 34/105 round completed......................... Accurecy: 0.5894736842105263
# 35/105 round completed......................... Accurecy: 0.5684210526315789
# 36/105 round completed......................... Accurecy: 0.6105263157894737
# 37/105 round completed......................... Accurecy: 0.6
# 38/105 round completed......................... Accurecy: 0.6
# 39/105 round completed......................... Accurecy: 0.5789473684210527
# 40/105 round completed......................... Accurecy: 0.5789473684210527
# 41/105 round completed......................... Accurecy: 0.5789473684210527
# 42/105 round completed......................... Accurecy: 0.6105263157894737
# 43/105 round completed......................... Accurecy: 0.6
# 44/105 round completed......................... Accurecy: 0.6
# 45/105 round completed......................... Accurecy: 0.5894736842105263
# 46/105 round completed......................... Accurecy: 0.6105263157894737
# 47/105 round completed......................... Accurecy: 0.5894736842105263
# 48/105 round completed......................... Accurecy: 0.5894736842105263
# 49/105 round completed......................... Accurecy: 0.5894736842105263
# 50/105 round completed......................... Accurecy: 0.6105263157894737
# 51/105 round completed......................... Accurecy: 0.6105263157894737
# 52/105 round completed......................... Accurecy: 0.6105263157894737
# 53/105 round completed......................... Accurecy: 0.6
# 54/105 round completed......................... Accurecy: 0.6
# 55/105 round completed......................... Accurecy: 0.6
# 56/105 round completed......................... Accurecy: 0.6210526315789474
# 57/105 round completed......................... Accurecy: 0.6105263157894737
# 58/105 round completed......................... Accurecy: 0.631578947368421
# 59/105 round completed......................... Accurecy: 0.631578947368421
# 60/105 round completed......................... Accurecy: 0.631578947368421
# 61/105 round completed......................... Accurecy: 0.6210526315789474
# 62/105 round completed......................... Accurecy: 0.6210526315789474
# 63/105 round completed......................... Accurecy: 0.6421052631578947
# 64/105 round completed......................... Accurecy: 0.6105263157894737
# 65/105 round completed......................... Accurecy: 0.6105263157894737
# 66/105 round completed......................... Accurecy: 0.6105263157894737
# 67/105 round completed......................... Accurecy: 0.6210526315789474
# 68/105 round completed......................... Accurecy: 0.6105263157894737
# 69/105 round completed......................... Accurecy: 0.6
# 70/105 round completed......................... Accurecy: 0.6
# 71/105 round completed......................... Accurecy: 0.6
# 72/105 round completed......................... Accurecy: 0.6
# 73/105 round completed......................... Accurecy: 0.6
# 74/105 round completed......................... Accurecy: 0.6
# 75/105 round completed......................... Accurecy: 0.6
# 76/105 round completed......................... Accurecy: 0.6
# 77/105 round completed......................... Accurecy: 0.6
# 78/105 round completed......................... Accurecy: 0.6105263157894737
# 79/105 round completed......................... Accurecy: 0.6
# 80/105 round completed......................... Accurecy: 0.6
# 81/105 round completed......................... Accurecy: 0.6105263157894737
# 82/105 round completed......................... Accurecy: 0.6
# 83/105 round completed......................... Accurecy: 0.6
# 84/105 round completed......................... Accurecy: 0.6
# 85/105 round completed......................... Accurecy: 0.6
# 86/105 round completed......................... Accurecy: 0.6
# 87/105 round completed......................... Accurecy: 0.6105263157894737
# 88/105 round completed......................... Accurecy: 0.5894736842105263
# 89/105 round completed......................... Accurecy: 0.6
# 90/105 round completed......................... Accurecy: 0.5894736842105263
# 91/105 round completed......................... Accurecy: 0.6
# 92/105 round completed......................... Accurecy: 0.5894736842105263
# 93/105 round completed......................... Accurecy: 0.6
# 94/105 round completed......................... Accurecy: 0.5894736842105263
# 95/105 round completed......................... Accurecy: 0.6
# 96/105 round completed......................... Accurecy: 0.5894736842105263
# 97/105 round completed......................... Accurecy: 0.6105263157894737
# 98/105 round completed......................... Accurecy: 0.6
# 99/105 round completed......................... Accurecy: 0.6
# 100/105 round completed......................... Accurecy: 0.6105263157894737
# 101/105 round completed......................... Accurecy: 0.6
# 102/105 round completed......................... Accurecy: 0.6
# 103/105 round completed......................... Accurecy: 0.6
# 104/105 round completed......................... Accurecy: 0.6
# 105/105 round completed......................... Accurecy: 0.6105263157894737
# The best Depth:
# 4

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_neighbors = KNeighborsClassifier(n_neighbors=best)
knn_neighbors.fit(X_train, y_train)
y_pred=knn_neighbors.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(knn_neighbors,5,'KNeighborsClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[37 13]
#  [15 30]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73        50
#            1       0.70      0.67      0.68        45
#
#     accuracy                           0.71        95
#    macro avg       0.70      0.70      0.70        95
# weighted avg       0.70      0.71      0.70        95
#
# Accurecy:  0.7052631578947368

# %% [markdown]
# #NB

# %%
from sklearn.naive_bayes import GaussianNB

nb_deafult = GaussianNB()
nb_deafult.fit(X_train, y_train)
y_pred = nb_deafult.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(nb_deafult,6,'GaussianNB')]=accuracy_score(y_test, y_pred)
# Out:
# [[48  2]
#  [37  8]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.96      0.71        50
#            1       0.80      0.18      0.29        45
#
#     accuracy                           0.59        95
#    macro avg       0.68      0.57      0.50        95
# weighted avg       0.68      0.59      0.51        95
#
# Accurecy:  0.5894736842105263

# %% [markdown]
# #Histogram-Based Gradient Boosting

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hisgradBoost_default = HistGradientBoostingClassifier(random_state=0)
hisgradBoost_default.fit(X_train, y_train)
y_pred = hisgradBoost_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_default,7,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=1000
k_range = range (100,N+1,100)
scores={}
scores_list = []
for k in k_range:
  hisgradBoost_cls = HistGradientBoostingClassifier(max_iter=k,random_state=0)
  hisgradBoost_cls.fit(X_train, y_train)
  y_pred=hisgradBoost_cls.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best max_iter:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 100/1000 round completed......................... Accurecy: 0.7578947368421053
# 200/1000 round completed......................... Accurecy: 0.7368421052631579
# 300/1000 round completed......................... Accurecy: 0.7473684210526316
# 400/1000 round completed......................... Accurecy: 0.7473684210526316
# 500/1000 round completed......................... Accurecy: 0.7368421052631579
# 600/1000 round completed......................... Accurecy: 0.7263157894736842
# 700/1000 round completed......................... Accurecy: 0.7368421052631579
# 800/1000 round completed......................... Accurecy: 0.7263157894736842
# 900/1000 round completed......................... Accurecy: 0.7263157894736842
# 1000/1000 round completed......................... Accurecy: 0.7368421052631579
# The best max_iter:
# 100

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=50
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  hisgradBoost_cls = HistGradientBoostingClassifier(max_depth=k,random_state=0)
  hisgradBoost_cls.fit(X_train, y_train)
  y_pred=hisgradBoost_cls.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best max_depth:")
max_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(max_depth)
# Out:
# 1/50 round completed......................... Accurecy: 0.6210526315789474
# 2/50 round completed......................... Accurecy: 0.6842105263157895
# 3/50 round completed......................... Accurecy: 0.7052631578947368
# 4/50 round completed......................... Accurecy: 0.7052631578947368
# 5/50 round completed......................... Accurecy: 0.7263157894736842
# 6/50 round completed......................... Accurecy: 0.7157894736842105
# 7/50 round completed......................... Accurecy: 0.7157894736842105
# 8/50 round completed......................... Accurecy: 0.7368421052631579
# 9/50 round completed......................... Accurecy: 0.7157894736842105
# 10/50 round completed......................... Accurecy: 0.7578947368421053
# 11/50 round completed......................... Accurecy: 0.7578947368421053
# 12/50 round completed......................... Accurecy: 0.7578947368421053
# 13/50 round completed......................... Accurecy: 0.7578947368421053
# 14/50 round completed......................... Accurecy: 0.7578947368421053
# 15/50 round completed......................... Accurecy: 0.7578947368421053
# 16/50 round completed......................... Accurecy: 0.7578947368421053
# 17/50 round completed......................... Accurecy: 0.7578947368421053
# 18/50 round completed......................... Accurecy: 0.7578947368421053
# 19/50 round completed......................... Accurecy: 0.7578947368421053
# 20/50 round completed......................... Accurecy: 0.7578947368421053
# 21/50 round completed......................... Accurecy: 0.7578947368421053
# 22/50 round completed......................... Accurecy: 0.7578947368421053
# 23/50 round completed......................... Accurecy: 0.7578947368421053
# 24/50 round completed......................... Accurecy: 0.7578947368421053
# 25/50 round completed......................... Accurecy: 0.7578947368421053
# 26/50 round completed......................... Accurecy: 0.7578947368421053
# 27/50 round completed......................... Accurecy: 0.7578947368421053
# 28/50 round completed......................... Accurecy: 0.7578947368421053
# 29/50 round completed......................... Accurecy: 0.7578947368421053
# 30/50 round completed......................... Accurecy: 0.7578947368421053
# 31/50 round completed......................... Accurecy: 0.7578947368421053
# 32/50 round completed......................... Accurecy: 0.7578947368421053
# 33/50 round completed......................... Accurecy: 0.7578947368421053
# 34/50 round completed......................... Accurecy: 0.7578947368421053
# 35/50 round completed......................... Accurecy: 0.7578947368421053
# 36/50 round completed......................... Accurecy: 0.7578947368421053
# 37/50 round completed......................... Accurecy: 0.7578947368421053
# 38/50 round completed......................... Accurecy: 0.7578947368421053
# 39/50 round completed......................... Accurecy: 0.7578947368421053
# 40/50 round completed......................... Accurecy: 0.7578947368421053
# 41/50 round completed......................... Accurecy: 0.7578947368421053
# 42/50 round completed......................... Accurecy: 0.7578947368421053
# 43/50 round completed......................... Accurecy: 0.7578947368421053
# 44/50 round completed......................... Accurecy: 0.7578947368421053
# 45/50 round completed......................... Accurecy: 0.7578947368421053
# 46/50 round completed......................... Accurecy: 0.7578947368421053
# 47/50 round completed......................... Accurecy: 0.7578947368421053
# 48/50 round completed......................... Accurecy: 0.7578947368421053
# 49/50 round completed......................... Accurecy: 0.7578947368421053
# 50/50 round completed......................... Accurecy: 0.7578947368421053
# The best max_depth:
# 10

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hisgradBoost_max_iter = HistGradientBoostingClassifier(max_iter=best_estimator,random_state=0)
hisgradBoost_max_iter.fit(X_train, y_train)
y_pred = hisgradBoost_max_iter.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_max_iter,8,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hisgradBoost_max_depth = HistGradientBoostingClassifier(max_depth=max_depth,random_state=0)
hisgradBoost_max_depth.fit(X_train, y_train)
y_pred = hisgradBoost_max_depth.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_max_depth,9,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hisgradBoost_all = HistGradientBoostingClassifier(max_iter=best_estimator,max_depth=max_depth,random_state=0)
hisgradBoost_all.fit(X_train, y_train)
y_pred = hisgradBoost_all.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(hisgradBoost_all,10,'HistGradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053

# %% [markdown]
# #Result

# %%
models=[]

for i in result:
  models.append(i[0])
  print(i[0],i[1]," : ",result[i])
  print("---------------------------------------------------------------")
  print()
# Out:
# AdaBoostClassifier(random_state=0) 1  :  0.6631578947368421
# ---------------------------------------------------------------
#
# AdaBoostClassifier(n_estimators=21, random_state=0) 1  :  0.7052631578947368
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(random_state=0) 2  :  0.6736842105263158
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(n_estimators=141, random_state=0) 2  :  0.7052631578947368
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(max_depth=11, random_state=0) 2  :  0.7052631578947368
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0) 2  :  0.7052631578947368
# ---------------------------------------------------------------
#
# RandomForestClassifier(random_state=0) 3  :  0.7052631578947368
# ---------------------------------------------------------------
#
# RandomForestClassifier(n_estimators=8, random_state=0) 3  :  0.7157894736842105
# ---------------------------------------------------------------
#
# RandomForestClassifier(max_depth=11, random_state=0) 3  :  0.7052631578947368
# ---------------------------------------------------------------
#
# RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0) 3  :  0.6736842105263158
# ---------------------------------------------------------------
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...) 4  :  0.7368421052631579
# ---------------------------------------------------------------
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...) 4  :  0.7578947368421053
# ---------------------------------------------------------------
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...) 4  :  0.7473684210526316
# ---------------------------------------------------------------
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...) 4  :  0.7578947368421053
# ---------------------------------------------------------------
#
# KNeighborsClassifier() 5  :  0.6947368421052632
# ---------------------------------------------------------------
#
# KNeighborsClassifier(n_neighbors=4) 5  :  0.7052631578947368
# ---------------------------------------------------------------
#
# GaussianNB() 6  :  0.5894736842105263
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(random_state=0) 7  :  0.7578947368421053
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(random_state=0) 8  :  0.7578947368421053
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(max_depth=10, random_state=0) 9  :  0.7578947368421053
# ---------------------------------------------------------------
#
# HistGradientBoostingClassifier(max_depth=10, random_state=0) 10  :  0.7578947368421053
# ---------------------------------------------------------------

# %%
sorted_list=[]
sorted_list = sorted(result, key=result.get,reverse=True)

for i in sorted_list:
  print(i,"  : ",result[i])
  print("-------------------------------------------------------------------------------------------------")

print(sorted_list)


flage=[]
best_models=[]
it=0

for i in sorted_list:
  if it==4:
    break

  if i[1] not in flage:
    best_models.append((i[0],i[2]))
    flage.append(i[1])
    it+=1
# Out:
# (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost')   :  0.7578947368421053
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost')   :  0.7578947368421053
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier')   :  0.7578947368421053
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier')   :  0.7578947368421053
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=10, random_state=0), 9, 'HistGradientBoostingClassifier')   :  0.7578947368421053
# -------------------------------------------------------------------------------------------------
# (HistGradientBoostingClassifier(max_depth=10, random_state=0), 10, 'HistGradientBoostingClassifier')   :  0.7578947368421053
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost')   :  0.7473684210526316
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost')   :  0.7368421052631579
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(n_estimators=8, random_state=0), 3, 'RandomForestClassifier')   :  0.7157894736842105
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(n_estimators=21, random_state=0), 1, 'AdaBoostClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(n_estimators=141, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=11, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=11, random_state=0), 3, 'RandomForestClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(n_neighbors=4), 5, 'KNeighborsClassifier')   :  0.7052631578947368
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(), 5, 'KNeighborsClassifier')   :  0.6947368421052632
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier')   :  0.6736842105263158
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0), 3, 'RandomForestClassifier')   :  0.6736842105263158
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier')   :  0.6631578947368421
# -------------------------------------------------------------------------------------------------
# (GaussianNB(), 6, 'GaussianNB')   :  0.5894736842105263
# -------------------------------------------------------------------------------------------------
# [(XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost'), (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost'), (HistGradientBoostingClassifier(random_state=0), 7, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(random_state=0), 8, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=10, random_state=0), 9, 'HistGradientBoostingClassifier'), (HistGradientBoostingClassifier(max_depth=10, random_state=0), 10, 'HistGradientBoostingClassifier'), (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=157, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost'), (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 4, 'xgboost'), (RandomForestClassifier(n_estimators=8, random_state=0), 3, 'RandomForestClassifier'), (AdaBoostClassifier(n_estimators=21, random_state=0), 1, 'AdaBoostClassifier'), (GradientBoostingClassifier(n_estimators=141, random_state=0), 2, 'GradientBoostingClassifier'), (GradientBoostingClassifier(max_depth=11, random_state=0), 2, 'GradientBoostingClassifier'), (GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier'), (RandomForestClassifier(max_depth=11, random_state=0), 3, 'RandomForestClassifier'), (KNeighborsClassifier(n_neighbors=4), 5, 'KNeighborsClassifier'), (KNeighborsClassifier(), 5, 'KNeighborsClassifier'), (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0), 3, 'RandomForestClassifier'), (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier'), (GaussianNB(), 6, 'GaussianNB')]

# %%
print("best_models:")
for i in best_models:
  print(i)
# Out:
# best_models:
# (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...), 'xgboost')
# (HistGradientBoostingClassifier(random_state=0), 'HistGradientBoostingClassifier')
# (HistGradientBoostingClassifier(random_state=0), 'HistGradientBoostingClassifier')
# (HistGradientBoostingClassifier(max_depth=10, random_state=0), 'HistGradientBoostingClassifier')

# %%
len(best_models)
# Out:
# 4

# %% [markdown]
# #Testing Accuracy For Best 4 Models

# %%
for i in best_models:
  print("--------------------------------------------------")
  print(i[0])
  y_pred=i[0].predict(X_test)
  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test,y_pred))
  print("Accurecy: ",accuracy_score(y_test, y_pred))
# Out:
# --------------------------------------------------
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...)
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053
# --------------------------------------------------
# HistGradientBoostingClassifier(random_state=0)
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053
# --------------------------------------------------
# HistGradientBoostingClassifier(random_state=0)
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053
# --------------------------------------------------
# HistGradientBoostingClassifier(max_depth=10, random_state=0)
# [[36 14]
#  [ 9 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        50
#            1       0.72      0.80      0.76        45
#
#     accuracy                           0.76        95
#    macro avg       0.76      0.76      0.76        95
# weighted avg       0.76      0.76      0.76        95
#
# Accurecy:  0.7578947368421053

# %% [markdown]
# #SHAP

# %%
# !pip install shap
import shap
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.43.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
def SHAP_EXP(model,graph_feat):
  print("Models: ",model)

  explainer = shap.Explainer(model.predict, X_train)

  shap_values1 = explainer(X_train)
  features_names=list_of_feat1

  if 'Subjects' in features_names:
    features_names.pop(0)

  print("Global Explaination")
  shap.plots.bar(shap_values1,max_display=30,show=False)

  plt.xlabel('Mean SHAP value',fontweight="bold",fontsize=13)
  plt.ylabel('Features',fontweight="bold",fontsize=13)
  plt.xticks(fontsize=13, weight = 'bold')
  plt.yticks(fontsize=13, weight = 'bold')

  plt.show()
  print("Global Explaination")

  shap.summary_plot(shap_values1,max_display=30,show=False)
  plt.xlabel('Mean SHAP value',fontweight="bold",fontsize=13)
  plt.ylabel('Features',fontweight="bold",fontsize=13)
  plt.xticks(fontsize=13, weight = 'bold')
  plt.yticks(fontsize=13, weight = 'bold')

  plt.show()
  print("__________________________")
  shap.plots.violin(shap_values1, feature_names=features_names, plot_type="layered_violin",max_display=30,show=False)
  plt.xlabel('Mean SHAP value',fontweight="bold",fontsize=13)
  plt.ylabel('Features',fontweight="bold",fontsize=13)
  plt.xticks(fontsize=13, weight = 'bold')
  plt.yticks(fontsize=13, weight = 'bold')

  plt.show()
  print("Local Explaination")
  shap.plots.violin(shap_values1,feature_names=features_names, max_display=30,show=False)
  plt.xlabel('Mean SHAP value',fontweight="bold",fontsize=13)
  plt.ylabel('Features',fontweight="bold",fontsize=13)
  plt.xticks(fontsize=13, weight = 'bold')
  plt.yticks(fontsize=13, weight = 'bold')

  plt.show()

  print("___________________________")

  print("Local Explaination")
  shap.plots.waterfall(shap_values1[graph_feat["shap_values Index"]],max_display=25,show=False)
  plt.xlabel('Model Output',fontweight="bold",fontsize=13)
  plt.ylabel('Features',fontweight="bold",fontsize=13)
  plt.xticks(fontsize=13, weight = 'bold')
  plt.yticks(fontsize=13, weight = 'bold')

  plt.show()


  print("Local Explaination")

  shap.plots.bar(shap_values1[graph_feat["shap_values Index"]],max_display=25,show=False)
  plt.xlabel('Mean SHAP value',fontweight="bold",fontsize=13)
  plt.ylabel('Features',fontweight="bold",fontsize=13)
  plt.xticks(fontsize=13, weight = 'bold')
  plt.yticks(fontsize=13, weight = 'bold')

  plt.show()

# %% [markdown]
# **Model Check Box Function**

# %%
def models_check_box(models):
  import ipywidgets as widgets
  from IPython.display import display
  new_keys=[]
  for i in models:
    i=widgets.Checkbox(
      value=False,
      description=str(i),
      disabled=False,
      indent=False
      )
    display(i)
    new_keys.append(i)
  return new_keys

# %%
new_keys_7=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=21, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=141, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0)'…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…

# %%
graph_feat={
    "max_display":30,
    "shap_values Index":10
}

for i in range(len(new_keys_7)):
  if new_keys_7[i].value ==True:
    SHAP_EXP(models[i],graph_feat)
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")

# %% [markdown]
# #Confusion Matrix For Testing

# %%
def Conf_Mat_percent(X_,y_,attb,keys):

  import matplotlib.pyplot as plt
  from yellowbrick.classifier import ConfusionMatrix
  import matplotlib.dates as dates

  fig = plt.figure(figsize=(attb["Fig Height"],attb["Fig weidth"]))
  ax = fig.add_subplot(111)


  for i in range(len(keys)):
    if keys[i].value ==True:
      cm = ConfusionMatrix(models[i], classes=['Control', 'Stroke'],fontsize=attb["Confusion Matrix Inner Fontsize"],ax=ax,percent=True,fontweight="bold")

      if str(models[i])[:3] == "XGB":
        cm.fit(X_train.values, y_train.values)
        cm.score(X_.values, y_.values)
      else:
        cm.fit(X_train, y_train)
        cm.score(X_, y_)
      cm.ax.set_title(str(models[i]), fontsize=75, fontweight="bold")
      cm.ax.set_xlabel("Predicted Class", fontsize=attb["X Axis Fontsize"],fontweight="bold")
      cm.ax.set_ylabel("True Class", fontsize=attb["Y Axis Fontsize"],fontweight="bold")
      cm.ax.xaxis.set_tick_params(labelsize=attb["X Label Fontsize"])
      cm.ax.yaxis.set_tick_params(labelsize=attb["Y Label Fontsize"])
      for label in ax.get_xticklabels():
        label.set_fontweight(850)
      for label in ax.get_yticklabels():
        label.set_fontweight(850)

      plt.savefig(attb["type"]+"_Confusion_mat("+str(models[i])+").png")
      cm.show()
      print("--------------------")
      print("--------------------")

# %%
new_keys_6=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=21, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=141, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0)'…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…

# %%
'''
from yellowbrick.classifier import ConfusionMatrix


for i in range(len(new_keys_6)):
  if new_keys_6[i].value ==True:
    cm = ConfusionMatrix(models[i], classes=classes, percent=True)

    cm.fit(X_train, y_train)
    cm.score(X_test, y_test)
    cm.show()
'''
# Out:
# '\nfrom yellowbrick.classifier import ConfusionMatrix\n\n\nfor i in range(len(new_keys_6)):\n  if new_keys_6[i].value ==True:\n    cm = ConfusionMatrix(models[i], classes=classes, percent=True)\n\n    cm.fit(X_train, y_train)\n    cm.score(X_test, y_test)\n    cm.show()\n'

# %%
attributes={
   "Fig Height": 10,
   "Fig weidth": 10,

  "Y Axis Fontsize" : 35,
  "X Axis Fontsize" : 35,

  "Y Label Fontsize" : 30,
  "X Label Fontsize" : 30,

  "Confusion Matrix Inner Fontsize": 50,
  "type"  : "Training"

}

Conf_Mat_percent(X_test,y_test,attributes,new_keys_6)

# %% [markdown]
# #Confusion Matrix For Training

# %%
new_keys_5=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=21, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=141, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0)'…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…

# %%
for i in range(len(new_keys_5)):
  if new_keys_5[i].value ==True:
    cm = ConfusionMatrix(models[i], classes=classes)

    cm.fit(X_train, y_train)
    cm.score(X_train, y_train)
    cm.show()
    print("-------------------------------")
    print("-------------------------------")

# %% [markdown]
# #Result CSV<br>
# Predicted and Actual Row will be added at the end index

# %%
def reverse_transfrom(my_list):
  for i in range(len(my_list)):
    if my_list[i] == 0:
      my_list[i] = 'Control'
    else:
      my_list[i] = 'Tinnitus'
  return my_list

# %%
new_keys_4=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=73, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=121, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=6, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=6, n_estimators=121, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=34, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=10, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=10, n_estimators=34, random_state=0)', ind…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=2)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=4, random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=4, random_state=0)', indent=False)

# %%
for i in range(len(new_keys_4)):
  if new_keys_4[i].value ==True:
    temp=X_test

    prediction_cls = reverse_transfrom(list(models[i].predict(X_test[0:])))
    actual_cls = reverse_transfrom(list(y_test[0:]))

    temp["Actual"] = actual_cls
    temp["Predicted"] = prediction_cls

    temp.to_csv(str(models[i])+".csv")

# %% [markdown]
# #ROC Comparaing Machine Learning Models

# %%
def ROC(mod,X_t,y_t,graph_feat):
  r_probs = [0 for _ in range(len(y_t))]

  model_probs = []


  for i in mod:
    model_probs.append(i.predict_proba(X_t))


  model_probs2=[]

  for i in model_probs:
    model_probs2.append(i[:,1])


  from sklearn.metrics import roc_curve, roc_auc_score

  model_auc=[]
  r_auc = roc_auc_score(y_t, r_probs)

  for i in model_probs2:
    model_auc.append(roc_auc_score(y_t,i))


  fpr_tpr=[]
  r_fpr, r_tpr, _ = roc_curve(y_t, r_probs)

  for i in model_probs2:
    fpr, tpr, _ = roc_curve(y_t, i)
    fpr_tpr.append((fpr,tpr))

  import matplotlib.pyplot as plt
  plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)

  for i in range(len(model_auc)):
    plt.plot(fpr_tpr[i][0], fpr_tpr[i][1], marker='.', label=str(mod[i])+' (AUROC = %0.3f)' % model_auc[i], lw = 5)

  # Title
  plt.title('ROC Plot Testing',fontsize= graph_feat["Title Size"], fontweight=graph_feat["Title Fontweight"])
  plt.xlabel('False Positive Rate',fontweight=graph_feat["X axis Label Fontweight"],fontsize=graph_feat["X axis Label Font Size"])
  plt.ylabel('True Positive Rate',fontweight=graph_feat["Y axis Label Fontweight"],fontsize=graph_feat["Y axis Label Font Size"])

  plt.legend(
           prop = {'size' : graph_feat["legend Font Size"]},
           loc = graph_feat["legend Position"])
  plt.xticks(fontsize=20, weight = 'bold')
  plt.yticks(fontsize=20, weight = 'bold')
  fig = plt.gcf()
  fig.set_size_inches(graph_feat["Fig Width (inches)"], graph_feat["Fig Height (inches)"])
  fig.savefig(graph_feat["Fig Saving Name"], dpi=graph_feat["dpi"])
  plt.show()

# %% [markdown]
# ***Training ROC***<br>
# Chosse the Models

# %%
new_keys_2=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=73, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=121, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=6, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=6, n_estimators=121, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=34, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=10, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=10, n_estimators=34, random_state=0)', ind…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=2)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=4, random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=4, random_state=0)', indent=False)

# %% [markdown]
# Change  the given dictionary of graph feature for desire graph.

# %%
graph_feat={
    "Title Size":30,
    "Title Fontweight":'bold',

    "legend Font Size": 20,
    "legend Position": "lower right",
    "legend Fontweight":'bold',

    "X axis Label Font Size":25,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":25,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}

mod=[]
for i in range(len(new_keys_2)):
  if new_keys_2[i].value ==True:
    mod.append(models[i])

ROC(mod,X_test,y_test,graph_feat)

# %% [markdown]
# ---

# %% [markdown]
# ***Testing ROC***<br>
# Chosse the Models

# %%
new_keys_3=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=73, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=121, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=6, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=6, n_estimators=121, random_state=0)',…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=34, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=10, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=10, n_estimators=34, random_state=0)', ind…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=2)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=4, random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=4, random_state=0)', indent=False)

# %% [markdown]
# Change  the given dictionary of graph feature for desire graph.

# %%
graph_feat={
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}

mod=[]
for i in range(len(new_keys_3)):
  if new_keys_3[i].value ==True:
    mod.append(models[i])

ROC(mod,X_test,y_test,graph_feat)

# %% [markdown]
# # **Performance Matrces_Test Dataset**

# %%
model_compare = models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=21, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=141, random_state=0)', indent=False…
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=11, n_estimators=141, random_state=0)'…
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=11, n_estimators=8, random_state=0)', inde…
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='XGBClassifier(base_score=None, booster=None, callbacks=None,\n             …
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=4)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…
# Checkbox(value=False, description='HistGradientBoostingClassifier(max_depth=10, random_state=0)', indent=False…

# %%
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score,f1_score
import seaborn as sns
import matplotlib.pyplot as plt
# Create a figure with a specific size

def plot_model_comp(df):
  plt.figure(figsize=(15, 7))
  ax = sns.barplot(data=df, x=df.columns[0], y=df.columns[1])

  ax.set_xlabel("Models", fontdict={'size': 40, 'weight': 'bold'})
  ax.set_ylabel("Scores", fontdict={'size': 40, 'weight': 'bold'})
  #ax.tick_params(axis='both', which='major', labelsize=14,fontweight='bold')


  plt.yticks(fontsize=30,fontweight='bold')
  plt.xticks(fontsize=30,fontweight='bold')
  ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=30,fontweight='bold')

  plt.show()







m=[]
acc=[]
precision_list=[]
recall_list=[]
f1_score_list=[]



for i in range(len(model_compare)):
  if model_compare[i].value ==True:
    y_pred = models[i].predict(X_test)
    m.append(str(models[i]).split('(')[0])
    acc.append(accuracy_score(y_pred,y_test))
    precision_list.append(precision_score(y_pred,y_test))
    recall_list.append(recall_score(y_pred,y_test))
    f1_score_list.append(f1_score(y_pred,y_test))




df_accu = {
    "Models" : m,
    "Accurecy" : acc,

}
df_accu = pd.DataFrame.from_dict(df_accu)


df_precision={
    "Models" : m,
    "Precision" : precision_list
}
df_precision = pd.DataFrame.from_dict(df_precision)

df_recall = {
    "Models" : m,
    "Recall" : recall_list
}
df_recall = pd.DataFrame.from_dict(df_recall)

df_f1_score = {
    "Models" : m,
    "f1_score" : f1_score_list
}
df_f1_score = pd.DataFrame.from_dict(df_f1_score)

# %% [markdown]
# ##Accurecy

# %%
plot_model_comp(df_accu)

# %% [markdown]
# ##Precision

# %%
plot_model_comp(df_precision)

# %% [markdown]
# ##Recall

# %%
plot_model_comp(df_recall)

# %% [markdown]
# ##f1_score

# %%
plot_model_comp(df_f1_score)

# %% [markdown]
# # **Voilin Plot_K-fold CV**

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score,f1_score

scoring = {'accuracy' : make_scorer(accuracy_score),
           'precision' : make_scorer(precision_score),
           'recall' : make_scorer(recall_score),
           'f1_score' : make_scorer(f1_score)}


k=10
for i in result:
  print(i[0]," -> Accuracy: ",result[i])
  #l=list(cross_val_score(i[0],X_new.iloc[:,1:], y_new,cv=k, scoring=scoring))
  #avg=sum(l)/k
  outcome = cross_validate(i[0],X_new.iloc[:,1:], y_new,cv=k, scoring=scoring)
  #print(i[0]," -> AVG Accurecy After CV: "+str(avg)+ " (For "+str(k)+" Fold)")
  print(i[0], outcome)
  print("--------------------------------------------------------------------------")

# %%
vio_plot_key=models_check_box(models)

# %%
k =10
mod_outcomes = []
for i in range(len(vio_plot_key)):
  if vio_plot_key[i].value ==True:
    mod_outcomes.append((str(models[i]).split('(')[0],cross_validate(models[i],X_new.iloc[:,1:], y_new,cv=k, scoring=scoring)))

mat_dic={
    'test_accuracy': "Accuracy",
    'test_precision':"Precision",
    'test_recall':"Recall",
    'test_f1_score':"F1-Score"
}



m = []
matrics = []
mat_score = []



for i in mod_outcomes:
  for j in i[1]:
    for l in i[1][j]:
      if j in mat_dic.keys():
        m.append(i[0])
        matrics.append(mat_dic[j])
        mat_score.append(l)


df={
    "Models" : m,
    "Matrics": matrics,
    "Scores":mat_score
}

df = pd.DataFrame.from_dict(df)




import seaborn as sns
import matplotlib.pyplot as plt
# Create a figure with a specific size
plt.figure(figsize=(20, 8))

my_pal = {"GradientBoostingClassifier": "cyan", "RandomForestClassifier": "coral", "HistGradientBoostingClassifier": "lime"}
ax = sns.violinplot(data=df, x="Matrics", y="Scores", hue="Models", palette=my_pal)
#ax = sns.violinplot(data=df, y="Performance Scores", hue="Models")

ax.set_xlabel("Matrics", fontdict={'size': 20, 'weight': 'bold'})
ax.set_ylabel("Performance Scores", fontdict={'size': 20, 'weight': 'bold'})
#ax.tick_params(axis='both', which='major', labelsize=14,fontweight='bold')


plt.yticks(fontsize=15,fontweight='bold')
plt.xticks(fontsize=15,fontweight='bold')

plt.legend(title='Models',fontsize= 15, title_fontproperties={'weight':'bold'})


plt.show()

# %% [markdown]
# # **CV_ROC**

# %%
def CV_ROC(model,folds,graph_feat):
  import matplotlib.pyplot as plt

  from sklearn import svm
  from sklearn.metrics import auc,roc_curve
  from sklearn.metrics import RocCurveDisplay
  from sklearn.model_selection import StratifiedKFold


  cv = StratifiedKFold(n_splits=folds)



  tprs = []
  aucs = []
  mean_fpr = np.linspace(0,1,100)
  i = 1
  for train,test in cv.split(X_new.iloc[:,1:], y_new.values):
      prediction = model.fit(X_new.iloc[:,1:].values[train], y_new.values[train]).predict_proba(X_new.iloc[:,1:].values[test])
      fpr, tpr, t = roc_curve(y_new.values[test], prediction[:, 1])
      tprs.append(np.interp(mean_fpr, fpr, tpr))
      roc_auc = auc(fpr, tpr)
      aucs.append(roc_auc)
      plt.plot(fpr, tpr, lw=5, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
      i= i+1

  plt.plot([0,1],[0,1],linestyle = '--',lw = 5,color = 'black')
  mean_tpr = np.mean(tprs, axis=0)
  mean_auc = auc(mean_fpr, mean_tpr)
  plt.plot(mean_fpr, mean_tpr, color='blue',
          label=r'Mean ROC (AUC = %0.2f )' % (mean_auc),lw=2, alpha=1)

  plt.title('CV-ROC-> '+str(model),fontsize= graph_feat["Title Size"], fontweight=graph_feat["Title Fontweight"])
  plt.xlabel('False Positive Rate',fontweight=graph_feat["X axis Label Fontweight"],fontsize=graph_feat["X axis Label Font Size"])
  plt.ylabel('True Positive Rate',fontweight=graph_feat["Y axis Label Fontweight"],fontsize=graph_feat["Y axis Label Font Size"])
  plt.legend(
           prop = {'size' : graph_feat["legend Font Size"]},
           loc = graph_feat["legend Position"])
  plt.xticks(fontsize=25, weight = 'bold')
  plt.yticks(fontsize=25, weight = 'bold')
  fig = plt.gcf()
  fig.set_size_inches(graph_feat["Fig Width (inches)"], graph_feat["Fig Height (inches)"])
  fig.savefig(graph_feat["Fig Saving Name"], dpi=graph_feat["dpi"])
  plt.show()

# %%
new_keys=models_check_box(models)

# %% [markdown]
# <font color="apple green">Just mark the above cell to select the Multiple Algorithms for ROC CV graph. <font color="sky blue"><b>Then run the cell below after selecting.</b></font> You do not need to run above cell everytime...</font><font color='red'><b>Do not run above cell after selecting</b></font>

# %%
# run this cell after selecting

graph_feat={
    "Title Size":30,
    "Title Fontweight":'bold',

    "legend Font Size": 20,
    "legend Position": "lower right",

    "X axis Label Font Size":25,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":25,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}





k_fold=10

for i in range(len(new_keys)):
  if new_keys[i].value ==True:
    CV_ROC(models[i],10,graph_feat)
    print("-----------------------------------------------------------------")
    print("-----------------------------------------------------------------")

# %% [markdown]
# # **LIME**

# %%
# !pip install lime

# %%
def LIME_EXP(model,row):
  import lime
  from lime import lime_tabular


  if str(model)[:3] == "XGB":

    '''
    explainer = lime.lime_tabular.LimeTabularExplainer(
      X_train.values,
      feature_names=list(list(X_new.columns)),
      class_names=['Reading', 'Resting', 'Walking', 'Working']
      )

    exp = explainer.explain_instance(X_test.iloc[row, :].values,
                                model.predict_proba,
                                num_features=6,
                                top_labels=2)'''
    print("Plz RUN XGboost cell....")
    return None

  else:
    explainer = lime_tabular.LimeTabularExplainer(
      training_data=np.array(X_train),
      feature_names=list(X_new.columns),
      class_names=['Control', 'Stroke'],
      mode='classification'
      )

    exp = explainer.explain_instance(X_test.iloc[row],
                                    model.predict_proba,
                                    num_features=6,
                                    top_labels=4)



  #exp.show_in_notebook(show_table=True, show_all=True)
  exp.show_in_notebook(show_table=True)


  import matplotlib.pyplot as plt
  with plt.style.context("ggplot"):
      exp.as_pyplot_figure()


  from IPython.display import HTML
  html_data = exp.as_html()
  HTML(data=html_data)

  exp.save_to_file(str(model)+".html")

# %%
row = int(input("Enter the index of row to explain: "))      # the index of row to be explained in LIME

# %%
new_keys_8=models_check_box(models)

# %%
for i in range(len(new_keys_8)):
  if new_keys_8[i].value ==True:
    print(models[i])
    LIME_EXP(models[i],row)
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")

# %% [markdown]
# ### LIME for XGboost

# %%
row = 18  ## the index of row to be explained in LIME

import lime
from lime import lime_tabular
explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values,
                                                   feature_names=list(list(X_new.columns)),
                                                   class_names=['Control', 'Stroke'])

# %% [markdown]
# ####Default

# %%
exp = explainer.explain_instance(X_test.iloc[row, :].values,
                                 xgb_deafult.predict_proba,
                                 num_features=6,
                                 top_labels=4)

exp.show_in_notebook(show_table=True, show_all=False)

import matplotlib.pyplot as plt
with plt.style.context("ggplot"):
    exp.as_pyplot_figure()


from IPython.display import HTML
html_data = exp.as_html()
HTML(data=html_data)

exp.save_to_file("xgb_deafult.html")

# %% [markdown]
# ####Best Max Depth

# %%
exp = explainer.explain_instance(X_test.iloc[row, :].values,
                                 xgb_depth.predict_proba,
                                 num_features=6,
                                 top_labels=4)

exp.show_in_notebook(show_table=True, show_all=False)

import matplotlib.pyplot as plt
with plt.style.context("ggplot"):
    exp.as_pyplot_figure()


from IPython.display import HTML
html_data = exp.as_html()
HTML(data=html_data)

exp.save_to_file("xgb_depth.html")

# %% [markdown]
# ####Best N Estimator

# %%
exp = explainer.explain_instance(X_test.iloc[row, :].values,
                                 xgb_estimator.predict_proba,
                                 num_features=6,
                                 top_labels=4)

exp.show_in_notebook(show_table=True, show_all=False)

import matplotlib.pyplot as plt
with plt.style.context("ggplot"):
    exp.as_pyplot_figure()


from IPython.display import HTML
html_data = exp.as_html()
HTML(data=html_data)

exp.save_to_file("xgb_estimator.html")

# %% [markdown]
# ####Best Depth and Best Estimator

# %%
exp = explainer.explain_instance(X_test.iloc[row, :].values,
                                 xgb_all.predict_proba,
                                 num_features=6,
                                 top_labels=4)

exp.show_in_notebook(show_table=True, show_all=False)


import matplotlib.pyplot as plt
with plt.style.context("ggplot"):
    exp.as_pyplot_figure()


from IPython.display import HTML
html_data = exp.as_html()
HTML(data=html_data)

exp.save_to_file("xgb_all.html")
