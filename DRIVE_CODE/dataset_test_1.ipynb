# %% [markdown]
# confidential data/ classified data - > very very secrate data (not public)

# %% [markdown]
# #Mounting Google Drive with colab file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("/content/drive/MyDrive/Thesis_Data/EEG_HMC_NUM.csv")

# %%
print(df.shape)
# Out:
# (108451, 76)

# %%
df.iloc[:,:]
# Out:
#         Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0                 0         0.00051           8.74146        18.48195
# 1                 0         0.00040          10.24000        17.48293
# 2                 0         0.00036           9.74049        17.98244
# 3                 0         0.00035          10.11512        17.60780
# 4                 0         0.00033           9.74049        17.60780
# ...             ...             ...               ...             ...
# 108446            1         0.00031          10.11512        17.48293
# 108447            1         0.00042           9.99024        16.35902
# 108448            1         0.00040           9.86537        15.73463
# 108449            0         0.00051          10.11512        17.85756
# 108450            0         0.00128          10.61463        21.47902
#
#         Spect4al Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  \
# 0                     17.48293         8.24195        0.00071
# ...

# %%
print("Total number of row: ",df2.isnull().sum().sum())
print("Total number of columns: ",df2.isna().any().sum())
# Out:
# Total number of row:  0
# Total number of columns:  0

# %%
df.iloc[:,:78].to_csv("HMC_Sleep_Stages.csv",index = False)

# %%
df2 = pd.read_csv("/content/HMC_Sleep_Stages.csv")

# %%
df2.head()
# Out:
#   Subject Sleep_Stage  Epoch  MeanP_Alpha_F4  MedianF_Alpha_F4  \
# 0   SN002          N1      6         0.00034          10.11512
# 1   SN002          N1      7         0.00035          10.73951
# 2   SN002          N1      8         0.00035           9.36585
# 3   SN002          N1    116         0.00054           9.74049
# 4   SN002          N1    117         0.00034          10.11512
#
#    MeanF_Alpha_F4  SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  \
# 0        17.85756               17.48293        10.24000        0.00047
# 1        17.60780               17.10829         9.11610        0.00048
# 2        17.60780               16.98341         9.24098        0.00042
# 3        15.98439               15.48488         8.36683        0.00051
# 4        16.48390               15.98439        12.23805        0.00034
#
#    MedianF_Beta_F4  ...  MeanP_Delta_O2  MedianF_Delta_O2  MeanF_Delta_O2  \
# 0         17.73268  ...         0.00112           0.74927         6.36878
# ...

# %%
df2
# Out:
#        Subject Sleep_Stage  Epoch  MeanP_Alpha_F4  MedianF_Alpha_F4  \
# 0        SN002          N1      6         0.00034          10.11512
# 1        SN002          N1      7         0.00035          10.73951
# 2        SN002          N1      8         0.00035           9.36585
# 3        SN002          N1    116         0.00054           9.74049
# 4        SN002          N1    117         0.00034          10.11512
# ...        ...         ...    ...             ...               ...
# 108446   SN154           W    994         0.00042           9.99024
# 108447   SN154           W    995         0.00033          10.48976
# 108448   SN154           W    997         0.00064          10.48976
# 108449   SN154           W   1001         0.00051          10.11512
# 108450   SN154           W   1002         0.00128          10.61463
#
#         MeanF_Alpha_F4  SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  \
# ...
