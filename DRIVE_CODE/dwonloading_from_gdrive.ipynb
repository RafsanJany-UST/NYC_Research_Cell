# %%
# !pip install gdown

# %%
import gdown
# copy the shareble link with anyone and take the id from the url
url = 'https://drive.google.com/uc?id=1QKhJv759FK37OST8BiDX0Enb33NyU2Tr' # do not take the whle link, take the id only

gdown.download(url, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QKhJv759FK37OST8BiDX0Enb33NyU2Tr
# To: /content/Vital_ECG_MAP_features_120s.csv
# 100%|██████████| 1.34G/1.34G [00:12<00:00, 104MB/s]
# 'Vital_ECG_MAP_features_120s.csv'

# %%
import pandas as pd
df = pd.read_csv("/content/Vital_ECG_MAP_features_120s.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2566151 entries, 0 to 2566150
# Data columns (total 38 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Case_ID             int64
#  1   Segment             int64
#  2   ST_II               float64
#  3   ART_MBP             float64
#  4   ART_SBP             float64
#  5   ART_DBP             float64
#  6   Cycle               int64
#  7   R_wave_amplitude    float64
#  8   ΔR_wave_amplitude   float64
#  9   R_wave_duration     float64
#  10  ΔR_wave_duration    float64
#  11  T_wave_amplitude    float64
#  12  ΔT_wave_amplitude   float64
#  13  T_wave_duration     float64
#  14  ΔT_wave_duration    float64
#  15  p_wave_duration     float64
#  16  ΔP_wave_duration    float64
#  17  S_wave_amplitude    float64
#  18  ΔS_wave_amplitude   float64
#  19  ST_amplitude        float64
#  20  ΔST_amplitude       float64
#  21  q_wave_amplitude    float64
#  22  Δq_wave_amplitude   float64
# ...
