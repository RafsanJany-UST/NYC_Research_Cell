# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.7 MB/s eta 0:00:00
# ...

# %%
from mne.datasets import eegbci
eegbci.load_data(1, [6, 10, 14], "~/datasets")
# Out:
# ...
# Do you want to set the path:
#     /root/datasets
# as the default EEGBCI dataset path in the mne-python config [y]/n? y
# Attempting to create new mne-python configuration file:
# /root/.mne/mne-python.json
# Download complete in 16s (7.4 MB)
# [PosixPath('/root/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R06.edf'),
#  PosixPath('/root/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R10.edf'),
#  PosixPath('/root/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R14.edf')]

# %%
import mne

# Load the data (assuming the dataset is in the current directory)
# You might need to specify the correct path to the dataset
raw = mne.io.read_raw_edf('/root/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R06.edf', preload=True)  # Replace with your file path

# Inspect the data
print(raw.info)
raw.plot()
# Out:
# Extracting EDF parameters from /root/datasets/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
#  subject_info: 3 items (dict)
# >
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
print(mne.find_events(raw))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#     758     try:
# --> 759         stim_channel = _get_stim_channel(stim_channel, raw.info)
#     760     except ValueError:
#
# /usr/local/lib/python3.10/dist-packages/mne/utils/config.py in _get_stim_channel(stim_channel, info, raise_error)
#     529     if len(stim_channel) == 0 and raise_error:
# --> 530         raise ValueError(
#     531             "No stim channels found. Consider specifying them "
#
# ValueError: No stim channels found. Consider specifying them manually using the 'stim_channel' parameter.
#
# During handling of the above exception, another exception occurred:
#
# ...
