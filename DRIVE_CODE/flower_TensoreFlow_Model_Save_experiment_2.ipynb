# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("/content/drive/MyDrive/Tanjila_mam/DS-Healthcare_version_2.xlsx")

# %%
df.loc[:,["Type","RR-I","HR","R-H","P-H","QRS","PRQ","QT","QTC","ST"]]
# Out:
#               Type      RR-I         HR    R-H    P-H       QRS       PRQ  \
# 0         ischemic  0.932000  64.377682  3.305  3.810  0.088000  0.160000
# 1         ischemic  1.004000  59.760956  3.285  3.810  0.100000  0.160000
# 2         ischemic  0.996000  60.240964  3.340  3.830  0.128000  0.148000
# 3         ischemic  1.016000  59.055118  3.325  3.810  0.108000  0.172000
# 4         ischemic  0.972000  61.728395  3.290  3.765  0.100000  0.160000
# ...            ...       ...        ...    ...    ...       ...       ...
# 888812  arrhythmic  0.652778  91.914894  0.660 -0.335  0.066667  0.163889
# 888813  arrhythmic  0.675000  88.888889  0.605 -0.345  0.066667  0.172222
# 888814  arrhythmic  0.647222  92.703863  0.795 -0.335  0.055556  0.161111
# 888815  arrhythmic  0.647222  92.703863  0.825 -0.330  0.069444  0.152778
# 888816  arrhythmic  0.641667  93.506494  0.625 -0.300  0.066667  0.161111
#
#               QT       QTC        ST
# 0       0.384000  0.397762  0.296000
# ...

# %%
"""from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import math
NUM_CLIENTS = 100

def partition_blan():
    """Download and partitions the MNIST dataset."""
    # Assuming df is your DataFrame containing the dataset

    encoder = LabelEncoder()
    df['Type'] = encoder.fit_transform(df['Type'])
    X = df.iloc[:, 4:]
    y = df['Type']

    # Apply SMOTE to balance the dataset
    smote = SMOTE(random_state=42)
    X_resampled, y_resampled = smote.fit_resample(X, y)

    print("Original dataset shape:", Counter(y))
    print("Resampled dataset shape:", Counter(y_resampled))

    x_train, x_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.33, random_state=0)
    print("y_train dataset shape:", Counter(y_train))
    print("y_test dataset shape:", Counter(y_test))

    x_train = x_train.to_numpy()
    x_test = x_test.to_numpy()
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()
    testset = (x_test, y_test)
    print(type(x_train))
    partitions = []
    # We keep all partitions equal-sized in this example
    partition_size = math.floor(len(x_train) / NUM_CLIENTS)
    for cid in range(NUM_CLIENTS):
        # Split dataset into non-overlapping NUM_CLIENT partitions
        idx_from, idx_to = int(cid) * partition_size, (int(cid) + 1) * partition_size
        print('_____________________----------------____________________---------------_________________-----------------')
        print("Partition:", Counter(y_train[idx_from:idx_to]))

        partitions.append((x_train[idx_from:idx_to], y_train[idx_from:idx_to]))


    return partitions, testset

# Call the function with the number of clients you desire
partitions, testset = partition_blan()"""

# %%
"""
def partition_data():

    encoder=LabelEncoder()
    df['Type']=encoder.fit_transform(df['Type'])
    X = df.iloc[:,4:]
    y = df['Type']
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)
    x_train = x_train.to_numpy()
    x_test = x_test.to_numpy()
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()
    testset = (x_test,y_test)
    print(type(x_train))
    partitions = []
    # We keep all partitions equal-sized in this example
    partition_size = math.floor(len(x_train) / NUM_CLIENTS)
    for cid in range(NUM_CLIENTS):
        # Split dataset into non-overlapping NUM_CLIENT partitions
        idx_from, idx_to = int(cid) * partition_size, (int(cid) + 1) * partition_size
        # Apply SMOTE to balance the dataset
        smote = SMOTE()
        X_temp, y_temp = smote.fit_resample(x_train[idx_from:idx_to], y_train[idx_from:idx_to])
        print('_____________________----------------____________________---------------_________________-----------------')
        print("Partition:", Counter(y_temp))
        partitions.append((X_temp, y_temp))
    return partitions, testset


partitions, testset = partition()"""

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import math
NUM_CLIENTS = 50






def partition():

    encoder=LabelEncoder()
    df['Type']=encoder.fit_transform(df['Type'])
    X = df.iloc[:,4:]
    y = df['Type']
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)
    print("y_train dataset shape:", Counter(y_train))
    print("y_test dataset shape:", Counter(y_test))
    x_train = x_train.to_numpy()
    x_test = x_test.to_numpy()
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()
    testset = (x_test,y_test)
    print(type(x_train))
    partitions = []
    # We keep all partitions equal-sized in this example
    partition_size = math.floor(len(x_train) / NUM_CLIENTS)
    for cid in range(NUM_CLIENTS):
        # Split dataset into non-overlapping NUM_CLIENT partitions
        idx_from, idx_to = int(cid) * partition_size, (int(cid) + 1) * partition_size
        print('_____________________----------------____________________---------------_________________-----------------')
        print("Partition:", Counter(y_train[idx_from:idx_to]))
        partitions.append((x_train[idx_from:idx_to], y_train[idx_from:idx_to]))
    return partitions, testset



trainset, testset = partition()
# Out:
# y_train dataset shape: Counter({2: 389026, 1: 179355, 0: 27126})
# y_test dataset shape: Counter({2: 192193, 1: 88005, 0: 13112})
# <class 'numpy.ndarray'>
# _____________________----------------____________________---------------_________________-----------------
# Partition: Counter({2: 7714, 1: 3641, 0: 555})
# _____________________----------------____________________---------------_________________-----------------
# Partition: Counter({2: 7910, 1: 3459, 0: 541})
# _____________________----------------____________________---------------_________________-----------------
# Partition: Counter({2: 7808, 1: 3607, 0: 495})
# _____________________----------------____________________---------------_________________-----------------
# Partition: Counter({2: 7853, 1: 3535, 0: 522})
# _____________________----------------____________________---------------_________________-----------------
# Partition: Counter({2: 7731, 1: 3657, 0: 522})
# ...

# %%
import math
from typing import Dict, List, Tuple
import tensorflow as tf
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


#LSTM
def get_model():
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, activation="relu", input_shape=(9, 1), return_sequences=True),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(32, activation="relu", return_sequences=True),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(16, activation="relu"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(3, activation="softmax")
    ])

    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model





model = get_model()
partitions, testset = partition()
x_test, y_test = testset
hist = model.fit(x_test,y_test)

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model("/content/50_15_ann_model.h5")

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import shap as shp

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import numpy as np
import tensorflow as tf

# Load your pre-trained model
model_path = '/content/50_15_ann_model.h5'  # Update this to your model's file location
model = tf.keras.models.load_model(model_path)



"""encoder=LabelEncoder()
df['Type']=encoder.fit_transform(df['Type'])
X = df.iloc[:,4:]
y = df['Type']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

"""
# Assuming your data is in a pandas DataFrame named 'data'
# If it's in a different format, adjust accordingly
X = df.drop('Type', axis=1)  # Features
y = df['Type']  # Target variable

# Use SHAP explainer for your model type (here, assuming a deep learning model)
explainer = shp.DeepExplainer(model, np.array(X[:100]))

# Get the input shape as a tuple
input_shape = model.input_shape[1:]  # Assuming the first dimension is batch size

# Convert the input shape to a list
list_input_shape = list(input_shape)  # Explicitly convert to list

# Use SHAP explainer for your model type
explainer = shp.DeepExplainer(model, X, input_shape=list_input_shape)

# ... rest of your code for visualization
# Out:
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-93fa807df66a> in <cell line: 28>()
#      26
#      27 # Use SHAP explainer for your model type (here, assuming a deep learning model)
# ---> 28 explainer = shp.DeepExplainer(model, np.array(X[:100]))
#      29
#      30 # Get the input shape as a tuple
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import numpy as np
import tensorflow as tf

# Load your pre-trained model
model_path = '/content/50_15_ann_model.h5'  # Update this to your model's file location
model = tf.keras.models.load_model(model_path)



encoder=LabelEncoder()
df['Type']=encoder.fit_transform(df['Type'])
X = df.iloc[:,4:]
y = df['Type']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)



import shap

background = x_train[:100]  # Using 100 samples for the background distribution

explainer = shap.DeepExplainer(model, np.array(background))


shap_values = explainer.shap_values(np.array(x_test[:10])) # Explaining 10 instances for example

# Visualize the first prediction's explanation
shap.initjs()  # Initialize JavaScript in the notebook for SHAP plots
shap.force_plot(explainer.expected_value[0], shap_values[0][0], x_test[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap_values_instance
# Out:
# array([ 0.00784913, -0.02104301,  0.0131939 ])

# %%
X_test[0:1]
# Out:
#          RR-I         HR    R-H    P-H    QRS    PRQ     QT      QTC     ST
# 325285  0.788  76.142132 -0.665 -1.125  0.072  0.164  0.376  0.42357  0.304

# %%
# !pip install shap

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
import tensorflow as tf

# Load your pre-trained model
model_path = '/content/50_15_ann_model.h5'
model = tf.keras.models.load_model(model_path)



encoder=LabelEncoder()
df['Type']=encoder.fit_transform(df['Type'])
X = df.iloc[:,4:]
y = df['Type']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)




encoder=LabelEncoder()
df['Type']=encoder.fit_transform(df['Type'])
X = df.iloc[:,4:]
y = df['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)



import shap

background = X_train[0:500]
forground = X_test[:25]

explainer = shap.KernelExplainer(model.predict,background)

shap_values = explainer.shap_values(forground)
# Out:
# 16/16 [==============================] - 0s 3ms/step
# WARNING:shap:Using 500 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# ...
# 7969/7969 [==============================] - 12s 1ms/step

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[0], shap_values[..., 0], forground)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
# Now, create an Explanation object
expl = shap.Explanation(values=shap_values[..., 0],
                        base_values=explainer.expected_value,
                        data=forground,
                        feature_names=X_train.columns)

shap.plots.bar(expl)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.summary_plot(expl)

# %%
shap.plots.waterfall(expl[0])

# %%
shap.plots.bar(expl[0])

# %%
def SHAP_EXP(model,graph_feat,list_of_feat1,start_index,end_index):
  print("Models: ",model)

  explainer = shap.Explainer(model.predict, X_test)

  shap_values1 = explainer(X_test[start_index:end_index])
  features_names=list_of_feat1


  print("Global Explaination")
  shap.plots.bar(shap_values1,max_display=graph_feat["max_display"])

  print("Global Explaination")

  shap.summary_plot(shap_values1,max_display=graph_feat["max_display"])

  print("---------------------")

  print("Local Explaination")
  shap.plots.waterfall(shap_values1[graph_feat["shap_values Index"]],max_display=graph_feat["max_display"])


  print("Local Explaination")

  shap.plots.bar(shap_values1[graph_feat["shap_values Index"]],max_display=graph_feat["max_display"])

# %%
loaded_model.predict(testset[0][0:1])
# Out:
# 1/1 [==============================] - 0s 99ms/step
# array([[2.1217242e-02, 5.9235481e-06, 9.7877687e-01]], dtype=float32)

# %%
shap_values[0][0]
# Out:
# array([ 0.06208463,  0.00203769, -0.06412224])

# %%
 testset[0][0:1]
# Out:
# array([[ 7.88000000e-01,  7.61421320e+01, -6.65000000e-01,
#         -1.12500000e+00,  7.20000000e-02,  1.64000000e-01,
#          3.76000000e-01,  4.23569555e-01,  3.04000000e-01]])

# %%
import shap


def f(X):
    return loaded_model.predict(X).flatten()



background = testset[0][:100][0:100]

explainer = shap.Explainer(model)

# Compute SHAP values - use a subset of your data here to speed up the process
shap_values = explainer.shap_values(background)





# Now you can visualize the SHAP values for the first prediction
shap.initjs()
shap.force_plot(explainer.expected_value[0], shap_values[0][0],  testset[0][0:1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-82e3c1339b47> in <cell line: 11>()
#       9 background = testset[0][:100][0:100]
#      10
# ---> 11 explainer = shap.Explainer(model)
#      12
#      13 # Compute SHAP values - use a subset of your data here to speed up the process
#
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_explainer.py in __init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     180             elif algorithm == "permutation":
#     181                 self.__class__ = explainers.PermutationExplainer
# --> 182                 explainers.PermutationExplainer.__init__(self, self.model, self.masker, link=self.link, feature_names=self.feature_names, linearize_link=linearize_link, seed=seed, **kwargs)
#     183             elif algorithm == "partition":
# ...

# %%
import shap


background = testset[0][:100]

explainer = shap.KernelExplainer(loaded_model, background)

# Compute SHAP values - use a subset of your data here to speed up the process
shap_values = explainer.shap_values(background)





# Now you can visualize the SHAP values for the first prediction
shap.initjs()
shap.force_plot(explainer.expected_value[0], shap_values[0][0],  testset[0][0:1])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
 testset[0][0:1]
# Out:
# array([[ 7.88000000e-01,  7.61421320e+01, -6.65000000e-01,
#         -1.12500000e+00,  7.20000000e-02,  1.64000000e-01,
#          3.76000000e-01,  4.23569555e-01,  3.04000000e-01]])

# %%
shap_values[0]
# Out:
# array([[-0.00106423, -0.00466271,  0.00572694],
#        [ 0.00570207,  0.0213803 , -0.02708237],
#        [-0.24042556, -0.05278241,  0.29320797],
#        [ 0.16478345, -0.28950021,  0.12471678],
#        [-0.03177052,  0.01364239,  0.01812814],
#        [ 0.00063425, -0.00134392,  0.00070967],
#        [-0.01208329,  0.00438751,  0.00769579],
#        [-0.01462814,  0.00367149,  0.01095666],
#        [-0.00209814,  0.00032488,  0.00177327]])

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 8.6 MB/s eta 0:00:00
# ...

# %%
from keras.layers import (
    Dense,
    Dropout,
    Flatten,
    Input,
    concatenate,
)
from tensorflow.keras.layers import Embedding
from keras.models import Model
from sklearn.model_selection import train_test_split

import shap

# print the JS visualization code to the notebook
shap.initjs()



X, y = shap.datasets.adult()
X_display, y_display = shap.datasets.adult(display=True)

# normal
#size data (this is important for model convergence)
dtypes = list(zip(X.dtypes.index, map(str, X.dtypes)))
for k, dtype in dtypes:
    if dtype == "float32":
        X[k] -= X[k].mean()
        X[k] /= X[k].std()

X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.2, random_state=7
)




# build model
input_els = []
encoded_els = []
for k, dtype in dtypes:
    input_els.append(Input(shape=(1,)))
    if dtype == "int8":
        e = Flatten()(Embedding(X_train[k].max() + 1, 1)(input_els[-1]))
    else:
        e = input_els[-1]
    encoded_els.append(e)
encoded_els = concatenate(encoded_els)
layer1 = Dropout(0.5)(Dense(100, activation="relu")(encoded_els))
out = Dense(1)(layer1)



# train model
regression = Model(inputs=input_els, outputs=[out])
regression.compile(optimizer="adam", loss="binary_crossentropy")

regression.fit(
    [X_train[k].values for k, t in dtypes],
    y_train,
    epochs=5,
    batch_size=512,
    shuffle=True,
    validation_data=([X_valid[k].values for k, t in dtypes], y_valid),
)


def f(X):
    return regression.predict([X[:, i] for i in range(X.shape[1])]).flatten()



explainer = shap.KernelExplainer(f, X.iloc[:50, :])
shap_values = explainer.shap_values(X.iloc[299, :], nsamples=500)
shap.force_plot(explainer.expected_value, shap_values, X_display.iloc[299, :])


shap_values50 = explainer.shap_values(X.iloc[280:330, :], nsamples=500)
shap.force_plot(explainer.expected_value, shap_values50, X_display.iloc[280:330, :])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
from keras.layers import (
    Dense,
    Dropout,
    Flatten,
    Input,
    concatenate,
)
from tensorflow.keras.layers import Embedding
from keras.models import Model
from sklearn.model_selection import train_test_split

import shap

# print the JS visualization code to the notebook
shap.initjs()




encoder=LabelEncoder()
df['Type']=encoder.fit_transform(df['Type'])
X = df.iloc[:,4:]
y = df['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)






def f(X):
    return model.predict(X).flatten()



explainer = shap.KernelExplainer(model, np.array(X_train[0:100]))
shap_values = explainer.shap_values(np.array(X_train[0:100]), nsamples=500)
shap.force_plot(explainer.expected_value[0],shap_values[0][0,:], np.array(X_test[0:1]))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import shap
import numpy as np

# select a set of background examples to take an expectation over
background = x_train[np.random.choice(x_train.shape[0], 100, replace=False)]

# explain predictions of the model on four images
e = shap.DeepExplainer(model, background)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-cf56abb983fb> in <cell line: 5>()
#       3
#       4 # select a set of background examples to take an expectation over
# ----> 5 background = X_train[np.random.choice(x_train.shape[0], 100, replace=False)]
#       6
#       7 # explain predictions of the model on four images
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# ...

# %%
shap_values
# Out:
# array([ 0.03564714,  0.        , -0.08852222,  0.00100307,  0.00297772,
#        -0.01354748,  0.        ,  0.00201745, -0.02246836,  0.0126264 ,
#        -0.07514882,  0.        ])

# %%
X_display.iloc[299, :]
# Out:
# Age                         38.0
# Workclass                Private
# Education-Num                9.0
# Marital Status          Divorced
# Occupation                 Sales
# Relationship       Not-in-family
# Race                       White
# Sex                         Male
# Capital Gain                 0.0
# Capital Loss                 0.0
# Hours per week              80.0
# Country            United-States
# Name: 299, dtype: object

# %%
y_display
# Out:
# array([False, False, False, ..., False, False,  True])
