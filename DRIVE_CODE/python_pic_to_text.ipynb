# %%
# !pip install pywhatkit
# Out:
# ...
#      |████████████████████████████████| 61kB 4.4MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 133kB 20.8MB/s
# ...
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-cp37-none-any.whl size=7420 sha256=d6d115943694e929416941936d653bc8b22413d179ac7bc62ca5ac95c0d4608e
#   Stored in directory: /root/.cache/pip/wheels/16/d7/4e/fffdd54b1cca86608b7655c9a2854890a38f955ce9532848cd
# Successfully built pymsgbox
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-cp37-none-any.whl size=11686 sha256=84bd86cd944e1c9e1bc5f411f9d91d2150724464a05831b219bb6dc4a7316af4
#   Stored in directory: /root/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-cp37-none-any.whl size=35194 sha256=f4ba5dd13d5ca5116e116a67877a491e2bb532d0a774ae35d73d50066124cebf
# ...

# %%
# !pip install pywhatkit

# %%
import pywhatkit
pywhatkit.image_to_ascii_art('hello.jpg','rizvi.txt')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ee573e3b41b9> in <module>()
# ----> 1 import pywhatkit
#       2 pywhatkit.image_to_ascii_art('hello.jpg','rizvi.txt')
#
# /usr/local/lib/python3.7/dist-packages/pywhatkit/__init__.py in <module>()
#       2 Pull requests are always welcomed"""
#       3
# ----> 4 from pywhatkit.mainfunctions import sendwhatmsg_to_group, watch_tutorial_in_English, watch_tutorial_in_Hindi, developer_contact, showHistory, shutdown, cancelShutdown, prnt_sleeptm, check_window, sendwhatmsg, info, playonyt, image_to_ascii_art, search
#       5 from pywhatkit.chr_to_handwriting import text_to_handwriting
#       6 import pywhatkit.help
#
# /usr/local/lib/python3.7/dist-packages/pywhatkit/mainfunctions.py in <module>()
#       1 import time
#       2 import webbrowser as web
# ----> 3 import pyautogui as pg
#       4 import wikipedia
# ...
