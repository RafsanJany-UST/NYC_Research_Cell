# %%
path = "C:/Users/RAZER/Desktop/TEMp/New folder/KINECT_dataset_with_qor15.csv"

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from sklearn.metrics import classification_report, brier_score_loss
from sklearn.model_selection import train_test_split
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve

# Dataset Path


# Load and preprocess dataset
dataframe = pd.read_csv(path)
dataframe = dataframe[dataframe['walking_speed'] == 'Fast']
dataframe.dropna(subset=['QoR_class'], inplace=True)

# Graph structure
joints = ['PELVIS', 'SPINE_NAVAL', 'SPINE_CHEST', 'NECK', 'CLAVICLE_LEFT', 'SHOULDER_LEFT',
          'ELBOW_LEFT', 'WRIST_LEFT', 'HAND_LEFT', 'HANDTIP_LEFT', 'THUMB_LEFT',
          'CLAVICLE_RIGHT', 'SHOULDER_RIGHT', 'ELBOW_RIGHT', 'WRIST_RIGHT', 'HAND_RIGHT',
          'HANDTIP_RIGHT', 'THUMB_RIGHT', 'HIP_LEFT', 'KNEE_LEFT', 'ANKLE_LEFT',
          'FOOT_LEFT', 'HIP_RIGHT', 'KNEE_RIGHT', 'ANKLE_RIGHT', 'FOOT_RIGHT',
          'HEAD', 'NOSE', 'EYE_LEFT', 'EAR_LEFT', 'EYE_RIGHT', 'EAR_RIGHT']

edges = [(a, b) for a, b in zip(joints[:-1], joints[1:])]  # Simplified for this demo
joint_to_idx = {j: i for i, j in enumerate(joints)}
edge_index = torch.tensor([[joint_to_idx[a], joint_to_idx[b]] for a, b in edges] + 
                          [[joint_to_idx[b], joint_to_idx[a]] for a, b in edges], dtype=torch.long).t()

# Dataset class with patient-aware sequences
class WindowedSkeletonDataset(torch.utils.data.Dataset):
    def __init__(self, df, window_size=30, stride=15):
        self.samples = []
        grouped = df.groupby(['patient_id', 'trial'])
        for (pid, trial), group in grouped:
            group = group.sort_values('t_uniform')
            if len(group) < window_size:
                continue
            for i in range(0, len(group) - window_size + 1, stride):
                window = group.iloc[i:i+window_size]
                x_seq, aux_seq = [], []
                for _, row in window.iterrows():
                    node_features = [[row[f'{j}_X'], row[f'{j}_Y'], row[f'{j}_Z'], row['t_uniform']] for j in joints]
                    x_seq.append(torch.tensor(node_features, dtype=torch.float))
                    aux_seq.append(torch.tensor([row['left_foot_swing'], row['right_foot_swing'], row['pelvis_pos']], dtype=torch.float))
                label = torch.tensor(window['QoR_class'].mode().values[0], dtype=torch.float)
                self.samples.append((torch.stack(x_seq), torch.stack(aux_seq), label, pid))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# Split patients (no overlap)
unique_ids = dataframe['patient_id'].unique()
train_ids, test_ids = train_test_split(unique_ids, test_size=0.3, random_state=42)
train_df = dataframe[dataframe['patient_id'].isin(train_ids)]
test_df = dataframe[dataframe['patient_id'].isin(test_ids)]

# Dataset creation
train_dataset = WindowedSkeletonDataset(train_df, window_size=120, stride=10)
test_dataset = WindowedSkeletonDataset(test_df, window_size=120, stride=10)

# Dataloaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16)

# Model
class WindowedSTGCN(nn.Module):
    def __init__(self, in_channels, hidden_channels):
        super().__init__()
        self.gcn = GCNConv(in_channels, hidden_channels)
        self.lstm = nn.LSTM(hidden_channels, hidden_channels, batch_first=True)
        self.aux_fc = nn.Linear(3, hidden_channels)
        self.classifier = nn.Linear(2 * hidden_channels, 1)

    def forward(self, x_seq, aux_seq):
        B, T, N, feat_dim = x_seq.shape
        x_seq = x_seq.view(B * T * N, feat_dim)
        full_edge_index = torch.cat([edge_index + b * N for b in range(B * T)], dim=1).to(x_seq.device)
        x = F.relu(self.gcn(x_seq, full_edge_index))
        x = x.view(B, T, N, -1).mean(2)
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        aux = F.relu(self.aux_fc(aux_seq.mean(1)))
        return self.classifier(torch.cat([x, aux], dim=-1)).squeeze()

# Focal Loss
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        if self.reduction == 'mean':
            return F_loss.mean()
        else:
            return F_loss.sum()

# Training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = WindowedSTGCN(in_channels=4, hidden_channels=128).to(device)
criterion = FocalLoss(alpha=1, gamma=2)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

for epoch in range(1, 101):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for x_seq, aux_seq, y, _ in train_dataset:
        x_seq, aux_seq, y = x_seq.unsqueeze(0).to(device), aux_seq.unsqueeze(0).to(device), y.unsqueeze(0).to(device)
        optimizer.zero_grad()
        out = model(x_seq, aux_seq)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += ((torch.sigmoid(out) >= 0.5).float() == y).sum().item()
        total += 1
    print(f"Epoch {epoch:03d} | Loss: {total_loss / total:.4f} | Accuracy: {correct / total:.4f}")





import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict
from sklearn.model_selection import train_test_split

# Load dataset

dataframe = pd.read_csv(path)
dataframe = dataframe[dataframe['walking_speed'] == 'Fast']
dataframe.dropna(subset=['QoR_class'], inplace=True)



# Graph structure
# Graph structure
joints = ['PELVIS', 'SPINE_NAVAL', 'SPINE_CHEST', 'NECK', 'CLAVICLE_LEFT', 'SHOULDER_LEFT',
          'ELBOW_LEFT', 'WRIST_LEFT', 'HAND_LEFT', 'HANDTIP_LEFT', 'THUMB_LEFT',
          'CLAVICLE_RIGHT', 'SHOULDER_RIGHT', 'ELBOW_RIGHT', 'WRIST_RIGHT', 'HAND_RIGHT',
          'HANDTIP_RIGHT', 'THUMB_RIGHT', 'HIP_LEFT', 'KNEE_LEFT', 'ANKLE_LEFT',
          'FOOT_LEFT', 'HIP_RIGHT', 'KNEE_RIGHT', 'ANKLE_RIGHT', 'FOOT_RIGHT',
          'HEAD', 'NOSE', 'EYE_LEFT', 'EAR_LEFT', 'EYE_RIGHT', 'EAR_RIGHT']

edges = [(a, b) for a, b in zip(joints[:-1], joints[1:])] 



joint_to_idx = {j: i for i, j in enumerate(joints)}
edge_index = torch.tensor([[joint_to_idx[a], joint_to_idx[b]] for a, b in edges] + 
                          [[joint_to_idx[b], joint_to_idx[a]] for a, b in edges], dtype=torch.long).t()

# Dataset
class WindowedSkeletonDataset(torch.utils.data.Dataset):
    def __init__(self, df, window_size=30, stride=15):
        self.samples = []
        grouped = df.groupby(['patient_id', 'trial'])
        for (pid, trial), group in grouped:
            group = group.sort_values('t_uniform')
            if len(group) < window_size:
                continue
            for i in range(0, len(group) - window_size + 1, stride):
                window = group.iloc[i:i+window_size]
                x_seq, aux_seq = [], []
                for _, row in window.iterrows():
                    node_features = [[row[f'{j}_X'], row[f'{j}_Y'], row[f'{j}_Z'], row['t_uniform']] for j in joints]
                    x_seq.append(torch.tensor(node_features, dtype=torch.float))
                    aux_seq.append(torch.tensor([row['left_foot_swing'], row['right_foot_swing'], row['pelvis_pos']], dtype=torch.float))
                label = torch.tensor(window['QoR_class'].mode().values[0], dtype=torch.float)
                self.samples.append((torch.stack(x_seq), torch.stack(aux_seq), label, pid))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# Split
unique_ids = dataframe['patient_id'].unique()
train_ids, test_ids = train_test_split(unique_ids, test_size=0.3, random_state=42)
train_df = dataframe[dataframe['patient_id'].isin(train_ids)]
test_df = dataframe[dataframe['patient_id'].isin(test_ids)]

wind_size, stride_size, b_size = 120, 10, 16
train_dataset = WindowedSkeletonDataset(train_df, wind_size, stride_size)
test_dataset = WindowedSkeletonDataset(test_df, wind_size, stride_size)
train_loader = DataLoader(train_dataset, batch_size=b_size)
test_loader = DataLoader(test_dataset, batch_size=b_size)

# Model
class WindowedSTGCN(nn.Module):
    def __init__(self, in_channels, hidden_channels):
        super().__init__()
        self.gcn = GCNConv(in_channels, hidden_channels)
        self.lstm = nn.LSTM(hidden_channels, hidden_channels, batch_first=True)
        self.aux_fc = nn.Linear(3, hidden_channels)
        self.classifier = nn.Linear(2 * hidden_channels, 1)

    def forward(self, x_seq, aux_seq):
        B, T, N, feat_dim = x_seq.shape
        x_seq = x_seq.view(B * T * N, feat_dim)
        full_edge_index = torch.cat([edge_index + b * N for b in range(B * T)], dim=1).to(x_seq.device)
        x = F.relu(self.gcn(x_seq, full_edge_index))
        x = x.view(B, T, N, -1).mean(2)
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        aux = F.relu(self.aux_fc(aux_seq.mean(1)))
        return self.classifier(torch.cat([x, aux], dim=-1)).squeeze()

# Training with Focal Loss
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        return F_loss.mean()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = WindowedSTGCN(4, 128).to(device)
criterion = FocalLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

for epoch in range(1, 100):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for x_seq, aux_seq, y, _ in train_dataset:
        x_seq, aux_seq, y = x_seq.unsqueeze(0).to(device), aux_seq.unsqueeze(0).to(device), y.unsqueeze(0).to(device)
        optimizer.zero_grad()
        out = model(x_seq, aux_seq)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += ((torch.sigmoid(out) >= 0.5).float() == y).sum().item()
        total += 1
    print(f"Epoch {epoch:03d} | Loss: {total_loss / total:.4f} | Accuracy: {correct / total:.4f}")

# Evaluation - Per patient + Calibration Curve
def calculate_ece(probs, labels, n_bins=10):
    bins = np.linspace(0, 1, n_bins + 1)
    bin_indices = np.digitize(probs, bins) - 1
    ece = 0.0
    for i in range(n_bins):
        bin_mask = bin_indices == i
        if bin_mask.sum() == 0:
            continue
        bin_acc = labels[bin_mask].mean()
        bin_conf = probs[bin_mask].mean()
        ece += np.abs(bin_acc - bin_conf) * bin_mask.sum() / len(probs)
    return ece

def calculate_mce(probs, labels, n_bins=10):
    bins = np.linspace(0, 1, n_bins + 1)
    bin_indices = np.digitize(probs, bins) - 1
    mce = 0.0
    for i in range(n_bins):
        bin_mask = bin_indices == i
        if bin_mask.sum() == 0:
            continue
        bin_acc = labels[bin_mask].mean()
        bin_conf = probs[bin_mask].mean()
        mce = max(mce, np.abs(bin_acc - bin_conf))
    return mce

model.eval()
patient_results = defaultdict(list)
all_probs, all_labels = [], []

with torch.no_grad():
    for x_seq, aux_seq, y, pid in test_dataset:
        x_seq, aux_seq = x_seq.unsqueeze(0).to(device), aux_seq.unsqueeze(0).to(device)
        output = model(x_seq, aux_seq)
        prob = torch.sigmoid(output).cpu().item()
        pred_label = int(prob >= 0.5)
        true_label = int(y.item())
        patient_results[pid].append({'pred': pred_label, 'true': true_label, 'prob': prob})
        all_probs.append(prob)
        all_labels.append(true_label)

# Global Calibration
prob_true, prob_pred = calibration_curve(all_labels, all_probs, n_bins=10)
plt.figure(figsize=(6, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Model Calibration')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfect Calibration')
plt.xlabel('Mean predicted probability')
plt.ylabel('Fraction of positives')
plt.title('Global Calibration Curve')
plt.legend()
plt.show()

print(f"Global ECE: {calculate_ece(np.array(all_probs), np.array(all_labels)):.4f}")
print(f"Global MCE: {calculate_mce(np.array(all_probs), np.array(all_labels)):.4f}")

# Per-patient calibration report
for pid, records in patient_results.items():
    p_probs = np.array([r['prob'] for r in records])
    p_trues = np.array([r['true'] for r in records])
    if len(np.unique(p_trues)) == 1:
        print(f"Patient {pid}: Cannot calculate ECE/MCE (only one class present).")
    else:
        ece = calculate_ece(p_probs, p_trues)
        mce = calculate_mce(p_probs, p_trues)
        print(f"Patient {pid} | ECE: {ece:.4f} | MCE: {mce:.4f}")
# Out:
# Epoch 001 | Loss: 12.1795 | Accuracy: 0.7360
# Epoch 002 | Loss: 14.1336 | Accuracy: 0.7289
# Epoch 003 | Loss: 13.3829 | Accuracy: 0.7319
# Epoch 004 | Loss: 13.0786 | Accuracy: 0.7304
# Epoch 005 | Loss: 13.1686 | Accuracy: 0.7314
# Epoch 006 | Loss: 12.6238 | Accuracy: 0.7335
# Epoch 007 | Loss: 12.4634 | Accuracy: 0.7314
# Epoch 008 | Loss: 12.3271 | Accuracy: 0.7284
# Epoch 009 | Loss: 12.4751 | Accuracy: 0.7233
# Epoch 010 | Loss: 11.6025 | Accuracy: 0.7289
# Epoch 011 | Loss: 12.0354 | Accuracy: 0.7269
# Epoch 012 | Loss: 10.9764 | Accuracy: 0.7335
# Epoch 013 | Loss: 11.5574 | Accuracy: 0.7279
# Epoch 014 | Loss: 10.5738 | Accuracy: 0.7330
# Epoch 015 | Loss: 10.9910 | Accuracy: 0.7309
# Epoch 016 | Loss: 10.5914 | Accuracy: 0.7319
# Epoch 017 | Loss: 10.0957 | Accuracy: 0.7360
# Epoch 018 | Loss: 10.3625 | Accuracy: 0.7325
# Epoch 019 | Loss: 10.2572 | Accuracy: 0.7309
# Epoch 020 | Loss: 9.9025 | Accuracy: 0.7335
# Epoch 021 | Loss: 9.8180 | Accuracy: 0.7319
# Epoch 022 | Loss: 9.7477 | Accuracy: 0.7309
# Epoch 023 | Loss: 9.4402 | Accuracy: 0.7325
# Epoch 024 | Loss: 9.0042 | Accuracy: 0.7325
# Epoch 025 | Loss: 9.4592 | Accuracy: 0.7258
# Epoch 026 | Loss: 9.3214 | Accuracy: 0.7274
# Epoch 027 | Loss: 9.1950 | Accuracy: 0.7263
# Epoch 028 | Loss: 8.6366 | Accuracy: 0.7335
# Epoch 029 | Loss: 8.9027 | Accuracy: 0.7248
# Epoch 030 | Loss: 8.4934 | Accuracy: 0.7284
# Epoch 031 | Loss: 8.4939 | Accuracy: 0.7289
# Epoch 032 | Loss: 8.1162 | Accuracy: 0.7299
# Epoch 033 | Loss: 8.2517 | Accuracy: 0.7279
# Epoch 034 | Loss: 7.6527 | Accuracy: 0.7386
# Epoch 035 | Loss: 7.8880 | Accuracy: 0.7345
# Epoch 036 | Loss: 7.8889 | Accuracy: 0.7284
# Epoch 037 | Loss: 7.8984 | Accuracy: 0.7228
# Epoch 038 | Loss: 7.7754 | Accuracy: 0.7223
# Epoch 039 | Loss: 7.2177 | Accuracy: 0.7350
# Epoch 040 | Loss: 7.3283 | Accuracy: 0.7314
# Epoch 041 | Loss: 7.1365 | Accuracy: 0.7319
# Epoch 042 | Loss: 6.8436 | Accuracy: 0.7325
# Epoch 043 | Loss: 6.7145 | Accuracy: 0.7335
# Epoch 044 | Loss: 6.5213 | Accuracy: 0.7350
# Epoch 045 | Loss: 6.6182 | Accuracy: 0.7279
# Epoch 046 | Loss: 6.3791 | Accuracy: 0.7289
# Epoch 047 | Loss: 6.2726 | Accuracy: 0.7314
# Epoch 048 | Loss: 6.4967 | Accuracy: 0.7248
# Epoch 049 | Loss: 6.1163 | Accuracy: 0.7263
# Epoch 050 | Loss: 6.2188 | Accuracy: 0.7218
# Epoch 051 | Loss: 6.0888 | Accuracy: 0.7213
# Epoch 052 | Loss: 5.7834 | Accuracy: 0.7243
# Epoch 053 | Loss: 5.4857 | Accuracy: 0.7243
# Epoch 054 | Loss: 5.2486 | Accuracy: 0.7289
# Epoch 055 | Loss: 5.2310 | Accuracy: 0.7269
# Epoch 056 | Loss: 4.9462 | Accuracy: 0.7274
# Epoch 057 | Loss: 4.8570 | Accuracy: 0.7284
# Epoch 058 | Loss: 4.8196 | Accuracy: 0.7269
# Epoch 059 | Loss: 4.5015 | Accuracy: 0.7319
# Epoch 060 | Loss: 4.4293 | Accuracy: 0.7304
# Epoch 061 | Loss: 4.3794 | Accuracy: 0.7284
# Epoch 062 | Loss: 4.1861 | Accuracy: 0.7309
# Epoch 063 | Loss: 4.1757 | Accuracy: 0.7274
# Epoch 064 | Loss: 4.0260 | Accuracy: 0.7289
# Epoch 065 | Loss: 3.9708 | Accuracy: 0.7274
# Epoch 066 | Loss: 3.8790 | Accuracy: 0.7279
# Epoch 067 | Loss: 3.8717 | Accuracy: 0.7248
# Epoch 068 | Loss: 3.6892 | Accuracy: 0.7228
# Epoch 069 | Loss: 3.6292 | Accuracy: 0.7233
# Epoch 070 | Loss: 3.3710 | Accuracy: 0.7258
# Epoch 071 | Loss: 3.3210 | Accuracy: 0.7304
# Epoch 072 | Loss: 3.2581 | Accuracy: 0.7279
# Epoch 073 | Loss: 3.1144 | Accuracy: 0.7289
# Epoch 074 | Loss: 3.0756 | Accuracy: 0.7269
# Epoch 075 | Loss: 2.8638 | Accuracy: 0.7309
# Epoch 076 | Loss: 2.9031 | Accuracy: 0.7248
# Epoch 077 | Loss: 2.7029 | Accuracy: 0.7284
# Epoch 078 | Loss: 2.7006 | Accuracy: 0.7233
# Epoch 079 | Loss: 2.5144 | Accuracy: 0.7304
# Epoch 080 | Loss: 2.6233 | Accuracy: 0.7228
# Epoch 081 | Loss: 2.3448 | Accuracy: 0.7299
# Epoch 082 | Loss: 2.3658 | Accuracy: 0.7269
# Epoch 083 | Loss: 2.4773 | Accuracy: 0.7202
# Epoch 084 | Loss: 2.2257 | Accuracy: 0.7218
# Epoch 085 | Loss: 2.2056 | Accuracy: 0.7208
# Epoch 086 | Loss: 2.1454 | Accuracy: 0.7202
# Epoch 087 | Loss: 1.9796 | Accuracy: 0.7238
# Epoch 088 | Loss: 1.8933 | Accuracy: 0.7269
# Epoch 089 | Loss: 1.8824 | Accuracy: 0.7182
# Epoch 090 | Loss: 1.7778 | Accuracy: 0.7208
# Epoch 091 | Loss: 1.6837 | Accuracy: 0.7208
# Epoch 092 | Loss: 1.6065 | Accuracy: 0.7218
# Epoch 093 | Loss: 1.5609 | Accuracy: 0.7197
# Epoch 094 | Loss: 1.5041 | Accuracy: 0.7172
# Epoch 095 | Loss: 1.4272 | Accuracy: 0.7208
# Epoch 096 | Loss: 1.3626 | Accuracy: 0.7208
# Epoch 097 | Loss: 1.3016 | Accuracy: 0.7218
# Epoch 098 | Loss: 1.2433 | Accuracy: 0.7243
# Epoch 099 | Loss: 1.2207 | Accuracy: 0.7218
# Epoch 100 | Loss: 1.1831 | Accuracy: 0.7218
# Epoch 001 | Loss: 13.5087 | Accuracy: 0.7299
# Epoch 002 | Loss: 13.4645 | Accuracy: 0.7319
# Epoch 003 | Loss: 13.2508 | Accuracy: 0.7294
# Epoch 004 | Loss: 12.4093 | Accuracy: 0.7340
# Epoch 005 | Loss: 11.9990 | Accuracy: 0.7365
# Epoch 006 | Loss: 11.6761 | Accuracy: 0.7365
# Epoch 007 | Loss: 11.4441 | Accuracy: 0.7370
# Epoch 008 | Loss: 11.1863 | Accuracy: 0.7340
# Epoch 009 | Loss: 10.8361 | Accuracy: 0.7314
# Epoch 010 | Loss: 10.7637 | Accuracy: 0.7299
# Epoch 011 | Loss: 10.1789 | Accuracy: 0.7350
# Epoch 012 | Loss: 9.9767 | Accuracy: 0.7330
# Epoch 013 | Loss: 10.0145 | Accuracy: 0.7325
# Epoch 014 | Loss: 9.7483 | Accuracy: 0.7299
# Epoch 015 | Loss: 9.5742 | Accuracy: 0.7335
# Epoch 016 | Loss: 9.4993 | Accuracy: 0.7335
# Epoch 017 | Loss: 8.7553 | Accuracy: 0.7350
# Epoch 018 | Loss: 9.2483 | Accuracy: 0.7309
# Epoch 019 | Loss: 8.8228 | Accuracy: 0.7309
# Epoch 020 | Loss: 8.1328 | Accuracy: 0.7350
# Epoch 021 | Loss: 8.5958 | Accuracy: 0.7299
# Epoch 022 | Loss: 7.9135 | Accuracy: 0.7360
# Epoch 023 | Loss: 8.4114 | Accuracy: 0.7279
# Epoch 024 | Loss: 7.8050 | Accuracy: 0.7355
# Epoch 025 | Loss: 7.4787 | Accuracy: 0.7365
# Epoch 026 | Loss: 7.2484 | Accuracy: 0.7370
# Epoch 027 | Loss: 7.8145 | Accuracy: 0.7309
# Epoch 028 | Loss: 7.1194 | Accuracy: 0.7370
# Epoch 029 | Loss: 7.2041 | Accuracy: 0.7304
# Epoch 030 | Loss: 7.0145 | Accuracy: 0.7319
# Epoch 031 | Loss: 6.7341 | Accuracy: 0.7340
# Epoch 032 | Loss: 6.5126 | Accuracy: 0.7375
# Epoch 033 | Loss: 6.3215 | Accuracy: 0.7401
# Epoch 034 | Loss: 6.0817 | Accuracy: 0.7370
# Epoch 035 | Loss: 6.0294 | Accuracy: 0.7375
# Epoch 036 | Loss: 5.9784 | Accuracy: 0.7396
# Epoch 037 | Loss: 5.8400 | Accuracy: 0.7365
# Epoch 038 | Loss: 5.7109 | Accuracy: 0.7396
# Epoch 039 | Loss: 5.6117 | Accuracy: 0.7396
# Epoch 040 | Loss: 5.5590 | Accuracy: 0.7365
# Epoch 041 | Loss: 5.3904 | Accuracy: 0.7370
# Epoch 042 | Loss: 5.2494 | Accuracy: 0.7360
# Epoch 043 | Loss: 5.4033 | Accuracy: 0.7325
# Epoch 044 | Loss: 5.2236 | Accuracy: 0.7365
# Epoch 045 | Loss: 5.1438 | Accuracy: 0.7375
# Epoch 046 | Loss: 5.0401 | Accuracy: 0.7401
# Epoch 047 | Loss: 4.9871 | Accuracy: 0.7365
# Epoch 048 | Loss: 4.9308 | Accuracy: 0.7345
# Epoch 049 | Loss: 4.7771 | Accuracy: 0.7401
# Epoch 050 | Loss: 4.7220 | Accuracy: 0.7396
# Epoch 051 | Loss: 4.6604 | Accuracy: 0.7380
# Epoch 052 | Loss: 4.5791 | Accuracy: 0.7380
# Epoch 053 | Loss: 4.5847 | Accuracy: 0.7319
# Epoch 054 | Loss: 4.5076 | Accuracy: 0.7335
# Epoch 055 | Loss: 4.3914 | Accuracy: 0.7355
# Epoch 056 | Loss: 4.3085 | Accuracy: 0.7365
# Epoch 057 | Loss: 4.2398 | Accuracy: 0.7365
# Epoch 058 | Loss: 4.3163 | Accuracy: 0.7345
# Epoch 059 | Loss: 4.2160 | Accuracy: 0.7325
# Epoch 060 | Loss: 3.9958 | Accuracy: 0.7350
# Epoch 061 | Loss: 3.6805 | Accuracy: 0.7411
# Epoch 062 | Loss: 3.7848 | Accuracy: 0.7370
# Epoch 063 | Loss: 3.5542 | Accuracy: 0.7396
# Epoch 064 | Loss: 3.5372 | Accuracy: 0.7375
# Epoch 065 | Loss: 3.4068 | Accuracy: 0.7396
# Epoch 066 | Loss: 3.4571 | Accuracy: 0.7411
# Epoch 067 | Loss: 3.3670 | Accuracy: 0.7365
# Epoch 068 | Loss: 3.4071 | Accuracy: 0.7355
# Epoch 069 | Loss: 3.2630 | Accuracy: 0.7350
# Epoch 070 | Loss: 3.1646 | Accuracy: 0.7365
# Epoch 071 | Loss: 3.1036 | Accuracy: 0.7370
# Epoch 072 | Loss: 3.0535 | Accuracy: 0.7365
# Epoch 073 | Loss: 2.9403 | Accuracy: 0.7406
# Epoch 074 | Loss: 3.0000 | Accuracy: 0.7335
# Epoch 075 | Loss: 2.9412 | Accuracy: 0.7345
# Epoch 076 | Loss: 2.6954 | Accuracy: 0.7370
# Epoch 077 | Loss: 2.8084 | Accuracy: 0.7309
# Epoch 078 | Loss: 2.6915 | Accuracy: 0.7355
# Epoch 079 | Loss: 2.5691 | Accuracy: 0.7375
# Epoch 080 | Loss: 2.5222 | Accuracy: 0.7365
# Epoch 081 | Loss: 2.3833 | Accuracy: 0.7391
# Epoch 082 | Loss: 2.3019 | Accuracy: 0.7396
# Epoch 083 | Loss: 2.3219 | Accuracy: 0.7335
# Epoch 084 | Loss: 2.2971 | Accuracy: 0.7350
# Epoch 085 | Loss: 2.2203 | Accuracy: 0.7325
# Epoch 086 | Loss: 2.0924 | Accuracy: 0.7386
# Epoch 087 | Loss: 2.0669 | Accuracy: 0.7355
# Epoch 088 | Loss: 2.0466 | Accuracy: 0.7350
# Epoch 089 | Loss: 1.9968 | Accuracy: 0.7355
# Epoch 090 | Loss: 1.9276 | Accuracy: 0.7365
# Epoch 091 | Loss: 1.8503 | Accuracy: 0.7396
# Epoch 092 | Loss: 1.8977 | Accuracy: 0.7345
# Epoch 093 | Loss: 1.7923 | Accuracy: 0.7345
# Epoch 094 | Loss: 1.8871 | Accuracy: 0.7340
# Epoch 095 | Loss: 1.7788 | Accuracy: 0.7345
# Epoch 096 | Loss: 1.7049 | Accuracy: 0.7370
# Epoch 097 | Loss: 1.6929 | Accuracy: 0.7360
# Epoch 098 | Loss: 1.6655 | Accuracy: 0.7319
# Epoch 099 | Loss: 1.5945 | Accuracy: 0.7325
# Global ECE: 0.1846
# Global MCE: 0.6800
# Patient 001-LO: Cannot calculate ECE/MCE (only one class present).
# Patient 005-GP: Cannot calculate ECE/MCE (only one class present).
# Patient 006-TR: Cannot calculate ECE/MCE (only one class present).
# Patient 010-RA: Cannot calculate ECE/MCE (only one class present).
# Patient 011-CB: Cannot calculate ECE/MCE (only one class present).
# Patient 013-MS: Cannot calculate ECE/MCE (only one class present).
# Patient 018-OS: Cannot calculate ECE/MCE (only one class present).
# Patient 020-MM: Cannot calculate ECE/MCE (only one class present).
# Patient 025-PS: Cannot calculate ECE/MCE (only one class present).
# Patient 033-JF: Cannot calculate ECE/MCE (only one class present).
# Patient 037-MA: Cannot calculate ECE/MCE (only one class present).
# Patient 039-EB: Cannot calculate ECE/MCE (only one class present).
# Patient 040-KR: Cannot calculate ECE/MCE (only one class present).
# Patient 058-ZS: Cannot calculate ECE/MCE (only one class present).
# Patient 064-SC: Cannot calculate ECE/MCE (only one class present).
# Patient 070-TC: Cannot calculate ECE/MCE (only one class present).
# Patient 072-DD: Cannot calculate ECE/MCE (only one class present).
# Patient 080-TW: Cannot calculate ECE/MCE (only one class present).
# Patient 082-BK: Cannot calculate ECE/MCE (only one class present).
# Patient 100-JG: Cannot calculate ECE/MCE (only one class present).
# Patient 103-EL: Cannot calculate ECE/MCE (only one class present).

# %%
# Evaluation - Patient-wise report
model.eval()
patient_results = defaultdict(list)

with torch.no_grad():
    for x_seq, aux_seq, y, pid in test_dataset:
        x_seq, aux_seq = x_seq.unsqueeze(0).to(device), aux_seq.unsqueeze(0).to(device)
        output = model(x_seq, aux_seq)
        prob = torch.sigmoid(output).item()
        pred_label = int(prob >= 0.5)
        true_label = int(y.item())

        patient_results[pid].append({
            'pred': pred_label,
            'true': true_label,
            'prob': prob
        })

# Summarize per patient
summary = []
for pid, records in patient_results.items():
    preds = [r['pred'] for r in records]
    trues = [r['true'] for r in records]
    probs = [r['prob'] for r in records]

    correct_count = sum(p == t for p, t in zip(preds, trues))
    total = len(records)
    valid_percentage = 100 * correct_count / total
    invalid_percentage = 100 - valid_percentage

    summary.append({
        'PatientID': pid,
        'Predicted_QoR_class': max(set(preds), key=preds.count),
        'Actual_QoR_class': max(set(trues), key=trues.count),
        'valid_percentage': round(valid_percentage, 2),
        'invalid_percentage': round(invalid_percentage, 2),
        'average_model_output': round(sum(probs) / len(probs), 6)
    })

# Display
report_df = pd.DataFrame(summary).sort_values(by='PatientID').reset_index(drop=True)
print(report_df)
# Out:
#    PatientID  Predicted_QoR_class  Actual_QoR_class  valid_percentage  \
# 0     001-LO                    1                 1             57.14
# 1     005-GP                    0                 0             83.33
# 2     006-TR                    0                 1              0.00
# 3     010-RA                    0                 0             94.12
# 4     011-CB                    0                 0             93.75
# 5     013-MS                    0                 1             15.79
# 6     018-OS                    0                 0             87.50
# 7     020-MM                    0                 0             75.00
# 8     025-PS                    0                 1             19.05
# 9     033-JF                    0                 1             25.00
# 10    037-MA                    0                 0            100.00
# 11    039-EB                    0                 0            100.00
# 12    040-KR                    0                 1              8.70
# 13    058-ZS                    0                 1              6.90
# 14    064-SC                    0                 0             89.66
# 15    070-TC                    0                 0            100.00
# 16    072-DD                    0                 0            100.00
# 17    080-TW                    0                 0             95.74
# 18    082-BK                    0                 0            100.00
# 19    100-JG                    0                 0             72.73
# 20    103-EL                    0                 0             73.68
#
#     invalid_percentage  average_model_output
# 0                42.86              0.542326
# 1                16.67              0.277880
# 2               100.00              0.035259
# 3                 5.88              0.058907
# 4                 6.25              0.187768
# 5                84.21              0.207635
# 6                12.50              0.171343
# 7                25.00              0.247926
# 8                80.95              0.221170
# 9                75.00              0.359801
# 10                0.00              0.026730
# 11                0.00              0.070245
# 12               91.30              0.109262
# 13               93.10              0.144905
# 14               10.34              0.158086
# 15                0.00              0.030309
# 16                0.00              0.056368
# 17                4.26              0.073806
# 18                0.00              0.099568
# 19               27.27              0.295472
# 20               26.32              0.293014
